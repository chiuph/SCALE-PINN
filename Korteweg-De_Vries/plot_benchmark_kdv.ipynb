# %%
import jax
import flax
import optax
from jax import lax, random, numpy as jnp
from jax import random, grad, vmap, hessian, jacfwd, jit
from jax import config
from flax import linen as nn
from evojax.util import get_params_format_fn

import os
import time
import numpy as np
import pandas as pd
from scipy import io
import matplotlib.pyplot as plt
import argparse

# choose GPU
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

#jax.config.update("jax_enable_x64", True)
jax.config.update("jax_default_matmul_precision", "highest")

# %%
"""DNN / PINN   """

class PINN(nn.Module):
    """PINNs"""
    n_nodes: int
    def setup(self):
        self.layers = [nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       jnp.sin,
                       nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       nn.softplus,
                       nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       nn.softplus,
                       nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       nn.softplus]
        self.last_layer = nn.Dense(1, kernel_init = jax.nn.initializers.he_uniform(), use_bias=False)

    @nn.compact
    def __call__(self, inputs):
        # split the two variables, probably just by slicing
        t, x = inputs[:,0:1], inputs[:,1:2]
        def get_u(t, x):
            f = jnp.hstack([t, x, t - 1.])
            fs = [f]
            for i, lyr in enumerate(self.layers):
                f = lyr(f)
                if (i == 0):
                    f = 2 *jnp.pi *f
                if (i%2 != 0):
                    fs.append(f)
            f = jnp.hstack(fs)
            u = self.last_layer(f)
            return u

        u = get_u(t, x)

        # obtain u_t, u_x, u_xxx
        def get_u_dir(get_u, t, x):
            u_t, u_x = jacfwd(get_u)(t, x), jacfwd(get_u, argnums=1)(t, x)
            u_xx = jacfwd(jacfwd(get_u, argnums=1), argnums=1)(t, x)
            u_xxx = jacfwd(jacfwd(jacfwd(get_u, argnums=1), argnums=1), argnums=1)(t, x)
            return u_t, u_x, u_xx, u_xxx

        f_dir_vmap = vmap(get_u_dir, in_axes=(None, 0, 0))
        u_t, u_x, u_xx, u_xxx = f_dir_vmap(get_u, t, x)
        u_t, u_x, u_xx, u_xxx = u_t[:,:,0], u_x[:,:,0], u_xx[:,:,0,0], u_xxx[:,:,0,0,0]

        # PDE: u_t + v1*u*u_x + v2*u_xxx = 0
        # pde =( u_t + v1*u*u_x + v2*u_xxx)/jax.sqrt(1/dt+jax.abs(u*v1)/dx + v2*2.5/dx**3)
        pde = ( u_t + v1*u*u_x + v2*u_xxx)

        # obtain BC/IC indices
        ic, bc = (t == t_l), (x == x_l)  # lower x
        pbc = get_u(t, jnp.ones_like(t)*x_u) - u

        outputs = jnp.hstack([u, u_xx, pde, pbc, ic, bc])
        return outputs


class DNN(nn.Module):
    """DNNs"""
    n_nodes: int
    def setup(self):
        self.layers = [nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       jnp.sin,
                       nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       nn.softplus,
                       nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       nn.softplus,
                       nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       nn.softplus]
        self.last_layer = nn.Dense(1, kernel_init = jax.nn.initializers.he_uniform(), use_bias=False)

    @nn.compact
    def __call__(self, inputs):
        # split the two variables, probably just by slicing
        t, x = inputs[:,0:1], inputs[:,1:2]
        def get_u(t, x):
            f = jnp.hstack([t, x, t - 1.])
            fs = [f]
            for i, lyr in enumerate(self.layers):
                f = lyr(f)
                if (i == 0):
                    f = 2 *jnp.pi *f
                if (i%2 != 0):
                    fs.append(f)
            f = jnp.hstack(fs)
            u = self.last_layer(f)
            return u

        u = get_u(t, x)

        def get_u_dir(get_u, t, x):
            u_xx = jacfwd(jacfwd(get_u, argnums=1), argnums=1)(t, x)
            return u_xx

        f_dir_vmap = vmap(get_u_dir, in_axes=(None, 0, 0))
        u_xx = f_dir_vmap(get_u, t, x)[:,:,0,0]

        outputs = jnp.hstack([u, u_xx])
        return outputs

# %%
def main(ER, ER_xx, weight_ic, weight_bc, max_lr, exponent, max_iter, seed, gpu):
    
    
    global v1, v2, t_l, t_u, x_l, x_u
    
    # parameter
    v1 = 1.0
    v2 = 0.022*0.022

    mat_data = io.loadmat('kdv.mat')

    sim_t = np.repeat(mat_data['t'], 512).reshape(-1,1)
    sim_x = np.tile(mat_data['x'], 201).reshape(-1,1)
    sim_u = mat_data['usol'].reshape(-1,1)

    t_l, t_u, x_l, x_u = np.min(sim_t), np.max(sim_t), np.min(sim_x), np.max(sim_x)

    data_X, data_Y = np.hstack([sim_t, sim_x]), sim_u

    # split into BC / IC data
    bic = (data_X[:,0] == 0) | (data_X[:,1] == x_l)
    data_X_BIC, data_Y_BIC = data_X[bic], data_Y[bic]
    
    # convert to jnp
    data_X, data_Y, data_X_BIC, data_Y_BIC = jnp.array(data_X), jnp.array(data_Y), jnp.array(data_X_BIC), jnp.array(data_Y_BIC)


    # choose seed
    seed = seed
    key, rng = random.split(random.PRNGKey(seed))

    # dummy input
    a = random.normal(key, [1,2])

    # initialization call
    n_nodes = 128
    model, model_0 = PINN(n_nodes), DNN(n_nodes)
    params = model.init(key, a)
    num_params, format_params_fn = get_params_format_fn(params)

    # flatten initial params
    params = jax.flatten_util.ravel_pytree(params)[0]

    # update u_0
    params_0 = params

    # minibatch (set #sample)
    BS_ALL = 1000
    BS_BIC = 50

    n_all, n_bic = len(data_X), len(data_X_BIC)

    @jit
    def minibatch(key):
        key1, key2 = key
        batch_all = random.choice(key1, n_all, (BS_ALL - BS_BIC,))
        batch_bic = random.choice(key2, n_bic, (BS_BIC,))
        batch_X = jnp.vstack([data_X[batch_all], data_X_BIC[batch_bic]])
        batch_Y = jnp.vstack([data_Y[batch_all], data_Y_BIC[batch_bic]])
        return (batch_X, batch_Y)

    # loss function
    def eval_loss(params, params_0, inputs, labels):
        pred = model.apply(format_params_fn(params), inputs)
        u, u_xx, pde, pbc, ic, bc = jnp.split(pred, 6, axis=1)
        # stable evolution
        pred_0 = model_0.apply(format_params_fn(params_0), inputs)
        u_0, u0_xx = jnp.split(pred_0, 2, axis=1)
        if (ER > 0):
            pde = pde + (u - u_0) / ER - jnp.sqrt(v2)*(u_xx - u0_xx) / ER_xx  # ER @PDE
        pde_loss = jnp.mean(jnp.square(pde))
        # IC
        ic_e = (labels - u) * ic
        ic_loss = jnp.sum(jnp.square(ic_e)) / ic.sum()
        # BC (periodic)
        bc_e = pbc * bc
        bc_loss = jnp.sum(jnp.square(bc_e)) / bc.sum()
        # stable evolution
        #er_loss = jnp.mean(jnp.square((u - u_0))) / .2
        # mse
        mse = jnp.mean(jnp.square(labels - u))
        rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
        loss = pde_loss + weight_ic* ic_loss + weight_bc* bc_loss #+ er_loss
        return loss, (mse, rl2)

    loss_grad = jax.jit(jax.value_and_grad(eval_loss, has_aux=True))

    # weights update
    @jit
    def update(params, params_0, opt_state, key):
        batch_X, batch_Y = minibatch(key)
        (loss, (mse, rl2)), grad = loss_grad(params, params_0, batch_X, batch_Y)
        updates, opt_state = optimizer.update(grad, opt_state)
        params_0 = params # update u_0
        params = optax.apply_updates(params, updates)
        return params, params_0, opt_state, loss, mse, rl2

    # optimizer
    max_iters = max_iter
    max_lr = max_lr
    lr_scheduler = optax.warmup_cosine_decay_schedule(init_value=max_lr, peak_value=max_lr, warmup_steps=0,
                                                    decay_steps=max_iters, end_value=1e-10, exponent=exponent)
    optimizer = optax.adam(learning_rate=lr_scheduler) # Choose the method
    opt_state = optimizer.init(params)

    """Training"""

    # training iteration
    runtime = 0
    train_iters = 0

    #store = []
    store_nnws = []
    store_nnws.append([0, format_params_fn(params)])

    while (train_iters <= max_iters) and (runtime < 10000):
        # mini-batch update
        start = time.time()
        key1, key2, rng = random.split(rng, 3) # update random generator
        params, params_0, opt_state, loss, mse, rl2 = update(params, params_0, opt_state, (key1, key2))
        end = time.time()
        runtime += (end-start)
        # append weights
        if (train_iters % 5000 == 0):
            print ('iter. = %05d,  time = %03ds,  loss = %.2e  |  mse = %.2e,  rl2 = %.2e'%(train_iters, runtime, loss, mse, rl2))
            # store.append([train_iters, runtime, loss, mse, rl2])
            store_nnws.append([runtime, format_params_fn(params)])
        train_iters += 1

    # store = jnp.array(store)
    
    """PINN solution"""

    # on all tasks
    inputs, labels = data_X, data_Y
    pred = model.apply(format_params_fn(params), inputs)
    u, _, _, _, _, _ = jnp.split(pred, 6, axis=1)
    mse = jnp.mean(jnp.square(labels - u))
    rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
    print ('[v1=%.1f, v2=%.1e] :  MSE = %.2e  RL2 = %.2e'%(v1, v2, mse, rl2))
    
    return format_params_fn(params), store_nnws

# %%
# # run main (ER)
# params, store_nnws = main(ER=0.1, ER_xx=20, weight_ic=1000, weight_bc=1000,
#                           max_lr=1e-3, exponent=0.8, max_iter=300000, seed=50, gpu=0)
# Out:
# iter. = 00000,  time = 005s,  loss = 3.43e+03  |  mse = 1.79e+00,  rl2 = 1.95e+00
# iter. = 05000,  time = 014s,  loss = 1.85e+00  |  mse = 1.96e-01,  rl2 = 6.28e-01
# iter. = 10000,  time = 023s,  loss = 2.07e-01  |  mse = 1.42e-02,  rl2 = 1.66e-01
# iter. = 15000,  time = 032s,  loss = 1.41e-01  |  mse = 8.66e-03,  rl2 = 1.33e-01
# iter. = 20000,  time = 041s,  loss = 2.58e-02  |  mse = 3.24e-03,  rl2 = 7.96e-02
# iter. = 25000,  time = 050s,  loss = 1.46e-02  |  mse = 2.30e-03,  rl2 = 6.60e-02
# iter. = 30000,  time = 059s,  loss = 2.83e-02  |  mse = 9.33e-04,  rl2 = 4.44e-02
# iter. = 35000,  time = 068s,  loss = 1.19e-01  |  mse = 7.59e-04,  rl2 = 3.85e-02
# iter. = 40000,  time = 077s,  loss = 2.32e-02  |  mse = 4.66e-02,  rl2 = 3.01e-01
# iter. = 45000,  time = 086s,  loss = 7.72e-03  |  mse = 1.32e-03,  rl2 = 5.14e-02
# iter. = 50000,  time = 095s,  loss = 4.47e-02  |  mse = 3.09e-04,  rl2 = 2.44e-02
# iter. = 55000,  time = 105s,  loss = 1.20e-02  |  mse = 4.05e-04,  rl2 = 2.91e-02
# iter. = 60000,  time = 114s,  loss = 2.12e-02  |  mse = 1.33e-04,  rl2 = 1.59e-02
# iter. = 65000,  time = 123s,  loss = 3.44e-03  |  mse = 5.28e-04,  rl2 = 3.41e-02
# iter. = 70000,  time = 132s,  loss = 1.27e-01  |  mse = 5.99e-04,  rl2 = 3.31e-02
# iter. = 75000,  time = 141s,  loss = 5.34e-03  |  mse = 1.50e-04,  rl2 = 1.72e-02
# iter. = 80000,  time = 150s,  loss = 3.97e-02  |  mse = 1.74e-03,  rl2 = 5.70e-02
# iter. = 85000,  time = 159s,  loss = 1.69e-02  |  mse = 3.93e-04,  rl2 = 2.74e-02
# iter. = 90000,  time = 168s,  loss = 5.46e-03  |  mse = 6.66e-04,  rl2 = 3.55e-02
# iter. = 95000,  time = 177s,  loss = 4.98e-04  |  mse = 5.85e-05,  rl2 = 1.06e-02
# iter. = 100000,  time = 187s,  loss = 1.04e-01  |  mse = 2.52e-04,  rl2 = 2.24e-02
# iter. = 105000,  time = 196s,  loss = 1.34e-02  |  mse = 4.60e-05,  rl2 = 9.82e-03
# iter. = 110000,  time = 205s,  loss = 7.67e-03  |  mse = 1.08e-04,  rl2 = 1.44e-02
# iter. = 115000,  time = 214s,  loss = 2.65e-03  |  mse = 3.11e-04,  rl2 = 2.51e-02
# iter. = 120000,  time = 223s,  loss = 7.38e-04  |  mse = 1.59e-04,  rl2 = 1.72e-02
# iter. = 125000,  time = 233s,  loss = 6.62e-03  |  mse = 2.88e-05,  rl2 = 7.53e-03
# iter. = 130000,  time = 242s,  loss = 3.27e-03  |  mse = 1.37e-04,  rl2 = 1.66e-02
# iter. = 135000,  time = 251s,  loss = 1.96e-02  |  mse = 2.11e-05,  rl2 = 6.49e-03
# iter. = 140000,  time = 260s,  loss = 2.92e-02  |  mse = 4.19e-05,  rl2 = 9.66e-03
# iter. = 145000,  time = 269s,  loss = 2.35e-02  |  mse = 5.17e-05,  rl2 = 1.04e-02
# iter. = 150000,  time = 278s,  loss = 6.08e-03  |  mse = 9.98e-06,  rl2 = 4.44e-03
# iter. = 155000,  time = 288s,  loss = 2.83e-04  |  mse = 1.44e-06,  rl2 = 1.67e-03
# iter. = 160000,  time = 297s,  loss = 2.01e-03  |  mse = 8.17e-05,  rl2 = 1.26e-02
# iter. = 165000,  time = 306s,  loss = 5.18e-03  |  mse = 1.13e-05,  rl2 = 4.56e-03
# iter. = 170000,  time = 315s,  loss = 1.05e-02  |  mse = 1.43e-04,  rl2 = 1.74e-02
# iter. = 175000,  time = 324s,  loss = 6.79e-03  |  mse = 8.64e-06,  rl2 = 4.19e-03
# iter. = 180000,  time = 334s,  loss = 1.72e-04  |  mse = 1.32e-05,  rl2 = 5.26e-03
# iter. = 185000,  time = 343s,  loss = 4.04e-03  |  mse = 2.72e-05,  rl2 = 7.29e-03
# iter. = 190000,  time = 352s,  loss = 4.87e-03  |  mse = 1.25e-05,  rl2 = 5.23e-03
# iter. = 195000,  time = 361s,  loss = 1.89e-04  |  mse = 1.11e-05,  rl2 = 4.95e-03
# iter. = 200000,  time = 371s,  loss = 1.01e-03  |  mse = 8.65e-06,  rl2 = 4.17e-03
# iter. = 205000,  time = 380s,  loss = 1.38e-03  |  mse = 4.00e-06,  rl2 = 2.82e-03
# iter. = 210000,  time = 389s,  loss = 2.06e-02  |  mse = 8.12e-05,  rl2 = 1.31e-02
# iter. = 215000,  time = 398s,  loss = 2.52e-04  |  mse = 1.72e-05,  rl2 = 5.96e-03
# iter. = 220000,  time = 408s,  loss = 1.74e-04  |  mse = 1.15e-06,  rl2 = 1.48e-03
# iter. = 225000,  time = 417s,  loss = 1.56e-03  |  mse = 3.69e-06,  rl2 = 2.75e-03
# iter. = 230000,  time = 426s,  loss = 1.03e-03  |  mse = 1.02e-05,  rl2 = 4.29e-03
# iter. = 235000,  time = 435s,  loss = 4.73e-04  |  mse = 3.48e-06,  rl2 = 2.67e-03
# iter. = 240000,  time = 445s,  loss = 3.25e-05  |  mse = 8.32e-07,  rl2 = 1.31e-03
# iter. = 245000,  time = 454s,  loss = 1.58e-04  |  mse = 2.43e-06,  rl2 = 2.18e-03
# iter. = 250000,  time = 463s,  loss = 8.40e-05  |  mse = 1.15e-06,  rl2 = 1.49e-03
# iter. = 255000,  time = 472s,  loss = 5.03e-04  |  mse = 1.24e-06,  rl2 = 1.60e-03
# iter. = 260000,  time = 482s,  loss = 3.77e-04  |  mse = 3.76e-07,  rl2 = 8.82e-04
# iter. = 265000,  time = 491s,  loss = 7.08e-04  |  mse = 8.09e-07,  rl2 = 1.34e-03
# iter. = 270000,  time = 500s,  loss = 4.46e-05  |  mse = 3.39e-07,  rl2 = 8.36e-04
# iter. = 275000,  time = 509s,  loss = 4.58e-05  |  mse = 2.58e-07,  rl2 = 7.45e-04
# iter. = 280000,  time = 519s,  loss = 3.90e-05  |  mse = 1.60e-07,  rl2 = 5.57e-04
# iter. = 285000,  time = 528s,  loss = 1.63e-05  |  mse = 1.80e-07,  rl2 = 6.25e-04
# iter. = 290000,  time = 537s,  loss = 1.36e-05  |  mse = 1.65e-07,  rl2 = 5.50e-04
# iter. = 295000,  time = 547s,  loss = 8.86e-06  |  mse = 1.01e-07,  rl2 = 4.56e-04
# iter. = 300000,  time = 556s,  loss = 1.05e-05  |  mse = 4.61e-08,  rl2 = 3.01e-04
# [v1=1.0, v2=4.8e-04] :  MSE = 3.96e-08  RL2 = 2.82e-04

# %%
# 5 runs
params_5, store_nnws_5 = {}, {}
for seed in [10, 20, 30, 40, 50]:
    # run main (ER)
    params, store_nnws = main(ER=0.1, ER_xx=20, weight_ic=1000, weight_bc=1000,
                              max_lr=1e-3, exponent=0.8, max_iter=300000, seed=seed, gpu=0)
    params_5[seed] = params
    store_nnws_5[seed] = store_nnws
# Out:
# iter. = 00000,  time = 004s,  loss = 1.58e+03  |  mse = 7.76e-01,  rl2 = 1.26e+00
# iter. = 05000,  time = 013s,  loss = 9.85e-01  |  mse = 1.88e-01,  rl2 = 5.93e-01
# iter. = 10000,  time = 022s,  loss = 1.52e-01  |  mse = 1.70e-02,  rl2 = 1.76e-01
# iter. = 15000,  time = 031s,  loss = 4.70e-02  |  mse = 4.93e-03,  rl2 = 9.66e-02
# iter. = 20000,  time = 040s,  loss = 2.04e-01  |  mse = 1.90e-03,  rl2 = 6.24e-02
# iter. = 25000,  time = 049s,  loss = 4.91e-02  |  mse = 1.61e-03,  rl2 = 5.60e-02
# iter. = 30000,  time = 059s,  loss = 2.79e-02  |  mse = 1.49e-03,  rl2 = 5.64e-02
# iter. = 35000,  time = 068s,  loss = 5.51e-02  |  mse = 7.56e-04,  rl2 = 3.91e-02
# iter. = 40000,  time = 077s,  loss = 1.55e-01  |  mse = 1.05e-02,  rl2 = 1.42e-01
# iter. = 45000,  time = 086s,  loss = 9.44e-03  |  mse = 1.28e-04,  rl2 = 1.59e-02
# iter. = 50000,  time = 096s,  loss = 3.55e-02  |  mse = 1.48e-02,  rl2 = 1.74e-01
# iter. = 55000,  time = 105s,  loss = 4.83e-02  |  mse = 7.78e-05,  rl2 = 1.23e-02
# iter. = 60000,  time = 114s,  loss = 5.35e-02  |  mse = 1.30e-03,  rl2 = 5.20e-02
# iter. = 65000,  time = 123s,  loss = 4.05e-02  |  mse = 2.34e-04,  rl2 = 2.18e-02
# iter. = 70000,  time = 133s,  loss = 2.56e-01  |  mse = 2.63e-04,  rl2 = 2.27e-02
# iter. = 75000,  time = 142s,  loss = 1.23e-03  |  mse = 1.08e-04,  rl2 = 1.47e-02
# iter. = 80000,  time = 151s,  loss = 1.61e-02  |  mse = 6.39e-03,  rl2 = 1.09e-01
# iter. = 85000,  time = 160s,  loss = 2.68e-02  |  mse = 1.66e-04,  rl2 = 1.86e-02
# iter. = 90000,  time = 170s,  loss = 5.43e-02  |  mse = 1.98e-04,  rl2 = 1.93e-02
# iter. = 95000,  time = 179s,  loss = 8.06e-03  |  mse = 4.71e-05,  rl2 = 9.57e-03
# iter. = 100000,  time = 188s,  loss = 1.49e-02  |  mse = 1.63e-03,  rl2 = 5.84e-02
# iter. = 105000,  time = 198s,  loss = 4.39e-03  |  mse = 3.18e-04,  rl2 = 2.58e-02
# iter. = 110000,  time = 207s,  loss = 1.77e-03  |  mse = 4.38e-05,  rl2 = 9.81e-03
# iter. = 115000,  time = 216s,  loss = 2.30e-03  |  mse = 1.28e-05,  rl2 = 5.06e-03
# iter. = 120000,  time = 225s,  loss = 6.57e-04  |  mse = 7.69e-06,  rl2 = 3.97e-03
# iter. = 125000,  time = 235s,  loss = 4.96e-02  |  mse = 6.38e-04,  rl2 = 3.65e-02
# iter. = 130000,  time = 244s,  loss = 4.36e-03  |  mse = 2.68e-05,  rl2 = 7.41e-03
# iter. = 135000,  time = 253s,  loss = 4.22e-03  |  mse = 3.73e-05,  rl2 = 8.67e-03
# iter. = 140000,  time = 262s,  loss = 2.27e-03  |  mse = 3.16e-05,  rl2 = 7.88e-03
# iter. = 145000,  time = 272s,  loss = 8.82e-04  |  mse = 8.81e-06,  rl2 = 4.30e-03
# iter. = 150000,  time = 281s,  loss = 3.82e-03  |  mse = 7.68e-05,  rl2 = 1.29e-02
# iter. = 155000,  time = 290s,  loss = 4.46e-04  |  mse = 3.08e-05,  rl2 = 7.61e-03
# iter. = 160000,  time = 300s,  loss = 1.10e-02  |  mse = 5.00e-05,  rl2 = 1.00e-02
# iter. = 165000,  time = 309s,  loss = 8.47e-04  |  mse = 1.18e-04,  rl2 = 1.56e-02
# iter. = 170000,  time = 318s,  loss = 2.14e-03  |  mse = 5.10e-05,  rl2 = 1.04e-02
# iter. = 175000,  time = 327s,  loss = 1.55e-03  |  mse = 2.11e-05,  rl2 = 6.40e-03
# iter. = 180000,  time = 337s,  loss = 1.01e-02  |  mse = 2.63e-04,  rl2 = 2.33e-02
# iter. = 185000,  time = 346s,  loss = 6.10e-04  |  mse = 1.00e-05,  rl2 = 4.49e-03
# iter. = 190000,  time = 355s,  loss = 4.13e-03  |  mse = 1.35e-05,  rl2 = 5.19e-03
# iter. = 195000,  time = 364s,  loss = 7.43e-03  |  mse = 2.37e-05,  rl2 = 7.00e-03
# iter. = 200000,  time = 374s,  loss = 7.50e-04  |  mse = 1.97e-05,  rl2 = 6.38e-03
# iter. = 205000,  time = 383s,  loss = 3.52e-03  |  mse = 4.71e-05,  rl2 = 9.91e-03
# iter. = 210000,  time = 392s,  loss = 3.86e-03  |  mse = 3.65e-05,  rl2 = 8.43e-03
# iter. = 215000,  time = 401s,  loss = 2.04e-04  |  mse = 2.36e-06,  rl2 = 2.21e-03
# iter. = 220000,  time = 411s,  loss = 4.87e-04  |  mse = 8.39e-06,  rl2 = 4.14e-03
# iter. = 225000,  time = 420s,  loss = 8.37e-04  |  mse = 5.12e-06,  rl2 = 3.24e-03
# iter. = 230000,  time = 429s,  loss = 1.88e-03  |  mse = 9.75e-06,  rl2 = 4.24e-03
# iter. = 235000,  time = 438s,  loss = 1.69e-03  |  mse = 3.92e-06,  rl2 = 2.77e-03
# iter. = 240000,  time = 448s,  loss = 2.26e-03  |  mse = 2.60e-06,  rl2 = 2.27e-03
# iter. = 245000,  time = 457s,  loss = 1.54e-04  |  mse = 3.25e-06,  rl2 = 2.52e-03
# iter. = 250000,  time = 466s,  loss = 3.94e-03  |  mse = 4.06e-06,  rl2 = 2.81e-03
# iter. = 255000,  time = 476s,  loss = 4.85e-05  |  mse = 2.78e-07,  rl2 = 7.36e-04
# iter. = 260000,  time = 485s,  loss = 9.86e-04  |  mse = 1.63e-06,  rl2 = 1.80e-03
# iter. = 265000,  time = 494s,  loss = 5.35e-05  |  mse = 8.62e-07,  rl2 = 1.33e-03
# iter. = 270000,  time = 503s,  loss = 4.95e-05  |  mse = 5.01e-07,  rl2 = 9.90e-04
# iter. = 275000,  time = 513s,  loss = 2.75e-05  |  mse = 2.88e-07,  rl2 = 7.81e-04
# iter. = 280000,  time = 522s,  loss = 1.66e-05  |  mse = 1.48e-07,  rl2 = 5.52e-04
# iter. = 285000,  time = 531s,  loss = 1.31e-05  |  mse = 1.30e-07,  rl2 = 5.21e-04
# iter. = 290000,  time = 540s,  loss = 1.15e-05  |  mse = 6.88e-08,  rl2 = 3.78e-04
# iter. = 295000,  time = 550s,  loss = 8.70e-06  |  mse = 9.69e-08,  rl2 = 4.55e-04
# iter. = 300000,  time = 559s,  loss = 8.45e-06  |  mse = 4.47e-08,  rl2 = 2.90e-04
# [v1=1.0, v2=4.8e-04] :  MSE = 6.80e-08  RL2 = 3.69e-04
# iter. = 00000,  time = 004s,  loss = 2.47e+03  |  mse = 1.49e+00,  rl2 = 1.71e+00
# iter. = 05000,  time = 013s,  loss = 6.32e-01  |  mse = 2.11e-01,  rl2 = 6.51e-01
# iter. = 10000,  time = 022s,  loss = 9.07e-01  |  mse = 4.41e-02,  rl2 = 2.87e-01
# iter. = 15000,  time = 031s,  loss = 4.92e-01  |  mse = 6.61e-03,  rl2 = 1.16e-01
# iter. = 20000,  time = 041s,  loss = 1.12e-01  |  mse = 5.66e-03,  rl2 = 1.05e-01
# iter. = 25000,  time = 050s,  loss = 4.22e-01  |  mse = 2.55e-03,  rl2 = 7.34e-02
# iter. = 30000,  time = 059s,  loss = 4.23e-02  |  mse = 1.19e-03,  rl2 = 4.98e-02
# iter. = 35000,  time = 068s,  loss = 2.34e-02  |  mse = 1.28e-03,  rl2 = 5.07e-02
# iter. = 40000,  time = 077s,  loss = 1.40e+00  |  mse = 9.52e-04,  rl2 = 4.53e-02
# iter. = 45000,  time = 087s,  loss = 6.56e-03  |  mse = 4.48e-04,  rl2 = 3.04e-02
# iter. = 50000,  time = 096s,  loss = 2.34e-02  |  mse = 2.48e-03,  rl2 = 7.08e-02
# iter. = 55000,  time = 105s,  loss = 3.48e-02  |  mse = 1.53e-03,  rl2 = 5.63e-02
# iter. = 60000,  time = 114s,  loss = 3.91e-02  |  mse = 7.32e-04,  rl2 = 3.93e-02
# iter. = 65000,  time = 124s,  loss = 3.81e-01  |  mse = 7.10e-04,  rl2 = 3.84e-02
# iter. = 70000,  time = 133s,  loss = 1.13e-02  |  mse = 3.09e-03,  rl2 = 7.85e-02
# iter. = 75000,  time = 142s,  loss = 8.88e-03  |  mse = 9.51e-05,  rl2 = 1.39e-02
# iter. = 80000,  time = 151s,  loss = 2.38e-03  |  mse = 7.98e-05,  rl2 = 1.22e-02
# iter. = 85000,  time = 161s,  loss = 6.09e-04  |  mse = 1.69e-04,  rl2 = 1.90e-02
# iter. = 90000,  time = 170s,  loss = 9.19e-03  |  mse = 1.55e-04,  rl2 = 1.71e-02
# iter. = 95000,  time = 179s,  loss = 6.46e-03  |  mse = 6.16e-04,  rl2 = 3.53e-02
# iter. = 100000,  time = 188s,  loss = 3.88e-02  |  mse = 4.01e-05,  rl2 = 8.62e-03
# iter. = 105000,  time = 198s,  loss = 2.19e-02  |  mse = 1.84e-04,  rl2 = 2.02e-02
# iter. = 110000,  time = 207s,  loss = 2.50e-03  |  mse = 1.46e-03,  rl2 = 5.29e-02
# iter. = 115000,  time = 216s,  loss = 8.69e-03  |  mse = 8.95e-05,  rl2 = 1.32e-02
# iter. = 120000,  time = 225s,  loss = 1.00e-02  |  mse = 9.81e-04,  rl2 = 4.27e-02
# iter. = 125000,  time = 235s,  loss = 7.03e-04  |  mse = 1.33e-05,  rl2 = 5.13e-03
# iter. = 130000,  time = 244s,  loss = 6.38e-02  |  mse = 5.77e-05,  rl2 = 1.06e-02
# iter. = 135000,  time = 253s,  loss = 2.66e-03  |  mse = 8.16e-06,  rl2 = 3.99e-03
# iter. = 140000,  time = 262s,  loss = 1.42e-02  |  mse = 2.86e-04,  rl2 = 2.40e-02
# iter. = 145000,  time = 272s,  loss = 9.63e-03  |  mse = 5.04e-05,  rl2 = 1.04e-02
# iter. = 150000,  time = 281s,  loss = 2.13e-03  |  mse = 2.25e-05,  rl2 = 6.87e-03
# iter. = 155000,  time = 290s,  loss = 4.04e-04  |  mse = 8.10e-06,  rl2 = 4.07e-03
# iter. = 160000,  time = 299s,  loss = 6.75e-04  |  mse = 3.64e-05,  rl2 = 8.33e-03
# iter. = 165000,  time = 309s,  loss = 2.14e-03  |  mse = 5.28e-05,  rl2 = 1.08e-02
# iter. = 170000,  time = 318s,  loss = 2.00e-02  |  mse = 2.71e-05,  rl2 = 7.52e-03
# iter. = 175000,  time = 327s,  loss = 3.59e-04  |  mse = 3.11e-05,  rl2 = 7.93e-03
# iter. = 180000,  time = 337s,  loss = 5.29e-04  |  mse = 1.31e-05,  rl2 = 5.14e-03
# iter. = 185000,  time = 346s,  loss = 1.31e-03  |  mse = 4.57e-06,  rl2 = 2.96e-03
# iter. = 190000,  time = 355s,  loss = 7.61e-04  |  mse = 4.54e-05,  rl2 = 9.72e-03
# iter. = 195000,  time = 365s,  loss = 6.10e-04  |  mse = 1.20e-05,  rl2 = 4.99e-03
# iter. = 200000,  time = 374s,  loss = 1.87e-04  |  mse = 3.13e-05,  rl2 = 7.70e-03
# iter. = 205000,  time = 383s,  loss = 5.91e-03  |  mse = 1.34e-05,  rl2 = 5.06e-03
# iter. = 210000,  time = 393s,  loss = 1.17e-03  |  mse = 2.95e-06,  rl2 = 2.39e-03
# iter. = 215000,  time = 402s,  loss = 1.96e-03  |  mse = 3.85e-06,  rl2 = 2.80e-03
# iter. = 220000,  time = 411s,  loss = 6.08e-04  |  mse = 1.89e-06,  rl2 = 2.08e-03
# iter. = 225000,  time = 421s,  loss = 1.35e-03  |  mse = 3.55e-06,  rl2 = 2.62e-03
# iter. = 230000,  time = 430s,  loss = 6.93e-04  |  mse = 7.19e-06,  rl2 = 3.77e-03
# iter. = 235000,  time = 439s,  loss = 3.68e-04  |  mse = 6.76e-06,  rl2 = 3.63e-03
# iter. = 240000,  time = 449s,  loss = 1.24e-04  |  mse = 1.61e-06,  rl2 = 1.80e-03
# iter. = 245000,  time = 458s,  loss = 5.34e-05  |  mse = 5.79e-07,  rl2 = 1.08e-03
# iter. = 250000,  time = 467s,  loss = 1.16e-04  |  mse = 8.15e-07,  rl2 = 1.30e-03
# iter. = 255000,  time = 477s,  loss = 1.12e-03  |  mse = 9.73e-07,  rl2 = 1.39e-03
# iter. = 260000,  time = 486s,  loss = 2.63e-05  |  mse = 2.71e-07,  rl2 = 7.20e-04
# iter. = 265000,  time = 495s,  loss = 6.33e-05  |  mse = 3.93e-07,  rl2 = 9.06e-04
# iter. = 270000,  time = 505s,  loss = 2.65e-05  |  mse = 3.92e-07,  rl2 = 8.88e-04
# iter. = 275000,  time = 514s,  loss = 1.79e-04  |  mse = 1.19e-06,  rl2 = 1.57e-03
# iter. = 280000,  time = 523s,  loss = 1.04e-04  |  mse = 4.31e-07,  rl2 = 9.31e-04
# iter. = 285000,  time = 533s,  loss = 4.10e-05  |  mse = 2.64e-07,  rl2 = 6.76e-04
# iter. = 290000,  time = 542s,  loss = 1.64e-05  |  mse = 4.10e-07,  rl2 = 8.68e-04
# iter. = 295000,  time = 552s,  loss = 1.26e-05  |  mse = 3.46e-07,  rl2 = 8.22e-04
# iter. = 300000,  time = 561s,  loss = 1.63e-05  |  mse = 3.45e-07,  rl2 = 8.27e-04
# [v1=1.0, v2=4.8e-04] :  MSE = 3.12e-07  RL2 = 7.90e-04
# iter. = 00000,  time = 004s,  loss = 1.41e+03  |  mse = 2.96e+00,  rl2 = 2.53e+00
# iter. = 05000,  time = 013s,  loss = 6.88e-01  |  mse = 1.74e-01,  rl2 = 6.02e-01
# iter. = 10000,  time = 022s,  loss = 2.36e-01  |  mse = 2.47e-02,  rl2 = 2.15e-01
# iter. = 15000,  time = 031s,  loss = 1.18e+00  |  mse = 6.58e-03,  rl2 = 1.14e-01
# iter. = 20000,  time = 041s,  loss = 2.42e-01  |  mse = 3.75e-03,  rl2 = 8.84e-02
# iter. = 25000,  time = 050s,  loss = 2.98e-01  |  mse = 1.93e-03,  rl2 = 6.07e-02
# iter. = 30000,  time = 059s,  loss = 1.65e-01  |  mse = 1.58e-03,  rl2 = 5.79e-02
# iter. = 35000,  time = 068s,  loss = 2.36e-02  |  mse = 8.61e-04,  rl2 = 4.17e-02
# iter. = 40000,  time = 078s,  loss = 2.05e-02  |  mse = 6.93e-04,  rl2 = 3.72e-02
# iter. = 45000,  time = 087s,  loss = 7.06e-03  |  mse = 6.97e-04,  rl2 = 3.63e-02
# iter. = 50000,  time = 096s,  loss = 6.16e-03  |  mse = 7.61e-04,  rl2 = 3.91e-02
# iter. = 55000,  time = 106s,  loss = 2.18e-02  |  mse = 2.52e-04,  rl2 = 2.33e-02
# iter. = 60000,  time = 115s,  loss = 1.69e-02  |  mse = 3.65e-04,  rl2 = 2.74e-02
# iter. = 65000,  time = 124s,  loss = 2.60e-01  |  mse = 7.96e-04,  rl2 = 3.90e-02
# iter. = 70000,  time = 133s,  loss = 9.99e-03  |  mse = 3.26e-04,  rl2 = 2.63e-02
# iter. = 75000,  time = 143s,  loss = 2.46e-02  |  mse = 1.83e-04,  rl2 = 1.99e-02
# iter. = 80000,  time = 152s,  loss = 8.36e-03  |  mse = 4.00e-04,  rl2 = 3.03e-02
# iter. = 85000,  time = 161s,  loss = 7.44e-03  |  mse = 4.17e-04,  rl2 = 2.87e-02
# iter. = 90000,  time = 170s,  loss = 3.93e-03  |  mse = 1.23e-03,  rl2 = 5.05e-02
# iter. = 95000,  time = 180s,  loss = 8.07e-03  |  mse = 5.26e-04,  rl2 = 3.32e-02
# iter. = 100000,  time = 189s,  loss = 6.39e-03  |  mse = 2.28e-05,  rl2 = 6.96e-03
# iter. = 105000,  time = 198s,  loss = 1.83e-02  |  mse = 7.79e-05,  rl2 = 1.25e-02
# iter. = 110000,  time = 208s,  loss = 1.15e-02  |  mse = 8.21e-04,  rl2 = 3.96e-02
# iter. = 115000,  time = 217s,  loss = 1.99e-01  |  mse = 2.57e-04,  rl2 = 2.35e-02
# iter. = 120000,  time = 226s,  loss = 2.87e-03  |  mse = 2.05e-05,  rl2 = 6.78e-03
# iter. = 125000,  time = 235s,  loss = 5.12e-02  |  mse = 9.94e-05,  rl2 = 1.45e-02
# iter. = 130000,  time = 245s,  loss = 2.12e-03  |  mse = 3.29e-05,  rl2 = 8.39e-03
# iter. = 135000,  time = 254s,  loss = 6.04e-03  |  mse = 1.21e-04,  rl2 = 1.52e-02
# iter. = 140000,  time = 263s,  loss = 1.46e-02  |  mse = 2.23e-05,  rl2 = 6.54e-03
# iter. = 145000,  time = 273s,  loss = 5.45e-04  |  mse = 8.34e-06,  rl2 = 4.00e-03
# iter. = 150000,  time = 282s,  loss = 3.50e-04  |  mse = 4.63e-06,  rl2 = 3.11e-03
# iter. = 155000,  time = 291s,  loss = 1.40e-04  |  mse = 9.99e-07,  rl2 = 1.34e-03
# iter. = 160000,  time = 300s,  loss = 5.87e-03  |  mse = 1.90e-04,  rl2 = 2.02e-02
# iter. = 165000,  time = 310s,  loss = 2.16e-03  |  mse = 5.61e-05,  rl2 = 1.08e-02
# iter. = 170000,  time = 319s,  loss = 5.92e-03  |  mse = 3.63e-05,  rl2 = 8.57e-03
# iter. = 175000,  time = 328s,  loss = 1.78e-03  |  mse = 2.35e-05,  rl2 = 6.81e-03
# iter. = 180000,  time = 337s,  loss = 4.05e-04  |  mse = 2.41e-05,  rl2 = 7.59e-03
# iter. = 185000,  time = 347s,  loss = 1.52e-03  |  mse = 8.42e-06,  rl2 = 4.22e-03
# iter. = 190000,  time = 356s,  loss = 7.02e-04  |  mse = 2.62e-05,  rl2 = 7.49e-03
# iter. = 195000,  time = 365s,  loss = 1.19e-02  |  mse = 3.77e-05,  rl2 = 9.19e-03
# iter. = 200000,  time = 375s,  loss = 6.57e-03  |  mse = 7.65e-05,  rl2 = 1.23e-02
# iter. = 205000,  time = 384s,  loss = 4.70e-04  |  mse = 4.22e-06,  rl2 = 2.88e-03
# iter. = 210000,  time = 393s,  loss = 1.27e-04  |  mse = 3.06e-06,  rl2 = 2.35e-03
# iter. = 215000,  time = 402s,  loss = 4.73e-03  |  mse = 2.09e-05,  rl2 = 6.43e-03
# iter. = 220000,  time = 412s,  loss = 4.78e-05  |  mse = 1.17e-06,  rl2 = 1.51e-03
# iter. = 225000,  time = 421s,  loss = 3.50e-03  |  mse = 1.00e-05,  rl2 = 4.39e-03
# iter. = 230000,  time = 430s,  loss = 1.48e-04  |  mse = 2.60e-06,  rl2 = 2.28e-03
# iter. = 235000,  time = 439s,  loss = 1.69e-03  |  mse = 3.52e-06,  rl2 = 2.63e-03
# iter. = 240000,  time = 449s,  loss = 5.65e-04  |  mse = 1.90e-06,  rl2 = 1.94e-03
# iter. = 245000,  time = 458s,  loss = 2.64e-05  |  mse = 1.90e-07,  rl2 = 6.46e-04
# iter. = 250000,  time = 467s,  loss = 3.50e-04  |  mse = 2.01e-06,  rl2 = 2.06e-03
# iter. = 255000,  time = 477s,  loss = 3.77e-05  |  mse = 5.28e-07,  rl2 = 1.02e-03
# iter. = 260000,  time = 486s,  loss = 4.89e-05  |  mse = 1.63e-07,  rl2 = 5.78e-04
# iter. = 265000,  time = 495s,  loss = 4.77e-05  |  mse = 2.19e-07,  rl2 = 6.50e-04
# iter. = 270000,  time = 504s,  loss = 2.82e-05  |  mse = 1.92e-07,  rl2 = 6.20e-04
# iter. = 275000,  time = 514s,  loss = 4.93e-05  |  mse = 2.15e-07,  rl2 = 6.59e-04
# iter. = 280000,  time = 523s,  loss = 3.12e-05  |  mse = 1.51e-07,  rl2 = 5.58e-04
# iter. = 285000,  time = 532s,  loss = 2.34e-05  |  mse = 3.29e-07,  rl2 = 8.03e-04
# iter. = 290000,  time = 541s,  loss = 1.20e-05  |  mse = 2.03e-07,  rl2 = 6.43e-04
# iter. = 295000,  time = 551s,  loss = 9.91e-06  |  mse = 8.46e-08,  rl2 = 4.29e-04
# iter. = 300000,  time = 560s,  loss = 1.04e-05  |  mse = 6.51e-08,  rl2 = 3.56e-04
# [v1=1.0, v2=4.8e-04] :  MSE = 7.13e-08  RL2 = 3.78e-04
# iter. = 00000,  time = 004s,  loss = 2.65e+03  |  mse = 1.06e+00,  rl2 = 1.47e+00
# iter. = 05000,  time = 013s,  loss = 7.69e-01  |  mse = 1.75e-01,  rl2 = 6.00e-01
# iter. = 10000,  time = 022s,  loss = 3.29e-01  |  mse = 4.31e-02,  rl2 = 2.89e-01
# iter. = 15000,  time = 031s,  loss = 1.44e+00  |  mse = 9.00e-03,  rl2 = 1.40e-01
# iter. = 20000,  time = 040s,  loss = 6.02e-01  |  mse = 8.81e-03,  rl2 = 1.40e-01
# iter. = 25000,  time = 050s,  loss = 5.41e-01  |  mse = 5.45e-03,  rl2 = 1.02e-01
# iter. = 30000,  time = 059s,  loss = 9.83e-03  |  mse = 3.06e-03,  rl2 = 7.71e-02
# iter. = 35000,  time = 068s,  loss = 1.44e-01  |  mse = 5.23e-04,  rl2 = 3.21e-02
# iter. = 40000,  time = 077s,  loss = 1.21e-01  |  mse = 6.41e-03,  rl2 = 1.09e-01
# iter. = 45000,  time = 087s,  loss = 4.39e-03  |  mse = 4.07e-03,  rl2 = 8.84e-02
# iter. = 50000,  time = 096s,  loss = 3.39e-02  |  mse = 1.84e-03,  rl2 = 6.15e-02
# iter. = 55000,  time = 105s,  loss = 9.41e-02  |  mse = 9.16e-04,  rl2 = 4.29e-02
# iter. = 60000,  time = 114s,  loss = 1.23e-01  |  mse = 1.17e-03,  rl2 = 4.98e-02
# iter. = 65000,  time = 124s,  loss = 4.44e-02  |  mse = 3.03e-04,  rl2 = 2.56e-02
# iter. = 70000,  time = 133s,  loss = 4.36e-02  |  mse = 1.64e-03,  rl2 = 5.86e-02
# iter. = 75000,  time = 142s,  loss = 1.51e-03  |  mse = 1.64e-04,  rl2 = 1.79e-02
# iter. = 80000,  time = 151s,  loss = 5.25e-03  |  mse = 4.79e-04,  rl2 = 3.07e-02
# iter. = 85000,  time = 161s,  loss = 1.28e-02  |  mse = 6.60e-04,  rl2 = 3.60e-02
# iter. = 90000,  time = 170s,  loss = 5.19e-03  |  mse = 4.93e-04,  rl2 = 3.22e-02
# iter. = 95000,  time = 179s,  loss = 1.82e-02  |  mse = 1.54e-04,  rl2 = 1.80e-02
# iter. = 100000,  time = 188s,  loss = 1.56e-02  |  mse = 6.82e-04,  rl2 = 3.58e-02
# iter. = 105000,  time = 198s,  loss = 4.90e-02  |  mse = 9.40e-04,  rl2 = 4.36e-02
# iter. = 110000,  time = 207s,  loss = 3.02e-02  |  mse = 1.86e-04,  rl2 = 1.96e-02
# iter. = 115000,  time = 216s,  loss = 5.25e-02  |  mse = 6.40e-04,  rl2 = 3.65e-02
# iter. = 120000,  time = 225s,  loss = 1.28e-02  |  mse = 5.48e-05,  rl2 = 1.05e-02
# iter. = 125000,  time = 235s,  loss = 5.05e-02  |  mse = 1.58e-04,  rl2 = 1.80e-02
# iter. = 130000,  time = 244s,  loss = 1.74e-02  |  mse = 7.50e-05,  rl2 = 1.27e-02
# iter. = 135000,  time = 253s,  loss = 8.48e-04  |  mse = 1.24e-05,  rl2 = 5.10e-03
# iter. = 140000,  time = 262s,  loss = 7.05e-03  |  mse = 2.66e-05,  rl2 = 7.23e-03
# iter. = 145000,  time = 272s,  loss = 5.34e-03  |  mse = 1.74e-05,  rl2 = 5.96e-03
# iter. = 150000,  time = 281s,  loss = 1.98e-03  |  mse = 1.75e-04,  rl2 = 1.79e-02
# iter. = 155000,  time = 290s,  loss = 1.20e-02  |  mse = 3.18e-04,  rl2 = 2.65e-02
# iter. = 160000,  time = 299s,  loss = 4.96e-03  |  mse = 1.48e-05,  rl2 = 5.38e-03
# iter. = 165000,  time = 309s,  loss = 1.32e-02  |  mse = 5.18e-05,  rl2 = 1.03e-02
# iter. = 170000,  time = 318s,  loss = 8.55e-04  |  mse = 9.95e-06,  rl2 = 4.32e-03
# iter. = 175000,  time = 327s,  loss = 2.21e-03  |  mse = 1.54e-05,  rl2 = 5.69e-03
# iter. = 180000,  time = 337s,  loss = 3.91e-04  |  mse = 3.37e-05,  rl2 = 8.40e-03
# iter. = 185000,  time = 346s,  loss = 3.59e-03  |  mse = 3.81e-05,  rl2 = 8.44e-03
# iter. = 190000,  time = 355s,  loss = 3.28e-04  |  mse = 8.15e-06,  rl2 = 4.15e-03
# iter. = 195000,  time = 364s,  loss = 2.12e-04  |  mse = 3.88e-06,  rl2 = 2.66e-03
# iter. = 200000,  time = 374s,  loss = 9.48e-03  |  mse = 1.44e-05,  rl2 = 5.45e-03
# iter. = 205000,  time = 383s,  loss = 2.03e-03  |  mse = 4.65e-06,  rl2 = 3.06e-03
# iter. = 210000,  time = 392s,  loss = 1.63e-02  |  mse = 2.44e-05,  rl2 = 7.12e-03
# iter. = 215000,  time = 401s,  loss = 1.34e-04  |  mse = 2.38e-06,  rl2 = 2.23e-03
# iter. = 220000,  time = 411s,  loss = 1.87e-04  |  mse = 3.84e-06,  rl2 = 2.81e-03
# iter. = 225000,  time = 420s,  loss = 3.28e-04  |  mse = 3.31e-06,  rl2 = 2.56e-03
# iter. = 230000,  time = 429s,  loss = 1.36e-03  |  mse = 2.75e-05,  rl2 = 7.32e-03
# iter. = 235000,  time = 438s,  loss = 2.75e-04  |  mse = 4.21e-06,  rl2 = 2.90e-03
# iter. = 240000,  time = 448s,  loss = 4.61e-05  |  mse = 2.35e-06,  rl2 = 2.26e-03
# iter. = 245000,  time = 457s,  loss = 1.66e-04  |  mse = 3.46e-06,  rl2 = 2.64e-03
# iter. = 250000,  time = 466s,  loss = 1.63e-04  |  mse = 2.57e-06,  rl2 = 2.38e-03
# iter. = 255000,  time = 475s,  loss = 9.95e-05  |  mse = 1.80e-06,  rl2 = 1.98e-03
# iter. = 260000,  time = 484s,  loss = 2.68e-05  |  mse = 2.86e-06,  rl2 = 2.30e-03
# iter. = 265000,  time = 494s,  loss = 3.13e-05  |  mse = 1.24e-06,  rl2 = 1.57e-03
# iter. = 270000,  time = 503s,  loss = 5.96e-05  |  mse = 1.99e-06,  rl2 = 1.97e-03
# iter. = 275000,  time = 512s,  loss = 3.89e-05  |  mse = 1.54e-06,  rl2 = 1.73e-03
# iter. = 280000,  time = 521s,  loss = 1.21e-04  |  mse = 1.53e-06,  rl2 = 1.76e-03
# iter. = 285000,  time = 531s,  loss = 2.39e-05  |  mse = 1.93e-06,  rl2 = 1.91e-03
# iter. = 290000,  time = 540s,  loss = 1.12e-05  |  mse = 1.35e-06,  rl2 = 1.69e-03
# iter. = 295000,  time = 549s,  loss = 1.27e-05  |  mse = 1.46e-06,  rl2 = 1.79e-03
# iter. = 300000,  time = 558s,  loss = 9.44e-06  |  mse = 1.08e-06,  rl2 = 1.46e-03
# [v1=1.0, v2=4.8e-04] :  MSE = 1.24e-06  RL2 = 1.58e-03
# iter. = 00000,  time = 004s,  loss = 3.43e+03  |  mse = 1.79e+00,  rl2 = 1.95e+00
# iter. = 05000,  time = 013s,  loss = 1.85e+00  |  mse = 1.96e-01,  rl2 = 6.28e-01
# iter. = 10000,  time = 022s,  loss = 2.07e-01  |  mse = 1.42e-02,  rl2 = 1.66e-01
# iter. = 15000,  time = 031s,  loss = 1.41e-01  |  mse = 8.66e-03,  rl2 = 1.33e-01
# iter. = 20000,  time = 040s,  loss = 2.58e-02  |  mse = 3.24e-03,  rl2 = 7.96e-02
# iter. = 25000,  time = 050s,  loss = 1.46e-02  |  mse = 2.30e-03,  rl2 = 6.60e-02
# iter. = 30000,  time = 059s,  loss = 2.83e-02  |  mse = 9.33e-04,  rl2 = 4.44e-02
# iter. = 35000,  time = 068s,  loss = 1.19e-01  |  mse = 7.59e-04,  rl2 = 3.85e-02
# iter. = 40000,  time = 077s,  loss = 2.32e-02  |  mse = 4.66e-02,  rl2 = 3.01e-01
# iter. = 45000,  time = 087s,  loss = 7.72e-03  |  mse = 1.32e-03,  rl2 = 5.14e-02
# iter. = 50000,  time = 096s,  loss = 4.47e-02  |  mse = 3.09e-04,  rl2 = 2.44e-02
# iter. = 55000,  time = 105s,  loss = 1.20e-02  |  mse = 4.05e-04,  rl2 = 2.91e-02
# iter. = 60000,  time = 114s,  loss = 2.12e-02  |  mse = 1.33e-04,  rl2 = 1.59e-02
# iter. = 65000,  time = 123s,  loss = 3.44e-03  |  mse = 5.28e-04,  rl2 = 3.41e-02
# iter. = 70000,  time = 133s,  loss = 1.27e-01  |  mse = 5.99e-04,  rl2 = 3.31e-02
# iter. = 75000,  time = 142s,  loss = 5.34e-03  |  mse = 1.50e-04,  rl2 = 1.72e-02
# iter. = 80000,  time = 151s,  loss = 3.97e-02  |  mse = 1.74e-03,  rl2 = 5.70e-02
# iter. = 85000,  time = 160s,  loss = 1.69e-02  |  mse = 3.93e-04,  rl2 = 2.74e-02
# iter. = 90000,  time = 170s,  loss = 5.46e-03  |  mse = 6.66e-04,  rl2 = 3.55e-02
# iter. = 95000,  time = 179s,  loss = 4.98e-04  |  mse = 5.85e-05,  rl2 = 1.06e-02
# iter. = 100000,  time = 188s,  loss = 1.04e-01  |  mse = 2.52e-04,  rl2 = 2.24e-02
# iter. = 105000,  time = 197s,  loss = 1.34e-02  |  mse = 4.60e-05,  rl2 = 9.82e-03
# iter. = 110000,  time = 207s,  loss = 7.67e-03  |  mse = 1.08e-04,  rl2 = 1.44e-02
# iter. = 115000,  time = 216s,  loss = 2.65e-03  |  mse = 3.11e-04,  rl2 = 2.51e-02
# iter. = 120000,  time = 225s,  loss = 7.38e-04  |  mse = 1.59e-04,  rl2 = 1.72e-02
# iter. = 125000,  time = 234s,  loss = 6.62e-03  |  mse = 2.88e-05,  rl2 = 7.53e-03
# iter. = 130000,  time = 244s,  loss = 3.27e-03  |  mse = 1.37e-04,  rl2 = 1.66e-02
# iter. = 135000,  time = 253s,  loss = 1.96e-02  |  mse = 2.11e-05,  rl2 = 6.49e-03
# iter. = 140000,  time = 262s,  loss = 2.92e-02  |  mse = 4.19e-05,  rl2 = 9.66e-03
# iter. = 145000,  time = 271s,  loss = 2.35e-02  |  mse = 5.17e-05,  rl2 = 1.04e-02
# iter. = 150000,  time = 281s,  loss = 6.08e-03  |  mse = 9.98e-06,  rl2 = 4.44e-03
# iter. = 155000,  time = 290s,  loss = 2.83e-04  |  mse = 1.44e-06,  rl2 = 1.67e-03
# iter. = 160000,  time = 299s,  loss = 2.01e-03  |  mse = 8.17e-05,  rl2 = 1.26e-02
# iter. = 165000,  time = 308s,  loss = 5.18e-03  |  mse = 1.13e-05,  rl2 = 4.56e-03
# iter. = 170000,  time = 318s,  loss = 1.05e-02  |  mse = 1.43e-04,  rl2 = 1.74e-02
# iter. = 175000,  time = 327s,  loss = 6.79e-03  |  mse = 8.64e-06,  rl2 = 4.19e-03
# iter. = 180000,  time = 336s,  loss = 1.72e-04  |  mse = 1.32e-05,  rl2 = 5.26e-03
# iter. = 185000,  time = 345s,  loss = 4.04e-03  |  mse = 2.72e-05,  rl2 = 7.29e-03
# iter. = 190000,  time = 354s,  loss = 4.87e-03  |  mse = 1.25e-05,  rl2 = 5.23e-03
# iter. = 195000,  time = 364s,  loss = 1.89e-04  |  mse = 1.11e-05,  rl2 = 4.95e-03
# iter. = 200000,  time = 373s,  loss = 1.01e-03  |  mse = 8.65e-06,  rl2 = 4.17e-03
# iter. = 205000,  time = 382s,  loss = 1.38e-03  |  mse = 4.00e-06,  rl2 = 2.82e-03
# iter. = 210000,  time = 391s,  loss = 2.06e-02  |  mse = 8.12e-05,  rl2 = 1.31e-02
# iter. = 215000,  time = 401s,  loss = 2.52e-04  |  mse = 1.72e-05,  rl2 = 5.96e-03
# iter. = 220000,  time = 410s,  loss = 1.74e-04  |  mse = 1.15e-06,  rl2 = 1.48e-03
# iter. = 225000,  time = 419s,  loss = 1.56e-03  |  mse = 3.69e-06,  rl2 = 2.75e-03
# iter. = 230000,  time = 428s,  loss = 1.03e-03  |  mse = 1.02e-05,  rl2 = 4.29e-03
# iter. = 235000,  time = 438s,  loss = 4.73e-04  |  mse = 3.48e-06,  rl2 = 2.67e-03
# iter. = 240000,  time = 447s,  loss = 3.25e-05  |  mse = 8.32e-07,  rl2 = 1.31e-03
# iter. = 245000,  time = 456s,  loss = 1.58e-04  |  mse = 2.43e-06,  rl2 = 2.18e-03
# iter. = 250000,  time = 465s,  loss = 8.40e-05  |  mse = 1.15e-06,  rl2 = 1.49e-03
# iter. = 255000,  time = 474s,  loss = 5.03e-04  |  mse = 1.24e-06,  rl2 = 1.60e-03
# iter. = 260000,  time = 484s,  loss = 3.77e-04  |  mse = 3.76e-07,  rl2 = 8.82e-04
# iter. = 265000,  time = 493s,  loss = 7.08e-04  |  mse = 8.09e-07,  rl2 = 1.34e-03
# iter. = 270000,  time = 502s,  loss = 4.46e-05  |  mse = 3.39e-07,  rl2 = 8.36e-04
# iter. = 275000,  time = 511s,  loss = 4.58e-05  |  mse = 2.58e-07,  rl2 = 7.45e-04
# iter. = 280000,  time = 521s,  loss = 3.90e-05  |  mse = 1.60e-07,  rl2 = 5.57e-04
# iter. = 285000,  time = 530s,  loss = 1.63e-05  |  mse = 1.80e-07,  rl2 = 6.25e-04
# iter. = 290000,  time = 539s,  loss = 1.36e-05  |  mse = 1.65e-07,  rl2 = 5.50e-04
# iter. = 295000,  time = 548s,  loss = 8.86e-06  |  mse = 1.01e-07,  rl2 = 4.56e-04
# iter. = 300000,  time = 558s,  loss = 1.05e-05  |  mse = 4.61e-08,  rl2 = 3.01e-04
# [v1=1.0, v2=4.8e-04] :  MSE = 3.96e-08  RL2 = 2.82e-04

# %%
# 5 runs (ref)
ref_params_5, ref_store_nnws_5 = {}, {}
for seed in [10, 20, 30, 40, 50]:
    # run main (ER)
    params, store_nnws = main(ER=0, ER_xx=20, weight_ic=1000, weight_bc=1000,
                              max_lr=1e-3, exponent=0.8, max_iter=300000, seed=seed, gpu=0)
    ref_params_5[seed] = params
    ref_store_nnws_5[seed] = store_nnws
# Out:
# iter. = 00000,  time = 005s,  loss = 1.58e+03  |  mse = 7.76e-01,  rl2 = 1.26e+00
# iter. = 05000,  time = 014s,  loss = 3.14e-01  |  mse = 2.33e-01,  rl2 = 6.61e-01
# iter. = 10000,  time = 022s,  loss = 2.72e-01  |  mse = 2.57e-01,  rl2 = 6.82e-01
# iter. = 15000,  time = 031s,  loss = 2.34e-01  |  mse = 2.33e-01,  rl2 = 6.64e-01
# iter. = 20000,  time = 040s,  loss = 2.26e-01  |  mse = 2.41e-01,  rl2 = 7.03e-01
# iter. = 25000,  time = 049s,  loss = 1.12e-01  |  mse = 2.26e-01,  rl2 = 6.63e-01
# iter. = 30000,  time = 058s,  loss = 1.09e-01  |  mse = 1.42e-01,  rl2 = 5.49e-01
# iter. = 35000,  time = 067s,  loss = 3.00e-02  |  mse = 1.08e-01,  rl2 = 4.67e-01
# iter. = 40000,  time = 076s,  loss = 4.29e-02  |  mse = 1.29e-01,  rl2 = 5.00e-01
# iter. = 45000,  time = 085s,  loss = 1.91e-02  |  mse = 7.13e-02,  rl2 = 3.75e-01
# iter. = 50000,  time = 094s,  loss = 5.28e-02  |  mse = 4.55e-02,  rl2 = 3.05e-01
# iter. = 55000,  time = 102s,  loss = 9.12e-03  |  mse = 5.60e-02,  rl2 = 3.30e-01
# iter. = 60000,  time = 111s,  loss = 3.00e-02  |  mse = 3.49e-02,  rl2 = 2.70e-01
# iter. = 65000,  time = 120s,  loss = 2.18e-02  |  mse = 2.40e-02,  rl2 = 2.22e-01
# iter. = 70000,  time = 129s,  loss = 1.33e-01  |  mse = 1.90e-02,  rl2 = 1.93e-01
# iter. = 75000,  time = 138s,  loss = 1.54e-02  |  mse = 1.67e-02,  rl2 = 1.82e-01
# iter. = 80000,  time = 147s,  loss = 1.53e-02  |  mse = 1.45e-02,  rl2 = 1.64e-01
# iter. = 85000,  time = 156s,  loss = 5.19e-03  |  mse = 1.11e-02,  rl2 = 1.52e-01
# iter. = 90000,  time = 165s,  loss = 5.29e-03  |  mse = 1.18e-02,  rl2 = 1.49e-01
# iter. = 95000,  time = 174s,  loss = 3.03e-03  |  mse = 1.09e-02,  rl2 = 1.46e-01
# iter. = 100000,  time = 183s,  loss = 2.04e-02  |  mse = 1.67e-02,  rl2 = 1.87e-01
# iter. = 105000,  time = 192s,  loss = 4.58e-01  |  mse = 1.78e-02,  rl2 = 1.93e-01
# iter. = 110000,  time = 201s,  loss = 2.03e-03  |  mse = 1.40e-02,  rl2 = 1.76e-01
# iter. = 115000,  time = 210s,  loss = 1.20e-02  |  mse = 1.77e-02,  rl2 = 1.88e-01
# iter. = 120000,  time = 218s,  loss = 2.88e-03  |  mse = 1.66e-02,  rl2 = 1.85e-01
# iter. = 125000,  time = 227s,  loss = 5.53e-03  |  mse = 1.67e-02,  rl2 = 1.87e-01
# iter. = 130000,  time = 236s,  loss = 3.90e-03  |  mse = 1.69e-02,  rl2 = 1.86e-01
# iter. = 135000,  time = 245s,  loss = 1.95e-03  |  mse = 2.02e-02,  rl2 = 2.02e-01
# iter. = 140000,  time = 254s,  loss = 1.41e-03  |  mse = 2.04e-02,  rl2 = 2.00e-01
# iter. = 145000,  time = 263s,  loss = 9.77e-03  |  mse = 1.96e-02,  rl2 = 2.03e-01
# iter. = 150000,  time = 272s,  loss = 7.75e-02  |  mse = 2.29e-02,  rl2 = 2.22e-01
# iter. = 155000,  time = 281s,  loss = 4.15e-04  |  mse = 1.83e-02,  rl2 = 1.86e-01
# iter. = 160000,  time = 290s,  loss = 2.24e-03  |  mse = 1.82e-02,  rl2 = 1.91e-01
# iter. = 165000,  time = 299s,  loss = 3.82e-04  |  mse = 1.69e-02,  rl2 = 1.87e-01
# iter. = 170000,  time = 308s,  loss = 1.42e-03  |  mse = 2.23e-02,  rl2 = 2.17e-01
# iter. = 175000,  time = 317s,  loss = 3.60e-03  |  mse = 2.08e-02,  rl2 = 2.01e-01
# iter. = 180000,  time = 326s,  loss = 2.65e-03  |  mse = 2.20e-02,  rl2 = 2.13e-01
# iter. = 185000,  time = 335s,  loss = 6.25e-03  |  mse = 2.31e-02,  rl2 = 2.15e-01
# iter. = 190000,  time = 344s,  loss = 8.88e-03  |  mse = 2.16e-02,  rl2 = 2.07e-01
# iter. = 195000,  time = 353s,  loss = 2.08e-04  |  mse = 2.25e-02,  rl2 = 2.16e-01
# iter. = 200000,  time = 361s,  loss = 1.98e-03  |  mse = 2.16e-02,  rl2 = 2.11e-01
# iter. = 205000,  time = 370s,  loss = 8.16e-04  |  mse = 2.24e-02,  rl2 = 2.16e-01
# iter. = 210000,  time = 379s,  loss = 1.25e-03  |  mse = 2.40e-02,  rl2 = 2.16e-01
# iter. = 215000,  time = 388s,  loss = 2.92e-04  |  mse = 2.65e-02,  rl2 = 2.34e-01
# iter. = 220000,  time = 397s,  loss = 3.82e-03  |  mse = 2.17e-02,  rl2 = 2.11e-01
# iter. = 225000,  time = 406s,  loss = 2.42e-03  |  mse = 2.39e-02,  rl2 = 2.21e-01
# iter. = 230000,  time = 415s,  loss = 4.54e-03  |  mse = 2.53e-02,  rl2 = 2.16e-01
# iter. = 235000,  time = 424s,  loss = 4.76e-05  |  mse = 1.80e-02,  rl2 = 1.88e-01
# iter. = 240000,  time = 433s,  loss = 5.75e-04  |  mse = 1.83e-02,  rl2 = 1.91e-01
# iter. = 245000,  time = 442s,  loss = 9.81e-04  |  mse = 2.01e-02,  rl2 = 1.98e-01
# iter. = 250000,  time = 451s,  loss = 2.00e-04  |  mse = 1.53e-02,  rl2 = 1.72e-01
# iter. = 255000,  time = 460s,  loss = 2.87e-04  |  mse = 1.99e-02,  rl2 = 1.97e-01
# iter. = 260000,  time = 469s,  loss = 8.89e-05  |  mse = 1.54e-02,  rl2 = 1.75e-01
# iter. = 265000,  time = 478s,  loss = 4.47e-05  |  mse = 2.53e-02,  rl2 = 2.27e-01
# iter. = 270000,  time = 487s,  loss = 7.49e-05  |  mse = 1.44e-02,  rl2 = 1.68e-01
# iter. = 275000,  time = 495s,  loss = 1.11e-04  |  mse = 2.02e-02,  rl2 = 2.07e-01
# iter. = 280000,  time = 504s,  loss = 3.81e-05  |  mse = 1.80e-02,  rl2 = 1.92e-01
# iter. = 285000,  time = 513s,  loss = 4.02e-05  |  mse = 1.80e-02,  rl2 = 1.94e-01
# iter. = 290000,  time = 522s,  loss = 2.08e-05  |  mse = 1.56e-02,  rl2 = 1.79e-01
# iter. = 295000,  time = 531s,  loss = 1.47e-05  |  mse = 1.39e-02,  rl2 = 1.73e-01
# iter. = 300000,  time = 540s,  loss = 1.33e-05  |  mse = 2.03e-02,  rl2 = 1.95e-01
# [v1=1.0, v2=4.8e-04] :  MSE = 1.85e-02  RL2 = 1.92e-01
# iter. = 00000,  time = 004s,  loss = 2.47e+03  |  mse = 1.49e+00,  rl2 = 1.71e+00
# iter. = 05000,  time = 012s,  loss = 3.11e-01  |  mse = 2.04e-01,  rl2 = 6.40e-01
# iter. = 10000,  time = 021s,  loss = 2.80e-01  |  mse = 2.28e-01,  rl2 = 6.52e-01
# iter. = 15000,  time = 030s,  loss = 3.71e-01  |  mse = 1.89e-01,  rl2 = 6.22e-01
# iter. = 20000,  time = 039s,  loss = 1.98e-01  |  mse = 2.89e-01,  rl2 = 7.53e-01
# iter. = 25000,  time = 048s,  loss = 2.60e-01  |  mse = 2.16e-01,  rl2 = 6.75e-01
# iter. = 30000,  time = 057s,  loss = 7.47e-02  |  mse = 2.13e-01,  rl2 = 6.66e-01
# iter. = 35000,  time = 066s,  loss = 1.88e-01  |  mse = 1.79e-01,  rl2 = 6.00e-01
# iter. = 40000,  time = 075s,  loss = 1.39e-01  |  mse = 1.14e-01,  rl2 = 4.96e-01
# iter. = 45000,  time = 084s,  loss = 4.07e-01  |  mse = 1.15e-01,  rl2 = 4.88e-01
# iter. = 50000,  time = 093s,  loss = 3.54e-02  |  mse = 9.61e-02,  rl2 = 4.40e-01
# iter. = 55000,  time = 102s,  loss = 1.97e-02  |  mse = 5.93e-02,  rl2 = 3.51e-01
# iter. = 60000,  time = 111s,  loss = 9.79e-02  |  mse = 4.06e-02,  rl2 = 2.93e-01
# iter. = 65000,  time = 119s,  loss = 2.28e-02  |  mse = 2.73e-02,  rl2 = 2.38e-01
# iter. = 70000,  time = 128s,  loss = 8.11e-03  |  mse = 1.79e-02,  rl2 = 1.89e-01
# iter. = 75000,  time = 137s,  loss = 6.15e-02  |  mse = 1.65e-02,  rl2 = 1.83e-01
# iter. = 80000,  time = 146s,  loss = 1.45e-01  |  mse = 2.16e-02,  rl2 = 2.02e-01
# iter. = 85000,  time = 155s,  loss = 1.57e-02  |  mse = 1.55e-02,  rl2 = 1.82e-01
# iter. = 90000,  time = 164s,  loss = 1.15e-02  |  mse = 1.47e-02,  rl2 = 1.66e-01
# iter. = 95000,  time = 173s,  loss = 1.26e-02  |  mse = 1.73e-02,  rl2 = 1.87e-01
# iter. = 100000,  time = 182s,  loss = 6.90e-03  |  mse = 1.56e-02,  rl2 = 1.70e-01
# iter. = 105000,  time = 191s,  loss = 1.23e-02  |  mse = 1.37e-02,  rl2 = 1.74e-01
# iter. = 110000,  time = 200s,  loss = 1.13e-02  |  mse = 1.61e-02,  rl2 = 1.75e-01
# iter. = 115000,  time = 209s,  loss = 4.39e-03  |  mse = 1.56e-02,  rl2 = 1.75e-01
# iter. = 120000,  time = 218s,  loss = 9.23e-03  |  mse = 1.67e-02,  rl2 = 1.76e-01
# iter. = 125000,  time = 227s,  loss = 3.72e-02  |  mse = 1.91e-02,  rl2 = 1.95e-01
# iter. = 130000,  time = 236s,  loss = 6.04e-02  |  mse = 1.93e-02,  rl2 = 1.94e-01
# iter. = 135000,  time = 245s,  loss = 5.88e-03  |  mse = 1.60e-02,  rl2 = 1.77e-01
# iter. = 140000,  time = 253s,  loss = 1.05e-02  |  mse = 1.84e-02,  rl2 = 1.93e-01
# iter. = 145000,  time = 262s,  loss = 5.55e-03  |  mse = 2.12e-02,  rl2 = 2.13e-01
# iter. = 150000,  time = 271s,  loss = 4.88e-03  |  mse = 1.97e-02,  rl2 = 2.03e-01
# iter. = 155000,  time = 280s,  loss = 2.45e-03  |  mse = 1.85e-02,  rl2 = 1.95e-01
# iter. = 160000,  time = 289s,  loss = 1.29e-03  |  mse = 2.23e-02,  rl2 = 2.06e-01
# iter. = 165000,  time = 298s,  loss = 1.35e-03  |  mse = 1.61e-02,  rl2 = 1.88e-01
# iter. = 170000,  time = 307s,  loss = 1.72e-03  |  mse = 2.01e-02,  rl2 = 2.05e-01
# iter. = 175000,  time = 316s,  loss = 4.15e-03  |  mse = 2.05e-02,  rl2 = 2.04e-01
# iter. = 180000,  time = 325s,  loss = 1.01e-03  |  mse = 1.40e-02,  rl2 = 1.68e-01
# iter. = 185000,  time = 334s,  loss = 5.11e-04  |  mse = 2.27e-02,  rl2 = 2.09e-01
# iter. = 190000,  time = 343s,  loss = 3.50e-04  |  mse = 1.91e-02,  rl2 = 1.99e-01
# iter. = 195000,  time = 352s,  loss = 3.44e-04  |  mse = 1.63e-02,  rl2 = 1.83e-01
# iter. = 200000,  time = 361s,  loss = 1.31e-04  |  mse = 1.79e-02,  rl2 = 1.84e-01
# iter. = 205000,  time = 370s,  loss = 2.49e-04  |  mse = 2.07e-02,  rl2 = 1.99e-01
# iter. = 210000,  time = 379s,  loss = 1.93e-04  |  mse = 2.58e-02,  rl2 = 2.24e-01
# iter. = 215000,  time = 387s,  loss = 5.74e-03  |  mse = 1.80e-02,  rl2 = 1.92e-01
# iter. = 220000,  time = 396s,  loss = 5.08e-03  |  mse = 2.60e-02,  rl2 = 2.43e-01
# iter. = 225000,  time = 405s,  loss = 4.07e-04  |  mse = 2.05e-02,  rl2 = 1.99e-01
# iter. = 230000,  time = 414s,  loss = 7.98e-04  |  mse = 2.17e-02,  rl2 = 2.07e-01
# iter. = 235000,  time = 423s,  loss = 1.83e-04  |  mse = 2.27e-02,  rl2 = 2.10e-01
# iter. = 240000,  time = 432s,  loss = 4.98e-05  |  mse = 2.37e-02,  rl2 = 2.18e-01
# iter. = 245000,  time = 441s,  loss = 3.12e-04  |  mse = 1.91e-02,  rl2 = 1.96e-01
# iter. = 250000,  time = 450s,  loss = 1.11e-04  |  mse = 1.60e-02,  rl2 = 1.83e-01
# iter. = 255000,  time = 459s,  loss = 2.06e-04  |  mse = 2.09e-02,  rl2 = 2.03e-01
# iter. = 260000,  time = 468s,  loss = 1.01e-04  |  mse = 2.49e-02,  rl2 = 2.18e-01
# iter. = 265000,  time = 477s,  loss = 6.32e-05  |  mse = 2.28e-02,  rl2 = 2.18e-01
# iter. = 270000,  time = 486s,  loss = 1.42e-04  |  mse = 1.61e-02,  rl2 = 1.80e-01
# iter. = 275000,  time = 495s,  loss = 5.11e-05  |  mse = 2.36e-02,  rl2 = 2.20e-01
# iter. = 280000,  time = 504s,  loss = 3.32e-05  |  mse = 1.60e-02,  rl2 = 1.79e-01
# iter. = 285000,  time = 512s,  loss = 2.95e-05  |  mse = 1.70e-02,  rl2 = 1.71e-01
# iter. = 290000,  time = 521s,  loss = 2.04e-05  |  mse = 1.82e-02,  rl2 = 1.83e-01
# iter. = 295000,  time = 530s,  loss = 1.85e-05  |  mse = 1.43e-02,  rl2 = 1.67e-01
# iter. = 300000,  time = 539s,  loss = 1.30e-05  |  mse = 1.70e-02,  rl2 = 1.84e-01
# [v1=1.0, v2=4.8e-04] :  MSE = 1.86e-02  RL2 = 1.93e-01
# iter. = 00000,  time = 004s,  loss = 1.41e+03  |  mse = 2.96e+00,  rl2 = 2.53e+00
# iter. = 05000,  time = 013s,  loss = 7.77e-01  |  mse = 1.81e-01,  rl2 = 6.14e-01
# iter. = 10000,  time = 021s,  loss = 1.10e+00  |  mse = 1.96e-01,  rl2 = 6.07e-01
# iter. = 15000,  time = 030s,  loss = 2.51e-01  |  mse = 2.13e-01,  rl2 = 6.48e-01
# iter. = 20000,  time = 039s,  loss = 1.48e-01  |  mse = 2.55e-01,  rl2 = 7.30e-01
# iter. = 25000,  time = 048s,  loss = 1.80e-01  |  mse = 2.19e-01,  rl2 = 6.46e-01
# iter. = 30000,  time = 057s,  loss = 7.13e-02  |  mse = 1.51e-01,  rl2 = 5.65e-01
# iter. = 35000,  time = 066s,  loss = 9.72e-02  |  mse = 1.19e-01,  rl2 = 4.90e-01
# iter. = 40000,  time = 075s,  loss = 4.80e-02  |  mse = 9.43e-02,  rl2 = 4.34e-01
# iter. = 45000,  time = 084s,  loss = 1.13e-01  |  mse = 7.61e-02,  rl2 = 3.79e-01
# iter. = 50000,  time = 093s,  loss = 2.13e-02  |  mse = 4.50e-02,  rl2 = 3.01e-01
# iter. = 55000,  time = 102s,  loss = 1.07e-02  |  mse = 2.64e-02,  rl2 = 2.38e-01
# iter. = 60000,  time = 111s,  loss = 1.82e-02  |  mse = 2.30e-02,  rl2 = 2.17e-01
# iter. = 65000,  time = 119s,  loss = 4.87e-02  |  mse = 1.73e-02,  rl2 = 1.82e-01
# iter. = 70000,  time = 128s,  loss = 6.72e-03  |  mse = 1.30e-02,  rl2 = 1.66e-01
# iter. = 75000,  time = 137s,  loss = 3.74e-02  |  mse = 1.39e-02,  rl2 = 1.73e-01
# iter. = 80000,  time = 146s,  loss = 1.90e-01  |  mse = 8.14e-03,  rl2 = 1.37e-01
# iter. = 85000,  time = 155s,  loss = 1.77e-02  |  mse = 7.82e-03,  rl2 = 1.24e-01
# iter. = 90000,  time = 164s,  loss = 1.35e-02  |  mse = 9.60e-03,  rl2 = 1.41e-01
# iter. = 95000,  time = 173s,  loss = 4.84e-03  |  mse = 9.48e-03,  rl2 = 1.41e-01
# iter. = 100000,  time = 182s,  loss = 6.26e-02  |  mse = 1.09e-02,  rl2 = 1.52e-01
# iter. = 105000,  time = 191s,  loss = 9.05e-02  |  mse = 1.07e-02,  rl2 = 1.46e-01
# iter. = 110000,  time = 200s,  loss = 8.51e-03  |  mse = 1.48e-02,  rl2 = 1.68e-01
# iter. = 115000,  time = 209s,  loss = 2.76e-02  |  mse = 1.14e-02,  rl2 = 1.56e-01
# iter. = 120000,  time = 218s,  loss = 3.61e-02  |  mse = 1.47e-02,  rl2 = 1.82e-01
# iter. = 125000,  time = 227s,  loss = 1.46e-02  |  mse = 1.66e-02,  rl2 = 1.87e-01
# iter. = 130000,  time = 236s,  loss = 4.31e-03  |  mse = 1.43e-02,  rl2 = 1.75e-01
# iter. = 135000,  time = 244s,  loss = 2.70e-03  |  mse = 1.58e-02,  rl2 = 1.73e-01
# iter. = 140000,  time = 253s,  loss = 2.87e-03  |  mse = 1.56e-02,  rl2 = 1.73e-01
# iter. = 145000,  time = 262s,  loss = 3.16e-03  |  mse = 1.47e-02,  rl2 = 1.68e-01
# iter. = 150000,  time = 271s,  loss = 6.91e-04  |  mse = 1.86e-02,  rl2 = 1.97e-01
# iter. = 155000,  time = 280s,  loss = 2.65e-03  |  mse = 1.68e-02,  rl2 = 1.74e-01
# iter. = 160000,  time = 289s,  loss = 7.24e-04  |  mse = 1.39e-02,  rl2 = 1.73e-01
# iter. = 165000,  time = 298s,  loss = 4.68e-04  |  mse = 1.99e-02,  rl2 = 2.03e-01
# iter. = 170000,  time = 307s,  loss = 8.41e-04  |  mse = 2.05e-02,  rl2 = 2.04e-01
# iter. = 175000,  time = 316s,  loss = 6.56e-03  |  mse = 1.98e-02,  rl2 = 1.98e-01
# iter. = 180000,  time = 325s,  loss = 1.37e-03  |  mse = 1.40e-02,  rl2 = 1.83e-01
# iter. = 185000,  time = 334s,  loss = 1.04e-03  |  mse = 1.58e-02,  rl2 = 1.83e-01
# iter. = 190000,  time = 343s,  loss = 5.97e-03  |  mse = 2.06e-02,  rl2 = 2.10e-01
# iter. = 195000,  time = 352s,  loss = 4.40e-03  |  mse = 1.65e-02,  rl2 = 1.92e-01
# iter. = 200000,  time = 361s,  loss = 8.96e-03  |  mse = 1.63e-02,  rl2 = 1.79e-01
# iter. = 205000,  time = 369s,  loss = 3.11e-03  |  mse = 1.56e-02,  rl2 = 1.75e-01
# iter. = 210000,  time = 378s,  loss = 1.18e-04  |  mse = 2.32e-02,  rl2 = 2.05e-01
# iter. = 215000,  time = 387s,  loss = 1.36e-04  |  mse = 1.74e-02,  rl2 = 1.86e-01
# iter. = 220000,  time = 396s,  loss = 4.17e-04  |  mse = 2.03e-02,  rl2 = 1.98e-01
# iter. = 225000,  time = 405s,  loss = 2.17e-04  |  mse = 1.89e-02,  rl2 = 1.91e-01
# iter. = 230000,  time = 414s,  loss = 3.38e-03  |  mse = 2.02e-02,  rl2 = 2.01e-01
# iter. = 235000,  time = 423s,  loss = 1.06e-04  |  mse = 1.68e-02,  rl2 = 1.81e-01
# iter. = 240000,  time = 432s,  loss = 1.70e-03  |  mse = 1.84e-02,  rl2 = 1.91e-01
# iter. = 245000,  time = 441s,  loss = 5.22e-03  |  mse = 1.70e-02,  rl2 = 1.93e-01
# iter. = 250000,  time = 450s,  loss = 3.98e-05  |  mse = 1.99e-02,  rl2 = 2.05e-01
# iter. = 255000,  time = 459s,  loss = 5.26e-05  |  mse = 2.00e-02,  rl2 = 1.99e-01
# iter. = 260000,  time = 468s,  loss = 2.18e-04  |  mse = 1.25e-02,  rl2 = 1.60e-01
# iter. = 265000,  time = 477s,  loss = 4.02e-05  |  mse = 1.49e-02,  rl2 = 1.69e-01
# iter. = 270000,  time = 486s,  loss = 1.04e-04  |  mse = 1.34e-02,  rl2 = 1.64e-01
# iter. = 275000,  time = 494s,  loss = 4.46e-05  |  mse = 1.58e-02,  rl2 = 1.78e-01
# iter. = 280000,  time = 503s,  loss = 3.28e-05  |  mse = 1.47e-02,  rl2 = 1.74e-01
# iter. = 285000,  time = 512s,  loss = 3.50e-05  |  mse = 2.03e-02,  rl2 = 1.99e-01
# iter. = 290000,  time = 521s,  loss = 2.25e-05  |  mse = 1.69e-02,  rl2 = 1.85e-01
# iter. = 295000,  time = 530s,  loss = 1.94e-05  |  mse = 1.60e-02,  rl2 = 1.87e-01
# iter. = 300000,  time = 539s,  loss = 1.54e-05  |  mse = 1.65e-02,  rl2 = 1.79e-01
# [v1=1.0, v2=4.8e-04] :  MSE = 1.62e-02  RL2 = 1.80e-01
# iter. = 00000,  time = 004s,  loss = 2.65e+03  |  mse = 1.06e+00,  rl2 = 1.47e+00
# iter. = 05000,  time = 013s,  loss = 2.82e-01  |  mse = 1.76e-01,  rl2 = 6.00e-01
# iter. = 10000,  time = 022s,  loss = 2.77e-01  |  mse = 2.09e-01,  rl2 = 6.36e-01
# iter. = 15000,  time = 030s,  loss = 2.12e-01  |  mse = 1.81e-01,  rl2 = 6.29e-01
# iter. = 20000,  time = 039s,  loss = 1.41e-01  |  mse = 2.14e-01,  rl2 = 6.90e-01
# iter. = 25000,  time = 048s,  loss = 1.58e-01  |  mse = 2.62e-01,  rl2 = 7.09e-01
# iter. = 30000,  time = 057s,  loss = 2.34e-01  |  mse = 2.13e-01,  rl2 = 6.44e-01
# iter. = 35000,  time = 066s,  loss = 4.22e-02  |  mse = 1.68e-01,  rl2 = 5.75e-01
# iter. = 40000,  time = 075s,  loss = 2.86e-01  |  mse = 1.41e-01,  rl2 = 5.13e-01
# iter. = 45000,  time = 084s,  loss = 3.00e-02  |  mse = 1.08e-01,  rl2 = 4.55e-01
# iter. = 50000,  time = 093s,  loss = 2.46e-01  |  mse = 7.14e-02,  rl2 = 3.83e-01
# iter. = 55000,  time = 102s,  loss = 2.29e-02  |  mse = 4.55e-02,  rl2 = 3.02e-01
# iter. = 60000,  time = 111s,  loss = 2.90e-02  |  mse = 4.81e-02,  rl2 = 3.20e-01
# iter. = 65000,  time = 120s,  loss = 8.79e-03  |  mse = 3.94e-02,  rl2 = 2.92e-01
# iter. = 70000,  time = 129s,  loss = 1.28e-02  |  mse = 2.49e-02,  rl2 = 2.29e-01
# iter. = 75000,  time = 137s,  loss = 3.49e-02  |  mse = 1.94e-02,  rl2 = 1.95e-01
# iter. = 80000,  time = 146s,  loss = 6.14e-03  |  mse = 1.38e-02,  rl2 = 1.64e-01
# iter. = 85000,  time = 155s,  loss = 1.20e-02  |  mse = 9.57e-03,  rl2 = 1.37e-01
# iter. = 90000,  time = 164s,  loss = 6.01e-03  |  mse = 1.05e-02,  rl2 = 1.48e-01
# iter. = 95000,  time = 173s,  loss = 2.24e-03  |  mse = 1.10e-02,  rl2 = 1.52e-01
# iter. = 100000,  time = 182s,  loss = 1.12e-02  |  mse = 1.28e-02,  rl2 = 1.55e-01
# iter. = 105000,  time = 191s,  loss = 3.09e-03  |  mse = 1.16e-02,  rl2 = 1.53e-01
# iter. = 110000,  time = 200s,  loss = 3.83e-02  |  mse = 1.25e-02,  rl2 = 1.61e-01
# iter. = 115000,  time = 209s,  loss = 4.14e-03  |  mse = 1.37e-02,  rl2 = 1.69e-01
# iter. = 120000,  time = 218s,  loss = 2.29e-03  |  mse = 1.34e-02,  rl2 = 1.65e-01
# iter. = 125000,  time = 227s,  loss = 9.50e-03  |  mse = 1.63e-02,  rl2 = 1.83e-01
# iter. = 130000,  time = 236s,  loss = 1.14e-02  |  mse = 1.82e-02,  rl2 = 1.97e-01
# iter. = 135000,  time = 245s,  loss = 2.06e-02  |  mse = 1.50e-02,  rl2 = 1.77e-01
# iter. = 140000,  time = 254s,  loss = 1.28e-02  |  mse = 1.65e-02,  rl2 = 1.80e-01
# iter. = 145000,  time = 262s,  loss = 7.93e-04  |  mse = 1.68e-02,  rl2 = 1.85e-01
# iter. = 150000,  time = 271s,  loss = 7.73e-04  |  mse = 1.71e-02,  rl2 = 1.77e-01
# iter. = 155000,  time = 280s,  loss = 2.79e-02  |  mse = 1.58e-02,  rl2 = 1.87e-01
# iter. = 160000,  time = 289s,  loss = 8.67e-03  |  mse = 1.52e-02,  rl2 = 1.72e-01
# iter. = 165000,  time = 298s,  loss = 8.95e-04  |  mse = 1.94e-02,  rl2 = 2.00e-01
# iter. = 170000,  time = 307s,  loss = 5.21e-03  |  mse = 1.62e-02,  rl2 = 1.74e-01
# iter. = 175000,  time = 316s,  loss = 1.17e-02  |  mse = 2.35e-02,  rl2 = 2.22e-01
# iter. = 180000,  time = 325s,  loss = 2.35e-04  |  mse = 1.70e-02,  rl2 = 1.89e-01
# iter. = 185000,  time = 334s,  loss = 5.35e-03  |  mse = 2.30e-02,  rl2 = 2.07e-01
# iter. = 190000,  time = 343s,  loss = 2.76e-02  |  mse = 1.83e-02,  rl2 = 1.96e-01
# iter. = 195000,  time = 352s,  loss = 2.19e-03  |  mse = 2.09e-02,  rl2 = 1.95e-01
# iter. = 200000,  time = 361s,  loss = 1.96e-04  |  mse = 1.90e-02,  rl2 = 1.97e-01
# iter. = 205000,  time = 370s,  loss = 6.68e-03  |  mse = 1.65e-02,  rl2 = 1.83e-01
# iter. = 210000,  time = 378s,  loss = 1.37e-04  |  mse = 1.99e-02,  rl2 = 2.03e-01
# iter. = 215000,  time = 387s,  loss = 7.84e-04  |  mse = 1.56e-02,  rl2 = 1.81e-01
# iter. = 220000,  time = 396s,  loss = 3.47e-04  |  mse = 2.09e-02,  rl2 = 2.07e-01
# iter. = 225000,  time = 405s,  loss = 1.04e-03  |  mse = 2.71e-02,  rl2 = 2.31e-01
# iter. = 230000,  time = 414s,  loss = 6.43e-04  |  mse = 1.73e-02,  rl2 = 1.83e-01
# iter. = 235000,  time = 423s,  loss = 2.01e-03  |  mse = 1.53e-02,  rl2 = 1.75e-01
# iter. = 240000,  time = 432s,  loss = 5.71e-05  |  mse = 1.82e-02,  rl2 = 1.98e-01
# iter. = 245000,  time = 441s,  loss = 7.21e-05  |  mse = 1.55e-02,  rl2 = 1.77e-01
# iter. = 250000,  time = 450s,  loss = 4.48e-05  |  mse = 1.91e-02,  rl2 = 2.05e-01
# iter. = 255000,  time = 459s,  loss = 4.92e-05  |  mse = 1.78e-02,  rl2 = 1.97e-01
# iter. = 260000,  time = 468s,  loss = 5.80e-05  |  mse = 2.19e-02,  rl2 = 2.02e-01
# iter. = 265000,  time = 477s,  loss = 2.99e-05  |  mse = 1.43e-02,  rl2 = 1.69e-01
# iter. = 270000,  time = 485s,  loss = 3.90e-05  |  mse = 1.87e-02,  rl2 = 1.91e-01
# iter. = 275000,  time = 494s,  loss = 3.59e-05  |  mse = 2.01e-02,  rl2 = 1.98e-01
# iter. = 280000,  time = 503s,  loss = 3.99e-05  |  mse = 1.58e-02,  rl2 = 1.79e-01
# iter. = 285000,  time = 512s,  loss = 2.09e-05  |  mse = 1.52e-02,  rl2 = 1.69e-01
# iter. = 290000,  time = 521s,  loss = 2.14e-05  |  mse = 1.53e-02,  rl2 = 1.80e-01
# iter. = 295000,  time = 530s,  loss = 1.45e-05  |  mse = 1.17e-02,  rl2 = 1.60e-01
# iter. = 300000,  time = 539s,  loss = 1.42e-05  |  mse = 1.82e-02,  rl2 = 1.90e-01
# [v1=1.0, v2=4.8e-04] :  MSE = 1.67e-02  RL2 = 1.83e-01
# iter. = 00000,  time = 004s,  loss = 3.43e+03  |  mse = 1.79e+00,  rl2 = 1.95e+00
# iter. = 05000,  time = 013s,  loss = 3.65e-01  |  mse = 2.12e-01,  rl2 = 6.54e-01
# iter. = 10000,  time = 021s,  loss = 3.19e-01  |  mse = 2.06e-01,  rl2 = 6.32e-01
# iter. = 15000,  time = 030s,  loss = 2.37e-01  |  mse = 2.05e-01,  rl2 = 6.46e-01
# iter. = 20000,  time = 039s,  loss = 3.38e-01  |  mse = 2.45e-01,  rl2 = 6.91e-01
# iter. = 25000,  time = 048s,  loss = 2.34e-01  |  mse = 2.65e-01,  rl2 = 7.10e-01
# iter. = 30000,  time = 057s,  loss = 8.50e-02  |  mse = 2.55e-01,  rl2 = 7.34e-01
# iter. = 35000,  time = 066s,  loss = 8.13e-02  |  mse = 1.72e-01,  rl2 = 5.79e-01
# iter. = 40000,  time = 075s,  loss = 2.43e-01  |  mse = 1.87e-01,  rl2 = 6.05e-01
# iter. = 45000,  time = 084s,  loss = 2.07e-02  |  mse = 1.31e-01,  rl2 = 5.13e-01
# iter. = 50000,  time = 093s,  loss = 2.28e-02  |  mse = 1.42e-01,  rl2 = 5.24e-01
# iter. = 55000,  time = 101s,  loss = 2.15e-02  |  mse = 6.61e-02,  rl2 = 3.71e-01
# iter. = 60000,  time = 110s,  loss = 1.60e-02  |  mse = 6.26e-02,  rl2 = 3.45e-01
# iter. = 65000,  time = 119s,  loss = 3.36e-02  |  mse = 4.02e-02,  rl2 = 2.98e-01
# iter. = 70000,  time = 128s,  loss = 7.37e-03  |  mse = 3.34e-02,  rl2 = 2.47e-01
# iter. = 75000,  time = 137s,  loss = 4.94e-03  |  mse = 2.11e-02,  rl2 = 2.04e-01
# iter. = 80000,  time = 146s,  loss = 4.88e-02  |  mse = 1.87e-02,  rl2 = 1.87e-01
# iter. = 85000,  time = 155s,  loss = 1.84e-02  |  mse = 1.76e-02,  rl2 = 1.83e-01
# iter. = 90000,  time = 164s,  loss = 8.86e-03  |  mse = 1.32e-02,  rl2 = 1.58e-01
# iter. = 95000,  time = 173s,  loss = 1.15e-02  |  mse = 1.41e-02,  rl2 = 1.65e-01
# iter. = 100000,  time = 182s,  loss = 4.47e-02  |  mse = 1.40e-02,  rl2 = 1.67e-01
# iter. = 105000,  time = 191s,  loss = 8.45e-03  |  mse = 1.35e-02,  rl2 = 1.68e-01
# iter. = 110000,  time = 200s,  loss = 2.78e-02  |  mse = 1.37e-02,  rl2 = 1.62e-01
# iter. = 115000,  time = 209s,  loss = 2.20e-03  |  mse = 1.22e-02,  rl2 = 1.57e-01
# iter. = 120000,  time = 217s,  loss = 8.19e-03  |  mse = 1.42e-02,  rl2 = 1.62e-01
# iter. = 125000,  time = 226s,  loss = 2.19e-02  |  mse = 2.23e-02,  rl2 = 2.10e-01
# iter. = 130000,  time = 235s,  loss = 9.03e-03  |  mse = 1.83e-02,  rl2 = 1.92e-01
# iter. = 135000,  time = 244s,  loss = 2.27e-02  |  mse = 1.50e-02,  rl2 = 1.73e-01
# iter. = 140000,  time = 253s,  loss = 5.86e-03  |  mse = 1.71e-02,  rl2 = 1.95e-01
# iter. = 145000,  time = 262s,  loss = 5.85e-03  |  mse = 2.00e-02,  rl2 = 2.05e-01
# iter. = 150000,  time = 271s,  loss = 4.32e-02  |  mse = 1.91e-02,  rl2 = 1.94e-01
# iter. = 155000,  time = 280s,  loss = 6.88e-04  |  mse = 2.04e-02,  rl2 = 1.98e-01
# iter. = 160000,  time = 289s,  loss = 1.55e-03  |  mse = 1.85e-02,  rl2 = 1.90e-01
# iter. = 165000,  time = 298s,  loss = 3.47e-03  |  mse = 1.93e-02,  rl2 = 1.89e-01
# iter. = 170000,  time = 307s,  loss = 3.03e-03  |  mse = 1.78e-02,  rl2 = 1.94e-01
# iter. = 175000,  time = 316s,  loss = 4.54e-04  |  mse = 2.32e-02,  rl2 = 2.17e-01
# iter. = 180000,  time = 325s,  loss = 5.83e-04  |  mse = 1.98e-02,  rl2 = 2.03e-01
# iter. = 185000,  time = 333s,  loss = 4.05e-04  |  mse = 1.94e-02,  rl2 = 1.95e-01
# iter. = 190000,  time = 342s,  loss = 2.60e-04  |  mse = 1.50e-02,  rl2 = 1.82e-01
# iter. = 195000,  time = 351s,  loss = 1.21e-03  |  mse = 2.15e-02,  rl2 = 2.17e-01
# iter. = 200000,  time = 360s,  loss = 6.18e-04  |  mse = 1.90e-02,  rl2 = 1.95e-01
# iter. = 205000,  time = 369s,  loss = 7.00e-03  |  mse = 2.06e-02,  rl2 = 2.02e-01
# iter. = 210000,  time = 378s,  loss = 1.51e-02  |  mse = 1.96e-02,  rl2 = 2.04e-01
# iter. = 215000,  time = 387s,  loss = 9.18e-04  |  mse = 2.69e-02,  rl2 = 2.36e-01
# iter. = 220000,  time = 396s,  loss = 1.04e-04  |  mse = 2.44e-02,  rl2 = 2.16e-01
# iter. = 225000,  time = 405s,  loss = 3.01e-03  |  mse = 1.78e-02,  rl2 = 1.91e-01
# iter. = 230000,  time = 414s,  loss = 7.53e-04  |  mse = 2.04e-02,  rl2 = 1.92e-01
# iter. = 235000,  time = 423s,  loss = 1.49e-04  |  mse = 2.35e-02,  rl2 = 2.20e-01
# iter. = 240000,  time = 432s,  loss = 2.39e-04  |  mse = 1.71e-02,  rl2 = 1.88e-01
# iter. = 245000,  time = 441s,  loss = 2.25e-04  |  mse = 1.84e-02,  rl2 = 1.90e-01
# iter. = 250000,  time = 449s,  loss = 3.09e-04  |  mse = 2.12e-02,  rl2 = 2.02e-01
# iter. = 255000,  time = 458s,  loss = 7.17e-05  |  mse = 1.64e-02,  rl2 = 1.83e-01
# iter. = 260000,  time = 467s,  loss = 9.40e-05  |  mse = 1.50e-02,  rl2 = 1.76e-01
# iter. = 265000,  time = 476s,  loss = 2.06e-04  |  mse = 2.04e-02,  rl2 = 2.12e-01
# iter. = 270000,  time = 485s,  loss = 3.50e-05  |  mse = 1.62e-02,  rl2 = 1.83e-01
# iter. = 275000,  time = 494s,  loss = 3.12e-05  |  mse = 2.28e-02,  rl2 = 2.22e-01
# iter. = 280000,  time = 503s,  loss = 2.81e-05  |  mse = 1.45e-02,  rl2 = 1.68e-01
# iter. = 285000,  time = 512s,  loss = 1.92e-05  |  mse = 1.47e-02,  rl2 = 1.79e-01
# iter. = 290000,  time = 521s,  loss = 2.03e-05  |  mse = 2.40e-02,  rl2 = 2.09e-01
# iter. = 295000,  time = 530s,  loss = 1.12e-05  |  mse = 1.83e-02,  rl2 = 1.95e-01
# iter. = 300000,  time = 539s,  loss = 1.34e-05  |  mse = 1.85e-02,  rl2 = 1.91e-01
# [v1=1.0, v2=4.8e-04] :  MSE = 1.83e-02  RL2 = 1.92e-01

# %%
import pickle
# save all weight
pickle.dump(params_5, open('batch5_final_kdv', 'wb'))
pickle.dump(store_nnws_5, open('batch5_hist_kdv', 'wb'))
pickle.dump(ref_params_5, open('batch5_final_kdv-ref', 'wb'))
pickle.dump(ref_store_nnws_5, open('batch5_hist_kdv-ref', 'wb'))

# %%
# read data
mat_data = io.loadmat('kdv.mat')
sim_t = np.repeat(mat_data['t'], 512).reshape(-1,1)
sim_x = np.tile(mat_data['x'], 201).reshape(-1,1)
sim_u = mat_data['usol'].reshape(-1,1)
data_X, data_Y = np.hstack([sim_t, sim_x]), sim_u
t_l, t_u, x_l, x_u = np.min(data_X[:,0]), np.max(data_X[:,0]), np.min(data_X[:,1]), np.max(data_X[:,1])

# convert to jnp
inputs, labels = jnp.array(data_X), jnp.array(data_Y)

# parameter
v1 = 1.0
v2 = 0.022*0.022

# model
model = PINN(128)

# %%
# PINN (final)
params = params_5[50]
pred = model.apply(params, inputs)
u, _, _, _, _, _ = jnp.split(pred, 6, axis=1)

# prediction errors
mse = jnp.mean(jnp.square(labels - u))
rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
print ('[v1=%.1f, v2=%.1e] :  MSE = %.2e  RL2 = %.2e'%(v1, v2, mse, rl2))

# plot
fig = plt.figure(figsize=(15, 3))
plt.subplots_adjust(wspace=0.1)
# low fi
con_lv = 201
ext = [t_l, t_u, x_l, x_u]
# PINN
ax1 = fig.add_subplot(1,3,1)
plt.contourf(labels.reshape(-1, 512).T, con_lv, origin='lower', cmap='jet', extent=ext, vmin=-1, vmax=2);
plt.colorbar(ticks=[-1, 0, 1, 2]); plt.title('Reference'); plt.xlabel('t'); plt.ylabel('x'); plt.yticks([-1, 0, 1]);
ax1 = fig.add_subplot(1,3,2)
plt.contourf(u.reshape(-1, 512).T, con_lv, origin='lower', cmap='jet', extent=ext, vmin=-1, vmax=2);
plt.colorbar(ticks=[-1, 0, 1, 2]); plt.title('Predicted'); plt.yticks([-1, 0, 1]); 
ax1 = fig.add_subplot(1,3,3)
plt.contourf(abs(u - labels).reshape(-1, 512).T, con_lv, origin='lower', cmap='jet', extent=ext, vmin=0, vmax=0.002);
plt.colorbar(ticks=[0, 0.001, 0.002]); plt.title('Absolute error'); plt.yticks([-1, 0, 1]);
# Out:
# [v1=1.0, v2=4.8e-04] :  MSE = 3.96e-08  RL2 = 2.82e-04

# %% [markdown]
#     [v1=1.0, v2=4.8e-04] :  MSE = 3.96e-08  RL2 = 2.82e-04

# %%
# average of 5
rl2s = []
for seed in [10, 20, 30, 40, 50]:
    params = params_5[seed]
    pred = model.apply(params, inputs)
    u, _, _, _, _, _ = jnp.split(pred, 6, axis=1)
    # prediction errors
    mse = jnp.mean(jnp.square(labels - u))
    rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
    print ('[v1=%.1f, v2=%.1e] :  MSE = %.2e  RL2 = %.2e'%(v1, v2, mse, rl2))
    rl2s.append(rl2)
rl2s = np.array(rl2s)
print ('[v1=%.1f, v2=%.1e] :  RL2 best = %.2e  ave = %.2e'%(v1, v2, rl2s.min(), rl2s.mean()))
# Out:
# [v1=1.0, v2=4.8e-04] :  MSE = 6.80e-08  RL2 = 3.69e-04
# [v1=1.0, v2=4.8e-04] :  MSE = 3.12e-07  RL2 = 7.90e-04
# [v1=1.0, v2=4.8e-04] :  MSE = 7.13e-08  RL2 = 3.78e-04
# [v1=1.0, v2=4.8e-04] :  MSE = 1.24e-06  RL2 = 1.58e-03
# [v1=1.0, v2=4.8e-04] :  MSE = 3.96e-08  RL2 = 2.82e-04
# [v1=1.0, v2=4.8e-04] :  RL2 best = 2.82e-04  ave = 6.79e-04

# %%
# convergence
p_time2sol_5 = {}
for seed in [10, 20, 30, 40, 50]:
    store_nnws = store_nnws_5[seed]
    p_time2sol = []
    for i in range(0, len(store_nnws), 3):
        runtime, params = store_nnws[i]
        pred = model.apply(params, inputs)
        u, _, _, _, _, _ = jnp.split(pred, 6, axis=1)
        # prediction errors
        mse = jnp.mean(jnp.square(labels - u))
        rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
        #print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
        p_time2sol.append([runtime, rl2])
    runtime, params = store_nnws[-1]
    pred = model.apply(params, inputs)
    u, _, _, _, _, _ = jnp.split(pred, 6, axis=1)
    # prediction errors
    mse = jnp.mean(jnp.square(labels - u))
    rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
    #print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
    p_time2sol.append([runtime, rl2])    
    print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
    p_time2sol = np.array(p_time2sol)
    p_time2sol_5[seed] = p_time2sol
# Out:
# [time = 559s] :  RL2 = 3.69e-04
# [time = 561s] :  RL2 = 7.90e-04
# [time = 560s] :  RL2 = 3.78e-04
# [time = 558s] :  RL2 = 1.58e-03
# [time = 558s] :  RL2 = 2.82e-04

# %%
# convergence (ref)
ref_p_time2sol_5 = {}
for seed in [10, 20, 30, 40, 50]:
    store_nnws = ref_store_nnws_5[seed]
    p_time2sol = []
    for i in range(0, len(store_nnws), 3):
        runtime, params = store_nnws[i]
        pred = model.apply(params, inputs)
        u, _, _, _, _, _ = jnp.split(pred, 6, axis=1)
        # prediction errors
        mse = jnp.mean(jnp.square(labels - u))
        rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
        #print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
        p_time2sol.append([runtime, rl2])
    runtime, params = store_nnws[-1]
    pred = model.apply(params, inputs)
    u, _, _, _, _, _ = jnp.split(pred, 6, axis=1)
    # prediction errors
    mse = jnp.mean(jnp.square(labels - u))
    rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
    #print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
    p_time2sol.append([runtime, rl2])    
    print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
    p_time2sol = np.array(p_time2sol)
    ref_p_time2sol_5[seed] = p_time2sol
# Out:
# [time = 540s] :  RL2 = 1.92e-01
# [time = 539s] :  RL2 = 1.93e-01
# [time = 539s] :  RL2 = 1.80e-01
# [time = 539s] :  RL2 = 1.83e-01
# [time = 539s] :  RL2 = 1.92e-01

# %%
fig = plt.figure(figsize=(2, 4))
makers = ['^', '<', '>', 'v', 'o']
for i, seed in enumerate([10, 20, 30, 40, 50]):
    p_time2sol = p_time2sol_5[seed]
    plt.plot(p_time2sol[:,0], p_time2sol[:,1], c='lightgreen', markeredgecolor='green', marker=makers[i], markersize=3, linestyle='-.');
plt.plot(p_time2sol[:,0], p_time2sol[:,1], c='salmon', markeredgecolor='maroon', marker=makers[i], markersize=3, linestyle='-.', label='Baseline');
plt.plot(p_time2sol[:,0], p_time2sol[:,1], c='lightgreen', markeredgecolor='green', marker=makers[i], markersize=3, linestyle='-.', label='Scale-PINN');
for i, seed in enumerate([10, 20, 30, 40, 50]):
    p_time2sol = ref_p_time2sol_5[seed]
    plt.plot(p_time2sol[:,0], p_time2sol[:,1], c='salmon', markeredgecolor='maroon', marker=makers[i], markersize=3, linestyle='-.');
plt.xlabel('Training time (s)'); plt.ylabel('Relative error'); plt.yscale('log'); plt.ylim(1e-4, 10); plt.xlim(-0.5, 650);
plt.xticks([0, 300, 600]); plt.legend();

# %%
# PINN (final)
params = params_5[50]
pred = model.apply(params, inputs)
u, _, _, _, _, _ = jnp.split(pred, 6, axis=1)

# prediction errors
mse = jnp.mean(jnp.square(labels - u))
rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
print ('[v1=%.1f, v2=%.1e] :  MSE = %.2e  RL2 = %.2e'%(v1, v2, mse, rl2))

# plot
fig = plt.figure(figsize=(2, 1.5))
# low fi
con_lv = 201
ext = [t_l, t_u, x_l, x_u]
# PINN
plt.contourf(u.reshape(-1, 512).T, con_lv, origin='lower', cmap='jet', extent=ext, vmin=-1, vmax=2);
plt.colorbar(ticks=[0, 1, 2]); plt.title('Final (best)'); plt.yticks([-1, 0, 1]); plt.xticks([0.5], ['0.5s']);
# Out:
# [v1=1.0, v2=4.8e-04] :  MSE = 3.96e-08  RL2 = 2.82e-04

# %%
# PINN (ref)
params = ref_params_5[50]
pred = model.apply(params, inputs)
u, _, _, _, _, _ = jnp.split(pred, 6, axis=1)

# prediction errors
mse = jnp.mean(jnp.square(labels - u))
rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
print ('[v1=%.1f, v2=%.1e] :  MSE = %.2e  RL2 = %.2e'%(v1, v2, mse, rl2))

# plot
fig = plt.figure(figsize=(2, 1.5))
# low fi
con_lv = 201
ext = [t_l, t_u, x_l, x_u]
# PINN
plt.contourf(u.reshape(-1, 512).T, con_lv, origin='lower', cmap='jet', extent=ext, vmin=-1, vmax=2);
plt.colorbar(ticks=[0, 1, 2]); plt.title('Baseline'); plt.yticks([-1, 0, 1]); plt.xticks([0.5], ['0.5s']);
# Out:
# [v1=1.0, v2=4.8e-04] :  MSE = 1.83e-02  RL2 = 1.92e-01

# %%
# PINN (initial)
store_nnws = store_nnws_5[50]
runtime, params = store_nnws[0]
pred = model.apply(params, inputs)
u, _, _, _, _, _ = jnp.split(pred, 6, axis=1)

# prediction errors
mse = jnp.mean(jnp.square(labels - u))
rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
print ('[v1=%.1f, v2=%.1e] :  MSE = %.2e  RL2 = %.2e'%(v1, v2, mse, rl2))

# plot
fig = plt.figure(figsize=(2, 1.5))
# low fi
con_lv = 201
ext = [t_l, t_u, x_l, x_u]
# PINN
plt.contourf(u.reshape(-1, 512).T, con_lv, origin='lower', cmap='jet', extent=ext, vmin=-1, vmax=2);
plt.colorbar(ticks=[0, 1, 2]); plt.title('Initial'); plt.yticks([-1, 0, 1]); plt.xticks([0.5], ['0.5s']);
# Out:
# [v1=1.0, v2=4.8e-04] :  MSE = 1.76e+00  RL2 = 1.88e+00

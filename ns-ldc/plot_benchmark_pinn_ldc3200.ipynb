# %%
import jax
import flax
import optax
from jax import lax, random, numpy as jnp
from jax import random, grad, vmap, hessian, jacfwd, jit
from jax import config
from flax import linen as nn
from evojax.util import get_params_format_fn

import os
import time
import numpy as np
import pandas as pd
from scipy import io
import matplotlib.pyplot as plt
import argparse

# choose GPU
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

#jax.config.update("jax_enable_x64", True)
jax.config.update("jax_default_matmul_precision", "highest")

# %%
"""DNN / PINN   """

class PINN(nn.Module):
    """PINNs"""
    n_nodes:int
    def setup(self):
        # initialization
        kinit = jax.nn.initializers.he_uniform()
        # feature mapping later
        self.feats = nn.Dense(self.n_nodes * 4, kernel_init = kinit)
        # hidden layers
        self.layers = [nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu]
        # split layers
        self.splitu = nn.Dense(self.n_nodes, kernel_init = kinit)
        self.layeru = [nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu,
                       nn.Dense(1, kernel_init = kinit, use_bias=False)]
        self.splitv = nn.Dense(self.n_nodes, kernel_init = kinit)
        self.layerv = [nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu,
                       nn.Dense(1, kernel_init = kinit, use_bias=False)]
        self.splitp = nn.Dense(self.n_nodes, kernel_init = kinit)
        self.layerp = [nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu,
                       nn.Dense(1, kernel_init = kinit, use_bias=False)]

    @nn.compact
    def __call__(self, inputs):
        # split the two variables, probably just by slicing
        x, y = inputs[:,0:1], inputs[:,1:2]
        def get_uvp(x, y):
            inputs = jnp.hstack([x, y, x - 1., y - 1.])
            # feature mapping
            hidden = self.feats(inputs)
            hidden = jnp.sin(2*jnp.pi*hidden)
            # share hidden layer
            for i, lyr in enumerate(self.layers):
                hidden = lyr(hidden)
            # split hidden layer
            u = self.splitu(hidden)
            for i, lyr in enumerate(self.layeru):
                u = lyr(u)
            v = self.splitv(hidden)
            for i, lyr in enumerate(self.layerv):
                v = lyr(v)
            p = self.splitp(hidden)
            for i, lyr in enumerate(self.layerp):
                p = lyr(p)
            return (u, v, p)

        u, v, p = get_uvp(x, y)

        # obtain u_x, u_y, v_x, v_y, p_x, p_y
        def get_uvp_xy(get_uvp, x, y):
            u_x, v_x, p_x = jacfwd(get_uvp)(x, y)
            u_y, v_y, p_y = jacfwd(get_uvp, argnums=1)(x, y)
            return u_x, u_y, v_x, v_y, p_x , p_y

        get_uvp_xy_vmap = vmap(get_uvp_xy, in_axes=(None, 0, 0))
        u_x, u_y, v_x, v_y, p_x, p_y = get_uvp_xy_vmap(get_uvp, x, y)
        u_x, u_y, v_x, v_y, p_x, p_y = u_x[:,:,0], u_y[:,:,0], v_x[:,:,0], v_y[:,:,0], p_x[:,:,0] , p_y[:,:,0]

       # obtain u_xx, u_yy, v_xx, v_yy, p_xx, p_yy
        def get_uvp_xxyy(get_uvp, x, y):
            u_xx, v_xx, p_xx = jacfwd(jacfwd(get_uvp))(x, y)
            u_yy, v_yy, p_yy = jacfwd(jacfwd(get_uvp, argnums=1), argnums=1)(x, y)
            return u_xx, u_yy, v_xx, v_yy, p_xx , p_yy

        get_uvp_xxyy_vmap = vmap(get_uvp_xxyy, in_axes=(None, 0, 0))
        u_xx, u_yy, v_xx, v_yy, p_xx, p_yy = get_uvp_xxyy_vmap(get_uvp, x, y)
        u_xx, u_yy, v_xx, v_yy, p_xx, p_yy = u_xx[:,:,0,0], u_yy[:,:,0,0], v_xx[:,:,0,0], v_yy[:,:,0,0], p_xx[:,:,0,0] , p_yy[:,:,0,0]

        # obtain BC indices
        bc  = (x == x_l) | (x == x_u) | (y == y_l) | (y == y_u)
        nbc = (~bc)

        # compute PDE residual : N-S equations
        # continuity = u_x + v_y
        # momentum_1 = u*u_x + v*u_y + p_x - 1.0/Re*(u_xx + u_yy)
        # momentum_2 = u*v_x + v*v_y + p_y - 1.0/Re*(v_xx + v_yy)
        residuals_continuity = u_x + v_y
        residuals_momentum_1 = u*u_x + v*u_y + p_x - 1.0/Re*(u_xx + u_yy)
        residuals_momentum_2 = u*v_x + v*v_y + p_y - 1.0/Re*(v_xx + v_yy)

        mom1 = -1.0/Re*(u_xx + u_yy)
        mom2 = -1.0/Re*(v_xx + v_yy)

        outputs = jnp.hstack([u, v, p, residuals_continuity, residuals_momentum_1, residuals_momentum_2, bc, nbc, mom1, mom2])
        return outputs


class DNN(nn.Module):
    """DNNs"""
    n_nodes:int
    def setup(self):
        # initialization
        kinit = jax.nn.initializers.he_uniform()
        # feature mapping later
        self.feats = nn.Dense(self.n_nodes * 4, kernel_init = kinit)
        # hidden layers
        self.layers = [nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu]
        # split layers
        self.splitu = nn.Dense(self.n_nodes, kernel_init = kinit)
        self.layeru = [nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu,
                       nn.Dense(1, kernel_init = kinit, use_bias=False)]
        self.splitv = nn.Dense(self.n_nodes, kernel_init = kinit)
        self.layerv = [nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu,
                       nn.Dense(1, kernel_init = kinit, use_bias=False)]
        self.splitp = nn.Dense(self.n_nodes, kernel_init = kinit)
        self.layerp = [nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = kinit),
                       nn.silu,
                       nn.Dense(1, kernel_init = kinit, use_bias=False)]

    @nn.compact
    def __call__(self, inputs):
        # split the two variables, probably just by slicing
        x, y = inputs[:,0:1], inputs[:,1:2]
        def get_uvp(x, y):
            inputs = jnp.hstack([x, y, x - 1., y - 1.])
            # feature mapping
            hidden = self.feats(inputs)
            hidden = jnp.sin(2*jnp.pi*hidden)
            # share hidden layer
            for i, lyr in enumerate(self.layers):
                hidden = lyr(hidden)
            # split hidden layer
            u = self.splitu(hidden)
            for i, lyr in enumerate(self.layeru):
                u = lyr(u)
            v = self.splitv(hidden)
            for i, lyr in enumerate(self.layerv):
                v = lyr(v)
            p = self.splitp(hidden)
            for i, lyr in enumerate(self.layerp):
                p = lyr(p)
            return (u, v, p)

        u, v, p = get_uvp(x, y)

       # obtain u_xx, u_yy, v_xx, v_yy, p_xx, p_yy
        def get_uvp_xxyy(get_uvp, x, y):
            u_xx, v_xx, _ = jacfwd(jacfwd(get_uvp))(x, y)
            u_yy, v_yy, _ = jacfwd(jacfwd(get_uvp, argnums=1), argnums=1)(x, y)
            return u_xx, u_yy, v_xx, v_yy

        get_uvp_xxyy_vmap = vmap(get_uvp_xxyy, in_axes=(None, 0, 0))
        u_xx, u_yy, v_xx, v_yy = get_uvp_xxyy_vmap(get_uvp, x, y)
        u_xx, u_yy, v_xx, v_yy = u_xx[:,:,0,0], u_yy[:,:,0,0], v_xx[:,:,0,0], v_yy[:,:,0,0]

        mom1 = -1.0/Re*(u_xx + u_yy)
        mom2 = -1.0/Re*(v_xx + v_yy)

        #shift p_ref
        x_pref, y_pref = jnp.ones_like(x)*x_ref, jnp.ones_like(y)*y_ref
        _, _, pref = get_uvp(x_pref, y_pref)
        pout = p - pref

        outputs = jnp.hstack([u, v, pout, mom1, mom2])
        return outputs

# %%
def main(ER, ER_xx, weight_bc, max_lr, exponent, max_iters, seed, gpu):

    global  Re, x_l, x_u, y_l, y_u, x_ref, y_ref, dx, dy

    Re = 3200
    
    sim = pd.read_csv('LDC_RE3200_100x100_subsample200x200.csv')
    data_X, data_Y = sim[['x', 'y']].values, sim[['u', 'v', 'p']].values
    
    # dx & dy
    dx = dy = 1 / (101-1)

    # exclude corner points
    x_l, x_u, y_l, y_u = np.min(data_X[:,0]), np.max(data_X[:,0]), np.min(data_X[:,1]), np.max(data_X[:,1])
    corners = (sim.x == x_l) & (sim.y == y_u) | (sim.x == x_u) & (sim.y == y_u) | (sim.x == x_l) & (sim.y == y_l) | (sim.x == x_u) & (sim.y == y_l)
    data_X, data_Y = data_X[~corners], data_Y[~corners]

    # pressure ref
    x_ref, y_ref = np.unique(sim.x), np.unique(sim.y)
    x_ref, y_ref = np.take(x_ref, x_ref.size //2), np.take(y_ref, y_ref.size //2)

    # split into BC data
    bc = (data_X[:,0] == x_l) | (data_X[:,0] == x_u) | (data_X[:,1] == y_l) | (data_X[:,1] == y_u)
    data_X_BC, data_Y_BC = data_X[bc], data_Y[bc]

    # convert to jnp
    data_X, data_Y, data_X_BC, data_Y_BC = jnp.array(data_X), jnp.array(data_Y), jnp.array(data_X_BC), jnp.array(data_Y_BC)

    
    # choose seed
    seed = seed
    key, rng = random.split(random.PRNGKey(seed))

    # dummy input
    a = random.normal(key, [1,2])

    # initialization call
    n_nodes = 32
    model, model_0 = PINN(n_nodes), DNN(n_nodes)
    params = model.init(key, a)
    num_params, format_params_fn = get_params_format_fn(params)

    # flatten initial params
    params = jax.flatten_util.ravel_pytree(params)[0]

    # update u_0
    params_0 = params

    # minibatch (set #sample)
    BS_ALL = 400
    BS_BC = 50

    n_all, n_bc = len(data_X), len(data_X_BC)

    @jit
    def minibatch(key):
        key1, key2 = key
        batch_all = random.choice(key1, n_all, (BS_ALL - BS_BC,))
        batch_bc = random.choice(key2, n_bc, (BS_BC,))
        batch_X = jnp.vstack([data_X[batch_all], data_X_BC[batch_bc]])
        batch_Y = jnp.vstack([data_Y[batch_all], data_Y_BC[batch_bc]])
        return (batch_X, batch_Y)

    # loss function
    def eval_loss(params, params_0, inputs, labels):
        pred = model.apply(format_params_fn(params), inputs)
        u, v, p, residuals_continuity, residuals_momentum_1, residuals_momentum_2, bc, nbc, m_1, m_2 = jnp.split(pred, 10, axis=1)
        gt_u, gt_v, gt_p = jnp.split(labels, 3, axis=1)
        # PDE loss unadjusted
        pde_uvp_uadj  = jnp.square(residuals_continuity) + jnp.square(residuals_momentum_1) + jnp.square(residuals_momentum_2)
        pde_loss_uadj = jnp.sum(pde_uvp_uadj *nbc) / nbc.sum()
        # stable evolution
        pred0 = model_0.apply(format_params_fn(params_0), inputs)
        u_0, v_0, p_0, m0_1, m0_2 = jnp.split(pred0, 5, axis=1)
        # PDE
        if (ER > 0):
            residuals_continuity = residuals_continuity + (p - p_0) / ER # ER @PDE
            residuals_momentum_1 = residuals_momentum_1 + (u - u_0) / ER + (m_1 - m0_1) / ER_xx # ER @PDE
            residuals_momentum_2 = residuals_momentum_2 + (v - v_0) / ER + (m_2 - m0_2) / ER_xx # ER @PDE
        pde_uvp  = jnp.square(residuals_continuity) + jnp.square(residuals_momentum_1) + jnp.square(residuals_momentum_2)
        pde_loss = jnp.sum(pde_uvp *nbc) / nbc.sum()
        # BC
        bc_loss = jnp.sum(jnp.square(u - gt_u) *bc) / bc.sum() + jnp.sum(jnp.square(v - gt_v) *bc) / bc.sum()
        # mse
        uv, gt_uv = jnp.hstack([u, v]), jnp.hstack([gt_u, gt_v])
        mse = jnp.mean(jnp.square(uv - gt_uv))
        rl2 = jnp.linalg.norm(uv - gt_uv) / jnp.linalg.norm(gt_uv)
        loss = pde_loss + weight_bc* bc_loss
        return loss, (mse, rl2, pde_loss, pde_loss_uadj)

    loss_grad = jax.jit(jax.value_and_grad(eval_loss, has_aux=True))

    @jit
    def eval_ghia(params, x_ref_ghia, y_ref_ghia, v_ref_ghia, u_ref_ghia):
        # prediction
        u_pinn_ghia = model_0.apply(format_params_fn(params), y_ref_ghia)[:,0]
        v_pinn_ghia = model_0.apply(format_params_fn(params), x_ref_ghia)[:,1]
        ghia_uv, pinn_uv = jnp.vstack([u_ref_ghia, v_ref_ghia]).T, jnp.vstack([u_pinn_ghia, v_pinn_ghia]).T
        ghia_mse = jnp.mean(jnp.square(ghia_uv - pinn_uv))
        ghia_rl2 = jnp.linalg.norm(ghia_uv - pinn_uv) / jnp.linalg.norm(ghia_uv)
        return ghia_mse, ghia_rl2, pinn_uv

    # weights update
    @jit
    def update(params, params_0, opt_state, key):
        batch_X, batch_Y = minibatch(key)
        (loss, (mse, rl2, pde_loss, pde_loss_uadj)), grad = loss_grad(params, params_0, batch_X, batch_Y)
        updates, opt_state = optimizer.update(grad, opt_state)
        params_0 = params # update u_0
        params = optax.apply_updates(params, updates)
        return params, params_0, opt_state, loss, mse, rl2, pde_loss, pde_loss_uadj

    # optimizer
    max_iters = max_iters
    max_lr = max_lr
    lr_scheduler = optax.warmup_cosine_decay_schedule(init_value=max_lr, peak_value=max_lr, warmup_steps=0,
                                                      decay_steps=max_iters, end_value=1e-10 ,exponent=exponent)
    optimizer = optax.adam(learning_rate=lr_scheduler) # Choose the method
    opt_state = optimizer.init(params)

    """Training"""

    # training iteration
    runtime = 0
    train_iters = 0

    # store = []
    # store_ghia = []
    # store_loss = []
    store_nnws = []
    store_nnws.append([0, format_params_fn(params)])
    
    # CFD @ Ghia cut lines
    u_ghia, v_ghia = pd.read_csv('LDC_512x512_y_u.dat',sep='\\s+'), pd.read_csv('LDC_512x512_x_v.dat',sep='\\s+')
    x_ghia, y_ghia = v_ghia.x.values, u_ghia.y.values
    x_ref_ghia, y_ref_ghia = jnp.vstack([x_ghia, jnp.ones_like(x_ghia) *0.5]).T, jnp.vstack([jnp.ones_like(y_ghia) *0.5, y_ghia]).T
    v_ref_ghia, u_ref_ghia = v_ghia.v.values, u_ghia.u.values  

    while (train_iters <= max_iters) and (runtime < 300):
        # mini-batch update
        start = time.time()
        key1, key2, rng = random.split(rng, 3) # update random generator
        params, params_0, opt_state, loss, mse, rl2, pde_loss, pde_loss_uadj = update(params, params_0, opt_state, (key1, key2))
        end = time.time()
        runtime += (end-start)
        # store_loss.append([train_iters, loss, mse, rl2, pde_loss, pde_loss_uadj])
        # append weights
        if (train_iters % 500 == 0):
            #print ('iter. = %05d,  time = %03ds,  loss = %.2e  |  mse = %.2e,  rl2 = %.2e'%(train_iters, runtime, loss, mse, rl2))
            #store.append([train_iters, runtime, loss, mse, rl2])
            ghia_mse, ghia_rl2, pinn_uv = eval_ghia(params, x_ref_ghia, y_ref_ghia, v_ref_ghia, u_ref_ghia)
            print ('iter. = %05d,  time = %03ds,  loss = %.2e  |  mse = %.2e,  rl2 = %.2e  |  Ghia mse = %.2e,  Ghia rl2 = %.2e'%(train_iters, runtime, 
                                                                                                                                  loss, mse, rl2,
                                                                                                                                  ghia_mse, ghia_rl2))
            # store.append([train_iters, runtime, loss, mse, rl2, ghia_mse, ghia_rl2])
            # store_ghia.append(pinn_uv)
            store_nnws.append([runtime, format_params_fn(params)])
        train_iters += 1

    # store, store_ghia, store_loss = jnp.array(store), np.array(store_ghia), np.array(store_loss)

    """PINN solution"""
    inputs, labels = data_X, data_Y
    prediction = model_0.apply(format_params_fn(params), inputs)
    u, v, _, _, _ = jnp.split(prediction, 5, axis=-1)
    gt_u, gt_v, gt_p = jnp.split(labels, 3, axis=-1)
    # prediction errors
    uv, gt_uv = jnp.hstack([u, v]), jnp.hstack([gt_u, gt_v])
    mse = jnp.mean(jnp.square(uv - gt_uv))
    rl2 = jnp.linalg.norm(uv - gt_uv) / jnp.linalg.norm(gt_uv)
    print ('[In-house] :  MSE = %.2e  RL2 = %.2e'%(mse, rl2))

    """prediction @ Ghia"""
    ghia_mse, ghia_rl2, _ = eval_ghia(params, x_ref_ghia, y_ref_ghia, v_ref_ghia, u_ref_ghia)
    print ('[Ghia]     :  MSE = %.2e  RL2 = %.2e'%(ghia_mse, ghia_rl2))

    # """prediction @ JAX-PI"""
    # from scipy import io
    # mat_data = io.loadmat('ldc_Re3200.mat')
    # xx, yy = mat_data['x'].reshape(-1,1), mat_data['y'].reshape(-1,1)
    # x_256, y_256 = jnp.meshgrid(xx[:,0], yy[:,0], indexing='ij')
    # u_256, v_256 = mat_data['u'], mat_data['v']
    # xy_256 = jnp.hstack([x_256.reshape(-1,1), y_256.reshape(-1,1)])
    # uv_256 = jnp.hstack([u_256.reshape(-1,1), v_256.reshape(-1,1)])
    # # prediction errors
    # uv_pinn = model_0.apply(format_params_fn(params), xy_256)[:,:2]
    # jaxpi_mse = jnp.mean(jnp.square(uv_256 - uv_pinn))
    # jaxpi_rl2 = jnp.linalg.norm(uv_256 - uv_pinn) / jnp.linalg.norm(uv_256)
    # print ('[JAX-PI]   :  MSE = %.2e  RL2 = %.2e'%(jaxpi_mse, jaxpi_rl2))
    
    return format_params_fn(params), store_nnws

# %%
# run main (ER)
params, store_nnws = main(ER=0.06, ER_xx=1, weight_bc=15,
                     max_lr=5e-4, exponent=0.8, max_iters=50000, seed=50, gpu=0)
# Out:
# 2025-10-08 23:09:55.531744: E external/xla/xla/service/hlo_lexer.cc:438] Failed to parse int literal: 894515288310727292233
# iter. = 00000,  time = 007s,  loss = 2.67e+01  |  mse = 1.32e-01,  rl2 = 1.55e+00  |  Ghia mse = 3.60e-01,  Ghia rl2 = 1.50e+00
# iter. = 00500,  time = 008s,  loss = 2.08e-01  |  mse = 3.06e-02,  rl2 = 6.87e-01  |  Ghia mse = 9.88e-02,  Ghia rl2 = 7.85e-01
# iter. = 01000,  time = 009s,  loss = 1.16e-01  |  mse = 3.67e-02,  rl2 = 8.42e-01  |  Ghia mse = 1.09e-01,  Ghia rl2 = 8.26e-01
# iter. = 01500,  time = 010s,  loss = 7.56e-02  |  mse = 3.13e-02,  rl2 = 7.68e-01  |  Ghia mse = 1.13e-01,  Ghia rl2 = 8.40e-01
# iter. = 02000,  time = 010s,  loss = 1.61e-02  |  mse = 3.24e-02,  rl2 = 7.85e-01  |  Ghia mse = 1.14e-01,  Ghia rl2 = 8.43e-01
# iter. = 02500,  time = 011s,  loss = 4.00e-02  |  mse = 3.27e-02,  rl2 = 7.02e-01  |  Ghia mse = 1.13e-01,  Ghia rl2 = 8.39e-01
# iter. = 03000,  time = 012s,  loss = 6.85e-02  |  mse = 3.33e-02,  rl2 = 7.17e-01  |  Ghia mse = 1.14e-01,  Ghia rl2 = 8.41e-01
# iter. = 03500,  time = 013s,  loss = 1.36e-01  |  mse = 3.13e-02,  rl2 = 7.54e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.45e-01
# iter. = 04000,  time = 014s,  loss = 3.78e-02  |  mse = 3.23e-02,  rl2 = 7.98e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.48e-01
# iter. = 04500,  time = 014s,  loss = 5.09e-02  |  mse = 3.00e-02,  rl2 = 7.64e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.45e-01
# iter. = 05000,  time = 015s,  loss = 2.27e-02  |  mse = 3.14e-02,  rl2 = 8.10e-01  |  Ghia mse = 1.11e-01,  Ghia rl2 = 8.31e-01
# iter. = 05500,  time = 016s,  loss = 2.44e-02  |  mse = 2.49e-02,  rl2 = 6.43e-01  |  Ghia mse = 9.28e-02,  Ghia rl2 = 7.61e-01
# iter. = 06000,  time = 017s,  loss = 1.85e-02  |  mse = 2.09e-02,  rl2 = 5.61e-01  |  Ghia mse = 7.89e-02,  Ghia rl2 = 7.01e-01
# iter. = 06500,  time = 018s,  loss = 6.37e-02  |  mse = 1.75e-02,  rl2 = 5.18e-01  |  Ghia mse = 6.82e-02,  Ghia rl2 = 6.52e-01
# iter. = 07000,  time = 018s,  loss = 1.71e-02  |  mse = 1.37e-02,  rl2 = 4.57e-01  |  Ghia mse = 5.61e-02,  Ghia rl2 = 5.91e-01
# iter. = 07500,  time = 019s,  loss = 2.06e-02  |  mse = 1.14e-02,  rl2 = 4.15e-01  |  Ghia mse = 4.40e-02,  Ghia rl2 = 5.24e-01
# iter. = 08000,  time = 020s,  loss = 9.57e-03  |  mse = 1.08e-02,  rl2 = 4.23e-01  |  Ghia mse = 4.11e-02,  Ghia rl2 = 5.06e-01
# iter. = 08500,  time = 021s,  loss = 9.32e-03  |  mse = 8.56e-03,  rl2 = 3.81e-01  |  Ghia mse = 3.30e-02,  Ghia rl2 = 4.54e-01
# iter. = 09000,  time = 022s,  loss = 9.37e-03  |  mse = 1.06e-02,  rl2 = 4.05e-01  |  Ghia mse = 3.80e-02,  Ghia rl2 = 4.87e-01
# iter. = 09500,  time = 022s,  loss = 1.37e-02  |  mse = 7.98e-03,  rl2 = 3.66e-01  |  Ghia mse = 2.71e-02,  Ghia rl2 = 4.11e-01
# iter. = 10000,  time = 023s,  loss = 1.55e-02  |  mse = 6.45e-03,  rl2 = 3.22e-01  |  Ghia mse = 2.42e-02,  Ghia rl2 = 3.88e-01
# iter. = 10500,  time = 024s,  loss = 3.44e-02  |  mse = 6.58e-03,  rl2 = 3.30e-01  |  Ghia mse = 1.89e-02,  Ghia rl2 = 3.44e-01
# iter. = 11000,  time = 025s,  loss = 3.05e-02  |  mse = 5.55e-03,  rl2 = 3.02e-01  |  Ghia mse = 1.75e-02,  Ghia rl2 = 3.30e-01
# iter. = 11500,  time = 026s,  loss = 1.95e-02  |  mse = 4.35e-03,  rl2 = 2.65e-01  |  Ghia mse = 1.27e-02,  Ghia rl2 = 2.81e-01
# iter. = 12000,  time = 026s,  loss = 5.36e-03  |  mse = 5.84e-03,  rl2 = 3.33e-01  |  Ghia mse = 2.06e-02,  Ghia rl2 = 3.58e-01
# iter. = 12500,  time = 027s,  loss = 1.03e-02  |  mse = 3.91e-03,  rl2 = 2.74e-01  |  Ghia mse = 1.12e-02,  Ghia rl2 = 2.65e-01
# iter. = 13000,  time = 028s,  loss = 7.94e-03  |  mse = 3.29e-03,  rl2 = 2.20e-01  |  Ghia mse = 1.02e-02,  Ghia rl2 = 2.53e-01
# iter. = 13500,  time = 029s,  loss = 1.32e-02  |  mse = 2.73e-03,  rl2 = 2.08e-01  |  Ghia mse = 8.57e-03,  Ghia rl2 = 2.31e-01
# iter. = 14000,  time = 029s,  loss = 3.38e-02  |  mse = 2.66e-03,  rl2 = 2.11e-01  |  Ghia mse = 8.27e-03,  Ghia rl2 = 2.27e-01
# iter. = 14500,  time = 030s,  loss = 2.16e-02  |  mse = 2.35e-03,  rl2 = 1.99e-01  |  Ghia mse = 7.46e-03,  Ghia rl2 = 2.16e-01
# iter. = 15000,  time = 031s,  loss = 1.03e-02  |  mse = 1.94e-03,  rl2 = 1.91e-01  |  Ghia mse = 6.03e-03,  Ghia rl2 = 1.94e-01
# iter. = 15500,  time = 032s,  loss = 8.43e-03  |  mse = 1.53e-03,  rl2 = 1.70e-01  |  Ghia mse = 4.80e-03,  Ghia rl2 = 1.73e-01
# iter. = 16000,  time = 033s,  loss = 6.63e-03  |  mse = 2.18e-03,  rl2 = 2.03e-01  |  Ghia mse = 7.82e-03,  Ghia rl2 = 2.21e-01
# iter. = 16500,  time = 033s,  loss = 7.55e-03  |  mse = 1.74e-03,  rl2 = 1.93e-01  |  Ghia mse = 6.41e-03,  Ghia rl2 = 2.00e-01
# iter. = 17000,  time = 034s,  loss = 7.10e-03  |  mse = 1.38e-03,  rl2 = 1.57e-01  |  Ghia mse = 4.77e-03,  Ghia rl2 = 1.72e-01
# iter. = 17500,  time = 035s,  loss = 1.59e-02  |  mse = 1.68e-03,  rl2 = 1.67e-01  |  Ghia mse = 6.00e-03,  Ghia rl2 = 1.93e-01
# iter. = 18000,  time = 036s,  loss = 2.95e-02  |  mse = 1.20e-03,  rl2 = 1.44e-01  |  Ghia mse = 3.74e-03,  Ghia rl2 = 1.53e-01
# iter. = 18500,  time = 037s,  loss = 8.40e-03  |  mse = 1.62e-03,  rl2 = 1.72e-01  |  Ghia mse = 5.26e-03,  Ghia rl2 = 1.81e-01
# iter. = 19000,  time = 037s,  loss = 1.42e-02  |  mse = 1.42e-03,  rl2 = 1.53e-01  |  Ghia mse = 4.92e-03,  Ghia rl2 = 1.75e-01
# iter. = 19500,  time = 038s,  loss = 1.50e-02  |  mse = 1.39e-03,  rl2 = 1.56e-01  |  Ghia mse = 3.91e-03,  Ghia rl2 = 1.56e-01
# iter. = 20000,  time = 039s,  loss = 9.46e-03  |  mse = 1.17e-03,  rl2 = 1.40e-01  |  Ghia mse = 4.28e-03,  Ghia rl2 = 1.63e-01
# iter. = 20500,  time = 040s,  loss = 1.06e-02  |  mse = 9.71e-04,  rl2 = 1.24e-01  |  Ghia mse = 3.78e-03,  Ghia rl2 = 1.54e-01
# iter. = 21000,  time = 041s,  loss = 2.22e-03  |  mse = 9.18e-04,  rl2 = 1.39e-01  |  Ghia mse = 3.40e-03,  Ghia rl2 = 1.46e-01
# iter. = 21500,  time = 041s,  loss = 1.63e-02  |  mse = 1.02e-03,  rl2 = 1.27e-01  |  Ghia mse = 3.48e-03,  Ghia rl2 = 1.47e-01
# iter. = 22000,  time = 042s,  loss = 5.35e-03  |  mse = 9.90e-04,  rl2 = 1.32e-01  |  Ghia mse = 3.55e-03,  Ghia rl2 = 1.49e-01
# iter. = 22500,  time = 043s,  loss = 1.59e-02  |  mse = 1.51e-03,  rl2 = 1.65e-01  |  Ghia mse = 5.16e-03,  Ghia rl2 = 1.79e-01
# iter. = 23000,  time = 044s,  loss = 3.75e-03  |  mse = 1.12e-03,  rl2 = 1.30e-01  |  Ghia mse = 3.30e-03,  Ghia rl2 = 1.43e-01
# iter. = 23500,  time = 045s,  loss = 3.86e-03  |  mse = 1.54e-03,  rl2 = 1.64e-01  |  Ghia mse = 5.93e-03,  Ghia rl2 = 1.92e-01
# iter. = 24000,  time = 045s,  loss = 1.89e-03  |  mse = 9.03e-04,  rl2 = 1.27e-01  |  Ghia mse = 2.95e-03,  Ghia rl2 = 1.36e-01
# iter. = 24500,  time = 046s,  loss = 1.25e-02  |  mse = 1.01e-03,  rl2 = 1.36e-01  |  Ghia mse = 3.44e-03,  Ghia rl2 = 1.46e-01
# iter. = 25000,  time = 047s,  loss = 4.49e-03  |  mse = 7.73e-04,  rl2 = 1.09e-01  |  Ghia mse = 2.60e-03,  Ghia rl2 = 1.27e-01
# iter. = 25500,  time = 048s,  loss = 4.07e-02  |  mse = 9.31e-04,  rl2 = 1.22e-01  |  Ghia mse = 2.78e-03,  Ghia rl2 = 1.32e-01
# iter. = 26000,  time = 048s,  loss = 3.70e-03  |  mse = 5.68e-04,  rl2 = 9.70e-02  |  Ghia mse = 1.86e-03,  Ghia rl2 = 1.08e-01
# iter. = 26500,  time = 049s,  loss = 1.37e-03  |  mse = 1.16e-03,  rl2 = 1.40e-01  |  Ghia mse = 4.86e-03,  Ghia rl2 = 1.74e-01
# iter. = 27000,  time = 050s,  loss = 9.97e-03  |  mse = 6.63e-04,  rl2 = 1.07e-01  |  Ghia mse = 1.93e-03,  Ghia rl2 = 1.10e-01
# iter. = 27500,  time = 051s,  loss = 1.63e-03  |  mse = 5.73e-04,  rl2 = 9.70e-02  |  Ghia mse = 1.72e-03,  Ghia rl2 = 1.04e-01
# iter. = 28000,  time = 052s,  loss = 4.37e-03  |  mse = 5.07e-04,  rl2 = 8.92e-02  |  Ghia mse = 1.98e-03,  Ghia rl2 = 1.11e-01
# iter. = 28500,  time = 052s,  loss = 1.11e-03  |  mse = 4.79e-04,  rl2 = 9.62e-02  |  Ghia mse = 1.85e-03,  Ghia rl2 = 1.07e-01
# iter. = 29000,  time = 053s,  loss = 4.67e-03  |  mse = 5.25e-04,  rl2 = 9.73e-02  |  Ghia mse = 2.01e-03,  Ghia rl2 = 1.12e-01
# iter. = 29500,  time = 054s,  loss = 4.51e-03  |  mse = 3.86e-04,  rl2 = 7.90e-02  |  Ghia mse = 1.38e-03,  Ghia rl2 = 9.27e-02
# iter. = 30000,  time = 055s,  loss = 1.88e-03  |  mse = 3.42e-04,  rl2 = 7.62e-02  |  Ghia mse = 9.69e-04,  Ghia rl2 = 7.77e-02
# iter. = 30500,  time = 056s,  loss = 2.09e-03  |  mse = 3.75e-04,  rl2 = 7.83e-02  |  Ghia mse = 1.37e-03,  Ghia rl2 = 9.25e-02
# iter. = 31000,  time = 056s,  loss = 5.30e-03  |  mse = 2.37e-04,  rl2 = 5.99e-02  |  Ghia mse = 7.50e-04,  Ghia rl2 = 6.84e-02
# iter. = 31500,  time = 057s,  loss = 8.17e-04  |  mse = 2.24e-04,  rl2 = 6.79e-02  |  Ghia mse = 9.00e-04,  Ghia rl2 = 7.49e-02
# iter. = 32000,  time = 058s,  loss = 1.39e-03  |  mse = 1.68e-04,  rl2 = 5.45e-02  |  Ghia mse = 5.77e-04,  Ghia rl2 = 6.00e-02
# iter. = 32500,  time = 059s,  loss = 3.46e-03  |  mse = 3.42e-04,  rl2 = 7.47e-02  |  Ghia mse = 1.39e-03,  Ghia rl2 = 9.30e-02
# iter. = 33000,  time = 060s,  loss = 2.38e-03  |  mse = 1.99e-04,  rl2 = 6.62e-02  |  Ghia mse = 7.54e-04,  Ghia rl2 = 6.85e-02
# iter. = 33500,  time = 060s,  loss = 1.51e-03  |  mse = 1.22e-04,  rl2 = 4.54e-02  |  Ghia mse = 3.95e-04,  Ghia rl2 = 4.96e-02
# iter. = 34000,  time = 061s,  loss = 3.58e-03  |  mse = 1.90e-04,  rl2 = 5.86e-02  |  Ghia mse = 7.30e-04,  Ghia rl2 = 6.75e-02
# iter. = 34500,  time = 062s,  loss = 2.02e-03  |  mse = 1.56e-04,  rl2 = 5.44e-02  |  Ghia mse = 5.82e-04,  Ghia rl2 = 6.02e-02
# iter. = 35000,  time = 063s,  loss = 1.90e-03  |  mse = 1.87e-04,  rl2 = 5.76e-02  |  Ghia mse = 6.90e-04,  Ghia rl2 = 6.56e-02
# iter. = 35500,  time = 064s,  loss = 1.07e-03  |  mse = 9.46e-05,  rl2 = 3.94e-02  |  Ghia mse = 3.30e-04,  Ghia rl2 = 4.54e-02
# iter. = 36000,  time = 064s,  loss = 1.63e-03  |  mse = 8.84e-05,  rl2 = 3.89e-02  |  Ghia mse = 3.21e-04,  Ghia rl2 = 4.47e-02
# iter. = 36500,  time = 065s,  loss = 1.10e-03  |  mse = 5.80e-05,  rl2 = 3.11e-02  |  Ghia mse = 2.33e-04,  Ghia rl2 = 3.81e-02
# iter. = 37000,  time = 066s,  loss = 9.20e-04  |  mse = 9.24e-05,  rl2 = 3.74e-02  |  Ghia mse = 3.83e-04,  Ghia rl2 = 4.89e-02
# iter. = 37500,  time = 067s,  loss = 2.14e-03  |  mse = 7.65e-05,  rl2 = 3.64e-02  |  Ghia mse = 2.98e-04,  Ghia rl2 = 4.31e-02
# iter. = 38000,  time = 068s,  loss = 1.96e-03  |  mse = 6.00e-05,  rl2 = 3.08e-02  |  Ghia mse = 2.59e-04,  Ghia rl2 = 4.02e-02
# iter. = 38500,  time = 068s,  loss = 7.10e-04  |  mse = 6.49e-05,  rl2 = 3.36e-02  |  Ghia mse = 3.03e-04,  Ghia rl2 = 4.34e-02
# iter. = 39000,  time = 069s,  loss = 1.03e-03  |  mse = 5.96e-05,  rl2 = 3.15e-02  |  Ghia mse = 2.21e-04,  Ghia rl2 = 3.71e-02
# iter. = 39500,  time = 070s,  loss = 2.20e-03  |  mse = 5.39e-05,  rl2 = 2.98e-02  |  Ghia mse = 2.30e-04,  Ghia rl2 = 3.79e-02
# iter. = 40000,  time = 071s,  loss = 9.20e-04  |  mse = 4.61e-05,  rl2 = 3.00e-02  |  Ghia mse = 2.05e-04,  Ghia rl2 = 3.58e-02
# iter. = 40500,  time = 072s,  loss = 5.19e-04  |  mse = 3.31e-05,  rl2 = 2.29e-02  |  Ghia mse = 1.60e-04,  Ghia rl2 = 3.16e-02
# iter. = 41000,  time = 072s,  loss = 1.70e-03  |  mse = 4.03e-05,  rl2 = 2.71e-02  |  Ghia mse = 1.76e-04,  Ghia rl2 = 3.32e-02
# iter. = 41500,  time = 073s,  loss = 4.19e-04  |  mse = 3.45e-05,  rl2 = 2.30e-02  |  Ghia mse = 1.58e-04,  Ghia rl2 = 3.14e-02
# iter. = 42000,  time = 074s,  loss = 8.84e-04  |  mse = 2.31e-05,  rl2 = 2.13e-02  |  Ghia mse = 1.07e-04,  Ghia rl2 = 2.58e-02
# iter. = 42500,  time = 075s,  loss = 3.26e-03  |  mse = 1.89e-05,  rl2 = 1.83e-02  |  Ghia mse = 8.26e-05,  Ghia rl2 = 2.27e-02
# iter. = 43000,  time = 075s,  loss = 5.61e-04  |  mse = 1.78e-05,  rl2 = 1.82e-02  |  Ghia mse = 9.35e-05,  Ghia rl2 = 2.41e-02
# iter. = 43500,  time = 076s,  loss = 6.91e-04  |  mse = 2.04e-05,  rl2 = 1.81e-02  |  Ghia mse = 9.42e-05,  Ghia rl2 = 2.42e-02
# iter. = 44000,  time = 077s,  loss = 3.77e-04  |  mse = 1.57e-05,  rl2 = 1.57e-02  |  Ghia mse = 8.19e-05,  Ghia rl2 = 2.26e-02
# iter. = 44500,  time = 078s,  loss = 2.76e-03  |  mse = 2.93e-05,  rl2 = 2.29e-02  |  Ghia mse = 1.08e-04,  Ghia rl2 = 2.60e-02
# iter. = 45000,  time = 079s,  loss = 4.01e-04  |  mse = 1.61e-05,  rl2 = 1.63e-02  |  Ghia mse = 8.95e-05,  Ghia rl2 = 2.36e-02
# iter. = 45500,  time = 079s,  loss = 3.87e-04  |  mse = 1.58e-05,  rl2 = 1.66e-02  |  Ghia mse = 7.85e-05,  Ghia rl2 = 2.21e-02
# iter. = 46000,  time = 080s,  loss = 3.84e-04  |  mse = 1.84e-05,  rl2 = 1.79e-02  |  Ghia mse = 7.94e-05,  Ghia rl2 = 2.23e-02
# iter. = 46500,  time = 081s,  loss = 4.31e-04  |  mse = 1.44e-05,  rl2 = 1.61e-02  |  Ghia mse = 7.81e-05,  Ghia rl2 = 2.21e-02
# iter. = 47000,  time = 082s,  loss = 3.27e-04  |  mse = 1.79e-05,  rl2 = 1.79e-02  |  Ghia mse = 7.72e-05,  Ghia rl2 = 2.19e-02
# iter. = 47500,  time = 083s,  loss = 6.04e-04  |  mse = 1.39e-05,  rl2 = 1.58e-02  |  Ghia mse = 7.08e-05,  Ghia rl2 = 2.10e-02
# iter. = 48000,  time = 083s,  loss = 3.23e-04  |  mse = 1.28e-05,  rl2 = 1.58e-02  |  Ghia mse = 6.72e-05,  Ghia rl2 = 2.05e-02
# iter. = 48500,  time = 084s,  loss = 2.73e-04  |  mse = 1.40e-05,  rl2 = 1.60e-02  |  Ghia mse = 7.19e-05,  Ghia rl2 = 2.12e-02
# iter. = 49000,  time = 085s,  loss = 3.61e-04  |  mse = 1.39e-05,  rl2 = 1.54e-02  |  Ghia mse = 7.03e-05,  Ghia rl2 = 2.09e-02
# iter. = 49500,  time = 086s,  loss = 3.33e-04  |  mse = 1.24e-05,  rl2 = 1.43e-02  |  Ghia mse = 6.60e-05,  Ghia rl2 = 2.03e-02
# iter. = 50000,  time = 087s,  loss = 2.98e-04  |  mse = 1.25e-05,  rl2 = 1.58e-02  |  Ghia mse = 6.62e-05,  Ghia rl2 = 2.03e-02
# [In-house] :  MSE = 1.49e-05  RL2 = 1.74e-02
# [Ghia]     :  MSE = 6.62e-05  RL2 = 2.03e-02

# %%
# 5 runs
params_5, store_nnws_5 = {}, {}
for seed in [90, 10, 70, 30, 50]:
    # run main (ER)
    params, store_nnws = main(ER=0.06, ER_xx=1, weight_bc=15,
                         max_lr=5e-4, exponent=0.8, max_iters=50000, seed=seed, gpu=0)    
    params_5[seed] = params
    store_nnws_5[seed] = store_nnws
# Out:
# iter. = 00000,  time = 006s,  loss = 5.41e+01  |  mse = 2.19e-01,  rl2 = 1.94e+00  |  Ghia mse = 2.21e-01,  Ghia rl2 = 1.17e+00
# iter. = 00500,  time = 007s,  loss = 1.02e-01  |  mse = 3.33e-02,  rl2 = 8.07e-01  |  Ghia mse = 1.09e-01,  Ghia rl2 = 8.25e-01
# iter. = 01000,  time = 007s,  loss = 4.71e-02  |  mse = 3.19e-02,  rl2 = 7.29e-01  |  Ghia mse = 1.10e-01,  Ghia rl2 = 8.28e-01
# iter. = 01500,  time = 008s,  loss = 2.61e-02  |  mse = 3.26e-02,  rl2 = 7.59e-01  |  Ghia mse = 1.13e-01,  Ghia rl2 = 8.38e-01
# iter. = 02000,  time = 009s,  loss = 1.89e-02  |  mse = 3.34e-02,  rl2 = 7.73e-01  |  Ghia mse = 1.14e-01,  Ghia rl2 = 8.44e-01
# iter. = 02500,  time = 010s,  loss = 7.52e-02  |  mse = 3.24e-02,  rl2 = 7.92e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.46e-01
# iter. = 03000,  time = 011s,  loss = 1.49e-01  |  mse = 3.58e-02,  rl2 = 7.47e-01  |  Ghia mse = 1.14e-01,  Ghia rl2 = 8.44e-01
# iter. = 03500,  time = 011s,  loss = 3.32e-02  |  mse = 3.44e-02,  rl2 = 7.28e-01  |  Ghia mse = 1.11e-01,  Ghia rl2 = 8.33e-01
# iter. = 04000,  time = 012s,  loss = 1.01e-01  |  mse = 3.05e-02,  rl2 = 7.26e-01  |  Ghia mse = 1.04e-01,  Ghia rl2 = 8.07e-01
# iter. = 04500,  time = 013s,  loss = 1.49e-02  |  mse = 2.70e-02,  rl2 = 6.84e-01  |  Ghia mse = 9.73e-02,  Ghia rl2 = 7.79e-01
# iter. = 05000,  time = 014s,  loss = 3.94e-02  |  mse = 2.66e-02,  rl2 = 6.29e-01  |  Ghia mse = 9.02e-02,  Ghia rl2 = 7.50e-01
# iter. = 05500,  time = 015s,  loss = 3.05e-02  |  mse = 2.11e-02,  rl2 = 6.27e-01  |  Ghia mse = 8.32e-02,  Ghia rl2 = 7.20e-01
# iter. = 06000,  time = 015s,  loss = 2.42e-02  |  mse = 2.08e-02,  rl2 = 6.11e-01  |  Ghia mse = 7.66e-02,  Ghia rl2 = 6.91e-01
# iter. = 06500,  time = 016s,  loss = 4.80e-02  |  mse = 1.81e-02,  rl2 = 5.30e-01  |  Ghia mse = 6.62e-02,  Ghia rl2 = 6.42e-01
# iter. = 07000,  time = 017s,  loss = 1.79e-02  |  mse = 1.48e-02,  rl2 = 4.97e-01  |  Ghia mse = 5.95e-02,  Ghia rl2 = 6.09e-01
# iter. = 07500,  time = 018s,  loss = 3.34e-02  |  mse = 1.68e-02,  rl2 = 5.47e-01  |  Ghia mse = 5.03e-02,  Ghia rl2 = 5.60e-01
# iter. = 08000,  time = 019s,  loss = 1.30e-02  |  mse = 1.48e-02,  rl2 = 4.86e-01  |  Ghia mse = 4.39e-02,  Ghia rl2 = 5.23e-01
# iter. = 08500,  time = 019s,  loss = 1.29e-02  |  mse = 1.20e-02,  rl2 = 5.07e-01  |  Ghia mse = 3.94e-02,  Ghia rl2 = 4.95e-01
# iter. = 09000,  time = 020s,  loss = 5.04e-02  |  mse = 1.08e-02,  rl2 = 4.37e-01  |  Ghia mse = 3.51e-02,  Ghia rl2 = 4.68e-01
# iter. = 09500,  time = 021s,  loss = 8.88e-03  |  mse = 9.80e-03,  rl2 = 3.97e-01  |  Ghia mse = 2.99e-02,  Ghia rl2 = 4.32e-01
# iter. = 10000,  time = 022s,  loss = 1.15e-02  |  mse = 8.40e-03,  rl2 = 3.73e-01  |  Ghia mse = 2.37e-02,  Ghia rl2 = 3.85e-01
# iter. = 10500,  time = 022s,  loss = 4.21e-02  |  mse = 6.93e-03,  rl2 = 3.37e-01  |  Ghia mse = 2.28e-02,  Ghia rl2 = 3.77e-01
# iter. = 11000,  time = 023s,  loss = 3.26e-02  |  mse = 6.96e-03,  rl2 = 3.60e-01  |  Ghia mse = 2.18e-02,  Ghia rl2 = 3.69e-01
# iter. = 11500,  time = 024s,  loss = 8.36e-03  |  mse = 8.01e-03,  rl2 = 3.34e-01  |  Ghia mse = 2.61e-02,  Ghia rl2 = 4.03e-01
# iter. = 12000,  time = 025s,  loss = 6.10e-03  |  mse = 6.48e-03,  rl2 = 3.44e-01  |  Ghia mse = 2.04e-02,  Ghia rl2 = 3.56e-01
# iter. = 12500,  time = 026s,  loss = 7.63e-03  |  mse = 6.52e-03,  rl2 = 3.24e-01  |  Ghia mse = 1.93e-02,  Ghia rl2 = 3.47e-01
# iter. = 13000,  time = 026s,  loss = 8.07e-03  |  mse = 4.75e-03,  rl2 = 3.11e-01  |  Ghia mse = 1.58e-02,  Ghia rl2 = 3.14e-01
# iter. = 13500,  time = 027s,  loss = 3.05e-02  |  mse = 3.82e-03,  rl2 = 2.61e-01  |  Ghia mse = 1.13e-02,  Ghia rl2 = 2.66e-01
# iter. = 14000,  time = 028s,  loss = 1.05e-02  |  mse = 3.89e-03,  rl2 = 2.54e-01  |  Ghia mse = 1.31e-02,  Ghia rl2 = 2.86e-01
# iter. = 14500,  time = 029s,  loss = 1.97e-02  |  mse = 5.30e-03,  rl2 = 3.14e-01  |  Ghia mse = 1.79e-02,  Ghia rl2 = 3.34e-01
# iter. = 15000,  time = 030s,  loss = 8.37e-03  |  mse = 4.38e-03,  rl2 = 2.75e-01  |  Ghia mse = 1.78e-02,  Ghia rl2 = 3.33e-01
# iter. = 15500,  time = 030s,  loss = 2.37e-02  |  mse = 3.45e-03,  rl2 = 2.35e-01  |  Ghia mse = 1.08e-02,  Ghia rl2 = 2.59e-01
# iter. = 16000,  time = 031s,  loss = 4.98e-03  |  mse = 3.66e-03,  rl2 = 2.48e-01  |  Ghia mse = 9.98e-03,  Ghia rl2 = 2.49e-01
# iter. = 16500,  time = 032s,  loss = 1.07e-02  |  mse = 4.76e-03,  rl2 = 3.06e-01  |  Ghia mse = 1.19e-02,  Ghia rl2 = 2.73e-01
# iter. = 17000,  time = 033s,  loss = 2.23e-02  |  mse = 6.95e-03,  rl2 = 3.53e-01  |  Ghia mse = 2.00e-02,  Ghia rl2 = 3.53e-01
# iter. = 17500,  time = 034s,  loss = 1.46e-02  |  mse = 5.09e-03,  rl2 = 2.88e-01  |  Ghia mse = 1.52e-02,  Ghia rl2 = 3.08e-01
# iter. = 18000,  time = 034s,  loss = 6.38e-03  |  mse = 3.02e-03,  rl2 = 2.18e-01  |  Ghia mse = 1.04e-02,  Ghia rl2 = 2.55e-01
# iter. = 18500,  time = 035s,  loss = 4.00e-03  |  mse = 2.16e-03,  rl2 = 1.90e-01  |  Ghia mse = 7.11e-03,  Ghia rl2 = 2.10e-01
# iter. = 19000,  time = 036s,  loss = 1.26e-02  |  mse = 1.90e-03,  rl2 = 1.83e-01  |  Ghia mse = 6.00e-03,  Ghia rl2 = 1.93e-01
# iter. = 19500,  time = 037s,  loss = 5.99e-03  |  mse = 1.87e-03,  rl2 = 1.79e-01  |  Ghia mse = 6.13e-03,  Ghia rl2 = 1.95e-01
# iter. = 20000,  time = 038s,  loss = 1.06e-02  |  mse = 1.74e-03,  rl2 = 1.68e-01  |  Ghia mse = 4.26e-03,  Ghia rl2 = 1.63e-01
# iter. = 20500,  time = 038s,  loss = 1.09e-02  |  mse = 2.31e-03,  rl2 = 1.84e-01  |  Ghia mse = 8.15e-03,  Ghia rl2 = 2.25e-01
# iter. = 21000,  time = 039s,  loss = 1.25e-02  |  mse = 1.89e-03,  rl2 = 1.85e-01  |  Ghia mse = 4.60e-03,  Ghia rl2 = 1.69e-01
# iter. = 21500,  time = 040s,  loss = 7.19e-03  |  mse = 1.76e-03,  rl2 = 1.74e-01  |  Ghia mse = 5.95e-03,  Ghia rl2 = 1.93e-01
# iter. = 22000,  time = 041s,  loss = 6.67e-03  |  mse = 1.53e-03,  rl2 = 1.59e-01  |  Ghia mse = 4.55e-03,  Ghia rl2 = 1.68e-01
# iter. = 22500,  time = 042s,  loss = 7.60e-03  |  mse = 1.20e-03,  rl2 = 1.40e-01  |  Ghia mse = 3.26e-03,  Ghia rl2 = 1.43e-01
# iter. = 23000,  time = 042s,  loss = 1.41e-02  |  mse = 1.48e-03,  rl2 = 1.62e-01  |  Ghia mse = 5.49e-03,  Ghia rl2 = 1.85e-01
# iter. = 23500,  time = 043s,  loss = 3.94e-03  |  mse = 1.30e-03,  rl2 = 1.30e-01  |  Ghia mse = 4.27e-03,  Ghia rl2 = 1.63e-01
# iter. = 24000,  time = 044s,  loss = 7.94e-03  |  mse = 8.86e-04,  rl2 = 1.26e-01  |  Ghia mse = 2.92e-03,  Ghia rl2 = 1.35e-01
# iter. = 24500,  time = 045s,  loss = 9.71e-03  |  mse = 9.16e-04,  rl2 = 1.23e-01  |  Ghia mse = 2.77e-03,  Ghia rl2 = 1.31e-01
# iter. = 25000,  time = 045s,  loss = 6.78e-03  |  mse = 6.98e-04,  rl2 = 1.12e-01  |  Ghia mse = 2.33e-03,  Ghia rl2 = 1.20e-01
# iter. = 25500,  time = 046s,  loss = 4.46e-03  |  mse = 9.75e-04,  rl2 = 1.29e-01  |  Ghia mse = 2.90e-03,  Ghia rl2 = 1.34e-01
# iter. = 26000,  time = 047s,  loss = 7.93e-03  |  mse = 9.55e-04,  rl2 = 1.31e-01  |  Ghia mse = 3.42e-03,  Ghia rl2 = 1.46e-01
# iter. = 26500,  time = 048s,  loss = 1.53e-02  |  mse = 1.10e-03,  rl2 = 1.36e-01  |  Ghia mse = 4.07e-03,  Ghia rl2 = 1.59e-01
# iter. = 27000,  time = 049s,  loss = 4.74e-03  |  mse = 6.50e-04,  rl2 = 1.07e-01  |  Ghia mse = 2.44e-03,  Ghia rl2 = 1.23e-01
# iter. = 27500,  time = 049s,  loss = 9.16e-03  |  mse = 6.13e-04,  rl2 = 1.04e-01  |  Ghia mse = 1.45e-03,  Ghia rl2 = 9.52e-02
# iter. = 28000,  time = 050s,  loss = 1.94e-03  |  mse = 6.76e-04,  rl2 = 1.07e-01  |  Ghia mse = 2.14e-03,  Ghia rl2 = 1.15e-01
# iter. = 28500,  time = 051s,  loss = 5.74e-03  |  mse = 5.17e-04,  rl2 = 9.05e-02  |  Ghia mse = 1.78e-03,  Ghia rl2 = 1.05e-01
# iter. = 29000,  time = 052s,  loss = 2.41e-03  |  mse = 5.82e-04,  rl2 = 1.04e-01  |  Ghia mse = 2.02e-03,  Ghia rl2 = 1.12e-01
# iter. = 29500,  time = 053s,  loss = 3.38e-03  |  mse = 4.94e-04,  rl2 = 8.50e-02  |  Ghia mse = 1.99e-03,  Ghia rl2 = 1.11e-01
# iter. = 30000,  time = 053s,  loss = 2.04e-03  |  mse = 5.89e-04,  rl2 = 9.84e-02  |  Ghia mse = 2.25e-03,  Ghia rl2 = 1.18e-01
# iter. = 30500,  time = 054s,  loss = 7.69e-03  |  mse = 5.66e-04,  rl2 = 8.96e-02  |  Ghia mse = 2.12e-03,  Ghia rl2 = 1.15e-01
# iter. = 31000,  time = 055s,  loss = 1.57e-03  |  mse = 3.84e-04,  rl2 = 7.68e-02  |  Ghia mse = 1.35e-03,  Ghia rl2 = 9.19e-02
# iter. = 31500,  time = 056s,  loss = 4.15e-03  |  mse = 4.71e-04,  rl2 = 9.18e-02  |  Ghia mse = 1.78e-03,  Ghia rl2 = 1.05e-01
# iter. = 32000,  time = 057s,  loss = 3.57e-03  |  mse = 3.30e-04,  rl2 = 7.74e-02  |  Ghia mse = 1.04e-03,  Ghia rl2 = 8.05e-02
# iter. = 32500,  time = 057s,  loss = 3.75e-03  |  mse = 4.30e-04,  rl2 = 9.04e-02  |  Ghia mse = 1.66e-03,  Ghia rl2 = 1.02e-01
# iter. = 33000,  time = 058s,  loss = 2.37e-03  |  mse = 3.48e-04,  rl2 = 7.88e-02  |  Ghia mse = 1.13e-03,  Ghia rl2 = 8.41e-02
# iter. = 33500,  time = 059s,  loss = 1.82e-03  |  mse = 2.22e-04,  rl2 = 6.18e-02  |  Ghia mse = 7.11e-04,  Ghia rl2 = 6.66e-02
# iter. = 34000,  time = 060s,  loss = 2.70e-03  |  mse = 2.38e-04,  rl2 = 6.81e-02  |  Ghia mse = 7.88e-04,  Ghia rl2 = 7.01e-02
# iter. = 34500,  time = 061s,  loss = 1.36e-03  |  mse = 2.30e-04,  rl2 = 6.21e-02  |  Ghia mse = 9.77e-04,  Ghia rl2 = 7.80e-02
# iter. = 35000,  time = 061s,  loss = 1.05e-03  |  mse = 1.35e-04,  rl2 = 4.73e-02  |  Ghia mse = 5.15e-04,  Ghia rl2 = 5.67e-02
# iter. = 35500,  time = 062s,  loss = 4.28e-03  |  mse = 1.76e-04,  rl2 = 5.64e-02  |  Ghia mse = 5.12e-04,  Ghia rl2 = 5.65e-02
# iter. = 36000,  time = 063s,  loss = 2.07e-03  |  mse = 1.38e-04,  rl2 = 4.91e-02  |  Ghia mse = 4.85e-04,  Ghia rl2 = 5.50e-02
# iter. = 36500,  time = 064s,  loss = 3.16e-03  |  mse = 1.37e-04,  rl2 = 4.76e-02  |  Ghia mse = 5.31e-04,  Ghia rl2 = 5.75e-02
# iter. = 37000,  time = 065s,  loss = 2.74e-03  |  mse = 1.42e-04,  rl2 = 4.79e-02  |  Ghia mse = 5.76e-04,  Ghia rl2 = 5.99e-02
# iter. = 37500,  time = 065s,  loss = 1.57e-03  |  mse = 1.13e-04,  rl2 = 4.23e-02  |  Ghia mse = 4.82e-04,  Ghia rl2 = 5.48e-02
# iter. = 38000,  time = 066s,  loss = 2.81e-03  |  mse = 1.04e-04,  rl2 = 4.14e-02  |  Ghia mse = 4.32e-04,  Ghia rl2 = 5.19e-02
# iter. = 38500,  time = 067s,  loss = 1.56e-03  |  mse = 9.55e-05,  rl2 = 3.95e-02  |  Ghia mse = 4.17e-04,  Ghia rl2 = 5.10e-02
# iter. = 39000,  time = 068s,  loss = 1.81e-03  |  mse = 8.08e-05,  rl2 = 3.73e-02  |  Ghia mse = 3.28e-04,  Ghia rl2 = 4.52e-02
# iter. = 39500,  time = 069s,  loss = 1.26e-03  |  mse = 1.35e-04,  rl2 = 4.98e-02  |  Ghia mse = 5.78e-04,  Ghia rl2 = 6.00e-02
# iter. = 40000,  time = 069s,  loss = 9.78e-04  |  mse = 1.15e-04,  rl2 = 4.44e-02  |  Ghia mse = 4.72e-04,  Ghia rl2 = 5.42e-02
# iter. = 40500,  time = 070s,  loss = 1.84e-03  |  mse = 9.75e-05,  rl2 = 4.26e-02  |  Ghia mse = 3.11e-04,  Ghia rl2 = 4.40e-02
# iter. = 41000,  time = 071s,  loss = 1.05e-03  |  mse = 9.04e-05,  rl2 = 3.68e-02  |  Ghia mse = 3.39e-04,  Ghia rl2 = 4.60e-02
# iter. = 41500,  time = 072s,  loss = 1.12e-03  |  mse = 6.72e-05,  rl2 = 3.21e-02  |  Ghia mse = 2.88e-04,  Ghia rl2 = 4.24e-02
# iter. = 42000,  time = 073s,  loss = 1.70e-03  |  mse = 6.47e-05,  rl2 = 3.51e-02  |  Ghia mse = 2.12e-04,  Ghia rl2 = 3.64e-02
# iter. = 42500,  time = 073s,  loss = 1.36e-03  |  mse = 5.32e-05,  rl2 = 3.05e-02  |  Ghia mse = 1.87e-04,  Ghia rl2 = 3.42e-02
# iter. = 43000,  time = 074s,  loss = 7.16e-04  |  mse = 4.84e-05,  rl2 = 2.88e-02  |  Ghia mse = 1.73e-04,  Ghia rl2 = 3.29e-02
# iter. = 43500,  time = 075s,  loss = 1.36e-03  |  mse = 3.87e-05,  rl2 = 2.64e-02  |  Ghia mse = 1.38e-04,  Ghia rl2 = 2.93e-02
# iter. = 44000,  time = 076s,  loss = 1.31e-03  |  mse = 3.89e-05,  rl2 = 2.54e-02  |  Ghia mse = 1.46e-04,  Ghia rl2 = 3.02e-02
# iter. = 44500,  time = 077s,  loss = 7.36e-04  |  mse = 3.68e-05,  rl2 = 2.43e-02  |  Ghia mse = 1.28e-04,  Ghia rl2 = 2.82e-02
# iter. = 45000,  time = 077s,  loss = 2.16e-03  |  mse = 4.90e-05,  rl2 = 3.09e-02  |  Ghia mse = 1.61e-04,  Ghia rl2 = 3.17e-02
# iter. = 45500,  time = 078s,  loss = 6.76e-04  |  mse = 3.02e-05,  rl2 = 2.33e-02  |  Ghia mse = 1.27e-04,  Ghia rl2 = 2.81e-02
# iter. = 46000,  time = 079s,  loss = 6.42e-04  |  mse = 3.29e-05,  rl2 = 2.25e-02  |  Ghia mse = 1.30e-04,  Ghia rl2 = 2.85e-02
# iter. = 46500,  time = 080s,  loss = 5.55e-04  |  mse = 3.05e-05,  rl2 = 2.17e-02  |  Ghia mse = 1.20e-04,  Ghia rl2 = 2.74e-02
# iter. = 47000,  time = 081s,  loss = 6.51e-04  |  mse = 2.72e-05,  rl2 = 2.05e-02  |  Ghia mse = 1.19e-04,  Ghia rl2 = 2.72e-02
# iter. = 47500,  time = 081s,  loss = 1.07e-03  |  mse = 3.11e-05,  rl2 = 2.49e-02  |  Ghia mse = 1.21e-04,  Ghia rl2 = 2.75e-02
# iter. = 48000,  time = 082s,  loss = 6.25e-04  |  mse = 3.07e-05,  rl2 = 2.27e-02  |  Ghia mse = 1.24e-04,  Ghia rl2 = 2.78e-02
# iter. = 48500,  time = 083s,  loss = 8.46e-04  |  mse = 2.86e-05,  rl2 = 2.24e-02  |  Ghia mse = 1.29e-04,  Ghia rl2 = 2.83e-02
# iter. = 49000,  time = 084s,  loss = 7.47e-04  |  mse = 2.96e-05,  rl2 = 2.12e-02  |  Ghia mse = 1.28e-04,  Ghia rl2 = 2.83e-02
# iter. = 49500,  time = 084s,  loss = 7.53e-04  |  mse = 2.90e-05,  rl2 = 2.27e-02  |  Ghia mse = 1.28e-04,  Ghia rl2 = 2.83e-02
# iter. = 50000,  time = 085s,  loss = 5.16e-04  |  mse = 2.55e-05,  rl2 = 2.20e-02  |  Ghia mse = 1.31e-04,  Ghia rl2 = 2.85e-02
# [In-house] :  MSE = 3.20e-05  RL2 = 2.54e-02
# [Ghia]     :  MSE = 1.31e-04  RL2 = 2.85e-02
# iter. = 00000,  time = 006s,  loss = 2.55e+01  |  mse = 1.39e-01,  rl2 = 1.57e+00  |  Ghia mse = 1.85e-01,  Ghia rl2 = 1.07e+00
# iter. = 00500,  time = 007s,  loss = 1.28e-01  |  mse = 3.28e-02,  rl2 = 7.17e-01  |  Ghia mse = 1.01e-01,  Ghia rl2 = 7.95e-01
# iter. = 01000,  time = 008s,  loss = 5.67e-02  |  mse = 2.98e-02,  rl2 = 6.95e-01  |  Ghia mse = 1.02e-01,  Ghia rl2 = 7.96e-01
# iter. = 01500,  time = 008s,  loss = 1.12e-01  |  mse = 2.94e-02,  rl2 = 7.42e-01  |  Ghia mse = 1.01e-01,  Ghia rl2 = 7.94e-01
# iter. = 02000,  time = 009s,  loss = 1.98e-02  |  mse = 2.97e-02,  rl2 = 7.79e-01  |  Ghia mse = 9.78e-02,  Ghia rl2 = 7.81e-01
# iter. = 02500,  time = 010s,  loss = 3.09e-02  |  mse = 2.75e-02,  rl2 = 6.92e-01  |  Ghia mse = 9.90e-02,  Ghia rl2 = 7.86e-01
# iter. = 03000,  time = 011s,  loss = 4.71e-02  |  mse = 2.75e-02,  rl2 = 6.97e-01  |  Ghia mse = 9.59e-02,  Ghia rl2 = 7.73e-01
# iter. = 03500,  time = 012s,  loss = 2.43e-02  |  mse = 2.49e-02,  rl2 = 6.33e-01  |  Ghia mse = 9.15e-02,  Ghia rl2 = 7.55e-01
# iter. = 04000,  time = 012s,  loss = 3.37e-02  |  mse = 2.28e-02,  rl2 = 5.87e-01  |  Ghia mse = 8.66e-02,  Ghia rl2 = 7.35e-01
# iter. = 04500,  time = 013s,  loss = 2.00e-02  |  mse = 1.91e-02,  rl2 = 5.70e-01  |  Ghia mse = 8.11e-02,  Ghia rl2 = 7.11e-01
# iter. = 05000,  time = 014s,  loss = 4.54e-02  |  mse = 1.80e-02,  rl2 = 5.52e-01  |  Ghia mse = 7.41e-02,  Ghia rl2 = 6.80e-01
# iter. = 05500,  time = 015s,  loss = 3.95e-02  |  mse = 1.59e-02,  rl2 = 4.98e-01  |  Ghia mse = 6.36e-02,  Ghia rl2 = 6.30e-01
# iter. = 06000,  time = 016s,  loss = 6.84e-02  |  mse = 1.53e-02,  rl2 = 4.91e-01  |  Ghia mse = 6.17e-02,  Ghia rl2 = 6.20e-01
# iter. = 06500,  time = 016s,  loss = 1.62e-02  |  mse = 1.33e-02,  rl2 = 4.84e-01  |  Ghia mse = 5.21e-02,  Ghia rl2 = 5.70e-01
# iter. = 07000,  time = 017s,  loss = 1.05e-01  |  mse = 1.49e-02,  rl2 = 5.03e-01  |  Ghia mse = 5.27e-02,  Ghia rl2 = 5.73e-01
# iter. = 07500,  time = 018s,  loss = 7.37e-02  |  mse = 1.18e-02,  rl2 = 4.32e-01  |  Ghia mse = 3.77e-02,  Ghia rl2 = 4.85e-01
# iter. = 08000,  time = 019s,  loss = 3.08e-02  |  mse = 1.29e-02,  rl2 = 4.78e-01  |  Ghia mse = 4.09e-02,  Ghia rl2 = 5.05e-01
# iter. = 08500,  time = 020s,  loss = 3.00e-02  |  mse = 1.17e-02,  rl2 = 4.25e-01  |  Ghia mse = 3.84e-02,  Ghia rl2 = 4.89e-01
# iter. = 09000,  time = 020s,  loss = 4.02e-02  |  mse = 1.11e-02,  rl2 = 4.43e-01  |  Ghia mse = 4.15e-02,  Ghia rl2 = 5.09e-01
# iter. = 09500,  time = 021s,  loss = 9.50e-03  |  mse = 9.08e-03,  rl2 = 3.88e-01  |  Ghia mse = 2.81e-02,  Ghia rl2 = 4.18e-01
# iter. = 10000,  time = 022s,  loss = 1.09e-02  |  mse = 1.12e-02,  rl2 = 4.25e-01  |  Ghia mse = 4.19e-02,  Ghia rl2 = 5.11e-01
# iter. = 10500,  time = 023s,  loss = 7.47e-03  |  mse = 8.85e-03,  rl2 = 4.11e-01  |  Ghia mse = 2.60e-02,  Ghia rl2 = 4.02e-01
# iter. = 11000,  time = 023s,  loss = 2.29e-02  |  mse = 7.69e-03,  rl2 = 3.73e-01  |  Ghia mse = 2.48e-02,  Ghia rl2 = 3.93e-01
# iter. = 11500,  time = 024s,  loss = 1.20e-02  |  mse = 5.93e-03,  rl2 = 2.92e-01  |  Ghia mse = 1.62e-02,  Ghia rl2 = 3.18e-01
# iter. = 12000,  time = 025s,  loss = 1.15e-02  |  mse = 7.24e-03,  rl2 = 3.40e-01  |  Ghia mse = 2.60e-02,  Ghia rl2 = 4.03e-01
# iter. = 12500,  time = 026s,  loss = 8.51e-03  |  mse = 5.87e-03,  rl2 = 3.20e-01  |  Ghia mse = 1.60e-02,  Ghia rl2 = 3.16e-01
# iter. = 13000,  time = 027s,  loss = 5.74e-03  |  mse = 4.92e-03,  rl2 = 2.76e-01  |  Ghia mse = 1.39e-02,  Ghia rl2 = 2.94e-01
# iter. = 13500,  time = 027s,  loss = 1.80e-02  |  mse = 4.70e-03,  rl2 = 2.92e-01  |  Ghia mse = 1.48e-02,  Ghia rl2 = 3.04e-01
# iter. = 14000,  time = 028s,  loss = 8.19e-03  |  mse = 3.99e-03,  rl2 = 2.58e-01  |  Ghia mse = 1.06e-02,  Ghia rl2 = 2.58e-01
# iter. = 14500,  time = 029s,  loss = 1.35e-02  |  mse = 4.23e-03,  rl2 = 2.66e-01  |  Ghia mse = 1.35e-02,  Ghia rl2 = 2.90e-01
# iter. = 15000,  time = 030s,  loss = 1.24e-02  |  mse = 3.54e-03,  rl2 = 2.43e-01  |  Ghia mse = 1.02e-02,  Ghia rl2 = 2.52e-01
# iter. = 15500,  time = 031s,  loss = 3.49e-02  |  mse = 3.81e-03,  rl2 = 2.59e-01  |  Ghia mse = 1.11e-02,  Ghia rl2 = 2.62e-01
# iter. = 16000,  time = 031s,  loss = 3.02e-03  |  mse = 3.87e-03,  rl2 = 2.58e-01  |  Ghia mse = 1.18e-02,  Ghia rl2 = 2.71e-01
# iter. = 16500,  time = 032s,  loss = 7.13e-02  |  mse = 3.18e-03,  rl2 = 2.50e-01  |  Ghia mse = 1.06e-02,  Ghia rl2 = 2.57e-01
# iter. = 17000,  time = 033s,  loss = 2.20e-02  |  mse = 3.23e-03,  rl2 = 2.16e-01  |  Ghia mse = 8.98e-03,  Ghia rl2 = 2.37e-01
# iter. = 17500,  time = 034s,  loss = 2.47e-02  |  mse = 2.45e-03,  rl2 = 1.97e-01  |  Ghia mse = 7.69e-03,  Ghia rl2 = 2.19e-01
# iter. = 18000,  time = 035s,  loss = 4.49e-03  |  mse = 2.18e-03,  rl2 = 1.89e-01  |  Ghia mse = 7.28e-03,  Ghia rl2 = 2.13e-01
# iter. = 18500,  time = 035s,  loss = 2.94e-02  |  mse = 6.06e-03,  rl2 = 3.15e-01  |  Ghia mse = 2.23e-02,  Ghia rl2 = 3.73e-01
# iter. = 19000,  time = 036s,  loss = 5.65e-03  |  mse = 3.52e-03,  rl2 = 2.26e-01  |  Ghia mse = 1.20e-02,  Ghia rl2 = 2.74e-01
# iter. = 19500,  time = 037s,  loss = 5.62e-03  |  mse = 2.71e-03,  rl2 = 2.10e-01  |  Ghia mse = 7.89e-03,  Ghia rl2 = 2.22e-01
# iter. = 20000,  time = 038s,  loss = 3.38e-02  |  mse = 2.54e-03,  rl2 = 1.95e-01  |  Ghia mse = 6.86e-03,  Ghia rl2 = 2.07e-01
# iter. = 20500,  time = 039s,  loss = 7.00e-03  |  mse = 2.32e-03,  rl2 = 1.96e-01  |  Ghia mse = 6.33e-03,  Ghia rl2 = 1.99e-01
# iter. = 21000,  time = 039s,  loss = 9.73e-03  |  mse = 2.43e-03,  rl2 = 2.15e-01  |  Ghia mse = 8.45e-03,  Ghia rl2 = 2.29e-01
# iter. = 21500,  time = 040s,  loss = 8.72e-03  |  mse = 1.88e-03,  rl2 = 1.69e-01  |  Ghia mse = 5.98e-03,  Ghia rl2 = 1.93e-01
# iter. = 22000,  time = 041s,  loss = 8.58e-03  |  mse = 1.82e-03,  rl2 = 1.91e-01  |  Ghia mse = 5.92e-03,  Ghia rl2 = 1.92e-01
# iter. = 22500,  time = 042s,  loss = 8.23e-03  |  mse = 1.99e-03,  rl2 = 1.81e-01  |  Ghia mse = 6.44e-03,  Ghia rl2 = 2.00e-01
# iter. = 23000,  time = 043s,  loss = 1.39e-02  |  mse = 1.90e-03,  rl2 = 1.80e-01  |  Ghia mse = 5.70e-03,  Ghia rl2 = 1.89e-01
# iter. = 23500,  time = 043s,  loss = 5.94e-03  |  mse = 1.38e-03,  rl2 = 1.53e-01  |  Ghia mse = 4.63e-03,  Ghia rl2 = 1.70e-01
# iter. = 24000,  time = 044s,  loss = 6.01e-03  |  mse = 1.64e-03,  rl2 = 1.63e-01  |  Ghia mse = 4.65e-03,  Ghia rl2 = 1.70e-01
# iter. = 24500,  time = 045s,  loss = 3.05e-03  |  mse = 1.61e-03,  rl2 = 1.73e-01  |  Ghia mse = 4.91e-03,  Ghia rl2 = 1.75e-01
# iter. = 25000,  time = 046s,  loss = 1.15e-02  |  mse = 1.63e-03,  rl2 = 1.65e-01  |  Ghia mse = 5.61e-03,  Ghia rl2 = 1.87e-01
# iter. = 25500,  time = 047s,  loss = 8.03e-03  |  mse = 1.55e-03,  rl2 = 1.72e-01  |  Ghia mse = 4.88e-03,  Ghia rl2 = 1.74e-01
# iter. = 26000,  time = 047s,  loss = 4.87e-03  |  mse = 1.66e-03,  rl2 = 1.53e-01  |  Ghia mse = 5.25e-03,  Ghia rl2 = 1.81e-01
# iter. = 26500,  time = 048s,  loss = 8.52e-03  |  mse = 1.37e-03,  rl2 = 1.61e-01  |  Ghia mse = 4.24e-03,  Ghia rl2 = 1.63e-01
# iter. = 27000,  time = 049s,  loss = 3.55e-03  |  mse = 1.03e-03,  rl2 = 1.29e-01  |  Ghia mse = 3.40e-03,  Ghia rl2 = 1.46e-01
# iter. = 27500,  time = 050s,  loss = 2.42e-03  |  mse = 7.64e-04,  rl2 = 1.12e-01  |  Ghia mse = 2.36e-03,  Ghia rl2 = 1.21e-01
# iter. = 28000,  time = 051s,  loss = 1.41e-02  |  mse = 1.06e-03,  rl2 = 1.29e-01  |  Ghia mse = 3.80e-03,  Ghia rl2 = 1.54e-01
# iter. = 28500,  time = 051s,  loss = 5.82e-03  |  mse = 8.02e-04,  rl2 = 1.21e-01  |  Ghia mse = 2.72e-03,  Ghia rl2 = 1.30e-01
# iter. = 29000,  time = 052s,  loss = 1.73e-03  |  mse = 7.01e-04,  rl2 = 1.10e-01  |  Ghia mse = 2.56e-03,  Ghia rl2 = 1.26e-01
# iter. = 29500,  time = 053s,  loss = 8.31e-03  |  mse = 5.36e-04,  rl2 = 1.00e-01  |  Ghia mse = 1.74e-03,  Ghia rl2 = 1.04e-01
# iter. = 30000,  time = 054s,  loss = 5.41e-03  |  mse = 7.57e-04,  rl2 = 1.13e-01  |  Ghia mse = 2.95e-03,  Ghia rl2 = 1.36e-01
# iter. = 30500,  time = 055s,  loss = 4.00e-03  |  mse = 7.32e-04,  rl2 = 1.19e-01  |  Ghia mse = 2.62e-03,  Ghia rl2 = 1.28e-01
# iter. = 31000,  time = 055s,  loss = 3.24e-02  |  mse = 6.97e-04,  rl2 = 1.05e-01  |  Ghia mse = 2.44e-03,  Ghia rl2 = 1.23e-01
# iter. = 31500,  time = 056s,  loss = 7.21e-03  |  mse = 5.91e-04,  rl2 = 1.08e-01  |  Ghia mse = 1.91e-03,  Ghia rl2 = 1.09e-01
# iter. = 32000,  time = 057s,  loss = 1.34e-03  |  mse = 5.32e-04,  rl2 = 9.33e-02  |  Ghia mse = 1.82e-03,  Ghia rl2 = 1.07e-01
# iter. = 32500,  time = 058s,  loss = 6.87e-03  |  mse = 6.41e-04,  rl2 = 1.12e-01  |  Ghia mse = 2.57e-03,  Ghia rl2 = 1.26e-01
# iter. = 33000,  time = 059s,  loss = 1.39e-03  |  mse = 4.25e-04,  rl2 = 8.44e-02  |  Ghia mse = 1.46e-03,  Ghia rl2 = 9.54e-02
# iter. = 33500,  time = 059s,  loss = 2.52e-02  |  mse = 4.64e-04,  rl2 = 9.12e-02  |  Ghia mse = 1.59e-03,  Ghia rl2 = 9.94e-02
# iter. = 34000,  time = 060s,  loss = 8.34e-03  |  mse = 4.53e-04,  rl2 = 9.23e-02  |  Ghia mse = 1.84e-03,  Ghia rl2 = 1.07e-01
# iter. = 34500,  time = 061s,  loss = 8.36e-03  |  mse = 4.02e-04,  rl2 = 8.11e-02  |  Ghia mse = 1.44e-03,  Ghia rl2 = 9.47e-02
# iter. = 35000,  time = 062s,  loss = 6.32e-03  |  mse = 4.09e-04,  rl2 = 8.12e-02  |  Ghia mse = 1.58e-03,  Ghia rl2 = 9.92e-02
# iter. = 35500,  time = 063s,  loss = 1.38e-03  |  mse = 3.77e-04,  rl2 = 8.02e-02  |  Ghia mse = 1.60e-03,  Ghia rl2 = 1.00e-01
# iter. = 36000,  time = 063s,  loss = 2.44e-03  |  mse = 3.13e-04,  rl2 = 7.13e-02  |  Ghia mse = 1.26e-03,  Ghia rl2 = 8.88e-02
# iter. = 36500,  time = 064s,  loss = 1.25e-03  |  mse = 2.46e-04,  rl2 = 6.33e-02  |  Ghia mse = 9.12e-04,  Ghia rl2 = 7.54e-02
# iter. = 37000,  time = 065s,  loss = 1.25e-02  |  mse = 2.72e-04,  rl2 = 7.20e-02  |  Ghia mse = 9.40e-04,  Ghia rl2 = 7.65e-02
# iter. = 37500,  time = 066s,  loss = 2.46e-03  |  mse = 2.11e-04,  rl2 = 5.47e-02  |  Ghia mse = 8.25e-04,  Ghia rl2 = 7.17e-02
# iter. = 38000,  time = 066s,  loss = 3.10e-03  |  mse = 2.41e-04,  rl2 = 6.78e-02  |  Ghia mse = 1.03e-03,  Ghia rl2 = 8.03e-02
# iter. = 38500,  time = 067s,  loss = 3.67e-03  |  mse = 2.30e-04,  rl2 = 5.87e-02  |  Ghia mse = 9.48e-04,  Ghia rl2 = 7.69e-02
# iter. = 39000,  time = 068s,  loss = 1.49e-03  |  mse = 2.37e-04,  rl2 = 6.17e-02  |  Ghia mse = 9.85e-04,  Ghia rl2 = 7.83e-02
# iter. = 39500,  time = 069s,  loss = 1.84e-03  |  mse = 2.23e-04,  rl2 = 6.21e-02  |  Ghia mse = 8.68e-04,  Ghia rl2 = 7.36e-02
# iter. = 40000,  time = 070s,  loss = 3.23e-03  |  mse = 2.14e-04,  rl2 = 6.00e-02  |  Ghia mse = 1.03e-03,  Ghia rl2 = 8.02e-02
# iter. = 40500,  time = 070s,  loss = 2.07e-03  |  mse = 2.02e-04,  rl2 = 5.82e-02  |  Ghia mse = 7.98e-04,  Ghia rl2 = 7.05e-02
# iter. = 41000,  time = 071s,  loss = 8.15e-04  |  mse = 1.70e-04,  rl2 = 4.97e-02  |  Ghia mse = 7.08e-04,  Ghia rl2 = 6.64e-02
# iter. = 41500,  time = 072s,  loss = 1.02e-03  |  mse = 1.88e-04,  rl2 = 5.75e-02  |  Ghia mse = 7.60e-04,  Ghia rl2 = 6.88e-02
# iter. = 42000,  time = 073s,  loss = 1.20e-03  |  mse = 1.95e-04,  rl2 = 5.56e-02  |  Ghia mse = 7.68e-04,  Ghia rl2 = 6.92e-02
# iter. = 42500,  time = 074s,  loss = 6.52e-04  |  mse = 1.81e-04,  rl2 = 5.14e-02  |  Ghia mse = 7.19e-04,  Ghia rl2 = 6.69e-02
# iter. = 43000,  time = 074s,  loss = 8.12e-04  |  mse = 1.79e-04,  rl2 = 5.17e-02  |  Ghia mse = 7.94e-04,  Ghia rl2 = 7.04e-02
# iter. = 43500,  time = 075s,  loss = 5.48e-04  |  mse = 1.79e-04,  rl2 = 5.48e-02  |  Ghia mse = 7.22e-04,  Ghia rl2 = 6.71e-02
# iter. = 44000,  time = 076s,  loss = 2.03e-03  |  mse = 1.79e-04,  rl2 = 5.79e-02  |  Ghia mse = 7.52e-04,  Ghia rl2 = 6.85e-02
# iter. = 44500,  time = 077s,  loss = 1.21e-03  |  mse = 1.57e-04,  rl2 = 5.37e-02  |  Ghia mse = 6.60e-04,  Ghia rl2 = 6.41e-02
# iter. = 45000,  time = 078s,  loss = 2.49e-03  |  mse = 1.85e-04,  rl2 = 5.69e-02  |  Ghia mse = 6.83e-04,  Ghia rl2 = 6.52e-02
# iter. = 45500,  time = 078s,  loss = 7.87e-04  |  mse = 1.73e-04,  rl2 = 5.83e-02  |  Ghia mse = 6.83e-04,  Ghia rl2 = 6.52e-02
# iter. = 46000,  time = 079s,  loss = 7.90e-04  |  mse = 1.76e-04,  rl2 = 5.59e-02  |  Ghia mse = 7.24e-04,  Ghia rl2 = 6.72e-02
# iter. = 46500,  time = 080s,  loss = 1.60e-03  |  mse = 1.71e-04,  rl2 = 5.39e-02  |  Ghia mse = 7.23e-04,  Ghia rl2 = 6.71e-02
# iter. = 47000,  time = 081s,  loss = 5.27e-04  |  mse = 1.78e-04,  rl2 = 5.34e-02  |  Ghia mse = 7.11e-04,  Ghia rl2 = 6.65e-02
# iter. = 47500,  time = 082s,  loss = 9.16e-04  |  mse = 1.75e-04,  rl2 = 5.54e-02  |  Ghia mse = 7.11e-04,  Ghia rl2 = 6.66e-02
# iter. = 48000,  time = 082s,  loss = 4.54e-04  |  mse = 1.75e-04,  rl2 = 5.77e-02  |  Ghia mse = 6.86e-04,  Ghia rl2 = 6.54e-02
# iter. = 48500,  time = 083s,  loss = 7.87e-04  |  mse = 1.75e-04,  rl2 = 5.27e-02  |  Ghia mse = 6.98e-04,  Ghia rl2 = 6.60e-02
# iter. = 49000,  time = 084s,  loss = 1.93e-03  |  mse = 1.60e-04,  rl2 = 5.50e-02  |  Ghia mse = 6.84e-04,  Ghia rl2 = 6.53e-02
# iter. = 49500,  time = 085s,  loss = 5.14e-04  |  mse = 1.59e-04,  rl2 = 4.83e-02  |  Ghia mse = 6.94e-04,  Ghia rl2 = 6.58e-02
# iter. = 50000,  time = 086s,  loss = 4.02e-04  |  mse = 1.74e-04,  rl2 = 5.77e-02  |  Ghia mse = 6.96e-04,  Ghia rl2 = 6.58e-02
# [In-house] :  MSE = 1.90e-04  RL2 = 6.20e-02
# [Ghia]     :  MSE = 6.96e-04  RL2 = 6.58e-02
# iter. = 00000,  time = 006s,  loss = 2.72e+02  |  mse = 7.88e-01,  rl2 = 3.55e+00  |  Ghia mse = 7.77e-01,  Ghia rl2 = 2.20e+00
# iter. = 00500,  time = 007s,  loss = 3.36e-01  |  mse = 3.25e-02,  rl2 = 7.12e-01  |  Ghia mse = 1.09e-01,  Ghia rl2 = 8.26e-01
# iter. = 01000,  time = 008s,  loss = 1.76e-01  |  mse = 3.39e-02,  rl2 = 7.68e-01  |  Ghia mse = 1.11e-01,  Ghia rl2 = 8.30e-01
# iter. = 01500,  time = 008s,  loss = 8.54e-02  |  mse = 3.52e-02,  rl2 = 7.55e-01  |  Ghia mse = 1.16e-01,  Ghia rl2 = 8.49e-01
# iter. = 02000,  time = 009s,  loss = 9.01e-02  |  mse = 3.50e-02,  rl2 = 7.80e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.58e-01
# iter. = 02500,  time = 010s,  loss = 9.23e-02  |  mse = 3.49e-02,  rl2 = 8.04e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.60e-01
# iter. = 03000,  time = 011s,  loss = 1.22e-01  |  mse = 3.50e-02,  rl2 = 7.66e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.61e-01
# iter. = 03500,  time = 012s,  loss = 2.00e-02  |  mse = 3.33e-02,  rl2 = 7.21e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.59e-01
# iter. = 04000,  time = 012s,  loss = 3.88e-02  |  mse = 3.54e-02,  rl2 = 7.47e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.61e-01
# iter. = 04500,  time = 013s,  loss = 1.85e-02  |  mse = 3.29e-02,  rl2 = 7.47e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# iter. = 05000,  time = 014s,  loss = 2.73e-02  |  mse = 3.30e-02,  rl2 = 7.57e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.53e-01
# iter. = 05500,  time = 015s,  loss = 1.53e-01  |  mse = 3.39e-02,  rl2 = 7.53e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# iter. = 06000,  time = 016s,  loss = 4.00e-02  |  mse = 3.41e-02,  rl2 = 7.42e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.59e-01
# iter. = 06500,  time = 016s,  loss = 2.80e-02  |  mse = 3.45e-02,  rl2 = 7.80e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.58e-01
# iter. = 07000,  time = 017s,  loss = 3.22e-02  |  mse = 3.30e-02,  rl2 = 7.53e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.57e-01
# iter. = 07500,  time = 018s,  loss = 4.95e-02  |  mse = 3.41e-02,  rl2 = 7.67e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.59e-01
# iter. = 08000,  time = 019s,  loss = 4.18e-02  |  mse = 3.51e-02,  rl2 = 8.05e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.61e-01
# iter. = 08500,  time = 020s,  loss = 1.60e-02  |  mse = 3.58e-02,  rl2 = 8.34e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.63e-01
# iter. = 09000,  time = 020s,  loss = 1.54e-02  |  mse = 3.53e-02,  rl2 = 7.56e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 09500,  time = 021s,  loss = 2.14e-02  |  mse = 3.39e-02,  rl2 = 8.05e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 10000,  time = 022s,  loss = 8.53e-02  |  mse = 3.58e-02,  rl2 = 7.48e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.76e-01
# iter. = 10500,  time = 023s,  loss = 2.68e-02  |  mse = 3.37e-02,  rl2 = 8.09e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.64e-01
# iter. = 11000,  time = 024s,  loss = 3.21e-02  |  mse = 2.29e-02,  rl2 = 6.56e-01  |  Ghia mse = 9.21e-02,  Ghia rl2 = 7.58e-01
# iter. = 11500,  time = 024s,  loss = 4.10e-02  |  mse = 1.93e-02,  rl2 = 5.67e-01  |  Ghia mse = 7.15e-02,  Ghia rl2 = 6.67e-01
# iter. = 12000,  time = 025s,  loss = 9.17e-02  |  mse = 1.85e-02,  rl2 = 5.67e-01  |  Ghia mse = 6.12e-02,  Ghia rl2 = 6.18e-01
# iter. = 12500,  time = 026s,  loss = 1.88e-02  |  mse = 1.33e-02,  rl2 = 4.90e-01  |  Ghia mse = 4.82e-02,  Ghia rl2 = 5.48e-01
# iter. = 13000,  time = 027s,  loss = 1.93e-02  |  mse = 9.90e-03,  rl2 = 4.07e-01  |  Ghia mse = 3.61e-02,  Ghia rl2 = 4.74e-01
# iter. = 13500,  time = 028s,  loss = 7.12e-03  |  mse = 8.69e-03,  rl2 = 3.96e-01  |  Ghia mse = 3.14e-02,  Ghia rl2 = 4.43e-01
# iter. = 14000,  time = 028s,  loss = 4.28e-02  |  mse = 8.78e-03,  rl2 = 3.69e-01  |  Ghia mse = 2.77e-02,  Ghia rl2 = 4.16e-01
# iter. = 14500,  time = 029s,  loss = 4.49e-02  |  mse = 8.07e-03,  rl2 = 3.46e-01  |  Ghia mse = 2.55e-02,  Ghia rl2 = 3.99e-01
# iter. = 15000,  time = 030s,  loss = 1.12e-02  |  mse = 7.69e-03,  rl2 = 3.64e-01  |  Ghia mse = 2.28e-02,  Ghia rl2 = 3.77e-01
# iter. = 15500,  time = 031s,  loss = 4.08e-02  |  mse = 7.53e-03,  rl2 = 3.53e-01  |  Ghia mse = 2.27e-02,  Ghia rl2 = 3.77e-01
# iter. = 16000,  time = 031s,  loss = 6.41e-03  |  mse = 6.21e-03,  rl2 = 3.63e-01  |  Ghia mse = 1.97e-02,  Ghia rl2 = 3.50e-01
# iter. = 16500,  time = 032s,  loss = 7.21e-03  |  mse = 8.77e-03,  rl2 = 3.69e-01  |  Ghia mse = 2.65e-02,  Ghia rl2 = 4.07e-01
# iter. = 17000,  time = 033s,  loss = 9.23e-03  |  mse = 7.06e-03,  rl2 = 3.40e-01  |  Ghia mse = 2.07e-02,  Ghia rl2 = 3.59e-01
# iter. = 17500,  time = 034s,  loss = 6.28e-03  |  mse = 5.88e-03,  rl2 = 3.24e-01  |  Ghia mse = 1.70e-02,  Ghia rl2 = 3.26e-01
# iter. = 18000,  time = 035s,  loss = 6.08e-03  |  mse = 6.37e-03,  rl2 = 3.55e-01  |  Ghia mse = 1.94e-02,  Ghia rl2 = 3.48e-01
# iter. = 18500,  time = 035s,  loss = 1.19e-02  |  mse = 5.55e-03,  rl2 = 2.93e-01  |  Ghia mse = 1.60e-02,  Ghia rl2 = 3.16e-01
# iter. = 19000,  time = 036s,  loss = 1.02e-02  |  mse = 5.42e-03,  rl2 = 3.02e-01  |  Ghia mse = 1.49e-02,  Ghia rl2 = 3.05e-01
# iter. = 19500,  time = 037s,  loss = 6.14e-03  |  mse = 4.76e-03,  rl2 = 2.74e-01  |  Ghia mse = 1.37e-02,  Ghia rl2 = 2.92e-01
# iter. = 20000,  time = 038s,  loss = 6.27e-03  |  mse = 4.32e-03,  rl2 = 2.67e-01  |  Ghia mse = 1.20e-02,  Ghia rl2 = 2.74e-01
# iter. = 20500,  time = 039s,  loss = 1.09e-02  |  mse = 4.04e-03,  rl2 = 2.48e-01  |  Ghia mse = 1.26e-02,  Ghia rl2 = 2.80e-01
# iter. = 21000,  time = 039s,  loss = 4.32e-03  |  mse = 4.64e-03,  rl2 = 2.81e-01  |  Ghia mse = 1.45e-02,  Ghia rl2 = 3.00e-01
# iter. = 21500,  time = 040s,  loss = 1.48e-02  |  mse = 4.25e-03,  rl2 = 2.61e-01  |  Ghia mse = 1.20e-02,  Ghia rl2 = 2.73e-01
# iter. = 22000,  time = 041s,  loss = 1.01e-02  |  mse = 4.15e-03,  rl2 = 2.46e-01  |  Ghia mse = 1.36e-02,  Ghia rl2 = 2.91e-01
# iter. = 22500,  time = 042s,  loss = 5.62e-03  |  mse = 3.35e-03,  rl2 = 2.24e-01  |  Ghia mse = 1.09e-02,  Ghia rl2 = 2.61e-01
# iter. = 23000,  time = 043s,  loss = 7.81e-03  |  mse = 3.21e-03,  rl2 = 2.33e-01  |  Ghia mse = 9.94e-03,  Ghia rl2 = 2.49e-01
# iter. = 23500,  time = 043s,  loss = 9.30e-03  |  mse = 2.71e-03,  rl2 = 2.18e-01  |  Ghia mse = 7.72e-03,  Ghia rl2 = 2.19e-01
# iter. = 24000,  time = 044s,  loss = 6.22e-03  |  mse = 2.64e-03,  rl2 = 2.14e-01  |  Ghia mse = 8.28e-03,  Ghia rl2 = 2.27e-01
# iter. = 24500,  time = 045s,  loss = 4.38e-03  |  mse = 2.68e-03,  rl2 = 2.18e-01  |  Ghia mse = 7.65e-03,  Ghia rl2 = 2.18e-01
# iter. = 25000,  time = 046s,  loss = 2.95e-03  |  mse = 2.15e-03,  rl2 = 1.82e-01  |  Ghia mse = 6.63e-03,  Ghia rl2 = 2.03e-01
# iter. = 25500,  time = 047s,  loss = 2.47e-02  |  mse = 2.42e-03,  rl2 = 2.09e-01  |  Ghia mse = 7.55e-03,  Ghia rl2 = 2.17e-01
# iter. = 26000,  time = 047s,  loss = 9.47e-03  |  mse = 1.65e-03,  rl2 = 1.68e-01  |  Ghia mse = 4.64e-03,  Ghia rl2 = 1.70e-01
# iter. = 26500,  time = 048s,  loss = 5.58e-03  |  mse = 1.87e-03,  rl2 = 1.80e-01  |  Ghia mse = 5.71e-03,  Ghia rl2 = 1.89e-01
# iter. = 27000,  time = 049s,  loss = 2.26e-03  |  mse = 1.62e-03,  rl2 = 1.63e-01  |  Ghia mse = 6.19e-03,  Ghia rl2 = 1.96e-01
# iter. = 27500,  time = 050s,  loss = 1.15e-02  |  mse = 1.70e-03,  rl2 = 1.70e-01  |  Ghia mse = 5.19e-03,  Ghia rl2 = 1.80e-01
# iter. = 28000,  time = 051s,  loss = 4.93e-03  |  mse = 1.04e-03,  rl2 = 1.28e-01  |  Ghia mse = 3.21e-03,  Ghia rl2 = 1.41e-01
# iter. = 28500,  time = 051s,  loss = 7.81e-03  |  mse = 1.53e-03,  rl2 = 1.69e-01  |  Ghia mse = 6.20e-03,  Ghia rl2 = 1.97e-01
# iter. = 29000,  time = 052s,  loss = 2.80e-03  |  mse = 1.26e-03,  rl2 = 1.53e-01  |  Ghia mse = 4.06e-03,  Ghia rl2 = 1.59e-01
# iter. = 29500,  time = 053s,  loss = 1.73e-02  |  mse = 1.10e-03,  rl2 = 1.40e-01  |  Ghia mse = 3.44e-03,  Ghia rl2 = 1.46e-01
# iter. = 30000,  time = 054s,  loss = 1.23e-02  |  mse = 9.06e-04,  rl2 = 1.27e-01  |  Ghia mse = 3.05e-03,  Ghia rl2 = 1.38e-01
# iter. = 30500,  time = 055s,  loss = 1.11e-02  |  mse = 1.01e-03,  rl2 = 1.33e-01  |  Ghia mse = 3.51e-03,  Ghia rl2 = 1.48e-01
# iter. = 31000,  time = 055s,  loss = 4.81e-03  |  mse = 9.43e-04,  rl2 = 1.26e-01  |  Ghia mse = 2.99e-03,  Ghia rl2 = 1.37e-01
# iter. = 31500,  time = 056s,  loss = 3.00e-03  |  mse = 9.23e-04,  rl2 = 1.22e-01  |  Ghia mse = 2.85e-03,  Ghia rl2 = 1.33e-01
# iter. = 32000,  time = 057s,  loss = 3.01e-03  |  mse = 6.13e-04,  rl2 = 1.05e-01  |  Ghia mse = 1.78e-03,  Ghia rl2 = 1.05e-01
# iter. = 32500,  time = 058s,  loss = 7.72e-03  |  mse = 7.36e-04,  rl2 = 1.20e-01  |  Ghia mse = 2.47e-03,  Ghia rl2 = 1.24e-01
# iter. = 33000,  time = 059s,  loss = 5.29e-03  |  mse = 5.72e-04,  rl2 = 9.93e-02  |  Ghia mse = 2.01e-03,  Ghia rl2 = 1.12e-01
# iter. = 33500,  time = 059s,  loss = 3.94e-03  |  mse = 6.02e-04,  rl2 = 9.78e-02  |  Ghia mse = 2.43e-03,  Ghia rl2 = 1.23e-01
# iter. = 34000,  time = 060s,  loss = 6.63e-03  |  mse = 4.30e-04,  rl2 = 8.67e-02  |  Ghia mse = 1.45e-03,  Ghia rl2 = 9.51e-02
# iter. = 34500,  time = 061s,  loss = 3.16e-03  |  mse = 5.71e-04,  rl2 = 9.67e-02  |  Ghia mse = 2.22e-03,  Ghia rl2 = 1.18e-01
# iter. = 35000,  time = 062s,  loss = 3.13e-03  |  mse = 4.21e-04,  rl2 = 8.26e-02  |  Ghia mse = 1.41e-03,  Ghia rl2 = 9.37e-02
# iter. = 35500,  time = 063s,  loss = 3.09e-03  |  mse = 3.25e-04,  rl2 = 7.45e-02  |  Ghia mse = 1.13e-03,  Ghia rl2 = 8.40e-02
# iter. = 36000,  time = 063s,  loss = 7.27e-03  |  mse = 3.27e-04,  rl2 = 7.03e-02  |  Ghia mse = 1.09e-03,  Ghia rl2 = 8.25e-02
# iter. = 36500,  time = 064s,  loss = 1.15e-02  |  mse = 3.34e-04,  rl2 = 7.10e-02  |  Ghia mse = 9.09e-04,  Ghia rl2 = 7.53e-02
# iter. = 37000,  time = 065s,  loss = 2.58e-03  |  mse = 2.68e-04,  rl2 = 6.97e-02  |  Ghia mse = 7.56e-04,  Ghia rl2 = 6.86e-02
# iter. = 37500,  time = 066s,  loss = 2.01e-03  |  mse = 2.14e-04,  rl2 = 5.64e-02  |  Ghia mse = 6.36e-04,  Ghia rl2 = 6.30e-02
# iter. = 38000,  time = 067s,  loss = 4.68e-03  |  mse = 2.29e-04,  rl2 = 6.29e-02  |  Ghia mse = 7.43e-04,  Ghia rl2 = 6.80e-02
# iter. = 38500,  time = 067s,  loss = 1.32e-03  |  mse = 1.64e-04,  rl2 = 5.52e-02  |  Ghia mse = 6.60e-04,  Ghia rl2 = 6.41e-02
# iter. = 39000,  time = 068s,  loss = 3.73e-03  |  mse = 1.41e-04,  rl2 = 5.07e-02  |  Ghia mse = 5.23e-04,  Ghia rl2 = 5.71e-02
# iter. = 39500,  time = 069s,  loss = 1.44e-03  |  mse = 8.64e-05,  rl2 = 3.99e-02  |  Ghia mse = 3.81e-04,  Ghia rl2 = 4.87e-02
# iter. = 40000,  time = 070s,  loss = 2.77e-03  |  mse = 7.77e-05,  rl2 = 3.83e-02  |  Ghia mse = 3.40e-04,  Ghia rl2 = 4.60e-02
# iter. = 40500,  time = 071s,  loss = 1.28e-03  |  mse = 5.73e-05,  rl2 = 3.17e-02  |  Ghia mse = 2.29e-04,  Ghia rl2 = 3.78e-02
# iter. = 41000,  time = 071s,  loss = 4.38e-03  |  mse = 7.45e-05,  rl2 = 3.63e-02  |  Ghia mse = 2.60e-04,  Ghia rl2 = 4.02e-02
# iter. = 41500,  time = 072s,  loss = 8.53e-04  |  mse = 5.21e-05,  rl2 = 2.77e-02  |  Ghia mse = 2.09e-04,  Ghia rl2 = 3.61e-02
# iter. = 42000,  time = 073s,  loss = 1.43e-03  |  mse = 3.70e-05,  rl2 = 2.44e-02  |  Ghia mse = 2.07e-04,  Ghia rl2 = 3.59e-02
# iter. = 42500,  time = 074s,  loss = 3.26e-03  |  mse = 7.91e-05,  rl2 = 3.52e-02  |  Ghia mse = 2.45e-04,  Ghia rl2 = 3.91e-02
# iter. = 43000,  time = 075s,  loss = 1.47e-03  |  mse = 4.51e-05,  rl2 = 2.72e-02  |  Ghia mse = 1.73e-04,  Ghia rl2 = 3.29e-02
# iter. = 43500,  time = 075s,  loss = 1.95e-03  |  mse = 3.58e-05,  rl2 = 2.64e-02  |  Ghia mse = 1.58e-04,  Ghia rl2 = 3.14e-02
# iter. = 44000,  time = 076s,  loss = 1.22e-03  |  mse = 3.47e-05,  rl2 = 2.56e-02  |  Ghia mse = 1.24e-04,  Ghia rl2 = 2.78e-02
# iter. = 44500,  time = 077s,  loss = 1.13e-03  |  mse = 3.31e-05,  rl2 = 2.25e-02  |  Ghia mse = 1.19e-04,  Ghia rl2 = 2.73e-02
# iter. = 45000,  time = 078s,  loss = 1.36e-03  |  mse = 4.55e-05,  rl2 = 3.07e-02  |  Ghia mse = 1.32e-04,  Ghia rl2 = 2.87e-02
# iter. = 45500,  time = 079s,  loss = 9.37e-04  |  mse = 2.22e-05,  rl2 = 1.78e-02  |  Ghia mse = 1.10e-04,  Ghia rl2 = 2.62e-02
# iter. = 46000,  time = 079s,  loss = 8.12e-04  |  mse = 2.33e-05,  rl2 = 2.02e-02  |  Ghia mse = 1.09e-04,  Ghia rl2 = 2.60e-02
# iter. = 46500,  time = 080s,  loss = 1.26e-03  |  mse = 2.25e-05,  rl2 = 1.87e-02  |  Ghia mse = 7.98e-05,  Ghia rl2 = 2.23e-02
# iter. = 47000,  time = 081s,  loss = 8.67e-04  |  mse = 2.37e-05,  rl2 = 1.94e-02  |  Ghia mse = 9.00e-05,  Ghia rl2 = 2.37e-02
# iter. = 47500,  time = 082s,  loss = 3.40e-03  |  mse = 4.75e-05,  rl2 = 2.90e-02  |  Ghia mse = 1.08e-04,  Ghia rl2 = 2.60e-02
# iter. = 48000,  time = 082s,  loss = 1.42e-03  |  mse = 2.30e-05,  rl2 = 2.05e-02  |  Ghia mse = 8.74e-05,  Ghia rl2 = 2.33e-02
# iter. = 48500,  time = 083s,  loss = 8.20e-04  |  mse = 2.45e-05,  rl2 = 2.00e-02  |  Ghia mse = 9.78e-05,  Ghia rl2 = 2.47e-02
# iter. = 49000,  time = 084s,  loss = 2.65e-03  |  mse = 4.33e-05,  rl2 = 2.83e-02  |  Ghia mse = 9.48e-05,  Ghia rl2 = 2.43e-02
# iter. = 49500,  time = 085s,  loss = 1.32e-03  |  mse = 3.90e-05,  rl2 = 2.69e-02  |  Ghia mse = 9.36e-05,  Ghia rl2 = 2.42e-02
# iter. = 50000,  time = 086s,  loss = 9.83e-04  |  mse = 3.00e-05,  rl2 = 2.36e-02  |  Ghia mse = 9.11e-05,  Ghia rl2 = 2.38e-02
# [In-house] :  MSE = 3.18e-05  RL2 = 2.54e-02
# [Ghia]     :  MSE = 9.11e-05  RL2 = 2.38e-02
# iter. = 00000,  time = 006s,  loss = 6.69e+01  |  mse = 1.14e-01,  rl2 = 1.44e+00  |  Ghia mse = 3.21e-01,  Ghia rl2 = 1.41e+00
# iter. = 00500,  time = 007s,  loss = 2.12e-01  |  mse = 3.10e-02,  rl2 = 7.83e-01  |  Ghia mse = 9.24e-02,  Ghia rl2 = 7.59e-01
# iter. = 01000,  time = 008s,  loss = 1.17e-01  |  mse = 3.32e-02,  rl2 = 7.74e-01  |  Ghia mse = 1.03e-01,  Ghia rl2 = 8.02e-01
# iter. = 01500,  time = 009s,  loss = 2.78e-02  |  mse = 3.08e-02,  rl2 = 7.31e-01  |  Ghia mse = 1.07e-01,  Ghia rl2 = 8.15e-01
# iter. = 02000,  time = 009s,  loss = 6.02e-02  |  mse = 2.91e-02,  rl2 = 6.69e-01  |  Ghia mse = 1.08e-01,  Ghia rl2 = 8.19e-01
# iter. = 02500,  time = 010s,  loss = 1.52e-02  |  mse = 3.23e-02,  rl2 = 7.20e-01  |  Ghia mse = 1.09e-01,  Ghia rl2 = 8.22e-01
# iter. = 03000,  time = 011s,  loss = 1.46e-01  |  mse = 3.06e-02,  rl2 = 7.24e-01  |  Ghia mse = 1.10e-01,  Ghia rl2 = 8.27e-01
# iter. = 03500,  time = 012s,  loss = 1.55e-02  |  mse = 2.92e-02,  rl2 = 6.86e-01  |  Ghia mse = 1.08e-01,  Ghia rl2 = 8.22e-01
# iter. = 04000,  time = 013s,  loss = 8.60e-02  |  mse = 2.98e-02,  rl2 = 6.94e-01  |  Ghia mse = 1.07e-01,  Ghia rl2 = 8.18e-01
# iter. = 04500,  time = 013s,  loss = 1.83e-02  |  mse = 2.79e-02,  rl2 = 7.51e-01  |  Ghia mse = 1.03e-01,  Ghia rl2 = 8.01e-01
# iter. = 05000,  time = 014s,  loss = 6.53e-02  |  mse = 2.51e-02,  rl2 = 6.71e-01  |  Ghia mse = 9.20e-02,  Ghia rl2 = 7.57e-01
# iter. = 05500,  time = 015s,  loss = 5.93e-02  |  mse = 2.37e-02,  rl2 = 6.43e-01  |  Ghia mse = 8.34e-02,  Ghia rl2 = 7.21e-01
# iter. = 06000,  time = 016s,  loss = 1.84e-02  |  mse = 2.00e-02,  rl2 = 6.05e-01  |  Ghia mse = 6.83e-02,  Ghia rl2 = 6.52e-01
# iter. = 06500,  time = 017s,  loss = 1.11e-01  |  mse = 1.69e-02,  rl2 = 5.51e-01  |  Ghia mse = 5.95e-02,  Ghia rl2 = 6.09e-01
# iter. = 07000,  time = 017s,  loss = 6.12e-02  |  mse = 1.34e-02,  rl2 = 4.74e-01  |  Ghia mse = 5.46e-02,  Ghia rl2 = 5.84e-01
# iter. = 07500,  time = 018s,  loss = 6.55e-03  |  mse = 1.17e-02,  rl2 = 4.41e-01  |  Ghia mse = 4.14e-02,  Ghia rl2 = 5.08e-01
# iter. = 08000,  time = 019s,  loss = 2.96e-02  |  mse = 1.15e-02,  rl2 = 4.42e-01  |  Ghia mse = 4.17e-02,  Ghia rl2 = 5.10e-01
# iter. = 08500,  time = 020s,  loss = 6.95e-02  |  mse = 1.05e-02,  rl2 = 4.63e-01  |  Ghia mse = 3.85e-02,  Ghia rl2 = 4.90e-01
# iter. = 09000,  time = 021s,  loss = 1.61e-02  |  mse = 9.19e-03,  rl2 = 3.91e-01  |  Ghia mse = 3.18e-02,  Ghia rl2 = 4.45e-01
# iter. = 09500,  time = 021s,  loss = 2.95e-02  |  mse = 9.38e-03,  rl2 = 4.21e-01  |  Ghia mse = 3.51e-02,  Ghia rl2 = 4.67e-01
# iter. = 10000,  time = 022s,  loss = 3.47e-02  |  mse = 8.42e-03,  rl2 = 3.94e-01  |  Ghia mse = 2.73e-02,  Ghia rl2 = 4.12e-01
# iter. = 10500,  time = 023s,  loss = 6.55e-03  |  mse = 8.05e-03,  rl2 = 3.55e-01  |  Ghia mse = 3.08e-02,  Ghia rl2 = 4.38e-01
# iter. = 11000,  time = 024s,  loss = 7.92e-03  |  mse = 6.09e-03,  rl2 = 3.45e-01  |  Ghia mse = 2.00e-02,  Ghia rl2 = 3.53e-01
# iter. = 11500,  time = 025s,  loss = 3.44e-02  |  mse = 5.94e-03,  rl2 = 3.22e-01  |  Ghia mse = 1.93e-02,  Ghia rl2 = 3.47e-01
# iter. = 12000,  time = 025s,  loss = 4.66e-03  |  mse = 4.96e-03,  rl2 = 2.89e-01  |  Ghia mse = 1.63e-02,  Ghia rl2 = 3.19e-01
# iter. = 12500,  time = 026s,  loss = 1.00e-02  |  mse = 5.24e-03,  rl2 = 3.05e-01  |  Ghia mse = 1.72e-02,  Ghia rl2 = 3.28e-01
# iter. = 13000,  time = 027s,  loss = 3.18e-02  |  mse = 4.26e-03,  rl2 = 2.85e-01  |  Ghia mse = 1.27e-02,  Ghia rl2 = 2.82e-01
# iter. = 13500,  time = 028s,  loss = 2.81e-02  |  mse = 5.28e-03,  rl2 = 2.94e-01  |  Ghia mse = 1.77e-02,  Ghia rl2 = 3.32e-01
# iter. = 14000,  time = 029s,  loss = 6.44e-03  |  mse = 3.71e-03,  rl2 = 2.57e-01  |  Ghia mse = 1.16e-02,  Ghia rl2 = 2.69e-01
# iter. = 14500,  time = 029s,  loss = 1.46e-02  |  mse = 3.63e-03,  rl2 = 2.32e-01  |  Ghia mse = 1.03e-02,  Ghia rl2 = 2.54e-01
# iter. = 15000,  time = 030s,  loss = 5.08e-03  |  mse = 4.12e-03,  rl2 = 2.57e-01  |  Ghia mse = 1.39e-02,  Ghia rl2 = 2.95e-01
# iter. = 15500,  time = 031s,  loss = 5.57e-02  |  mse = 3.70e-03,  rl2 = 2.43e-01  |  Ghia mse = 9.37e-03,  Ghia rl2 = 2.42e-01
# iter. = 16000,  time = 032s,  loss = 2.09e-02  |  mse = 3.14e-03,  rl2 = 2.37e-01  |  Ghia mse = 9.11e-03,  Ghia rl2 = 2.38e-01
# iter. = 16500,  time = 033s,  loss = 5.65e-03  |  mse = 3.13e-03,  rl2 = 2.19e-01  |  Ghia mse = 8.40e-03,  Ghia rl2 = 2.29e-01
# iter. = 17000,  time = 033s,  loss = 2.08e-02  |  mse = 3.47e-03,  rl2 = 2.47e-01  |  Ghia mse = 9.94e-03,  Ghia rl2 = 2.49e-01
# iter. = 17500,  time = 034s,  loss = 1.31e-02  |  mse = 2.68e-03,  rl2 = 2.13e-01  |  Ghia mse = 9.20e-03,  Ghia rl2 = 2.39e-01
# iter. = 18000,  time = 035s,  loss = 2.18e-02  |  mse = 3.08e-03,  rl2 = 2.33e-01  |  Ghia mse = 9.22e-03,  Ghia rl2 = 2.40e-01
# iter. = 18500,  time = 036s,  loss = 7.96e-03  |  mse = 2.66e-03,  rl2 = 2.02e-01  |  Ghia mse = 7.96e-03,  Ghia rl2 = 2.23e-01
# iter. = 19000,  time = 037s,  loss = 2.88e-02  |  mse = 3.24e-03,  rl2 = 2.37e-01  |  Ghia mse = 1.06e-02,  Ghia rl2 = 2.57e-01
# iter. = 19500,  time = 037s,  loss = 9.48e-03  |  mse = 2.43e-03,  rl2 = 1.93e-01  |  Ghia mse = 7.15e-03,  Ghia rl2 = 2.11e-01
# iter. = 20000,  time = 038s,  loss = 6.04e-03  |  mse = 2.14e-03,  rl2 = 1.81e-01  |  Ghia mse = 6.45e-03,  Ghia rl2 = 2.01e-01
# iter. = 20500,  time = 039s,  loss = 8.43e-03  |  mse = 2.05e-03,  rl2 = 1.79e-01  |  Ghia mse = 6.24e-03,  Ghia rl2 = 1.97e-01
# iter. = 21000,  time = 040s,  loss = 1.01e-02  |  mse = 2.03e-03,  rl2 = 1.93e-01  |  Ghia mse = 6.02e-03,  Ghia rl2 = 1.94e-01
# iter. = 21500,  time = 041s,  loss = 4.65e-03  |  mse = 1.78e-03,  rl2 = 1.74e-01  |  Ghia mse = 5.30e-03,  Ghia rl2 = 1.82e-01
# iter. = 22000,  time = 041s,  loss = 8.27e-03  |  mse = 1.94e-03,  rl2 = 1.84e-01  |  Ghia mse = 5.57e-03,  Ghia rl2 = 1.86e-01
# iter. = 22500,  time = 042s,  loss = 4.54e-03  |  mse = 1.32e-03,  rl2 = 1.66e-01  |  Ghia mse = 3.51e-03,  Ghia rl2 = 1.48e-01
# iter. = 23000,  time = 043s,  loss = 2.89e-03  |  mse = 1.26e-03,  rl2 = 1.49e-01  |  Ghia mse = 3.60e-03,  Ghia rl2 = 1.50e-01
# iter. = 23500,  time = 044s,  loss = 1.49e-02  |  mse = 1.40e-03,  rl2 = 1.39e-01  |  Ghia mse = 3.95e-03,  Ghia rl2 = 1.57e-01
# iter. = 24000,  time = 045s,  loss = 2.41e-03  |  mse = 1.07e-03,  rl2 = 1.48e-01  |  Ghia mse = 3.04e-03,  Ghia rl2 = 1.38e-01
# iter. = 24500,  time = 045s,  loss = 1.92e-02  |  mse = 1.18e-03,  rl2 = 1.36e-01  |  Ghia mse = 3.84e-03,  Ghia rl2 = 1.55e-01
# iter. = 25000,  time = 046s,  loss = 6.51e-03  |  mse = 1.14e-03,  rl2 = 1.35e-01  |  Ghia mse = 3.12e-03,  Ghia rl2 = 1.39e-01
# iter. = 25500,  time = 047s,  loss = 3.23e-03  |  mse = 1.06e-03,  rl2 = 1.37e-01  |  Ghia mse = 3.41e-03,  Ghia rl2 = 1.46e-01
# iter. = 26000,  time = 048s,  loss = 1.46e-02  |  mse = 1.03e-03,  rl2 = 1.28e-01  |  Ghia mse = 3.31e-03,  Ghia rl2 = 1.44e-01
# iter. = 26500,  time = 049s,  loss = 5.07e-03  |  mse = 1.15e-03,  rl2 = 1.34e-01  |  Ghia mse = 3.97e-03,  Ghia rl2 = 1.57e-01
# iter. = 27000,  time = 049s,  loss = 3.46e-03  |  mse = 8.54e-04,  rl2 = 1.04e-01  |  Ghia mse = 2.64e-03,  Ghia rl2 = 1.28e-01
# iter. = 27500,  time = 050s,  loss = 2.58e-03  |  mse = 8.04e-04,  rl2 = 1.09e-01  |  Ghia mse = 2.45e-03,  Ghia rl2 = 1.24e-01
# iter. = 28000,  time = 051s,  loss = 5.38e-03  |  mse = 6.52e-04,  rl2 = 9.71e-02  |  Ghia mse = 1.86e-03,  Ghia rl2 = 1.08e-01
# iter. = 28500,  time = 052s,  loss = 1.25e-03  |  mse = 6.78e-04,  rl2 = 1.04e-01  |  Ghia mse = 2.20e-03,  Ghia rl2 = 1.17e-01
# iter. = 29000,  time = 053s,  loss = 2.30e-03  |  mse = 5.19e-04,  rl2 = 9.94e-02  |  Ghia mse = 1.56e-03,  Ghia rl2 = 9.87e-02
# iter. = 29500,  time = 053s,  loss = 2.65e-03  |  mse = 5.79e-04,  rl2 = 1.07e-01  |  Ghia mse = 2.09e-03,  Ghia rl2 = 1.14e-01
# iter. = 30000,  time = 054s,  loss = 1.63e-03  |  mse = 6.28e-04,  rl2 = 1.03e-01  |  Ghia mse = 2.20e-03,  Ghia rl2 = 1.17e-01
# iter. = 30500,  time = 055s,  loss = 2.16e-02  |  mse = 7.90e-04,  rl2 = 1.16e-01  |  Ghia mse = 2.43e-03,  Ghia rl2 = 1.23e-01
# iter. = 31000,  time = 056s,  loss = 1.24e-03  |  mse = 5.95e-04,  rl2 = 1.03e-01  |  Ghia mse = 1.99e-03,  Ghia rl2 = 1.11e-01
# iter. = 31500,  time = 056s,  loss = 1.20e-02  |  mse = 6.53e-04,  rl2 = 1.00e-01  |  Ghia mse = 1.97e-03,  Ghia rl2 = 1.11e-01
# iter. = 32000,  time = 057s,  loss = 6.38e-03  |  mse = 6.44e-04,  rl2 = 1.14e-01  |  Ghia mse = 2.12e-03,  Ghia rl2 = 1.15e-01
# iter. = 32500,  time = 058s,  loss = 2.85e-03  |  mse = 4.46e-04,  rl2 = 8.40e-02  |  Ghia mse = 1.37e-03,  Ghia rl2 = 9.25e-02
# iter. = 33000,  time = 059s,  loss = 4.21e-03  |  mse = 4.07e-04,  rl2 = 8.98e-02  |  Ghia mse = 1.25e-03,  Ghia rl2 = 8.83e-02
# iter. = 33500,  time = 060s,  loss = 8.35e-03  |  mse = 9.01e-04,  rl2 = 1.24e-01  |  Ghia mse = 3.93e-03,  Ghia rl2 = 1.56e-01
# iter. = 34000,  time = 060s,  loss = 2.55e-03  |  mse = 5.29e-04,  rl2 = 9.39e-02  |  Ghia mse = 1.61e-03,  Ghia rl2 = 1.00e-01
# ...
# iter. = 39500,  time = 069s,  loss = 5.29e-03  |  mse = 2.26e-04,  rl2 = 6.04e-02  |  Ghia mse = 7.91e-04,  Ghia rl2 = 7.02e-02
# iter. = 40000,  time = 070s,  loss = 2.01e-03  |  mse = 2.21e-04,  rl2 = 6.17e-02  |  Ghia mse = 7.02e-04,  Ghia rl2 = 6.62e-02
# iter. = 40500,  time = 071s,  loss = 1.40e-03  |  mse = 2.25e-04,  rl2 = 5.69e-02  |  Ghia mse = 7.75e-04,  Ghia rl2 = 6.95e-02
# iter. = 41000,  time = 072s,  loss = 2.24e-03  |  mse = 1.89e-04,  rl2 = 5.90e-02  |  Ghia mse = 7.05e-04,  Ghia rl2 = 6.63e-02
# iter. = 41500,  time = 072s,  loss = 2.69e-03  |  mse = 2.11e-04,  rl2 = 6.05e-02  |  Ghia mse = 7.13e-04,  Ghia rl2 = 6.66e-02
# iter. = 42000,  time = 073s,  loss = 4.38e-03  |  mse = 1.86e-04,  rl2 = 5.78e-02  |  Ghia mse = 6.60e-04,  Ghia rl2 = 6.42e-02
# iter. = 42500,  time = 074s,  loss = 4.79e-04  |  mse = 1.75e-04,  rl2 = 5.26e-02  |  Ghia mse = 6.01e-04,  Ghia rl2 = 6.12e-02
# iter. = 43000,  time = 075s,  loss = 6.94e-04  |  mse = 1.53e-04,  rl2 = 5.05e-02  |  Ghia mse = 6.16e-04,  Ghia rl2 = 6.19e-02
# iter. = 43500,  time = 076s,  loss = 8.09e-04  |  mse = 1.80e-04,  rl2 = 5.85e-02  |  Ghia mse = 6.78e-04,  Ghia rl2 = 6.50e-02
# iter. = 44000,  time = 076s,  loss = 3.98e-04  |  mse = 1.72e-04,  rl2 = 5.65e-02  |  Ghia mse = 6.27e-04,  Ghia rl2 = 6.25e-02
# iter. = 44500,  time = 077s,  loss = 6.22e-04  |  mse = 1.69e-04,  rl2 = 5.58e-02  |  Ghia mse = 6.19e-04,  Ghia rl2 = 6.21e-02
# iter. = 45000,  time = 078s,  loss = 6.00e-04  |  mse = 1.66e-04,  rl2 = 5.09e-02  |  Ghia mse = 6.45e-04,  Ghia rl2 = 6.34e-02
# iter. = 45500,  time = 079s,  loss = 5.37e-04  |  mse = 1.71e-04,  rl2 = 5.43e-02  |  Ghia mse = 6.28e-04,  Ghia rl2 = 6.26e-02
# iter. = 46000,  time = 080s,  loss = 1.05e-03  |  mse = 1.88e-04,  rl2 = 5.32e-02  |  Ghia mse = 6.63e-04,  Ghia rl2 = 6.43e-02
# iter. = 46500,  time = 080s,  loss = 5.85e-04  |  mse = 1.59e-04,  rl2 = 5.37e-02  |  Ghia mse = 6.20e-04,  Ghia rl2 = 6.22e-02
# iter. = 47000,  time = 081s,  loss = 4.25e-04  |  mse = 1.69e-04,  rl2 = 5.61e-02  |  Ghia mse = 6.07e-04,  Ghia rl2 = 6.15e-02
# iter. = 47500,  time = 082s,  loss = 3.04e-04  |  mse = 1.53e-04,  rl2 = 4.99e-02  |  Ghia mse = 6.00e-04,  Ghia rl2 = 6.12e-02
# iter. = 48000,  time = 083s,  loss = 1.19e-03  |  mse = 1.75e-04,  rl2 = 5.42e-02  |  Ghia mse = 5.97e-04,  Ghia rl2 = 6.10e-02
# iter. = 48500,  time = 084s,  loss = 1.07e-03  |  mse = 1.56e-04,  rl2 = 5.29e-02  |  Ghia mse = 5.91e-04,  Ghia rl2 = 6.07e-02
# iter. = 49000,  time = 084s,  loss = 1.04e-03  |  mse = 1.67e-04,  rl2 = 5.16e-02  |  Ghia mse = 5.89e-04,  Ghia rl2 = 6.06e-02
# iter. = 49500,  time = 085s,  loss = 1.84e-03  |  mse = 1.57e-04,  rl2 = 5.21e-02  |  Ghia mse = 5.85e-04,  Ghia rl2 = 6.04e-02
# iter. = 50000,  time = 086s,  loss = 4.35e-04  |  mse = 1.57e-04,  rl2 = 5.42e-02  |  Ghia mse = 5.85e-04,  Ghia rl2 = 6.04e-02
# [In-house] :  MSE = 1.82e-04  RL2 = 6.06e-02
# [Ghia]     :  MSE = 5.85e-04  RL2 = 6.04e-02
# iter. = 00000,  time = 006s,  loss = 2.67e+01  |  mse = 1.32e-01,  rl2 = 1.55e+00  |  Ghia mse = 3.60e-01,  Ghia rl2 = 1.50e+00
# iter. = 00500,  time = 007s,  loss = 2.08e-01  |  mse = 3.06e-02,  rl2 = 6.87e-01  |  Ghia mse = 9.88e-02,  Ghia rl2 = 7.85e-01
# iter. = 01000,  time = 008s,  loss = 1.16e-01  |  mse = 3.67e-02,  rl2 = 8.42e-01  |  Ghia mse = 1.09e-01,  Ghia rl2 = 8.26e-01
# iter. = 01500,  time = 008s,  loss = 7.56e-02  |  mse = 3.13e-02,  rl2 = 7.68e-01  |  Ghia mse = 1.13e-01,  Ghia rl2 = 8.40e-01
# iter. = 02000,  time = 009s,  loss = 1.61e-02  |  mse = 3.24e-02,  rl2 = 7.85e-01  |  Ghia mse = 1.14e-01,  Ghia rl2 = 8.43e-01
# iter. = 02500,  time = 010s,  loss = 4.00e-02  |  mse = 3.27e-02,  rl2 = 7.02e-01  |  Ghia mse = 1.13e-01,  Ghia rl2 = 8.39e-01
# iter. = 03000,  time = 011s,  loss = 6.85e-02  |  mse = 3.33e-02,  rl2 = 7.17e-01  |  Ghia mse = 1.14e-01,  Ghia rl2 = 8.41e-01
# iter. = 03500,  time = 012s,  loss = 1.36e-01  |  mse = 3.13e-02,  rl2 = 7.54e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.45e-01
# iter. = 04000,  time = 012s,  loss = 3.78e-02  |  mse = 3.23e-02,  rl2 = 7.98e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.48e-01
# iter. = 04500,  time = 013s,  loss = 5.09e-02  |  mse = 3.00e-02,  rl2 = 7.64e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.45e-01
# iter. = 05000,  time = 014s,  loss = 2.27e-02  |  mse = 3.14e-02,  rl2 = 8.10e-01  |  Ghia mse = 1.11e-01,  Ghia rl2 = 8.31e-01
# iter. = 05500,  time = 015s,  loss = 2.44e-02  |  mse = 2.49e-02,  rl2 = 6.43e-01  |  Ghia mse = 9.28e-02,  Ghia rl2 = 7.61e-01
# iter. = 06000,  time = 016s,  loss = 1.85e-02  |  mse = 2.09e-02,  rl2 = 5.61e-01  |  Ghia mse = 7.89e-02,  Ghia rl2 = 7.01e-01
# iter. = 06500,  time = 016s,  loss = 6.37e-02  |  mse = 1.75e-02,  rl2 = 5.18e-01  |  Ghia mse = 6.82e-02,  Ghia rl2 = 6.52e-01
# iter. = 07000,  time = 017s,  loss = 1.71e-02  |  mse = 1.37e-02,  rl2 = 4.57e-01  |  Ghia mse = 5.61e-02,  Ghia rl2 = 5.91e-01
# iter. = 07500,  time = 018s,  loss = 2.06e-02  |  mse = 1.14e-02,  rl2 = 4.15e-01  |  Ghia mse = 4.40e-02,  Ghia rl2 = 5.24e-01
# iter. = 08000,  time = 019s,  loss = 9.57e-03  |  mse = 1.08e-02,  rl2 = 4.23e-01  |  Ghia mse = 4.11e-02,  Ghia rl2 = 5.06e-01
# iter. = 08500,  time = 020s,  loss = 9.32e-03  |  mse = 8.56e-03,  rl2 = 3.81e-01  |  Ghia mse = 3.30e-02,  Ghia rl2 = 4.54e-01
# iter. = 09000,  time = 020s,  loss = 9.37e-03  |  mse = 1.06e-02,  rl2 = 4.05e-01  |  Ghia mse = 3.80e-02,  Ghia rl2 = 4.87e-01
# iter. = 09500,  time = 021s,  loss = 1.37e-02  |  mse = 7.98e-03,  rl2 = 3.66e-01  |  Ghia mse = 2.71e-02,  Ghia rl2 = 4.11e-01
# iter. = 10000,  time = 022s,  loss = 1.55e-02  |  mse = 6.45e-03,  rl2 = 3.22e-01  |  Ghia mse = 2.42e-02,  Ghia rl2 = 3.88e-01
# iter. = 10500,  time = 023s,  loss = 3.44e-02  |  mse = 6.58e-03,  rl2 = 3.30e-01  |  Ghia mse = 1.89e-02,  Ghia rl2 = 3.44e-01
# iter. = 11000,  time = 024s,  loss = 3.05e-02  |  mse = 5.55e-03,  rl2 = 3.02e-01  |  Ghia mse = 1.75e-02,  Ghia rl2 = 3.30e-01
# iter. = 11500,  time = 024s,  loss = 1.95e-02  |  mse = 4.35e-03,  rl2 = 2.65e-01  |  Ghia mse = 1.27e-02,  Ghia rl2 = 2.81e-01
# iter. = 12000,  time = 025s,  loss = 5.36e-03  |  mse = 5.84e-03,  rl2 = 3.33e-01  |  Ghia mse = 2.06e-02,  Ghia rl2 = 3.58e-01
# iter. = 12500,  time = 026s,  loss = 1.03e-02  |  mse = 3.91e-03,  rl2 = 2.74e-01  |  Ghia mse = 1.12e-02,  Ghia rl2 = 2.65e-01
# iter. = 13000,  time = 027s,  loss = 7.94e-03  |  mse = 3.29e-03,  rl2 = 2.20e-01  |  Ghia mse = 1.02e-02,  Ghia rl2 = 2.53e-01
# iter. = 13500,  time = 028s,  loss = 1.32e-02  |  mse = 2.73e-03,  rl2 = 2.08e-01  |  Ghia mse = 8.57e-03,  Ghia rl2 = 2.31e-01
# iter. = 14000,  time = 028s,  loss = 3.38e-02  |  mse = 2.66e-03,  rl2 = 2.11e-01  |  Ghia mse = 8.27e-03,  Ghia rl2 = 2.27e-01
# iter. = 14500,  time = 029s,  loss = 2.16e-02  |  mse = 2.35e-03,  rl2 = 1.99e-01  |  Ghia mse = 7.46e-03,  Ghia rl2 = 2.16e-01
# iter. = 15000,  time = 030s,  loss = 1.03e-02  |  mse = 1.94e-03,  rl2 = 1.91e-01  |  Ghia mse = 6.03e-03,  Ghia rl2 = 1.94e-01
# iter. = 15500,  time = 031s,  loss = 8.43e-03  |  mse = 1.53e-03,  rl2 = 1.70e-01  |  Ghia mse = 4.80e-03,  Ghia rl2 = 1.73e-01
# iter. = 16000,  time = 032s,  loss = 6.63e-03  |  mse = 2.18e-03,  rl2 = 2.03e-01  |  Ghia mse = 7.82e-03,  Ghia rl2 = 2.21e-01
# iter. = 16500,  time = 032s,  loss = 7.55e-03  |  mse = 1.74e-03,  rl2 = 1.93e-01  |  Ghia mse = 6.41e-03,  Ghia rl2 = 2.00e-01
# iter. = 17000,  time = 033s,  loss = 7.10e-03  |  mse = 1.38e-03,  rl2 = 1.57e-01  |  Ghia mse = 4.77e-03,  Ghia rl2 = 1.72e-01
# iter. = 17500,  time = 034s,  loss = 1.59e-02  |  mse = 1.68e-03,  rl2 = 1.67e-01  |  Ghia mse = 6.00e-03,  Ghia rl2 = 1.93e-01
# iter. = 18000,  time = 035s,  loss = 2.95e-02  |  mse = 1.20e-03,  rl2 = 1.44e-01  |  Ghia mse = 3.74e-03,  Ghia rl2 = 1.53e-01
# iter. = 18500,  time = 036s,  loss = 8.40e-03  |  mse = 1.62e-03,  rl2 = 1.72e-01  |  Ghia mse = 5.26e-03,  Ghia rl2 = 1.81e-01
# iter. = 19000,  time = 036s,  loss = 1.42e-02  |  mse = 1.42e-03,  rl2 = 1.53e-01  |  Ghia mse = 4.92e-03,  Ghia rl2 = 1.75e-01
# iter. = 19500,  time = 037s,  loss = 1.50e-02  |  mse = 1.39e-03,  rl2 = 1.56e-01  |  Ghia mse = 3.91e-03,  Ghia rl2 = 1.56e-01
# iter. = 20000,  time = 038s,  loss = 9.46e-03  |  mse = 1.17e-03,  rl2 = 1.40e-01  |  Ghia mse = 4.28e-03,  Ghia rl2 = 1.63e-01
# iter. = 20500,  time = 039s,  loss = 1.06e-02  |  mse = 9.71e-04,  rl2 = 1.24e-01  |  Ghia mse = 3.78e-03,  Ghia rl2 = 1.54e-01
# iter. = 21000,  time = 040s,  loss = 2.22e-03  |  mse = 9.18e-04,  rl2 = 1.39e-01  |  Ghia mse = 3.40e-03,  Ghia rl2 = 1.46e-01
# iter. = 21500,  time = 040s,  loss = 1.63e-02  |  mse = 1.02e-03,  rl2 = 1.27e-01  |  Ghia mse = 3.48e-03,  Ghia rl2 = 1.47e-01
# iter. = 22000,  time = 041s,  loss = 5.35e-03  |  mse = 9.90e-04,  rl2 = 1.32e-01  |  Ghia mse = 3.55e-03,  Ghia rl2 = 1.49e-01
# iter. = 22500,  time = 042s,  loss = 1.59e-02  |  mse = 1.51e-03,  rl2 = 1.65e-01  |  Ghia mse = 5.16e-03,  Ghia rl2 = 1.79e-01
# iter. = 23000,  time = 043s,  loss = 3.75e-03  |  mse = 1.12e-03,  rl2 = 1.30e-01  |  Ghia mse = 3.30e-03,  Ghia rl2 = 1.43e-01
# iter. = 23500,  time = 044s,  loss = 3.86e-03  |  mse = 1.54e-03,  rl2 = 1.64e-01  |  Ghia mse = 5.93e-03,  Ghia rl2 = 1.92e-01
# iter. = 24000,  time = 044s,  loss = 1.89e-03  |  mse = 9.03e-04,  rl2 = 1.27e-01  |  Ghia mse = 2.95e-03,  Ghia rl2 = 1.36e-01
# iter. = 24500,  time = 045s,  loss = 1.25e-02  |  mse = 1.01e-03,  rl2 = 1.36e-01  |  Ghia mse = 3.44e-03,  Ghia rl2 = 1.46e-01
# iter. = 25000,  time = 046s,  loss = 4.49e-03  |  mse = 7.73e-04,  rl2 = 1.09e-01  |  Ghia mse = 2.60e-03,  Ghia rl2 = 1.27e-01
# iter. = 25500,  time = 047s,  loss = 4.07e-02  |  mse = 9.31e-04,  rl2 = 1.22e-01  |  Ghia mse = 2.78e-03,  Ghia rl2 = 1.32e-01
# iter. = 26000,  time = 048s,  loss = 3.70e-03  |  mse = 5.68e-04,  rl2 = 9.70e-02  |  Ghia mse = 1.86e-03,  Ghia rl2 = 1.08e-01
# iter. = 26500,  time = 048s,  loss = 1.37e-03  |  mse = 1.16e-03,  rl2 = 1.40e-01  |  Ghia mse = 4.86e-03,  Ghia rl2 = 1.74e-01
# iter. = 27000,  time = 049s,  loss = 9.97e-03  |  mse = 6.63e-04,  rl2 = 1.07e-01  |  Ghia mse = 1.93e-03,  Ghia rl2 = 1.10e-01
# iter. = 27500,  time = 050s,  loss = 1.63e-03  |  mse = 5.73e-04,  rl2 = 9.70e-02  |  Ghia mse = 1.72e-03,  Ghia rl2 = 1.04e-01
# iter. = 28000,  time = 051s,  loss = 4.37e-03  |  mse = 5.07e-04,  rl2 = 8.92e-02  |  Ghia mse = 1.98e-03,  Ghia rl2 = 1.11e-01
# iter. = 28500,  time = 052s,  loss = 1.11e-03  |  mse = 4.79e-04,  rl2 = 9.62e-02  |  Ghia mse = 1.85e-03,  Ghia rl2 = 1.07e-01
# iter. = 29000,  time = 052s,  loss = 4.67e-03  |  mse = 5.25e-04,  rl2 = 9.73e-02  |  Ghia mse = 2.01e-03,  Ghia rl2 = 1.12e-01
# iter. = 29500,  time = 053s,  loss = 4.51e-03  |  mse = 3.86e-04,  rl2 = 7.90e-02  |  Ghia mse = 1.38e-03,  Ghia rl2 = 9.27e-02
# iter. = 30000,  time = 054s,  loss = 1.88e-03  |  mse = 3.42e-04,  rl2 = 7.62e-02  |  Ghia mse = 9.69e-04,  Ghia rl2 = 7.77e-02
# iter. = 30500,  time = 055s,  loss = 2.09e-03  |  mse = 3.75e-04,  rl2 = 7.83e-02  |  Ghia mse = 1.37e-03,  Ghia rl2 = 9.25e-02
# iter. = 31000,  time = 056s,  loss = 5.30e-03  |  mse = 2.37e-04,  rl2 = 5.99e-02  |  Ghia mse = 7.50e-04,  Ghia rl2 = 6.84e-02
# iter. = 31500,  time = 056s,  loss = 8.17e-04  |  mse = 2.24e-04,  rl2 = 6.79e-02  |  Ghia mse = 9.00e-04,  Ghia rl2 = 7.49e-02
# iter. = 32000,  time = 057s,  loss = 1.39e-03  |  mse = 1.68e-04,  rl2 = 5.45e-02  |  Ghia mse = 5.77e-04,  Ghia rl2 = 6.00e-02
# iter. = 32500,  time = 058s,  loss = 3.46e-03  |  mse = 3.42e-04,  rl2 = 7.47e-02  |  Ghia mse = 1.39e-03,  Ghia rl2 = 9.30e-02
# iter. = 33000,  time = 059s,  loss = 2.38e-03  |  mse = 1.99e-04,  rl2 = 6.62e-02  |  Ghia mse = 7.54e-04,  Ghia rl2 = 6.85e-02
# iter. = 33500,  time = 060s,  loss = 1.51e-03  |  mse = 1.22e-04,  rl2 = 4.54e-02  |  Ghia mse = 3.95e-04,  Ghia rl2 = 4.96e-02
# iter. = 34000,  time = 060s,  loss = 3.58e-03  |  mse = 1.90e-04,  rl2 = 5.86e-02  |  Ghia mse = 7.30e-04,  Ghia rl2 = 6.75e-02
# iter. = 34500,  time = 061s,  loss = 2.02e-03  |  mse = 1.56e-04,  rl2 = 5.44e-02  |  Ghia mse = 5.82e-04,  Ghia rl2 = 6.02e-02
# iter. = 35000,  time = 062s,  loss = 1.90e-03  |  mse = 1.87e-04,  rl2 = 5.76e-02  |  Ghia mse = 6.90e-04,  Ghia rl2 = 6.56e-02
# iter. = 35500,  time = 063s,  loss = 1.07e-03  |  mse = 9.46e-05,  rl2 = 3.94e-02  |  Ghia mse = 3.30e-04,  Ghia rl2 = 4.54e-02
# iter. = 36000,  time = 064s,  loss = 1.63e-03  |  mse = 8.84e-05,  rl2 = 3.89e-02  |  Ghia mse = 3.21e-04,  Ghia rl2 = 4.47e-02
# iter. = 36500,  time = 064s,  loss = 1.10e-03  |  mse = 5.80e-05,  rl2 = 3.11e-02  |  Ghia mse = 2.33e-04,  Ghia rl2 = 3.81e-02
# iter. = 37000,  time = 065s,  loss = 9.20e-04  |  mse = 9.24e-05,  rl2 = 3.74e-02  |  Ghia mse = 3.83e-04,  Ghia rl2 = 4.89e-02
# iter. = 37500,  time = 066s,  loss = 2.14e-03  |  mse = 7.65e-05,  rl2 = 3.64e-02  |  Ghia mse = 2.98e-04,  Ghia rl2 = 4.31e-02
# iter. = 38000,  time = 067s,  loss = 1.96e-03  |  mse = 6.00e-05,  rl2 = 3.08e-02  |  Ghia mse = 2.59e-04,  Ghia rl2 = 4.02e-02
# iter. = 38500,  time = 067s,  loss = 7.10e-04  |  mse = 6.49e-05,  rl2 = 3.36e-02  |  Ghia mse = 3.03e-04,  Ghia rl2 = 4.34e-02
# iter. = 39000,  time = 068s,  loss = 1.03e-03  |  mse = 5.96e-05,  rl2 = 3.15e-02  |  Ghia mse = 2.21e-04,  Ghia rl2 = 3.71e-02
# iter. = 39500,  time = 069s,  loss = 2.20e-03  |  mse = 5.39e-05,  rl2 = 2.98e-02  |  Ghia mse = 2.30e-04,  Ghia rl2 = 3.79e-02
# iter. = 40000,  time = 070s,  loss = 9.20e-04  |  mse = 4.61e-05,  rl2 = 3.00e-02  |  Ghia mse = 2.05e-04,  Ghia rl2 = 3.58e-02
# iter. = 40500,  time = 071s,  loss = 5.19e-04  |  mse = 3.31e-05,  rl2 = 2.29e-02  |  Ghia mse = 1.60e-04,  Ghia rl2 = 3.16e-02
# iter. = 41000,  time = 071s,  loss = 1.70e-03  |  mse = 4.03e-05,  rl2 = 2.71e-02  |  Ghia mse = 1.76e-04,  Ghia rl2 = 3.32e-02
# iter. = 41500,  time = 072s,  loss = 4.19e-04  |  mse = 3.45e-05,  rl2 = 2.30e-02  |  Ghia mse = 1.58e-04,  Ghia rl2 = 3.14e-02
# iter. = 42000,  time = 073s,  loss = 8.84e-04  |  mse = 2.31e-05,  rl2 = 2.13e-02  |  Ghia mse = 1.07e-04,  Ghia rl2 = 2.58e-02
# iter. = 42500,  time = 074s,  loss = 3.26e-03  |  mse = 1.89e-05,  rl2 = 1.83e-02  |  Ghia mse = 8.26e-05,  Ghia rl2 = 2.27e-02
# iter. = 43000,  time = 075s,  loss = 5.61e-04  |  mse = 1.78e-05,  rl2 = 1.82e-02  |  Ghia mse = 9.35e-05,  Ghia rl2 = 2.41e-02
# iter. = 43500,  time = 075s,  loss = 6.91e-04  |  mse = 2.04e-05,  rl2 = 1.81e-02  |  Ghia mse = 9.42e-05,  Ghia rl2 = 2.42e-02
# iter. = 44000,  time = 076s,  loss = 3.77e-04  |  mse = 1.57e-05,  rl2 = 1.57e-02  |  Ghia mse = 8.19e-05,  Ghia rl2 = 2.26e-02
# iter. = 44500,  time = 077s,  loss = 2.76e-03  |  mse = 2.93e-05,  rl2 = 2.29e-02  |  Ghia mse = 1.08e-04,  Ghia rl2 = 2.60e-02
# iter. = 45000,  time = 078s,  loss = 4.01e-04  |  mse = 1.61e-05,  rl2 = 1.63e-02  |  Ghia mse = 8.95e-05,  Ghia rl2 = 2.36e-02
# iter. = 45500,  time = 079s,  loss = 3.87e-04  |  mse = 1.58e-05,  rl2 = 1.66e-02  |  Ghia mse = 7.85e-05,  Ghia rl2 = 2.21e-02
# iter. = 46000,  time = 079s,  loss = 3.84e-04  |  mse = 1.84e-05,  rl2 = 1.79e-02  |  Ghia mse = 7.94e-05,  Ghia rl2 = 2.23e-02
# iter. = 46500,  time = 080s,  loss = 4.31e-04  |  mse = 1.44e-05,  rl2 = 1.61e-02  |  Ghia mse = 7.81e-05,  Ghia rl2 = 2.21e-02
# iter. = 47000,  time = 081s,  loss = 3.27e-04  |  mse = 1.79e-05,  rl2 = 1.79e-02  |  Ghia mse = 7.72e-05,  Ghia rl2 = 2.19e-02
# iter. = 47500,  time = 082s,  loss = 6.04e-04  |  mse = 1.39e-05,  rl2 = 1.58e-02  |  Ghia mse = 7.08e-05,  Ghia rl2 = 2.10e-02
# iter. = 48000,  time = 083s,  loss = 3.23e-04  |  mse = 1.28e-05,  rl2 = 1.58e-02  |  Ghia mse = 6.72e-05,  Ghia rl2 = 2.05e-02
# iter. = 48500,  time = 083s,  loss = 2.73e-04  |  mse = 1.40e-05,  rl2 = 1.60e-02  |  Ghia mse = 7.19e-05,  Ghia rl2 = 2.12e-02
# iter. = 49000,  time = 084s,  loss = 3.61e-04  |  mse = 1.39e-05,  rl2 = 1.54e-02  |  Ghia mse = 7.03e-05,  Ghia rl2 = 2.09e-02
# iter. = 49500,  time = 085s,  loss = 3.33e-04  |  mse = 1.24e-05,  rl2 = 1.43e-02  |  Ghia mse = 6.60e-05,  Ghia rl2 = 2.03e-02
# iter. = 50000,  time = 086s,  loss = 2.98e-04  |  mse = 1.25e-05,  rl2 = 1.58e-02  |  Ghia mse = 6.62e-05,  Ghia rl2 = 2.03e-02
# [In-house] :  MSE = 1.49e-05  RL2 = 1.74e-02
# [Ghia]     :  MSE = 6.62e-05  RL2 = 2.03e-02

# %%
# 5 runs (ref)
ref_params_5, ref_store_nnws_5 = {}, {}
for seed in [90, 10, 70, 30, 50]:
    # run main (NER)
    params, store_nnws = main(ER=0, ER_xx=1, weight_bc=15,
                              max_lr=5e-4, exponent=0.8, max_iters=50000, seed=seed, gpu=0)    
    ref_params_5[seed] = params
    ref_store_nnws_5[seed] = store_nnws
# Out:
# iter. = 00000,  time = 007s,  loss = 5.30e+01  |  mse = 2.19e-01,  rl2 = 1.94e+00  |  Ghia mse = 2.21e-01,  Ghia rl2 = 1.17e+00
# iter. = 00500,  time = 008s,  loss = 5.48e-02  |  mse = 3.30e-02,  rl2 = 8.02e-01  |  Ghia mse = 1.09e-01,  Ghia rl2 = 8.24e-01
# iter. = 01000,  time = 008s,  loss = 3.25e-02  |  mse = 3.30e-02,  rl2 = 7.41e-01  |  Ghia mse = 1.07e-01,  Ghia rl2 = 8.15e-01
# iter. = 01500,  time = 009s,  loss = 3.15e-02  |  mse = 3.48e-02,  rl2 = 7.84e-01  |  Ghia mse = 1.09e-01,  Ghia rl2 = 8.23e-01
# iter. = 02000,  time = 010s,  loss = 1.32e-02  |  mse = 3.57e-02,  rl2 = 7.99e-01  |  Ghia mse = 1.11e-01,  Ghia rl2 = 8.32e-01
# iter. = 02500,  time = 011s,  loss = 3.38e-02  |  mse = 3.44e-02,  rl2 = 8.17e-01  |  Ghia mse = 1.14e-01,  Ghia rl2 = 8.42e-01
# iter. = 03000,  time = 011s,  loss = 1.14e-01  |  mse = 3.82e-02,  rl2 = 7.72e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.46e-01
# iter. = 03500,  time = 012s,  loss = 2.35e-02  |  mse = 3.78e-02,  rl2 = 7.64e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.47e-01
# iter. = 04000,  time = 013s,  loss = 6.77e-02  |  mse = 3.67e-02,  rl2 = 7.96e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.55e-01
# iter. = 04500,  time = 014s,  loss = 3.00e-02  |  mse = 3.58e-02,  rl2 = 7.88e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.54e-01
# iter. = 05000,  time = 014s,  loss = 1.46e-02  |  mse = 3.87e-02,  rl2 = 7.59e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.59e-01
# iter. = 05500,  time = 015s,  loss = 7.33e-03  |  mse = 3.50e-02,  rl2 = 8.08e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.59e-01
# iter. = 06000,  time = 016s,  loss = 2.29e-02  |  mse = 3.62e-02,  rl2 = 8.06e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.63e-01
# iter. = 06500,  time = 017s,  loss = 5.05e-02  |  mse = 3.35e-02,  rl2 = 7.22e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.61e-01
# iter. = 07000,  time = 018s,  loss = 1.09e-02  |  mse = 3.11e-02,  rl2 = 7.22e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 07500,  time = 018s,  loss = 2.06e-02  |  mse = 3.93e-02,  rl2 = 8.37e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.74e-01
# iter. = 08000,  time = 019s,  loss = 1.22e-02  |  mse = 3.85e-02,  rl2 = 7.85e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 08500,  time = 020s,  loss = 2.59e-03  |  mse = 3.66e-02,  rl2 = 8.83e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.77e-01
# iter. = 09000,  time = 021s,  loss = 3.27e-02  |  mse = 3.90e-02,  rl2 = 8.28e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 09500,  time = 021s,  loss = 5.19e-03  |  mse = 3.76e-02,  rl2 = 7.79e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.78e-01
# iter. = 10000,  time = 022s,  loss = 1.29e-02  |  mse = 4.06e-02,  rl2 = 8.20e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.78e-01
# iter. = 10500,  time = 023s,  loss = 4.41e-02  |  mse = 3.67e-02,  rl2 = 7.75e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.79e-01
# iter. = 11000,  time = 024s,  loss = 1.48e-02  |  mse = 3.49e-02,  rl2 = 8.07e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.76e-01
# iter. = 11500,  time = 024s,  loss = 9.80e-03  |  mse = 4.08e-02,  rl2 = 7.53e-01  |  Ghia mse = 1.25e-01,  Ghia rl2 = 8.82e-01
# iter. = 12000,  time = 025s,  loss = 4.10e-03  |  mse = 3.59e-02,  rl2 = 8.08e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.80e-01
# iter. = 12500,  time = 026s,  loss = 6.17e-03  |  mse = 4.03e-02,  rl2 = 8.05e-01  |  Ghia mse = 1.25e-01,  Ghia rl2 = 8.81e-01
# iter. = 13000,  time = 027s,  loss = 2.36e-03  |  mse = 3.45e-02,  rl2 = 8.37e-01  |  Ghia mse = 1.26e-01,  Ghia rl2 = 8.86e-01
# iter. = 13500,  time = 027s,  loss = 1.08e-02  |  mse = 3.55e-02,  rl2 = 7.95e-01  |  Ghia mse = 1.27e-01,  Ghia rl2 = 8.88e-01
# iter. = 14000,  time = 028s,  loss = 2.77e-03  |  mse = 3.92e-02,  rl2 = 8.06e-01  |  Ghia mse = 1.26e-01,  Ghia rl2 = 8.85e-01
# iter. = 14500,  time = 029s,  loss = 2.56e-02  |  mse = 3.89e-02,  rl2 = 8.51e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.74e-01
# iter. = 15000,  time = 030s,  loss = 5.00e-03  |  mse = 3.47e-02,  rl2 = 7.74e-01  |  Ghia mse = 1.25e-01,  Ghia rl2 = 8.82e-01
# iter. = 15500,  time = 030s,  loss = 8.38e-03  |  mse = 3.65e-02,  rl2 = 7.64e-01  |  Ghia mse = 1.25e-01,  Ghia rl2 = 8.82e-01
# iter. = 16000,  time = 031s,  loss = 6.82e-03  |  mse = 3.53e-02,  rl2 = 7.71e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.79e-01
# iter. = 16500,  time = 032s,  loss = 3.65e-03  |  mse = 3.39e-02,  rl2 = 8.17e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.80e-01
# iter. = 17000,  time = 033s,  loss = 5.06e-03  |  mse = 3.70e-02,  rl2 = 8.15e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.78e-01
# iter. = 17500,  time = 033s,  loss = 8.01e-03  |  mse = 4.04e-02,  rl2 = 8.13e-01  |  Ghia mse = 1.25e-01,  Ghia rl2 = 8.84e-01
# iter. = 18000,  time = 034s,  loss = 1.44e-02  |  mse = 3.56e-02,  rl2 = 7.50e-01  |  Ghia mse = 1.26e-01,  Ghia rl2 = 8.87e-01
# iter. = 18500,  time = 035s,  loss = 2.16e-02  |  mse = 3.77e-02,  rl2 = 7.92e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.74e-01
# iter. = 19000,  time = 036s,  loss = 6.85e-03  |  mse = 3.83e-02,  rl2 = 8.20e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.79e-01
# iter. = 19500,  time = 037s,  loss = 6.44e-03  |  mse = 3.27e-02,  rl2 = 7.49e-01  |  Ghia mse = 1.25e-01,  Ghia rl2 = 8.81e-01
# iter. = 20000,  time = 037s,  loss = 8.82e-03  |  mse = 3.61e-02,  rl2 = 7.65e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.78e-01
# iter. = 20500,  time = 038s,  loss = 5.28e-02  |  mse = 3.74e-02,  rl2 = 7.38e-01  |  Ghia mse = 1.26e-01,  Ghia rl2 = 8.86e-01
# iter. = 21000,  time = 039s,  loss = 5.65e-03  |  mse = 3.61e-02,  rl2 = 8.11e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.74e-01
# iter. = 21500,  time = 040s,  loss = 5.67e-03  |  mse = 3.58e-02,  rl2 = 7.84e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.75e-01
# iter. = 22000,  time = 040s,  loss = 9.77e-03  |  mse = 3.88e-02,  rl2 = 8.01e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.76e-01
# iter. = 22500,  time = 041s,  loss = 5.34e-03  |  mse = 3.90e-02,  rl2 = 8.02e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.78e-01
# iter. = 23000,  time = 042s,  loss = 4.73e-03  |  mse = 3.69e-02,  rl2 = 8.09e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.75e-01
# iter. = 23500,  time = 043s,  loss = 5.51e-03  |  mse = 4.01e-02,  rl2 = 7.23e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.77e-01
# iter. = 24000,  time = 043s,  loss = 7.28e-03  |  mse = 3.75e-02,  rl2 = 8.20e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.79e-01
# iter. = 24500,  time = 044s,  loss = 7.74e-03  |  mse = 3.67e-02,  rl2 = 7.76e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.76e-01
# iter. = 25000,  time = 045s,  loss = 2.84e-03  |  mse = 3.39e-02,  rl2 = 7.80e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.75e-01
# iter. = 25500,  time = 046s,  loss = 2.21e-03  |  mse = 3.87e-02,  rl2 = 8.14e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.76e-01
# iter. = 26000,  time = 046s,  loss = 8.84e-03  |  mse = 3.23e-02,  rl2 = 7.64e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 26500,  time = 047s,  loss = 4.42e-03  |  mse = 3.52e-02,  rl2 = 7.73e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.74e-01
# iter. = 27000,  time = 048s,  loss = 3.44e-03  |  mse = 3.76e-02,  rl2 = 8.16e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.74e-01
# iter. = 27500,  time = 049s,  loss = 2.91e-03  |  mse = 3.65e-02,  rl2 = 7.99e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.75e-01
# iter. = 28000,  time = 049s,  loss = 1.11e-03  |  mse = 3.85e-02,  rl2 = 8.10e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.75e-01
# iter. = 28500,  time = 050s,  loss = 6.55e-03  |  mse = 3.76e-02,  rl2 = 7.72e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 29000,  time = 051s,  loss = 6.46e-04  |  mse = 3.84e-02,  rl2 = 8.47e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.75e-01
# iter. = 29500,  time = 052s,  loss = 1.72e-03  |  mse = 3.83e-02,  rl2 = 7.48e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 30000,  time = 053s,  loss = 5.41e-04  |  mse = 3.76e-02,  rl2 = 7.86e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.74e-01
# iter. = 30500,  time = 053s,  loss = 3.43e-03  |  mse = 3.63e-02,  rl2 = 7.18e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.75e-01
# iter. = 31000,  time = 054s,  loss = 5.09e-04  |  mse = 3.52e-02,  rl2 = 7.36e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 31500,  time = 055s,  loss = 1.28e-03  |  mse = 3.81e-02,  rl2 = 8.25e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.74e-01
# iter. = 32000,  time = 056s,  loss = 8.86e-04  |  mse = 3.87e-02,  rl2 = 8.39e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 32500,  time = 056s,  loss = 5.74e-04  |  mse = 3.59e-02,  rl2 = 8.26e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 33000,  time = 057s,  loss = 4.39e-03  |  mse = 3.76e-02,  rl2 = 8.20e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 33500,  time = 058s,  loss = 6.46e-03  |  mse = 3.73e-02,  rl2 = 8.00e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 34000,  time = 059s,  loss = 8.12e-04  |  mse = 3.67e-02,  rl2 = 8.46e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.74e-01
# iter. = 34500,  time = 059s,  loss = 6.40e-04  |  mse = 3.62e-02,  rl2 = 7.80e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 35000,  time = 060s,  loss = 5.02e-04  |  mse = 3.88e-02,  rl2 = 8.03e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 35500,  time = 061s,  loss = 4.90e-04  |  mse = 3.84e-02,  rl2 = 8.32e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 36000,  time = 062s,  loss = 8.41e-04  |  mse = 3.98e-02,  rl2 = 8.33e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 36500,  time = 062s,  loss = 1.07e-03  |  mse = 3.63e-02,  rl2 = 7.76e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.75e-01
# iter. = 37000,  time = 063s,  loss = 7.46e-04  |  mse = 3.54e-02,  rl2 = 7.56e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 37500,  time = 064s,  loss = 5.52e-04  |  mse = 3.72e-02,  rl2 = 7.66e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 38000,  time = 065s,  loss = 7.30e-04  |  mse = 3.35e-02,  rl2 = 7.42e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 38500,  time = 065s,  loss = 5.14e-04  |  mse = 3.65e-02,  rl2 = 7.72e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 39000,  time = 066s,  loss = 9.78e-04  |  mse = 3.79e-02,  rl2 = 8.08e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.74e-01
# iter. = 39500,  time = 067s,  loss = 1.08e-03  |  mse = 3.81e-02,  rl2 = 8.36e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 40000,  time = 068s,  loss = 3.97e-04  |  mse = 3.61e-02,  rl2 = 7.87e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 40500,  time = 068s,  loss = 5.27e-04  |  mse = 3.69e-02,  rl2 = 8.29e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 41000,  time = 069s,  loss = 6.55e-04  |  mse = 3.84e-02,  rl2 = 7.58e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 41500,  time = 070s,  loss = 3.65e-04  |  mse = 3.82e-02,  rl2 = 7.66e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 42000,  time = 071s,  loss = 4.98e-04  |  mse = 3.65e-02,  rl2 = 8.34e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 42500,  time = 072s,  loss = 4.89e-04  |  mse = 3.60e-02,  rl2 = 7.93e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 43000,  time = 072s,  loss = 8.83e-04  |  mse = 3.67e-02,  rl2 = 7.94e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 43500,  time = 073s,  loss = 4.22e-04  |  mse = 3.60e-02,  rl2 = 8.05e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 44000,  time = 074s,  loss = 4.75e-04  |  mse = 3.99e-02,  rl2 = 8.12e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 44500,  time = 075s,  loss = 3.22e-04  |  mse = 3.57e-02,  rl2 = 7.57e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 45000,  time = 075s,  loss = 5.79e-04  |  mse = 3.72e-02,  rl2 = 8.51e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 45500,  time = 076s,  loss = 3.72e-04  |  mse = 3.69e-02,  rl2 = 8.15e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 46000,  time = 077s,  loss = 4.04e-04  |  mse = 3.96e-02,  rl2 = 7.80e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 46500,  time = 078s,  loss = 3.08e-04  |  mse = 3.93e-02,  rl2 = 7.80e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 47000,  time = 078s,  loss = 3.54e-04  |  mse = 3.54e-02,  rl2 = 7.41e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 47500,  time = 079s,  loss = 4.47e-04  |  mse = 3.37e-02,  rl2 = 8.19e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 48000,  time = 080s,  loss = 3.76e-04  |  mse = 3.84e-02,  rl2 = 8.03e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 48500,  time = 081s,  loss = 3.73e-04  |  mse = 3.57e-02,  rl2 = 7.92e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 49000,  time = 081s,  loss = 3.95e-04  |  mse = 3.99e-02,  rl2 = 7.79e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 49500,  time = 082s,  loss = 3.57e-04  |  mse = 3.63e-02,  rl2 = 8.03e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 50000,  time = 083s,  loss = 3.60e-04  |  mse = 3.43e-02,  rl2 = 8.05e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# [In-house] :  MSE = 4.24e-02  RL2 = 9.26e-01
# [Ghia]     :  MSE = 1.22e-01  RL2 = 8.71e-01
# iter. = 00000,  time = 006s,  loss = 2.55e+01  |  mse = 1.39e-01,  rl2 = 1.57e+00  |  Ghia mse = 1.83e-01,  Ghia rl2 = 1.07e+00
# iter. = 00500,  time = 007s,  loss = 1.15e-01  |  mse = 3.20e-02,  rl2 = 7.08e-01  |  Ghia mse = 1.02e-01,  Ghia rl2 = 7.96e-01
# iter. = 01000,  time = 007s,  loss = 4.96e-02  |  mse = 3.22e-02,  rl2 = 7.22e-01  |  Ghia mse = 1.02e-01,  Ghia rl2 = 7.98e-01
# iter. = 01500,  time = 008s,  loss = 1.01e-01  |  mse = 3.29e-02,  rl2 = 7.85e-01  |  Ghia mse = 1.04e-01,  Ghia rl2 = 8.03e-01
# iter. = 02000,  time = 009s,  loss = 9.63e-03  |  mse = 3.68e-02,  rl2 = 8.67e-01  |  Ghia mse = 1.06e-01,  Ghia rl2 = 8.14e-01
# iter. = 02500,  time = 010s,  loss = 1.23e-02  |  mse = 3.49e-02,  rl2 = 7.81e-01  |  Ghia mse = 1.09e-01,  Ghia rl2 = 8.23e-01
# iter. = 03000,  time = 010s,  loss = 2.91e-02  |  mse = 3.59e-02,  rl2 = 7.97e-01  |  Ghia mse = 1.11e-01,  Ghia rl2 = 8.32e-01
# iter. = 03500,  time = 011s,  loss = 2.73e-02  |  mse = 3.46e-02,  rl2 = 7.46e-01  |  Ghia mse = 1.13e-01,  Ghia rl2 = 8.38e-01
# iter. = 04000,  time = 012s,  loss = 1.47e-02  |  mse = 3.53e-02,  rl2 = 7.30e-01  |  Ghia mse = 1.12e-01,  Ghia rl2 = 8.37e-01
# iter. = 04500,  time = 013s,  loss = 2.31e-02  |  mse = 3.28e-02,  rl2 = 7.47e-01  |  Ghia mse = 1.14e-01,  Ghia rl2 = 8.44e-01
# iter. = 05000,  time = 014s,  loss = 3.04e-02  |  mse = 3.38e-02,  rl2 = 7.55e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.46e-01
# iter. = 05500,  time = 014s,  loss = 1.51e-02  |  mse = 3.30e-02,  rl2 = 7.17e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.45e-01
# iter. = 06000,  time = 015s,  loss = 3.90e-02  |  mse = 3.23e-02,  rl2 = 7.12e-01  |  Ghia mse = 1.16e-01,  Ghia rl2 = 8.50e-01
# iter. = 06500,  time = 016s,  loss = 1.73e-02  |  mse = 3.17e-02,  rl2 = 7.47e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.47e-01
# iter. = 07000,  time = 017s,  loss = 3.78e-02  |  mse = 3.46e-02,  rl2 = 7.66e-01  |  Ghia mse = 1.16e-01,  Ghia rl2 = 8.51e-01
# iter. = 07500,  time = 017s,  loss = 3.22e-02  |  mse = 3.58e-02,  rl2 = 7.52e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# iter. = 08000,  time = 018s,  loss = 1.88e-02  |  mse = 3.64e-02,  rl2 = 8.02e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.60e-01
# iter. = 08500,  time = 019s,  loss = 2.87e-02  |  mse = 3.52e-02,  rl2 = 7.37e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.59e-01
# iter. = 09000,  time = 020s,  loss = 1.74e-02  |  mse = 3.28e-02,  rl2 = 7.62e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.62e-01
# iter. = 09500,  time = 020s,  loss = 1.94e-02  |  mse = 3.65e-02,  rl2 = 7.77e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 10000,  time = 021s,  loss = 1.27e-02  |  mse = 3.57e-02,  rl2 = 7.58e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.61e-01
# iter. = 10500,  time = 022s,  loss = 7.14e-03  |  mse = 3.76e-02,  rl2 = 8.46e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.63e-01
# iter. = 11000,  time = 023s,  loss = 1.01e-02  |  mse = 3.48e-02,  rl2 = 7.93e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.64e-01
# iter. = 11500,  time = 023s,  loss = 9.93e-03  |  mse = 3.70e-02,  rl2 = 7.30e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.62e-01
# iter. = 12000,  time = 024s,  loss = 1.22e-02  |  mse = 3.56e-02,  rl2 = 7.53e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.60e-01
# iter. = 12500,  time = 025s,  loss = 4.66e-03  |  mse = 4.03e-02,  rl2 = 8.38e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 13000,  time = 026s,  loss = 1.15e-02  |  mse = 3.62e-02,  rl2 = 7.49e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 13500,  time = 026s,  loss = 1.82e-02  |  mse = 3.35e-02,  rl2 = 7.80e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.62e-01
# iter. = 14000,  time = 027s,  loss = 6.23e-03  |  mse = 3.79e-02,  rl2 = 7.96e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 14500,  time = 028s,  loss = 1.32e-02  |  mse = 3.48e-02,  rl2 = 7.62e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 15000,  time = 029s,  loss = 7.10e-03  |  mse = 3.91e-02,  rl2 = 8.08e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.62e-01
# iter. = 15500,  time = 030s,  loss = 3.31e-02  |  mse = 3.50e-02,  rl2 = 7.85e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 16000,  time = 030s,  loss = 3.16e-03  |  mse = 3.61e-02,  rl2 = 7.88e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.64e-01
# iter. = 16500,  time = 031s,  loss = 9.55e-03  |  mse = 3.40e-02,  rl2 = 8.17e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 17000,  time = 032s,  loss = 2.83e-02  |  mse = 3.77e-02,  rl2 = 7.37e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.67e-01
# iter. = 17500,  time = 033s,  loss = 2.08e-02  |  mse = 3.53e-02,  rl2 = 7.47e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 18000,  time = 033s,  loss = 1.70e-02  |  mse = 3.44e-02,  rl2 = 7.53e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 18500,  time = 034s,  loss = 1.89e-02  |  mse = 3.57e-02,  rl2 = 7.64e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 19000,  time = 035s,  loss = 5.30e-03  |  mse = 3.76e-02,  rl2 = 7.38e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 19500,  time = 036s,  loss = 5.53e-03  |  mse = 3.78e-02,  rl2 = 7.83e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 20000,  time = 036s,  loss = 1.47e-02  |  mse = 3.64e-02,  rl2 = 7.36e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 20500,  time = 037s,  loss = 2.72e-03  |  mse = 3.70e-02,  rl2 = 7.82e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 21000,  time = 038s,  loss = 4.88e-03  |  mse = 3.50e-02,  rl2 = 8.18e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 21500,  time = 039s,  loss = 3.02e-03  |  mse = 3.36e-02,  rl2 = 7.13e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 22000,  time = 039s,  loss = 2.19e-03  |  mse = 3.63e-02,  rl2 = 8.54e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 22500,  time = 040s,  loss = 4.19e-03  |  mse = 3.54e-02,  rl2 = 7.64e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 23000,  time = 041s,  loss = 4.11e-03  |  mse = 3.64e-02,  rl2 = 7.90e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 23500,  time = 042s,  loss = 2.40e-03  |  mse = 3.52e-02,  rl2 = 7.76e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 24000,  time = 042s,  loss = 1.20e-03  |  mse = 3.65e-02,  rl2 = 7.67e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 24500,  time = 043s,  loss = 8.16e-04  |  mse = 3.69e-02,  rl2 = 8.30e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 25000,  time = 044s,  loss = 9.91e-03  |  mse = 3.57e-02,  rl2 = 7.74e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 25500,  time = 045s,  loss = 2.92e-03  |  mse = 3.40e-02,  rl2 = 8.06e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 26000,  time = 046s,  loss = 9.35e-03  |  mse = 3.83e-02,  rl2 = 7.33e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 26500,  time = 046s,  loss = 7.11e-03  |  mse = 3.68e-02,  rl2 = 8.30e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 27000,  time = 047s,  loss = 2.89e-03  |  mse = 4.06e-02,  rl2 = 8.07e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 27500,  time = 048s,  loss = 9.22e-04  |  mse = 3.62e-02,  rl2 = 7.71e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 28000,  time = 049s,  loss = 2.36e-03  |  mse = 3.76e-02,  rl2 = 7.69e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 28500,  time = 049s,  loss = 3.40e-03  |  mse = 3.59e-02,  rl2 = 8.11e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 29000,  time = 050s,  loss = 6.49e-04  |  mse = 3.62e-02,  rl2 = 7.90e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 29500,  time = 051s,  loss = 7.01e-03  |  mse = 3.62e-02,  rl2 = 8.21e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 30000,  time = 052s,  loss = 3.50e-03  |  mse = 3.85e-02,  rl2 = 8.10e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 30500,  time = 052s,  loss = 7.08e-04  |  mse = 3.63e-02,  rl2 = 8.35e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 31000,  time = 053s,  loss = 4.12e-03  |  mse = 3.72e-02,  rl2 = 7.67e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 31500,  time = 054s,  loss = 1.21e-03  |  mse = 3.48e-02,  rl2 = 8.32e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 32000,  time = 055s,  loss = 9.55e-04  |  mse = 3.68e-02,  rl2 = 7.76e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 32500,  time = 055s,  loss = 2.93e-03  |  mse = 3.72e-02,  rl2 = 8.56e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 33000,  time = 056s,  loss = 7.66e-04  |  mse = 3.68e-02,  rl2 = 7.86e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 33500,  time = 057s,  loss = 3.18e-03  |  mse = 3.33e-02,  rl2 = 7.73e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 34000,  time = 058s,  loss = 7.67e-04  |  mse = 3.37e-02,  rl2 = 7.96e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 34500,  time = 058s,  loss = 1.41e-03  |  mse = 3.53e-02,  rl2 = 7.60e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 35000,  time = 059s,  loss = 9.42e-04  |  mse = 3.76e-02,  rl2 = 7.78e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 35500,  time = 060s,  loss = 9.50e-04  |  mse = 3.72e-02,  rl2 = 7.96e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 36000,  time = 061s,  loss = 8.37e-04  |  mse = 3.70e-02,  rl2 = 7.75e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 36500,  time = 062s,  loss = 3.38e-03  |  mse = 3.52e-02,  rl2 = 7.57e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 37000,  time = 062s,  loss = 1.83e-03  |  mse = 3.87e-02,  rl2 = 8.59e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 37500,  time = 063s,  loss = 1.43e-03  |  mse = 3.50e-02,  rl2 = 7.05e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 38000,  time = 064s,  loss = 8.10e-04  |  mse = 3.60e-02,  rl2 = 8.29e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 38500,  time = 065s,  loss = 5.59e-04  |  mse = 3.55e-02,  rl2 = 7.29e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 39000,  time = 065s,  loss = 3.97e-04  |  mse = 3.84e-02,  rl2 = 7.85e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 39500,  time = 066s,  loss = 5.61e-04  |  mse = 3.46e-02,  rl2 = 7.74e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 40000,  time = 067s,  loss = 9.65e-04  |  mse = 3.51e-02,  rl2 = 7.69e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 40500,  time = 068s,  loss = 5.57e-04  |  mse = 3.71e-02,  rl2 = 7.89e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 41000,  time = 068s,  loss = 1.23e-03  |  mse = 3.79e-02,  rl2 = 7.42e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 41500,  time = 069s,  loss = 5.20e-04  |  mse = 3.65e-02,  rl2 = 8.01e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 42000,  time = 070s,  loss = 2.36e-03  |  mse = 3.75e-02,  rl2 = 7.71e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 42500,  time = 071s,  loss = 3.76e-04  |  mse = 3.70e-02,  rl2 = 7.36e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 43000,  time = 071s,  loss = 3.57e-04  |  mse = 3.38e-02,  rl2 = 7.11e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 43500,  time = 072s,  loss = 2.18e-03  |  mse = 3.72e-02,  rl2 = 7.91e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 44000,  time = 073s,  loss = 2.19e-03  |  mse = 3.39e-02,  rl2 = 7.97e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 44500,  time = 074s,  loss = 3.82e-04  |  mse = 3.41e-02,  rl2 = 7.91e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 45000,  time = 074s,  loss = 3.37e-04  |  mse = 3.85e-02,  rl2 = 8.20e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 45500,  time = 075s,  loss = 4.00e-04  |  mse = 3.93e-02,  rl2 = 8.78e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 46000,  time = 076s,  loss = 4.28e-04  |  mse = 3.72e-02,  rl2 = 8.14e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 46500,  time = 077s,  loss = 4.35e-04  |  mse = 3.59e-02,  rl2 = 7.81e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 47000,  time = 078s,  loss = 3.46e-04  |  mse = 3.75e-02,  rl2 = 7.76e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 47500,  time = 078s,  loss = 2.05e-03  |  mse = 3.98e-02,  rl2 = 8.36e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 48000,  time = 079s,  loss = 3.85e-04  |  mse = 3.63e-02,  rl2 = 8.31e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 48500,  time = 080s,  loss = 9.06e-04  |  mse = 3.52e-02,  rl2 = 7.49e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 49000,  time = 081s,  loss = 4.41e-04  |  mse = 3.57e-02,  rl2 = 8.22e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 49500,  time = 081s,  loss = 2.01e-03  |  mse = 3.55e-02,  rl2 = 7.21e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 50000,  time = 082s,  loss = 3.02e-04  |  mse = 3.78e-02,  rl2 = 8.51e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.67e-01
# [In-house] :  MSE = 4.18e-02  RL2 = 9.20e-01
# [Ghia]     :  MSE = 1.20e-01  RL2 = 8.67e-01
# iter. = 00000,  time = 006s,  loss = 2.72e+02  |  mse = 7.88e-01,  rl2 = 3.55e+00  |  Ghia mse = 7.63e-01,  Ghia rl2 = 2.18e+00
# iter. = 00500,  time = 007s,  loss = 2.06e-01  |  mse = 3.64e-02,  rl2 = 7.54e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# iter. = 01000,  time = 007s,  loss = 1.31e-01  |  mse = 3.48e-02,  rl2 = 7.78e-01  |  Ghia mse = 1.10e-01,  Ghia rl2 = 8.27e-01
# iter. = 01500,  time = 008s,  loss = 6.82e-02  |  mse = 3.40e-02,  rl2 = 7.42e-01  |  Ghia mse = 1.08e-01,  Ghia rl2 = 8.20e-01
# iter. = 02000,  time = 009s,  loss = 7.58e-02  |  mse = 3.41e-02,  rl2 = 7.69e-01  |  Ghia mse = 1.08e-01,  Ghia rl2 = 8.20e-01
# iter. = 02500,  time = 010s,  loss = 8.88e-02  |  mse = 3.51e-02,  rl2 = 8.06e-01  |  Ghia mse = 1.08e-01,  Ghia rl2 = 8.21e-01
# iter. = 03000,  time = 011s,  loss = 1.03e-01  |  mse = 3.55e-02,  rl2 = 7.71e-01  |  Ghia mse = 1.10e-01,  Ghia rl2 = 8.27e-01
# iter. = 03500,  time = 011s,  loss = 1.40e-02  |  mse = 3.41e-02,  rl2 = 7.31e-01  |  Ghia mse = 1.10e-01,  Ghia rl2 = 8.29e-01
# iter. = 04000,  time = 012s,  loss = 3.33e-02  |  mse = 3.61e-02,  rl2 = 7.54e-01  |  Ghia mse = 1.11e-01,  Ghia rl2 = 8.33e-01
# iter. = 04500,  time = 013s,  loss = 2.65e-02  |  mse = 3.39e-02,  rl2 = 7.58e-01  |  Ghia mse = 1.11e-01,  Ghia rl2 = 8.31e-01
# iter. = 05000,  time = 014s,  loss = 1.77e-02  |  mse = 3.39e-02,  rl2 = 7.67e-01  |  Ghia mse = 1.13e-01,  Ghia rl2 = 8.41e-01
# iter. = 05500,  time = 014s,  loss = 1.09e-01  |  mse = 3.48e-02,  rl2 = 7.63e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.46e-01
# iter. = 06000,  time = 015s,  loss = 6.07e-02  |  mse = 3.59e-02,  rl2 = 7.62e-01  |  Ghia mse = 1.13e-01,  Ghia rl2 = 8.38e-01
# iter. = 06500,  time = 016s,  loss = 1.52e-02  |  mse = 3.62e-02,  rl2 = 7.99e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.48e-01
# iter. = 07000,  time = 017s,  loss = 6.13e-02  |  mse = 3.43e-02,  rl2 = 7.67e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.47e-01
# iter. = 07500,  time = 017s,  loss = 7.12e-03  |  mse = 3.50e-02,  rl2 = 7.78e-01  |  Ghia mse = 1.14e-01,  Ghia rl2 = 8.43e-01
# iter. = 08000,  time = 018s,  loss = 6.01e-03  |  mse = 3.58e-02,  rl2 = 8.14e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.47e-01
# iter. = 08500,  time = 019s,  loss = 1.34e-02  |  mse = 3.67e-02,  rl2 = 8.44e-01  |  Ghia mse = 1.14e-01,  Ghia rl2 = 8.43e-01
# iter. = 09000,  time = 020s,  loss = 1.38e-02  |  mse = 3.55e-02,  rl2 = 7.58e-01  |  Ghia mse = 1.16e-01,  Ghia rl2 = 8.50e-01
# iter. = 09500,  time = 020s,  loss = 7.74e-03  |  mse = 3.35e-02,  rl2 = 8.01e-01  |  Ghia mse = 1.14e-01,  Ghia rl2 = 8.43e-01
# iter. = 10000,  time = 021s,  loss = 4.91e-02  |  mse = 3.43e-02,  rl2 = 7.32e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.45e-01
# iter. = 10500,  time = 022s,  loss = 1.10e-02  |  mse = 3.50e-02,  rl2 = 8.24e-01  |  Ghia mse = 1.16e-01,  Ghia rl2 = 8.50e-01
# iter. = 11000,  time = 023s,  loss = 1.46e-02  |  mse = 3.30e-02,  rl2 = 7.87e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.54e-01
# iter. = 11500,  time = 023s,  loss = 1.77e-02  |  mse = 3.36e-02,  rl2 = 7.48e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.54e-01
# iter. = 12000,  time = 024s,  loss = 2.35e-02  |  mse = 3.80e-02,  rl2 = 8.13e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.59e-01
# iter. = 12500,  time = 025s,  loss = 1.51e-02  |  mse = 3.79e-02,  rl2 = 8.28e-01  |  Ghia mse = 1.16e-01,  Ghia rl2 = 8.51e-01
# iter. = 13000,  time = 026s,  loss = 1.47e-02  |  mse = 3.57e-02,  rl2 = 7.73e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.55e-01
# iter. = 13500,  time = 027s,  loss = 6.17e-03  |  mse = 3.48e-02,  rl2 = 7.93e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.60e-01
# iter. = 14000,  time = 027s,  loss = 2.26e-02  |  mse = 3.75e-02,  rl2 = 7.63e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 14500,  time = 028s,  loss = 1.24e-02  |  mse = 3.64e-02,  rl2 = 7.34e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.60e-01
# iter. = 15000,  time = 029s,  loss = 7.41e-03  |  mse = 3.65e-02,  rl2 = 7.93e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.57e-01
# iter. = 15500,  time = 030s,  loss = 5.30e-02  |  mse = 3.78e-02,  rl2 = 7.91e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.61e-01
# iter. = 16000,  time = 030s,  loss = 5.80e-03  |  mse = 3.36e-02,  rl2 = 8.43e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.58e-01
# iter. = 16500,  time = 031s,  loss = 4.92e-03  |  mse = 3.78e-02,  rl2 = 7.66e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.55e-01
# iter. = 17000,  time = 032s,  loss = 1.63e-02  |  mse = 3.75e-02,  rl2 = 7.83e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.58e-01
# iter. = 17500,  time = 033s,  loss = 1.75e-02  |  mse = 3.81e-02,  rl2 = 8.23e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.59e-01
# iter. = 18000,  time = 033s,  loss = 5.82e-03  |  mse = 3.62e-02,  rl2 = 8.47e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.58e-01
# iter. = 18500,  time = 034s,  loss = 3.62e-02  |  mse = 3.70e-02,  rl2 = 7.57e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.60e-01
# iter. = 19000,  time = 035s,  loss = 1.02e-02  |  mse = 3.66e-02,  rl2 = 7.84e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 19500,  time = 036s,  loss = 8.60e-03  |  mse = 3.70e-02,  rl2 = 7.64e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.75e-01
# iter. = 20000,  time = 036s,  loss = 5.56e-03  |  mse = 3.77e-02,  rl2 = 7.90e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 20500,  time = 037s,  loss = 1.43e-02  |  mse = 3.50e-02,  rl2 = 7.30e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 21000,  time = 038s,  loss = 3.02e-03  |  mse = 3.72e-02,  rl2 = 7.96e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.70e-01
# iter. = 21500,  time = 039s,  loss = 2.78e-03  |  mse = 3.51e-02,  rl2 = 7.49e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 22000,  time = 039s,  loss = 4.84e-03  |  mse = 3.80e-02,  rl2 = 7.43e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 22500,  time = 040s,  loss = 7.02e-03  |  mse = 3.32e-02,  rl2 = 7.05e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 23000,  time = 041s,  loss = 1.89e-03  |  mse = 3.77e-02,  rl2 = 7.99e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 23500,  time = 042s,  loss = 3.23e-03  |  mse = 3.45e-02,  rl2 = 7.75e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 24000,  time = 043s,  loss = 2.24e-03  |  mse = 3.55e-02,  rl2 = 7.84e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 24500,  time = 043s,  loss = 1.58e-03  |  mse = 3.50e-02,  rl2 = 7.88e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 25000,  time = 044s,  loss = 1.74e-03  |  mse = 3.72e-02,  rl2 = 7.56e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 25500,  time = 045s,  loss = 2.78e-03  |  mse = 3.57e-02,  rl2 = 8.02e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 26000,  time = 046s,  loss = 4.16e-03  |  mse = 3.62e-02,  rl2 = 7.87e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 26500,  time = 046s,  loss = 4.13e-03  |  mse = 3.72e-02,  rl2 = 8.00e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 27000,  time = 047s,  loss = 1.59e-03  |  mse = 3.46e-02,  rl2 = 7.54e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.74e-01
# iter. = 27500,  time = 048s,  loss = 5.25e-03  |  mse = 3.69e-02,  rl2 = 7.89e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 28000,  time = 049s,  loss = 3.92e-03  |  mse = 3.55e-02,  rl2 = 7.48e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 28500,  time = 049s,  loss = 1.20e-02  |  mse = 3.48e-02,  rl2 = 8.03e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 29000,  time = 050s,  loss = 1.71e-03  |  mse = 3.96e-02,  rl2 = 8.60e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 29500,  time = 051s,  loss = 4.70e-03  |  mse = 3.52e-02,  rl2 = 7.88e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.70e-01
# iter. = 30000,  time = 052s,  loss = 1.16e-02  |  mse = 3.46e-02,  rl2 = 7.82e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 30500,  time = 052s,  loss = 3.21e-03  |  mse = 3.49e-02,  rl2 = 7.85e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 31000,  time = 053s,  loss = 2.10e-03  |  mse = 3.66e-02,  rl2 = 7.84e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 31500,  time = 054s,  loss = 5.72e-03  |  mse = 3.90e-02,  rl2 = 7.96e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 32000,  time = 055s,  loss = 1.02e-03  |  mse = 3.87e-02,  rl2 = 8.34e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 32500,  time = 055s,  loss = 1.38e-03  |  mse = 3.35e-02,  rl2 = 8.10e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.70e-01
# iter. = 33000,  time = 056s,  loss = 1.54e-03  |  mse = 3.78e-02,  rl2 = 8.08e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 33500,  time = 057s,  loss = 7.65e-04  |  mse = 3.25e-02,  rl2 = 7.18e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.70e-01
# iter. = 34000,  time = 058s,  loss = 1.39e-03  |  mse = 3.59e-02,  rl2 = 7.91e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 34500,  time = 059s,  loss = 4.82e-04  |  mse = 3.88e-02,  rl2 = 7.97e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 35000,  time = 059s,  loss = 9.52e-04  |  mse = 3.57e-02,  rl2 = 7.60e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 35500,  time = 060s,  loss = 7.59e-04  |  mse = 3.63e-02,  rl2 = 7.88e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 36000,  time = 061s,  loss = 1.68e-03  |  mse = 3.63e-02,  rl2 = 7.41e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.70e-01
# iter. = 36500,  time = 062s,  loss = 1.63e-03  |  mse = 4.02e-02,  rl2 = 7.79e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 37000,  time = 062s,  loss = 7.69e-04  |  mse = 3.59e-02,  rl2 = 8.07e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.70e-01
# iter. = 37500,  time = 063s,  loss = 2.68e-03  |  mse = 3.88e-02,  rl2 = 7.59e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 38000,  time = 064s,  loss = 2.79e-03  |  mse = 3.52e-02,  rl2 = 7.79e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.70e-01
# iter. = 38500,  time = 065s,  loss = 6.25e-04  |  mse = 3.88e-02,  rl2 = 8.47e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 39000,  time = 065s,  loss = 5.15e-04  |  mse = 3.77e-02,  rl2 = 8.29e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 39500,  time = 066s,  loss = 4.75e-04  |  mse = 3.47e-02,  rl2 = 7.98e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 40000,  time = 067s,  loss = 5.27e-04  |  mse = 3.55e-02,  rl2 = 8.18e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 40500,  time = 068s,  loss = 5.69e-04  |  mse = 3.49e-02,  rl2 = 7.83e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.70e-01
# iter. = 41000,  time = 068s,  loss = 2.48e-03  |  mse = 3.75e-02,  rl2 = 8.14e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 41500,  time = 069s,  loss = 5.39e-04  |  mse = 3.66e-02,  rl2 = 7.34e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.70e-01
# iter. = 42000,  time = 070s,  loss = 7.52e-04  |  mse = 3.50e-02,  rl2 = 7.51e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 42500,  time = 071s,  loss = 5.41e-04  |  mse = 3.86e-02,  rl2 = 7.77e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 43000,  time = 071s,  loss = 6.18e-04  |  mse = 3.97e-02,  rl2 = 8.08e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 43500,  time = 072s,  loss = 7.59e-04  |  mse = 3.93e-02,  rl2 = 8.75e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.70e-01
# iter. = 44000,  time = 073s,  loss = 8.94e-04  |  mse = 3.38e-02,  rl2 = 7.99e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 44500,  time = 074s,  loss = 3.97e-04  |  mse = 3.76e-02,  rl2 = 7.60e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 45000,  time = 075s,  loss = 5.42e-04  |  mse = 3.81e-02,  rl2 = 8.88e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 45500,  time = 075s,  loss = 6.43e-04  |  mse = 3.82e-02,  rl2 = 7.38e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 46000,  time = 076s,  loss = 6.49e-04  |  mse = 3.55e-02,  rl2 = 7.88e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 46500,  time = 077s,  loss = 5.91e-04  |  mse = 3.75e-02,  rl2 = 7.63e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 47000,  time = 078s,  loss = 4.84e-04  |  mse = 3.86e-02,  rl2 = 7.82e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 47500,  time = 078s,  loss = 5.19e-04  |  mse = 3.76e-02,  rl2 = 8.16e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 48000,  time = 079s,  loss = 6.35e-04  |  mse = 3.48e-02,  rl2 = 7.97e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 48500,  time = 080s,  loss = 4.03e-04  |  mse = 3.69e-02,  rl2 = 7.79e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 49000,  time = 081s,  loss = 6.46e-04  |  mse = 3.59e-02,  rl2 = 8.14e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 49500,  time = 081s,  loss = 3.76e-04  |  mse = 3.82e-02,  rl2 = 8.42e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 50000,  time = 082s,  loss = 8.77e-04  |  mse = 3.65e-02,  rl2 = 8.23e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# [In-house] :  MSE = 4.17e-02  RL2 = 9.18e-01
# [Ghia]     :  MSE = 1.21e-01  RL2 = 8.70e-01
# iter. = 00000,  time = 006s,  loss = 2.25e+01  |  mse = 1.14e-01,  rl2 = 1.44e+00  |  Ghia mse = 3.18e-01,  Ghia rl2 = 1.41e+00
# iter. = 00500,  time = 007s,  loss = 1.41e-01  |  mse = 3.22e-02,  rl2 = 7.98e-01  |  Ghia mse = 1.02e-01,  Ghia rl2 = 7.97e-01
# iter. = 01000,  time = 008s,  loss = 1.17e-01  |  mse = 3.53e-02,  rl2 = 7.98e-01  |  Ghia mse = 1.07e-01,  Ghia rl2 = 8.16e-01
# iter. = 01500,  time = 008s,  loss = 1.51e-02  |  mse = 3.30e-02,  rl2 = 7.57e-01  |  Ghia mse = 1.11e-01,  Ghia rl2 = 8.33e-01
# iter. = 02000,  time = 009s,  loss = 3.73e-02  |  mse = 3.27e-02,  rl2 = 7.09e-01  |  Ghia mse = 1.16e-01,  Ghia rl2 = 8.51e-01
# iter. = 02500,  time = 010s,  loss = 7.39e-03  |  mse = 3.74e-02,  rl2 = 7.74e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.52e-01
# iter. = 03000,  time = 011s,  loss = 9.91e-02  |  mse = 3.51e-02,  rl2 = 7.74e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 03500,  time = 011s,  loss = 1.24e-02  |  mse = 3.36e-02,  rl2 = 7.35e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 04000,  time = 012s,  loss = 5.72e-02  |  mse = 3.43e-02,  rl2 = 7.45e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.70e-01
# iter. = 04500,  time = 013s,  loss = 1.69e-02  |  mse = 3.55e-02,  rl2 = 8.47e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.55e-01
# iter. = 05000,  time = 014s,  loss = 4.20e-02  |  mse = 3.58e-02,  rl2 = 8.01e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 05500,  time = 014s,  loss = 1.98e-02  |  mse = 3.64e-02,  rl2 = 7.96e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 06000,  time = 015s,  loss = 9.53e-03  |  mse = 3.68e-02,  rl2 = 8.20e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 06500,  time = 016s,  loss = 3.36e-02  |  mse = 3.56e-02,  rl2 = 8.01e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.61e-01
# iter. = 07000,  time = 017s,  loss = 3.39e-02  |  mse = 3.30e-02,  rl2 = 7.43e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.60e-01
# iter. = 07500,  time = 018s,  loss = 6.77e-03  |  mse = 3.67e-02,  rl2 = 7.81e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.62e-01
# iter. = 08000,  time = 018s,  loss = 6.90e-03  |  mse = 3.61e-02,  rl2 = 7.83e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# iter. = 08500,  time = 019s,  loss = 1.13e-02  |  mse = 3.37e-02,  rl2 = 8.30e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# iter. = 09000,  time = 020s,  loss = 1.14e-02  |  mse = 3.66e-02,  rl2 = 7.80e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.59e-01
# iter. = 09500,  time = 021s,  loss = 6.58e-03  |  mse = 3.48e-02,  rl2 = 8.11e-01  |  Ghia mse = 1.16e-01,  Ghia rl2 = 8.52e-01
# iter. = 10000,  time = 021s,  loss = 1.74e-02  |  mse = 3.58e-02,  rl2 = 8.13e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.52e-01
# iter. = 10500,  time = 022s,  loss = 6.45e-03  |  mse = 3.54e-02,  rl2 = 7.44e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.58e-01
# iter. = 11000,  time = 023s,  loss = 4.06e-03  |  mse = 3.29e-02,  rl2 = 8.02e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.54e-01
# iter. = 11500,  time = 024s,  loss = 9.11e-03  |  mse = 3.39e-02,  rl2 = 7.68e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.55e-01
# iter. = 12000,  time = 024s,  loss = 9.86e-03  |  mse = 3.33e-02,  rl2 = 7.48e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.53e-01
# iter. = 12500,  time = 025s,  loss = 9.93e-03  |  mse = 3.43e-02,  rl2 = 7.80e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.55e-01
# iter. = 13000,  time = 026s,  loss = 4.32e-02  |  mse = 3.39e-02,  rl2 = 8.04e-01  |  Ghia mse = 1.25e-01,  Ghia rl2 = 8.84e-01
# iter. = 13500,  time = 027s,  loss = 3.61e-02  |  mse = 3.88e-02,  rl2 = 7.96e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 14000,  time = 027s,  loss = 7.16e-03  |  mse = 3.36e-02,  rl2 = 7.72e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.78e-01
# iter. = 14500,  time = 028s,  loss = 1.61e-02  |  mse = 3.51e-02,  rl2 = 7.23e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 15000,  time = 029s,  loss = 7.91e-03  |  mse = 3.54e-02,  rl2 = 7.54e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 15500,  time = 030s,  loss = 2.73e-02  |  mse = 4.15e-02,  rl2 = 8.13e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 16000,  time = 030s,  loss = 1.76e-02  |  mse = 3.55e-02,  rl2 = 7.98e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 16500,  time = 031s,  loss = 1.68e-02  |  mse = 3.87e-02,  rl2 = 7.70e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 17000,  time = 032s,  loss = 2.10e-02  |  mse = 3.71e-02,  rl2 = 8.09e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.77e-01
# iter. = 17500,  time = 033s,  loss = 1.53e-02  |  mse = 3.34e-02,  rl2 = 7.53e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 18000,  time = 034s,  loss = 8.56e-03  |  mse = 3.87e-02,  rl2 = 8.26e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.76e-01
# iter. = 18500,  time = 034s,  loss = 8.23e-03  |  mse = 3.87e-02,  rl2 = 7.70e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.77e-01
# iter. = 19000,  time = 035s,  loss = 1.19e-02  |  mse = 3.76e-02,  rl2 = 8.07e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.78e-01
# iter. = 19500,  time = 036s,  loss = 1.21e-02  |  mse = 3.79e-02,  rl2 = 7.63e-01  |  Ghia mse = 1.26e-01,  Ghia rl2 = 8.87e-01
# iter. = 20000,  time = 037s,  loss = 7.53e-03  |  mse = 3.85e-02,  rl2 = 7.66e-01  |  Ghia mse = 1.25e-01,  Ghia rl2 = 8.82e-01
# iter. = 20500,  time = 037s,  loss = 3.48e-03  |  mse = 3.59e-02,  rl2 = 7.49e-01  |  Ghia mse = 1.25e-01,  Ghia rl2 = 8.84e-01
# iter. = 21000,  time = 038s,  loss = 7.75e-03  |  mse = 3.78e-02,  rl2 = 8.33e-01  |  Ghia mse = 1.25e-01,  Ghia rl2 = 8.83e-01
# iter. = 21500,  time = 039s,  loss = 4.53e-03  |  mse = 3.60e-02,  rl2 = 7.84e-01  |  Ghia mse = 1.25e-01,  Ghia rl2 = 8.81e-01
# iter. = 22000,  time = 040s,  loss = 1.54e-02  |  mse = 3.73e-02,  rl2 = 8.06e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.79e-01
# iter. = 22500,  time = 040s,  loss = 2.76e-03  |  mse = 3.46e-02,  rl2 = 8.48e-01  |  Ghia mse = 1.25e-01,  Ghia rl2 = 8.81e-01
# iter. = 23000,  time = 041s,  loss = 2.42e-03  |  mse = 3.49e-02,  rl2 = 7.83e-01  |  Ghia mse = 1.25e-01,  Ghia rl2 = 8.82e-01
# iter. = 23500,  time = 042s,  loss = 1.33e-02  |  mse = 3.93e-02,  rl2 = 7.34e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 24000,  time = 043s,  loss = 1.11e-03  |  mse = 3.53e-02,  rl2 = 8.48e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.77e-01
# iter. = 24500,  time = 043s,  loss = 2.80e-03  |  mse = 3.51e-02,  rl2 = 7.42e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.78e-01
# iter. = 25000,  time = 044s,  loss = 1.19e-03  |  mse = 3.78e-02,  rl2 = 7.76e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.76e-01
# iter. = 25500,  time = 045s,  loss = 5.55e-03  |  mse = 3.56e-02,  rl2 = 7.94e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.77e-01
# iter. = 26000,  time = 046s,  loss = 9.50e-03  |  mse = 3.63e-02,  rl2 = 7.58e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.74e-01
# iter. = 26500,  time = 046s,  loss = 4.76e-03  |  mse = 3.82e-02,  rl2 = 7.75e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.78e-01
# iter. = 27000,  time = 047s,  loss = 1.71e-03  |  mse = 3.98e-02,  rl2 = 7.09e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.75e-01
# iter. = 27500,  time = 048s,  loss = 9.17e-04  |  mse = 3.77e-02,  rl2 = 7.47e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 28000,  time = 049s,  loss = 2.25e-03  |  mse = 3.59e-02,  rl2 = 7.21e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 28500,  time = 050s,  loss = 1.00e-03  |  mse = 3.47e-02,  rl2 = 7.47e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 29000,  time = 050s,  loss = 9.24e-04  |  mse = 3.45e-02,  rl2 = 8.10e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 29500,  time = 051s,  loss = 5.33e-04  |  mse = 3.33e-02,  rl2 = 8.14e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 30000,  time = 052s,  loss = 8.39e-04  |  mse = 3.55e-02,  rl2 = 7.77e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 30500,  time = 053s,  loss = 4.39e-03  |  mse = 3.53e-02,  rl2 = 7.79e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 31000,  time = 053s,  loss = 8.37e-04  |  mse = 3.90e-02,  rl2 = 8.36e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 31500,  time = 054s,  loss = 2.75e-03  |  mse = 3.53e-02,  rl2 = 7.37e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 32000,  time = 055s,  loss = 2.58e-03  |  mse = 3.60e-02,  rl2 = 8.55e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.70e-01
# iter. = 32500,  time = 056s,  loss = 9.33e-04  |  mse = 3.59e-02,  rl2 = 7.54e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 33000,  time = 056s,  loss = 2.22e-03  |  mse = 3.71e-02,  rl2 = 8.57e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 33500,  time = 057s,  loss = 1.42e-03  |  mse = 3.62e-02,  rl2 = 7.88e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.70e-01
# iter. = 34000,  time = 058s,  loss = 1.65e-03  |  mse = 3.74e-02,  rl2 = 7.89e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# ...
# iter. = 39500,  time = 066s,  loss = 4.85e-04  |  mse = 3.79e-02,  rl2 = 7.83e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 40000,  time = 067s,  loss = 3.59e-04  |  mse = 3.91e-02,  rl2 = 8.20e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 40500,  time = 068s,  loss = 6.23e-04  |  mse = 3.57e-02,  rl2 = 7.16e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 41000,  time = 069s,  loss = 6.85e-04  |  mse = 3.67e-02,  rl2 = 8.22e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 41500,  time = 069s,  loss = 3.91e-04  |  mse = 3.58e-02,  rl2 = 7.89e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 42000,  time = 070s,  loss = 5.33e-04  |  mse = 3.36e-02,  rl2 = 7.78e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 42500,  time = 071s,  loss = 4.00e-04  |  mse = 3.69e-02,  rl2 = 7.63e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.67e-01
# iter. = 43000,  time = 072s,  loss = 6.13e-04  |  mse = 3.28e-02,  rl2 = 7.39e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 43500,  time = 072s,  loss = 5.15e-04  |  mse = 3.38e-02,  rl2 = 8.02e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 44000,  time = 073s,  loss = 2.99e-04  |  mse = 3.56e-02,  rl2 = 8.13e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 44500,  time = 074s,  loss = 3.56e-04  |  mse = 3.48e-02,  rl2 = 8.00e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 45000,  time = 075s,  loss = 3.41e-04  |  mse = 3.32e-02,  rl2 = 7.20e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 45500,  time = 075s,  loss = 3.86e-04  |  mse = 3.55e-02,  rl2 = 7.83e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 46000,  time = 076s,  loss = 4.26e-04  |  mse = 3.94e-02,  rl2 = 7.71e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 46500,  time = 077s,  loss = 3.57e-04  |  mse = 3.35e-02,  rl2 = 7.80e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 47000,  time = 078s,  loss = 3.85e-04  |  mse = 3.81e-02,  rl2 = 8.42e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 47500,  time = 079s,  loss = 3.27e-04  |  mse = 3.70e-02,  rl2 = 7.75e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 48000,  time = 079s,  loss = 8.22e-04  |  mse = 3.73e-02,  rl2 = 7.92e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 48500,  time = 080s,  loss = 3.76e-04  |  mse = 3.60e-02,  rl2 = 8.03e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 49000,  time = 081s,  loss = 3.61e-04  |  mse = 3.71e-02,  rl2 = 7.68e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 49500,  time = 082s,  loss = 3.84e-04  |  mse = 3.61e-02,  rl2 = 7.89e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 50000,  time = 082s,  loss = 3.28e-04  |  mse = 3.50e-02,  rl2 = 8.08e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# [In-house] :  MSE = 4.18e-02  RL2 = 9.20e-01
# [Ghia]     :  MSE = 1.20e-01  RL2 = 8.66e-01
# iter. = 00000,  time = 006s,  loss = 1.84e+01  |  mse = 1.32e-01,  rl2 = 1.55e+00  |  Ghia mse = 3.55e-01,  Ghia rl2 = 1.49e+00
# iter. = 00500,  time = 007s,  loss = 1.62e-01  |  mse = 3.35e-02,  rl2 = 7.19e-01  |  Ghia mse = 1.08e-01,  Ghia rl2 = 8.21e-01
# iter. = 01000,  time = 007s,  loss = 9.26e-02  |  mse = 3.94e-02,  rl2 = 8.73e-01  |  Ghia mse = 1.12e-01,  Ghia rl2 = 8.37e-01
# iter. = 01500,  time = 008s,  loss = 6.64e-02  |  mse = 3.36e-02,  rl2 = 7.96e-01  |  Ghia mse = 1.15e-01,  Ghia rl2 = 8.46e-01
# iter. = 02000,  time = 009s,  loss = 1.21e-02  |  mse = 3.52e-02,  rl2 = 8.18e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.54e-01
# iter. = 02500,  time = 010s,  loss = 3.21e-02  |  mse = 3.61e-02,  rl2 = 7.37e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.56e-01
# iter. = 03000,  time = 011s,  loss = 7.38e-02  |  mse = 3.69e-02,  rl2 = 7.56e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.63e-01
# iter. = 03500,  time = 011s,  loss = 5.96e-02  |  mse = 3.52e-02,  rl2 = 7.99e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.62e-01
# iter. = 04000,  time = 012s,  loss = 2.25e-02  |  mse = 3.70e-02,  rl2 = 8.54e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.63e-01
# iter. = 04500,  time = 013s,  loss = 2.71e-02  |  mse = 3.46e-02,  rl2 = 8.21e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 05000,  time = 014s,  loss = 7.38e-03  |  mse = 3.61e-02,  rl2 = 8.69e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 05500,  time = 014s,  loss = 2.56e-02  |  mse = 3.74e-02,  rl2 = 7.88e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 06000,  time = 015s,  loss = 2.94e-02  |  mse = 3.90e-02,  rl2 = 7.66e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.63e-01
# iter. = 06500,  time = 016s,  loss = 4.51e-02  |  mse = 3.72e-02,  rl2 = 7.56e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.64e-01
# iter. = 07000,  time = 017s,  loss = 1.43e-02  |  mse = 3.55e-02,  rl2 = 7.35e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 07500,  time = 017s,  loss = 1.13e-02  |  mse = 3.76e-02,  rl2 = 7.53e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.61e-01
# iter. = 08000,  time = 018s,  loss = 8.47e-03  |  mse = 3.81e-02,  rl2 = 7.94e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 08500,  time = 019s,  loss = 1.08e-02  |  mse = 3.48e-02,  rl2 = 7.68e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 09000,  time = 020s,  loss = 1.05e-02  |  mse = 3.96e-02,  rl2 = 7.81e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 09500,  time = 020s,  loss = 5.66e-03  |  mse = 3.63e-02,  rl2 = 7.81e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 10000,  time = 021s,  loss = 1.16e-02  |  mse = 3.39e-02,  rl2 = 7.38e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 10500,  time = 022s,  loss = 1.49e-02  |  mse = 3.75e-02,  rl2 = 7.89e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 11000,  time = 023s,  loss = 1.26e-02  |  mse = 3.76e-02,  rl2 = 7.85e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.64e-01
# iter. = 11500,  time = 023s,  loss = 1.32e-02  |  mse = 3.58e-02,  rl2 = 7.61e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.64e-01
# iter. = 12000,  time = 024s,  loss = 5.67e-03  |  mse = 3.68e-02,  rl2 = 8.35e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 12500,  time = 025s,  loss = 3.32e-03  |  mse = 3.47e-02,  rl2 = 8.17e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.63e-01
# iter. = 13000,  time = 026s,  loss = 4.36e-03  |  mse = 3.96e-02,  rl2 = 7.61e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 13500,  time = 026s,  loss = 2.26e-02  |  mse = 3.47e-02,  rl2 = 7.43e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 14000,  time = 027s,  loss = 1.34e-02  |  mse = 3.92e-02,  rl2 = 8.10e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.63e-01
# iter. = 14500,  time = 028s,  loss = 2.06e-02  |  mse = 3.73e-02,  rl2 = 7.94e-01  |  Ghia mse = 1.23e-01,  Ghia rl2 = 8.74e-01
# iter. = 15000,  time = 029s,  loss = 5.67e-03  |  mse = 3.41e-02,  rl2 = 8.02e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 15500,  time = 030s,  loss = 1.21e-02  |  mse = 3.37e-02,  rl2 = 7.96e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 16000,  time = 030s,  loss = 5.49e-03  |  mse = 3.67e-02,  rl2 = 8.32e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 16500,  time = 031s,  loss = 7.05e-03  |  mse = 3.43e-02,  rl2 = 8.56e-01  |  Ghia mse = 1.26e-01,  Ghia rl2 = 8.85e-01
# iter. = 17000,  time = 032s,  loss = 9.26e-03  |  mse = 3.61e-02,  rl2 = 8.05e-01  |  Ghia mse = 1.24e-01,  Ghia rl2 = 8.81e-01
# iter. = 17500,  time = 033s,  loss = 1.51e-02  |  mse = 3.56e-02,  rl2 = 7.67e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 18000,  time = 033s,  loss = 3.77e-02  |  mse = 3.46e-02,  rl2 = 7.75e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 18500,  time = 034s,  loss = 7.13e-03  |  mse = 3.70e-02,  rl2 = 8.20e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.71e-01
# iter. = 19000,  time = 035s,  loss = 1.76e-02  |  mse = 3.45e-02,  rl2 = 7.53e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.72e-01
# iter. = 19500,  time = 036s,  loss = 8.28e-03  |  mse = 3.84e-02,  rl2 = 8.20e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.73e-01
# iter. = 20000,  time = 036s,  loss = 1.37e-02  |  mse = 3.51e-02,  rl2 = 7.68e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 20500,  time = 037s,  loss = 6.30e-03  |  mse = 3.73e-02,  rl2 = 7.69e-01  |  Ghia mse = 1.22e-01,  Ghia rl2 = 8.70e-01
# iter. = 21000,  time = 038s,  loss = 1.74e-03  |  mse = 3.55e-02,  rl2 = 8.67e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 21500,  time = 039s,  loss = 1.61e-02  |  mse = 3.60e-02,  rl2 = 7.59e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.68e-01
# iter. = 22000,  time = 039s,  loss = 4.36e-03  |  mse = 3.54e-02,  rl2 = 7.89e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 22500,  time = 040s,  loss = 1.25e-02  |  mse = 3.63e-02,  rl2 = 8.07e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 23000,  time = 041s,  loss = 1.96e-03  |  mse = 3.96e-02,  rl2 = 7.72e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 23500,  time = 042s,  loss = 1.82e-03  |  mse = 3.63e-02,  rl2 = 7.97e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 24000,  time = 042s,  loss = 1.50e-03  |  mse = 3.41e-02,  rl2 = 7.79e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.70e-01
# iter. = 24500,  time = 043s,  loss = 3.85e-03  |  mse = 3.45e-02,  rl2 = 7.94e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.69e-01
# iter. = 25000,  time = 044s,  loss = 3.60e-03  |  mse = 3.58e-02,  rl2 = 7.42e-01  |  Ghia mse = 1.21e-01,  Ghia rl2 = 8.67e-01
# iter. = 25500,  time = 045s,  loss = 1.59e-02  |  mse = 3.56e-02,  rl2 = 7.52e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.63e-01
# iter. = 26000,  time = 046s,  loss = 8.85e-04  |  mse = 3.47e-02,  rl2 = 7.58e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.66e-01
# iter. = 26500,  time = 046s,  loss = 6.83e-04  |  mse = 3.41e-02,  rl2 = 7.61e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 27000,  time = 047s,  loss = 8.49e-03  |  mse = 3.58e-02,  rl2 = 7.89e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 27500,  time = 048s,  loss = 1.77e-03  |  mse = 3.52e-02,  rl2 = 7.60e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 28000,  time = 049s,  loss = 4.81e-03  |  mse = 3.28e-02,  rl2 = 7.17e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.64e-01
# iter. = 28500,  time = 049s,  loss = 1.37e-03  |  mse = 3.42e-02,  rl2 = 8.13e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.65e-01
# iter. = 29000,  time = 050s,  loss = 1.67e-02  |  mse = 3.57e-02,  rl2 = 8.03e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.67e-01
# iter. = 29500,  time = 051s,  loss = 2.02e-03  |  mse = 3.63e-02,  rl2 = 7.66e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.64e-01
# iter. = 30000,  time = 052s,  loss = 1.35e-03  |  mse = 3.56e-02,  rl2 = 7.78e-01  |  Ghia mse = 1.20e-01,  Ghia rl2 = 8.64e-01
# iter. = 30500,  time = 052s,  loss = 3.81e-03  |  mse = 3.53e-02,  rl2 = 7.60e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.58e-01
# iter. = 31000,  time = 053s,  loss = 1.81e-03  |  mse = 3.78e-02,  rl2 = 7.57e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.60e-01
# iter. = 31500,  time = 054s,  loss = 7.46e-04  |  mse = 3.58e-02,  rl2 = 8.58e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.62e-01
# iter. = 32000,  time = 055s,  loss = 3.14e-03  |  mse = 3.64e-02,  rl2 = 8.03e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.62e-01
# iter. = 32500,  time = 055s,  loss = 8.61e-04  |  mse = 3.77e-02,  rl2 = 7.84e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.61e-01
# iter. = 33000,  time = 056s,  loss = 1.24e-03  |  mse = 3.28e-02,  rl2 = 8.50e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.61e-01
# iter. = 33500,  time = 057s,  loss = 5.14e-04  |  mse = 3.52e-02,  rl2 = 7.71e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.61e-01
# iter. = 34000,  time = 058s,  loss = 7.59e-04  |  mse = 3.69e-02,  rl2 = 8.17e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.61e-01
# iter. = 34500,  time = 058s,  loss = 1.67e-03  |  mse = 3.82e-02,  rl2 = 8.51e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.63e-01
# iter. = 35000,  time = 059s,  loss = 3.93e-04  |  mse = 3.57e-02,  rl2 = 7.96e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.61e-01
# iter. = 35500,  time = 060s,  loss = 5.26e-04  |  mse = 3.66e-02,  rl2 = 7.74e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.60e-01
# iter. = 36000,  time = 061s,  loss = 5.40e-04  |  mse = 3.46e-02,  rl2 = 7.71e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.60e-01
# iter. = 36500,  time = 061s,  loss = 5.81e-04  |  mse = 3.30e-02,  rl2 = 7.41e-01  |  Ghia mse = 1.19e-01,  Ghia rl2 = 8.60e-01
# iter. = 37000,  time = 062s,  loss = 5.09e-04  |  mse = 3.60e-02,  rl2 = 7.38e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.59e-01
# iter. = 37500,  time = 063s,  loss = 1.26e-03  |  mse = 3.47e-02,  rl2 = 7.77e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.59e-01
# iter. = 38000,  time = 064s,  loss = 1.84e-03  |  mse = 3.45e-02,  rl2 = 7.39e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.58e-01
# iter. = 38500,  time = 065s,  loss = 4.34e-04  |  mse = 3.73e-02,  rl2 = 8.04e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.58e-01
# iter. = 39000,  time = 065s,  loss = 4.55e-04  |  mse = 3.66e-02,  rl2 = 7.82e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.59e-01
# iter. = 39500,  time = 066s,  loss = 3.88e-04  |  mse = 3.40e-02,  rl2 = 7.48e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.59e-01
# iter. = 40000,  time = 067s,  loss = 3.73e-04  |  mse = 3.69e-02,  rl2 = 8.51e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.58e-01
# iter. = 40500,  time = 068s,  loss = 4.13e-04  |  mse = 3.94e-02,  rl2 = 7.89e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.58e-01
# iter. = 41000,  time = 068s,  loss = 5.13e-04  |  mse = 3.66e-02,  rl2 = 8.18e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.58e-01
# iter. = 41500,  time = 069s,  loss = 3.20e-04  |  mse = 3.62e-02,  rl2 = 7.43e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.58e-01
# iter. = 42000,  time = 070s,  loss = 4.71e-04  |  mse = 3.17e-02,  rl2 = 7.89e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.57e-01
# iter. = 42500,  time = 071s,  loss = 3.51e-04  |  mse = 3.87e-02,  rl2 = 8.29e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.57e-01
# iter. = 43000,  time = 071s,  loss = 4.56e-04  |  mse = 3.66e-02,  rl2 = 8.27e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.57e-01
# iter. = 43500,  time = 072s,  loss = 3.80e-04  |  mse = 3.38e-02,  rl2 = 7.38e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.57e-01
# iter. = 44000,  time = 073s,  loss = 3.04e-04  |  mse = 3.64e-02,  rl2 = 7.55e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.57e-01
# iter. = 44500,  time = 074s,  loss = 4.15e-04  |  mse = 3.45e-02,  rl2 = 7.85e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.57e-01
# iter. = 45000,  time = 074s,  loss = 3.41e-04  |  mse = 3.30e-02,  rl2 = 7.41e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# iter. = 45500,  time = 075s,  loss = 3.52e-04  |  mse = 3.10e-02,  rl2 = 7.34e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# iter. = 46000,  time = 076s,  loss = 3.01e-04  |  mse = 3.78e-02,  rl2 = 8.11e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# iter. = 46500,  time = 077s,  loss = 3.26e-04  |  mse = 3.50e-02,  rl2 = 7.95e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# iter. = 47000,  time = 077s,  loss = 3.08e-04  |  mse = 3.33e-02,  rl2 = 7.70e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# iter. = 47500,  time = 078s,  loss = 3.44e-04  |  mse = 3.50e-02,  rl2 = 7.95e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# iter. = 48000,  time = 079s,  loss = 3.17e-04  |  mse = 3.79e-02,  rl2 = 8.60e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# iter. = 48500,  time = 080s,  loss = 3.35e-04  |  mse = 3.33e-02,  rl2 = 7.82e-01  |  Ghia mse = 1.17e-01,  Ghia rl2 = 8.56e-01
# iter. = 49000,  time = 081s,  loss = 2.81e-04  |  mse = 3.56e-02,  rl2 = 7.82e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# iter. = 49500,  time = 081s,  loss = 3.09e-04  |  mse = 3.63e-02,  rl2 = 7.74e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# iter. = 50000,  time = 082s,  loss = 2.96e-04  |  mse = 3.66e-02,  rl2 = 8.57e-01  |  Ghia mse = 1.18e-01,  Ghia rl2 = 8.56e-01
# [In-house] :  MSE = 4.06e-02  RL2 = 9.07e-01
# [Ghia]     :  MSE = 1.18e-01  RL2 = 8.56e-01

# %% [markdown]
#     iter. = 50000,  time = 088s,  loss = 2.98e-04  |  mse = 1.25e-05,  rl2 = 1.58e-02  |  Ghia mse = 6.62e-05,  Ghia rl2 = 2.03e-02
#     [In-house] :  MSE = 1.49e-05  RL2 = 1.74e-02
#     [Ghia]     :  MSE = 6.62e-05  RL2 = 2.03e-02

# %%
# data
Re = 3200
sim = pd.read_csv('LDC_RE3200_100x100_subsample200x200.csv')
data_X, data_Y = sim[['x', 'y']].values, sim[['u', 'v', 'p']].values
# exclude BC data
x_l, x_u, y_l, y_u = np.min(data_X[:,0]), np.max(data_X[:,0]), np.min(data_X[:,1]), np.max(data_X[:,1])
bcs = (data_X[:,0] == x_l) | (data_X[:,0] == x_u) | (data_X[:,1] == y_l) | (data_X[:,1] == y_u)
corners = (data_X[:,0] == x_l) & (data_X[:,1] == y_u) | (data_X[:,0] == x_u) & (data_X[:,1] == y_u) | (data_X[:,0] == x_l) & (data_X[:,1] == y_l) | (data_X[:,0] == x_u) & (data_X[:,1] == y_l)
#data_X, data_Y = data_X[~bcs], data_Y[~bcs]
inputs, labels = jnp.array(data_X), jnp.array(data_Y)

# model
model = PINN(32)

# %%
# PINN (final)
params = params_5[50]
pred = model.apply(params, inputs)
u, v, p, residuals_continuity, residuals_momentum_1, residuals_momentum_2, bc, nbc, m_1, m_2 = jnp.split(pred, 10, axis=1)
# set corner value
gt_u, gt_v, gt_p = jnp.split(labels, 3, axis=-1)
#u, v = u.at[corners].set(gt_u[corners]), v.at[corners].set(gt_v[corners])
u, v = u.at[bcs].set(gt_u[bcs]), v.at[bcs].set(gt_v[bcs])

# prediction errors
uv, gt_uv = jnp.hstack([u, v]), jnp.hstack([gt_u, gt_v])
mse = jnp.mean(jnp.square(uv - gt_uv))
rl2 = jnp.linalg.norm(uv - gt_uv) / jnp.linalg.norm(gt_uv)
print ('[In-House] :  MSE = %.2e  RL2 = %.2e'%(mse, rl2))

# plot predicted velocity
uv, gt_uv = jnp.sqrt(u**2 + v**2), jnp.sqrt(gt_u**2 + gt_v**2)

# plot inner domain
fig = plt.figure(figsize=(15, 3))
# low fi
con_lv = 101
n = 102
ext = [x_l, x_u, y_l, y_u]
# PINN
ax1 = fig.add_subplot(1,3,1)
clv = plt.contourf(gt_uv.reshape(n, n), con_lv, origin='lower', cmap='jet', extent=ext, vmin=0, vmax=0.9);
plt.colorbar(ticks=[0, 0.5, 1]) ;plt.title('Reference'); plt.xlabel('x'); plt.ylabel('y');
ax1 = fig.add_subplot(1,3,2)
plt.contourf(uv.reshape(n, n), con_lv, origin='lower', cmap='jet', extent=ext, vmin=0, vmax=0.9); plt.colorbar(ticks=[0, 0.5, 1]); plt.title('Predicted'); 
ax1 = fig.add_subplot(1,3,3)
plt.contourf(abs(uv - gt_uv).reshape(n, n), con_lv, origin='lower', cmap='jet', extent=ext, vmin=0, vmax=0.1); plt.colorbar(ticks=[0, 0.05, 0.1]); plt.title('Absolute error');
# Out:
# [In-House] :  MSE = 1.48e-05  RL2 = 1.73e-02

# %% [markdown]
#     [In-House] :  MSE = 1.48e-05  RL2 = 1.73e-02

# %%
# average of 5
rl2s = []
for seed in [90, 10, 70, 30, 50]:
    params = params_5[seed]
    pred = model.apply(params, inputs)
    u, v, p, residuals_continuity, residuals_momentum_1, residuals_momentum_2, bc, nbc, m_1, m_2 = jnp.split(pred, 10, axis=1)
    # set corner value
    gt_u, gt_v, gt_p = jnp.split(labels, 3, axis=-1)
    #u, v = u.at[corners].set(gt_u[corners]), v.at[corners].set(gt_v[corners])
    u, v = u.at[bcs].set(gt_u[bcs]), v.at[bcs].set(gt_v[bcs])
    # prediction errors
    uv, gt_uv = jnp.hstack([u, v]), jnp.hstack([gt_u, gt_v])
    mse = jnp.mean(jnp.square(uv - gt_uv))
    rl2 = jnp.linalg.norm(uv - gt_uv) / jnp.linalg.norm(gt_uv)
    print ('[In-House] :  MSE = %.2e  RL2 = %.2e'%(mse, rl2))
    rl2s.append(rl2)
rl2s = np.array(rl2s)
print ('[In-House] :  RL2 best = %.2e  ave = %.2e'%(rl2s.min(), rl2s.mean()))
# Out:
# [In-House] :  MSE = 3.17e-05  RL2 = 2.53e-02
# [In-House] :  MSE = 1.89e-04  RL2 = 6.18e-02
# [In-House] :  MSE = 3.06e-05  RL2 = 2.49e-02
# [In-House] :  MSE = 1.81e-04  RL2 = 6.05e-02
# [In-House] :  MSE = 1.48e-05  RL2 = 1.73e-02
# [In-House] :  RL2 best = 1.73e-02  ave = 3.79e-02

# %%
# convergence
p_time2sol_5 = {}
for seed in [90, 10, 70, 30, 50]:
    store_nnws = store_nnws_5[seed]
    p_time2sol = []
    for i in range(0, len(store_nnws), 5):
        runtime, params = store_nnws[i]
        pred = model.apply(params, inputs)
        u, v, p, residuals_continuity, residuals_momentum_1, residuals_momentum_2, bc, nbc, m_1, m_2 = jnp.split(pred, 10, axis=1)
        # set corner value
        gt_u, gt_v, gt_p = jnp.split(labels, 3, axis=-1)
        u, v = u.at[bcs].set(gt_u[bcs]), v.at[bcs].set(gt_v[bcs])
        # prediction errors
        uv, gt_uv = jnp.hstack([u, v]), jnp.hstack([gt_u, gt_v])
        mse = jnp.mean(jnp.square(uv - gt_uv))
        rl2 = jnp.linalg.norm(uv - gt_uv) / jnp.linalg.norm(gt_uv)
        #print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
        p_time2sol.append([runtime, rl2])
    print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
    p_time2sol = np.array(p_time2sol)
    p_time2sol_5[seed] = p_time2sol
#plt.plot(p_time2sol[:,0], p_time2sol[:,1], c='lightgreen', markeredgecolor='green', marker='o', markersize=5, linestyle='-.');
#plt.xlabel('Training time'); plt.ylabel('Relative error'); plt.yscale('log');
# Out:
# [time = 084s] :  RL2 = 2.53e-02
# [time = 085s] :  RL2 = 6.17e-02
# [time = 085s] :  RL2 = 2.51e-02
# [time = 085s] :  RL2 = 6.06e-02
# [time = 085s] :  RL2 = 1.73e-02

# %%
# convergence (ref)
ref_p_time2sol_5 = {}
for seed in [90, 10, 70, 30, 50]:
    store_nnws = ref_store_nnws_5[seed]
    p_time2sol = []
    for i in range(0, len(store_nnws), 5):
        runtime, params = store_nnws[i]
        pred = model.apply(params, inputs)
        u, v, p, residuals_continuity, residuals_momentum_1, residuals_momentum_2, bc, nbc, m_1, m_2 = jnp.split(pred, 10, axis=1)
        # set corner value
        gt_u, gt_v, gt_p = jnp.split(labels, 3, axis=-1)
        u, v = u.at[bcs].set(gt_u[bcs]), v.at[bcs].set(gt_v[bcs])
        # prediction errors
        uv, gt_uv = jnp.hstack([u, v]), jnp.hstack([gt_u, gt_v])
        mse = jnp.mean(jnp.square(uv - gt_uv))
        rl2 = jnp.linalg.norm(uv - gt_uv) / jnp.linalg.norm(gt_uv)
        #print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
        p_time2sol.append([runtime, rl2])
    print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
    p_time2sol = np.array(p_time2sol)
    ref_p_time2sol_5[seed] = p_time2sol
# Out:
# [time = 082s] :  RL2 = 9.25e-01
# [time = 081s] :  RL2 = 9.19e-01
# [time = 081s] :  RL2 = 9.17e-01
# [time = 082s] :  RL2 = 9.19e-01
# [time = 081s] :  RL2 = 9.06e-01

# %%
fig = plt.figure(figsize=(2, 4))
makers = ['^', '<', '>', 'v', 'o']
for i, seed in enumerate([90, 10, 70, 30, 50]):
    p_time2sol = p_time2sol_5[seed]
    plt.plot(p_time2sol[:,0], p_time2sol[:,1], c='lightgreen', markeredgecolor='green', marker=makers[i], markersize=3, linestyle='-.');
plt.plot(p_time2sol[:,0], p_time2sol[:,1], c='salmon', markeredgecolor='maroon', marker=makers[i], markersize=3, linestyle='-.', label='Baseline');
plt.plot(p_time2sol[:,0], p_time2sol[:,1], c='lightgreen', markeredgecolor='green', marker=makers[i], markersize=3, linestyle='-.', label='Scale-PINN');
for i, seed in enumerate([90, 10, 70, 30, 50]):
    p_time2sol = ref_p_time2sol_5[seed]
    plt.plot(p_time2sol[:,0], p_time2sol[:,1], c='salmon', markeredgecolor='maroon', marker=makers[i], markersize=3, linestyle='-.');
plt.xlabel('Training time (s)'); plt.ylabel('Relative error'); plt.yscale('log'); plt.ylim(1e-2, 10); plt.xlim(-0.5, 90.5);
plt.xticks([0, 30, 60, 90]); plt.legend();

# %%
# PINN (final)
params = params_5[50]
pred = model.apply(params, inputs)
u, v, p, residuals_continuity, residuals_momentum_1, residuals_momentum_2, bc, nbc, m_1, m_2 = jnp.split(pred, 10, axis=1)
# set corner value
gt_u, gt_v, gt_p = jnp.split(labels, 3, axis=-1)
#u, v = u.at[corners].set(gt_u[corners]), v.at[corners].set(gt_v[corners])
u, v = u.at[bcs].set(gt_u[bcs]), v.at[bcs].set(gt_v[bcs])

# prediction errors
uv, gt_uv = jnp.hstack([u, v]), jnp.hstack([gt_u, gt_v])
mse = jnp.mean(jnp.square(uv - gt_uv))
rl2 = jnp.linalg.norm(uv - gt_uv) / jnp.linalg.norm(gt_uv)
print ('[In-House] :  MSE = %.2e  RL2 = %.2e'%(mse, rl2))

# plot predicted velocity
uv, gt_uv = jnp.sqrt(u**2 + v**2), jnp.sqrt(gt_u**2 + gt_v**2)

# plot inner domain
fig = plt.figure(figsize=(2, 1.5))
# low fi
con_lv = 101
n = 102
ext = [x_l, x_u, y_l, y_u]
test_x, test_y = np.linspace(0,1,n),np.linspace(0,1,n)
# PINN
plt.contourf(uv.reshape(n, n), con_lv, origin='lower', cmap='jet', extent=ext, vmin=0, vmax=0.9);
plt.colorbar(ticks=[0, 1]); plt.title('Final (best)'); 
plt.streamplot(test_x, test_y, np.array(u.reshape(n, n)), np.array(v.reshape(n, n)),
               density=1.1, linewidth=.45, arrowsize=.45, minlength=.1, arrowstyle='->', color='white');
plt.xticks([0.5], ['0.5']); plt.yticks([0.5], ['0.5']); plt.xlim(0.0, 0.999); plt.ylim(0.001, 1.0);
# Out:
# [In-House] :  MSE = 1.48e-05  RL2 = 1.73e-02

# %%
# PINN (ref)
params = ref_params_5[50]
pred = model.apply(params, inputs)
u, v, p, residuals_continuity, residuals_momentum_1, residuals_momentum_2, bc, nbc, m_1, m_2 = jnp.split(pred, 10, axis=1)
# set corner value
gt_u, gt_v, gt_p = jnp.split(labels, 3, axis=-1)
#u, v = u.at[corners].set(gt_u[corners]), v.at[corners].set(gt_v[corners])
u, v = u.at[bcs].set(gt_u[bcs]), v.at[bcs].set(gt_v[bcs])

# prediction errors
uv, gt_uv = jnp.hstack([u, v]), jnp.hstack([gt_u, gt_v])
mse = jnp.mean(jnp.square(uv - gt_uv))
rl2 = jnp.linalg.norm(uv - gt_uv) / jnp.linalg.norm(gt_uv)
print ('[In-House] :  MSE = %.2e  RL2 = %.2e'%(mse, rl2))

# plot predicted velocity
uv, gt_uv = jnp.sqrt(u**2 + v**2), jnp.sqrt(gt_u**2 + gt_v**2)

# plot inner domain
fig = plt.figure(figsize=(2, 1.5))
# low fi
con_lv = 101
n = 102
ext = [x_l, x_u, y_l, y_u]
test_x, test_y = np.linspace(0,1,n),np.linspace(0,1,n)
# PINN
plt.contourf(uv.reshape(n, n), con_lv, origin='lower', cmap='jet', extent=ext, vmin=0, vmax=0.9);
plt.colorbar(ticks=[0, 1]); plt.title('Baseline'); 
plt.streamplot(test_x, test_y, np.array(u.reshape(n, n)), np.array(v.reshape(n, n)),
               density=0.9, linewidth=.3, arrowsize=.3, minlength=.1, arrowstyle='->', color='white');
plt.xticks([0.5], ['0.5']); plt.yticks([0.5], ['0.5']); plt.xlim(0.0, 0.999); plt.ylim(0.001, 1.0);
# Out:
# [In-House] :  MSE = 4.06e-02  RL2 = 9.06e-01

# %%
# PINN (initial)
store_nnws = store_nnws_5[50]
runtime, params = store_nnws[0]
pred = model.apply(params, inputs)
u, v, p, residuals_continuity, residuals_momentum_1, residuals_momentum_2, bc, nbc, m_1, m_2 = jnp.split(pred, 10, axis=1)
# set corner value
gt_u, gt_v, gt_p = jnp.split(labels, 3, axis=-1)
#u, v = u.at[corners].set(gt_u[corners]), v.at[corners].set(gt_v[corners])
#u, v = u.at[bcs].set(gt_u[bcs]), v.at[bcs].set(gt_v[bcs])

# prediction errors
uv, gt_uv = jnp.hstack([u, v]), jnp.hstack([gt_u, gt_v])
mse = jnp.mean(jnp.square(uv - gt_uv))
rl2 = jnp.linalg.norm(uv - gt_uv) / jnp.linalg.norm(gt_uv)
print ('[In-House] :  MSE = %.2e  RL2 = %.2e'%(mse, rl2))

# plot predicted velocity
uv, gt_uv = jnp.sqrt(u**2 + v**2), jnp.sqrt(gt_u**2 + gt_v**2)

# plot inner domain
fig = plt.figure(figsize=(2, 1.5))
# low fi
con_lv = 101
n = 102
ext = [x_l, x_u, y_l, y_u]
test_x, test_y = np.linspace(0,1,n),np.linspace(0,1,n)
# PINN
plt.contourf(uv.reshape(n, n), con_lv, origin='lower', cmap='jet', extent=ext, vmin=0, vmax=0.9);
plt.colorbar(ticks=[0, 1]); plt.title('Initial'); 
plt.streamplot(test_x, test_y, np.array(u.reshape(n, n)), np.array(v.reshape(n, n)),
               density=1.05, linewidth=.45, arrowsize=.45, minlength=.1, arrowstyle='->', color='white');
plt.xticks([0.5], ['0.5']); plt.yticks([0.5], ['0.5']); plt.xlim(0.0, 0.999); plt.ylim(0.001, 1.0);
# Out:
# [In-House] :  MSE = 1.30e-01  RL2 = 1.62e+00

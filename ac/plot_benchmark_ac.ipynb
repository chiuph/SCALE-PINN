# %%
import jax
import flax
import optax
from jax import lax, random, numpy as jnp
from jax import random, grad, vmap, hessian, jacfwd, jit
from jax import config
from flax import linen as nn
from evojax.util import get_params_format_fn

import os
import time
import numpy as np
import pandas as pd
from scipy import io
import matplotlib.pyplot as plt
import argparse

# choose GPU
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

#jax.config.update("jax_enable_x64", True)
jax.config.update("jax_default_matmul_precision", "highest")

# %%
"""DNN / PINN   """

class PINN(nn.Module):
    """PINNs"""
    n_nodes: int
    def setup(self):
        self.layers = [nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       jnp.sin,
                       nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       nn.silu]
        self.last_layer = nn.Dense(1, kernel_init = jax.nn.initializers.he_uniform(), use_bias=False)

    @nn.compact
    def __call__(self, inputs):
        # split the two variables, probably just by slicing
        t, x = inputs[:,0:1], inputs[:,1:2]
        def get_u(t, x):
            f = jnp.hstack([t, x])
            fs = [f]
            for i, lyr in enumerate(self.layers):
                f = lyr(f)
                if (i == 0):
                    f = 2 *jnp.pi *f
                if (i%2 != 0):
                    fs.append(f)
            #f = jnp.hstack(fs)
            u = self.last_layer(f)
            return u

        u = get_u(t, x)

        # obtain u_t, u_xx
        def get_u_dir(get_u, t, x):
            u_t, u_x = jacfwd(get_u)(t, x), jacfwd(get_u, argnums=1)(t, x)
            u_xx = jacfwd(jacfwd(get_u, argnums=1), argnums=1)(t, x)
            return u_t, u_x, u_xx

        f_dir_vmap = vmap(get_u_dir, in_axes=(None, 0, 0))
        u_t, u_x, u_xx = f_dir_vmap(get_u, t, x)
        u_t, u_x, u_xx = u_t[:,:,0], u_x[:,:,0], u_xx[:,:,0,0]

        # obtain BC/IC indices
        ic, bc = (t == t_l), (x == x_l) # (x==x_l2)  # lower x
        pbc = get_u(t, jnp.ones_like(t)*x_u) - u
        nbc = get_u(t, jnp.ones_like(t)*x_u2) - get_u(t, jnp.ones_like(t)*x_l2)

        # PDE: u_t - v2* u_xx + 5*(u**3) - 5*u = 0
        pde = (u_t - v2* u_xx + 5*(u**3) - 5*u)  

        outputs = jnp.hstack([u, u_xx, pde, pbc, nbc, ic, bc])
        return outputs


class DNN(nn.Module):
    """DNNs"""
    n_nodes: int
    def setup(self):
        self.layers = [nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       jnp.sin,
                       nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       nn.silu,
                       nn.Dense(self.n_nodes, kernel_init = jax.nn.initializers.he_uniform()),
                       nn.silu]
        self.last_layer = nn.Dense(1, kernel_init = jax.nn.initializers.he_uniform(), use_bias=False)

    @nn.compact
    def __call__(self, inputs):
        # split the two variables, probably just by slicing
        t, x = inputs[:,0:1], inputs[:,1:2]
        def get_u(t, x):
            f = jnp.hstack([t, x])
            fs = [f]
            for i, lyr in enumerate(self.layers):
                f = lyr(f)
                if (i == 0):
                    f = 2 *jnp.pi *f
                if (i%2 != 0):
                    fs.append(f)
            #f = jnp.hstack(fs)
            u = self.last_layer(f)
            return u

        u = get_u(t, x)
        def get_u0_dir(get_u, t, x):
            u_xx = jacfwd(jacfwd(get_u, argnums=1), argnums=1)(t, x)
            return  u_xx
        
        f_dir_vmap = vmap(get_u0_dir, in_axes=(None, 0, 0))
        u_xx = f_dir_vmap(get_u, t, x)[:,:,0,0]

        outputs = jnp.hstack([u, u_xx])
        return outputs

# %%
def main(ER, ER_xx, weight_ic, weight_bc, max_lr, exponent, max_iter, seed, gpu):
    

    global v2, t_l, t_u, x_l, x_u, x_l2, x_u2
    
    # parameter
    v2 = 0.0001
    
    # read data
    mat_data = io.loadmat('allen_cahn.mat')

    sim_t = np.repeat(mat_data['t'], 512).reshape(-1,1)
    sim_x = np.tile(mat_data['x'], 201).reshape(-1,1)
    sim_u = mat_data['usol'].reshape(-1,1)
    tt, xx = mat_data['t'], mat_data['x']
    
    # spatial resolution
    t_l, t_u, x_l, x_u = np.min(sim_t), np.max(sim_t), np.min(sim_x), np.max(sim_x)
    dt, dx = tt[0,1] - tt[0,0], xx[0,1] - xx[0,0]
    x_l2, x_u2 = x_l + dx, x_u - dx

    data_X, data_Y = np.hstack([sim_t, sim_x]), sim_u

    # split into BC / IC data
    bic = (data_X[:,0] == 0) | (data_X[:,1] == x_l)
    data_X_BIC, data_Y_BIC = data_X[bic], data_Y[bic]

    # convert to jnp
    data_X, data_Y, data_X_BIC, data_Y_BIC = jnp.array(data_X), jnp.array(data_Y), jnp.array(data_X_BIC), jnp.array(data_Y_BIC)


    # choose seed
    seed = seed
    key, rng = random.split(random.PRNGKey(seed))

    # dummy input
    a = random.normal(key, [1,2])

    # initialization call
    n_nodes = 128
    model, model_0 = PINN(n_nodes), DNN(n_nodes)
    params = model.init(key, a)
    num_params, format_params_fn = get_params_format_fn(params)

    # flatten initial params
    params = jax.flatten_util.ravel_pytree(params)[0]

    # update u_0
    params_0 = params

    # minibatch (set #sample)
    BS_ALL = 1000
    BS_BIC = 50

    n_all, n_bic = len(data_X), len(data_X_BIC)

    @jit
    def minibatch(key):
        key1, key2 = key
        batch_all = random.choice(key1, n_all, (BS_ALL - BS_BIC,))
        batch_bic = random.choice(key2, n_bic, (BS_BIC,))
        batch_X = jnp.vstack([data_X[batch_all], data_X_BIC[batch_bic]])
        batch_Y = jnp.vstack([data_Y[batch_all], data_Y_BIC[batch_bic]])
        return (batch_X, batch_Y)

    # loss function
    def eval_loss(params, params_0, inputs, labels):
        pred = model.apply(format_params_fn(params), inputs)
        u, u_xx, pde, pbc, nbc, ic, bc = jnp.split(pred, 7, axis=1)
        # stable evolution
        pred_0 = model_0.apply(format_params_fn(params_0), inputs)
        u_0, u0_xx = jnp.split(pred_0, 2, axis=1)
        if (ER > 0):
            pde = pde + (u - u_0) / ER  - v2*(u_xx - u0_xx) / ER_xx # ER @PDE
        pde_loss = jnp.mean(jnp.square(pde))
        # IC
        ic_e = (labels - u) * ic
        ic_loss = jnp.sum(jnp.square(ic_e)) / ic.sum()
        # BC (periodic)
        bc_e, nbc_e = pbc * bc, nbc * bc
        bc_loss = jnp.sum(jnp.square(bc_e)) / bc.sum() + jnp.sum(jnp.square(nbc_e)) / bc.sum()
        # stable evolution
        #er_loss = jnp.mean(jnp.square((u - u_0))) / .2
        # mse
        mse = jnp.mean(jnp.square(labels - u))
        rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
        loss = pde_loss + weight_ic* ic_loss + weight_bc* bc_loss #+ er_loss
        return loss, (mse, rl2)

    loss_grad = jax.jit(jax.value_and_grad(eval_loss, has_aux=True))

    # weights update
    @jit
    def update(params, params_0, opt_state, key):
        batch_X, batch_Y = minibatch(key)
        (loss, (mse, rl2)), grad = loss_grad(params, params_0, batch_X, batch_Y)
        updates, opt_state = optimizer.update(grad, opt_state)
        params_0 = params # update u_0
        params = optax.apply_updates(params, updates)
        return params, params_0, opt_state, loss, mse, rl2

    # optimizer
    max_iters = max_iter
    max_lr = max_lr
    lr_scheduler = optax.warmup_cosine_decay_schedule(init_value=max_lr, peak_value=max_lr, warmup_steps=0,
                                                    decay_steps=max_iters, end_value=1e-10, exponent=exponent)
    optimizer = optax.adam(learning_rate=lr_scheduler) # Choose the method
    opt_state = optimizer.init(params)

    """Training"""

    # training iteration
    runtime = 0
    train_iters = 0

    #store = []
    store_nnws = []
    store_nnws.append([0, format_params_fn(params)])

    while (train_iters <= max_iters) and (runtime < 2000):
        # mini-batch update
        start = time.time()
        key1, key2, rng = random.split(rng, 3) # update random generator
        params, params_0, opt_state, loss, mse, rl2 = update(params, params_0, opt_state, (key1, key2))
        end = time.time()
        runtime += (end-start)
        # append weights
        if (train_iters % 5000 == 0):
            print ('iter. = %05d,  time = %03ds,  loss = %.2e  |  mse = %.2e,  rl2 = %.2e'%(train_iters, runtime, loss, mse, rl2))
            # store.append([train_iters, runtime, loss, mse, rl2])
            store_nnws.append([runtime, format_params_fn(params)])
        train_iters += 1

    # store = jnp.array(store)

    """iter. = 200000,  time = 151s,  loss = 1.76e-06  |  mse = 2.51e-07,  rl2 = 7.25e-04

    PINN solution
    """

    # on all tasks
    inputs, labels = data_X, data_Y
    pred = model.apply(format_params_fn(params), inputs)
    u, _, _, _, _, _,_ = jnp.split(pred, 7, axis=1)
    mse = jnp.mean(jnp.square(labels - u))
    rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
    print ('[v2=%.1e] :  MSE = %.2e  RL2 = %.2e'%(v2, mse, rl2))
    
    return format_params_fn(params), store_nnws

# %%
# # run main (ER)
# params = main(ER=0.45, ER_xx=1.5, weight_ic=100, weight_bc=100,
#               max_lr=2e-3, exponent=1.2, max_iter=500000, seed=50, gpu=0)

# %%
# 5 runs
params_5, store_nnws_5 = {}, {}
for seed in [10, 20, 30, 40, 50]:
    # run main (ER)
    params, store_nnws = main(ER=0.45, ER_xx=1.5, weight_ic=100, weight_bc=100,
                              max_lr=2e-3, exponent=1.2, max_iter=500000, seed=seed, gpu=0)
    params_5[seed] = params
    store_nnws_5[seed] = store_nnws
# Out:
# iter. = 00000,  time = 003s,  loss = 7.09e+01  |  mse = 7.51e-01,  rl2 = 1.23e+00
# iter. = 05000,  time = 008s,  loss = 2.15e-02  |  mse = 1.98e-02,  rl2 = 1.98e-01
# iter. = 10000,  time = 013s,  loss = 2.64e-03  |  mse = 7.57e-04,  rl2 = 3.94e-02
# iter. = 15000,  time = 019s,  loss = 1.25e-03  |  mse = 1.60e-04,  rl2 = 1.78e-02
# iter. = 20000,  time = 024s,  loss = 2.53e-02  |  mse = 2.88e-04,  rl2 = 2.40e-02
# iter. = 25000,  time = 029s,  loss = 2.83e-04  |  mse = 2.32e-04,  rl2 = 2.17e-02
# iter. = 30000,  time = 034s,  loss = 9.89e-04  |  mse = 5.94e-05,  rl2 = 1.07e-02
# iter. = 35000,  time = 039s,  loss = 2.29e-03  |  mse = 2.39e-04,  rl2 = 2.22e-02
# iter. = 40000,  time = 045s,  loss = 5.93e-04  |  mse = 2.93e-05,  rl2 = 7.71e-03
# iter. = 45000,  time = 050s,  loss = 1.68e-04  |  mse = 1.82e-05,  rl2 = 6.06e-03
# iter. = 50000,  time = 055s,  loss = 5.59e-04  |  mse = 3.84e-05,  rl2 = 8.67e-03
# iter. = 55000,  time = 060s,  loss = 1.20e-03  |  mse = 4.98e-05,  rl2 = 9.90e-03
# iter. = 60000,  time = 066s,  loss = 8.35e-04  |  mse = 2.68e-05,  rl2 = 7.43e-03
# iter. = 65000,  time = 071s,  loss = 5.88e-05  |  mse = 1.08e-05,  rl2 = 4.62e-03
# iter. = 70000,  time = 076s,  loss = 1.93e-04  |  mse = 1.53e-05,  rl2 = 5.53e-03
# iter. = 75000,  time = 081s,  loss = 3.93e-04  |  mse = 5.79e-05,  rl2 = 1.08e-02
# iter. = 80000,  time = 086s,  loss = 1.90e-04  |  mse = 4.07e-05,  rl2 = 8.96e-03
# iter. = 85000,  time = 092s,  loss = 1.63e-03  |  mse = 4.74e-05,  rl2 = 9.81e-03
# iter. = 90000,  time = 097s,  loss = 2.35e-04  |  mse = 3.76e-05,  rl2 = 8.85e-03
# iter. = 95000,  time = 102s,  loss = 3.74e-05  |  mse = 5.00e-05,  rl2 = 9.92e-03
# iter. = 100000,  time = 107s,  loss = 4.18e-04  |  mse = 9.81e-05,  rl2 = 1.43e-02
# iter. = 105000,  time = 113s,  loss = 7.59e-05  |  mse = 3.44e-05,  rl2 = 8.27e-03
# iter. = 110000,  time = 118s,  loss = 5.66e-05  |  mse = 3.29e-05,  rl2 = 8.25e-03
# iter. = 115000,  time = 123s,  loss = 5.91e-04  |  mse = 5.04e-05,  rl2 = 9.99e-03
# iter. = 120000,  time = 129s,  loss = 1.69e-04  |  mse = 3.47e-05,  rl2 = 8.38e-03
# iter. = 125000,  time = 134s,  loss = 7.71e-05  |  mse = 1.58e-05,  rl2 = 5.52e-03
# iter. = 130000,  time = 139s,  loss = 1.67e-04  |  mse = 4.32e-05,  rl2 = 9.44e-03
# iter. = 135000,  time = 144s,  loss = 2.22e-04  |  mse = 3.11e-05,  rl2 = 7.86e-03
# iter. = 140000,  time = 150s,  loss = 3.20e-04  |  mse = 5.35e-06,  rl2 = 3.23e-03
# iter. = 145000,  time = 155s,  loss = 1.47e-04  |  mse = 1.16e-05,  rl2 = 4.72e-03
# iter. = 150000,  time = 160s,  loss = 2.87e-04  |  mse = 3.51e-05,  rl2 = 8.18e-03
# iter. = 155000,  time = 165s,  loss = 1.30e-05  |  mse = 2.82e-06,  rl2 = 2.37e-03
# iter. = 160000,  time = 171s,  loss = 1.45e-03  |  mse = 3.88e-05,  rl2 = 8.90e-03
# iter. = 165000,  time = 176s,  loss = 6.39e-06  |  mse = 1.92e-06,  rl2 = 2.00e-03
# iter. = 170000,  time = 181s,  loss = 9.82e-05  |  mse = 8.34e-06,  rl2 = 4.11e-03
# iter. = 175000,  time = 186s,  loss = 6.85e-06  |  mse = 3.65e-06,  rl2 = 2.69e-03
# iter. = 180000,  time = 192s,  loss = 9.73e-05  |  mse = 1.21e-05,  rl2 = 4.96e-03
# iter. = 185000,  time = 197s,  loss = 7.16e-06  |  mse = 3.20e-06,  rl2 = 2.52e-03
# iter. = 190000,  time = 202s,  loss = 8.76e-06  |  mse = 1.21e-04,  rl2 = 1.55e-02
# iter. = 195000,  time = 208s,  loss = 5.08e-05  |  mse = 1.05e-05,  rl2 = 4.61e-03
# iter. = 200000,  time = 213s,  loss = 1.31e-04  |  mse = 1.82e-05,  rl2 = 6.17e-03
# iter. = 205000,  time = 218s,  loss = 4.10e-05  |  mse = 3.75e-06,  rl2 = 2.79e-03
# iter. = 210000,  time = 223s,  loss = 1.29e-05  |  mse = 1.19e-06,  rl2 = 1.57e-03
# iter. = 215000,  time = 229s,  loss = 3.65e-06  |  mse = 1.20e-06,  rl2 = 1.55e-03
# iter. = 220000,  time = 234s,  loss = 2.21e-05  |  mse = 3.22e-06,  rl2 = 2.58e-03
# iter. = 225000,  time = 239s,  loss = 1.50e-05  |  mse = 2.19e-06,  rl2 = 2.06e-03
# iter. = 230000,  time = 245s,  loss = 1.14e-04  |  mse = 5.97e-06,  rl2 = 3.46e-03
# iter. = 235000,  time = 250s,  loss = 1.07e-04  |  mse = 5.51e-06,  rl2 = 3.40e-03
# iter. = 240000,  time = 255s,  loss = 1.82e-05  |  mse = 2.54e-06,  rl2 = 2.26e-03
# iter. = 245000,  time = 260s,  loss = 4.14e-05  |  mse = 6.89e-06,  rl2 = 3.63e-03
# iter. = 250000,  time = 266s,  loss = 1.28e-05  |  mse = 9.71e-07,  rl2 = 1.42e-03
# iter. = 255000,  time = 271s,  loss = 1.71e-05  |  mse = 1.34e-06,  rl2 = 1.61e-03
# iter. = 260000,  time = 276s,  loss = 7.02e-06  |  mse = 7.02e-07,  rl2 = 1.18e-03
# iter. = 265000,  time = 282s,  loss = 2.02e-04  |  mse = 1.71e-05,  rl2 = 5.81e-03
# iter. = 270000,  time = 287s,  loss = 3.16e-06  |  mse = 2.08e-07,  rl2 = 6.42e-04
# iter. = 275000,  time = 292s,  loss = 4.40e-05  |  mse = 8.30e-07,  rl2 = 1.32e-03
# iter. = 280000,  time = 297s,  loss = 2.06e-05  |  mse = 2.53e-07,  rl2 = 7.21e-04
# iter. = 285000,  time = 303s,  loss = 8.98e-06  |  mse = 1.18e-06,  rl2 = 1.55e-03
# iter. = 290000,  time = 308s,  loss = 3.77e-06  |  mse = 2.74e-07,  rl2 = 7.49e-04
# iter. = 295000,  time = 313s,  loss = 7.99e-05  |  mse = 1.26e-06,  rl2 = 1.56e-03
# iter. = 300000,  time = 319s,  loss = 7.61e-07  |  mse = 3.31e-07,  rl2 = 8.30e-04
# iter. = 305000,  time = 324s,  loss = 1.19e-05  |  mse = 4.06e-07,  rl2 = 8.88e-04
# iter. = 310000,  time = 329s,  loss = 9.28e-07  |  mse = 1.90e-07,  rl2 = 6.21e-04
# iter. = 315000,  time = 335s,  loss = 1.28e-05  |  mse = 3.93e-07,  rl2 = 8.90e-04
# iter. = 320000,  time = 340s,  loss = 9.31e-06  |  mse = 2.53e-07,  rl2 = 7.06e-04
# iter. = 325000,  time = 345s,  loss = 1.31e-05  |  mse = 9.53e-07,  rl2 = 1.37e-03
# iter. = 330000,  time = 350s,  loss = 3.57e-06  |  mse = 1.55e-07,  rl2 = 5.62e-04
# iter. = 335000,  time = 356s,  loss = 2.25e-06  |  mse = 6.09e-08,  rl2 = 3.46e-04
# iter. = 340000,  time = 361s,  loss = 5.82e-06  |  mse = 3.16e-07,  rl2 = 7.91e-04
# iter. = 345000,  time = 366s,  loss = 2.68e-06  |  mse = 1.02e-06,  rl2 = 1.44e-03
# iter. = 350000,  time = 372s,  loss = 8.09e-06  |  mse = 2.42e-07,  rl2 = 6.84e-04
# iter. = 355000,  time = 377s,  loss = 1.24e-07  |  mse = 4.22e-08,  rl2 = 2.90e-04
# iter. = 360000,  time = 382s,  loss = 1.19e-05  |  mse = 1.28e-07,  rl2 = 5.07e-04
# iter. = 365000,  time = 388s,  loss = 8.33e-07  |  mse = 3.91e-08,  rl2 = 2.80e-04
# iter. = 370000,  time = 393s,  loss = 2.20e-07  |  mse = 2.89e-08,  rl2 = 2.41e-04
# iter. = 375000,  time = 398s,  loss = 5.67e-06  |  mse = 1.68e-07,  rl2 = 5.86e-04
# iter. = 380000,  time = 403s,  loss = 1.53e-06  |  mse = 7.54e-08,  rl2 = 3.89e-04
# iter. = 385000,  time = 409s,  loss = 6.49e-07  |  mse = 4.40e-08,  rl2 = 2.99e-04
# iter. = 390000,  time = 414s,  loss = 3.92e-07  |  mse = 3.95e-08,  rl2 = 2.77e-04
# iter. = 395000,  time = 419s,  loss = 2.48e-07  |  mse = 1.22e-08,  rl2 = 1.62e-04
# iter. = 400000,  time = 425s,  loss = 3.75e-06  |  mse = 7.28e-08,  rl2 = 3.88e-04
# iter. = 405000,  time = 430s,  loss = 2.21e-07  |  mse = 6.67e-09,  rl2 = 1.19e-04
# iter. = 410000,  time = 435s,  loss = 7.43e-07  |  mse = 5.30e-08,  rl2 = 3.26e-04
# iter. = 415000,  time = 441s,  loss = 3.59e-07  |  mse = 5.92e-09,  rl2 = 1.10e-04
# iter. = 420000,  time = 446s,  loss = 9.98e-08  |  mse = 6.42e-09,  rl2 = 1.14e-04
# iter. = 425000,  time = 451s,  loss = 5.71e-08  |  mse = 5.86e-09,  rl2 = 1.08e-04
# iter. = 430000,  time = 456s,  loss = 2.25e-07  |  mse = 7.66e-09,  rl2 = 1.21e-04
# iter. = 435000,  time = 462s,  loss = 5.88e-08  |  mse = 2.71e-09,  rl2 = 7.43e-05
# iter. = 440000,  time = 467s,  loss = 5.07e-08  |  mse = 3.36e-09,  rl2 = 8.08e-05
# iter. = 445000,  time = 472s,  loss = 6.30e-08  |  mse = 6.29e-09,  rl2 = 1.11e-04
# iter. = 450000,  time = 478s,  loss = 3.80e-08  |  mse = 3.02e-09,  rl2 = 7.80e-05
# iter. = 455000,  time = 483s,  loss = 3.19e-08  |  mse = 2.57e-09,  rl2 = 7.10e-05
# iter. = 460000,  time = 488s,  loss = 2.83e-08  |  mse = 4.32e-09,  rl2 = 9.42e-05
# iter. = 465000,  time = 494s,  loss = 3.06e-08  |  mse = 3.63e-09,  rl2 = 8.53e-05
# iter. = 470000,  time = 499s,  loss = 2.65e-08  |  mse = 2.36e-09,  rl2 = 7.00e-05
# iter. = 475000,  time = 504s,  loss = 2.57e-08  |  mse = 2.48e-09,  rl2 = 7.03e-05
# iter. = 480000,  time = 510s,  loss = 2.62e-08  |  mse = 3.53e-09,  rl2 = 8.41e-05
# iter. = 485000,  time = 515s,  loss = 1.99e-08  |  mse = 1.79e-09,  rl2 = 6.14e-05
# iter. = 490000,  time = 520s,  loss = 2.27e-08  |  mse = 1.43e-09,  rl2 = 5.32e-05
# iter. = 495000,  time = 525s,  loss = 2.50e-08  |  mse = 2.37e-09,  rl2 = 6.85e-05
# iter. = 500000,  time = 531s,  loss = 2.44e-08  |  mse = 1.98e-09,  rl2 = 6.25e-05
# [v2=1.0e-04] :  MSE = 1.41e-09  RL2 = 5.30e-05
# iter. = 00000,  time = 002s,  loss = 1.63e+02  |  mse = 9.51e-01,  rl2 = 1.42e+00
# iter. = 05000,  time = 007s,  loss = 1.33e-02  |  mse = 3.10e-02,  rl2 = 2.48e-01
# iter. = 10000,  time = 012s,  loss = 2.51e-03  |  mse = 2.13e-03,  rl2 = 6.55e-02
# iter. = 15000,  time = 018s,  loss = 7.00e-04  |  mse = 2.70e-04,  rl2 = 2.31e-02
# iter. = 20000,  time = 023s,  loss = 6.72e-04  |  mse = 1.44e-04,  rl2 = 1.70e-02
# iter. = 25000,  time = 028s,  loss = 8.82e-04  |  mse = 2.04e-04,  rl2 = 2.02e-02
# iter. = 30000,  time = 034s,  loss = 2.77e-03  |  mse = 9.49e-05,  rl2 = 1.38e-02
# iter. = 35000,  time = 039s,  loss = 4.31e-04  |  mse = 7.44e-05,  rl2 = 1.25e-02
# iter. = 40000,  time = 044s,  loss = 2.09e-03  |  mse = 7.01e-05,  rl2 = 1.18e-02
# iter. = 45000,  time = 050s,  loss = 1.14e-03  |  mse = 1.55e-04,  rl2 = 1.77e-02
# iter. = 50000,  time = 055s,  loss = 4.49e-05  |  mse = 2.96e-05,  rl2 = 7.78e-03
# iter. = 55000,  time = 060s,  loss = 8.09e-03  |  mse = 1.06e-04,  rl2 = 1.47e-02
# iter. = 60000,  time = 065s,  loss = 1.07e-02  |  mse = 3.64e-04,  rl2 = 2.64e-02
# iter. = 65000,  time = 071s,  loss = 3.87e-04  |  mse = 3.18e-05,  rl2 = 8.00e-03
# iter. = 70000,  time = 076s,  loss = 7.82e-04  |  mse = 1.73e-05,  rl2 = 6.04e-03
# iter. = 75000,  time = 081s,  loss = 3.72e-03  |  mse = 2.21e-05,  rl2 = 6.53e-03
# iter. = 80000,  time = 087s,  loss = 1.15e-04  |  mse = 3.59e-05,  rl2 = 8.32e-03
# iter. = 85000,  time = 092s,  loss = 8.65e-04  |  mse = 5.17e-05,  rl2 = 1.03e-02
# iter. = 90000,  time = 097s,  loss = 6.17e-04  |  mse = 1.83e-04,  rl2 = 1.96e-02
# iter. = 95000,  time = 103s,  loss = 3.63e-04  |  mse = 2.20e-05,  rl2 = 6.70e-03
# iter. = 100000,  time = 108s,  loss = 2.07e-04  |  mse = 1.80e-05,  rl2 = 6.07e-03
# iter. = 105000,  time = 113s,  loss = 3.92e-04  |  mse = 2.99e-05,  rl2 = 7.68e-03
# iter. = 110000,  time = 118s,  loss = 2.15e-04  |  mse = 2.74e-05,  rl2 = 7.46e-03
# iter. = 115000,  time = 124s,  loss = 1.27e-03  |  mse = 1.01e-04,  rl2 = 1.42e-02
# iter. = 120000,  time = 129s,  loss = 1.58e-04  |  mse = 3.99e-05,  rl2 = 9.10e-03
# iter. = 125000,  time = 134s,  loss = 1.85e-04  |  mse = 2.78e-05,  rl2 = 7.31e-03
# iter. = 130000,  time = 140s,  loss = 3.87e-04  |  mse = 3.52e-05,  rl2 = 8.43e-03
# iter. = 135000,  time = 145s,  loss = 6.71e-06  |  mse = 7.51e-06,  rl2 = 3.88e-03
# iter. = 140000,  time = 150s,  loss = 9.80e-05  |  mse = 2.16e-05,  rl2 = 6.76e-03
# iter. = 145000,  time = 156s,  loss = 9.34e-05  |  mse = 1.11e-05,  rl2 = 4.62e-03
# iter. = 150000,  time = 161s,  loss = 4.37e-05  |  mse = 1.03e-05,  rl2 = 4.58e-03
# iter. = 155000,  time = 166s,  loss = 1.22e-04  |  mse = 1.28e-05,  rl2 = 5.10e-03
# iter. = 160000,  time = 172s,  loss = 1.09e-04  |  mse = 2.22e-05,  rl2 = 6.51e-03
# iter. = 165000,  time = 177s,  loss = 1.61e-05  |  mse = 3.13e-06,  rl2 = 2.51e-03
# iter. = 170000,  time = 182s,  loss = 3.57e-04  |  mse = 2.09e-05,  rl2 = 6.59e-03
# iter. = 175000,  time = 187s,  loss = 3.98e-06  |  mse = 5.57e-06,  rl2 = 3.31e-03
# iter. = 180000,  time = 193s,  loss = 1.26e-03  |  mse = 5.54e-05,  rl2 = 1.05e-02
# iter. = 185000,  time = 198s,  loss = 2.82e-05  |  mse = 2.30e-06,  rl2 = 2.12e-03
# iter. = 190000,  time = 203s,  loss = 4.16e-05  |  mse = 5.14e-06,  rl2 = 3.21e-03
# iter. = 195000,  time = 209s,  loss = 2.09e-04  |  mse = 5.37e-05,  rl2 = 1.05e-02
# iter. = 200000,  time = 214s,  loss = 5.13e-04  |  mse = 2.54e-05,  rl2 = 7.17e-03
# iter. = 205000,  time = 219s,  loss = 3.13e-05  |  mse = 5.16e-06,  rl2 = 3.22e-03
# iter. = 210000,  time = 225s,  loss = 2.00e-05  |  mse = 3.76e-06,  rl2 = 2.76e-03
# iter. = 215000,  time = 230s,  loss = 1.75e-04  |  mse = 4.74e-06,  rl2 = 3.08e-03
# iter. = 220000,  time = 235s,  loss = 5.24e-04  |  mse = 3.78e-05,  rl2 = 8.62e-03
# iter. = 225000,  time = 240s,  loss = 4.80e-06  |  mse = 3.82e-06,  rl2 = 2.79e-03
# iter. = 230000,  time = 246s,  loss = 1.12e-04  |  mse = 6.94e-06,  rl2 = 3.71e-03
# iter. = 235000,  time = 251s,  loss = 3.23e-06  |  mse = 1.48e-06,  rl2 = 1.71e-03
# iter. = 240000,  time = 256s,  loss = 2.06e-04  |  mse = 4.42e-06,  rl2 = 3.01e-03
# iter. = 245000,  time = 262s,  loss = 7.81e-07  |  mse = 1.85e-06,  rl2 = 1.94e-03
# iter. = 250000,  time = 267s,  loss = 6.39e-05  |  mse = 1.86e-05,  rl2 = 6.20e-03
# iter. = 255000,  time = 272s,  loss = 4.84e-05  |  mse = 1.91e-06,  rl2 = 1.96e-03
# iter. = 260000,  time = 278s,  loss = 1.38e-05  |  mse = 1.95e-06,  rl2 = 1.98e-03
# iter. = 265000,  time = 283s,  loss = 5.62e-05  |  mse = 2.93e-06,  rl2 = 2.43e-03
# iter. = 270000,  time = 288s,  loss = 6.53e-06  |  mse = 4.81e-07,  rl2 = 9.77e-04
# iter. = 275000,  time = 294s,  loss = 7.27e-07  |  mse = 1.09e-06,  rl2 = 1.49e-03
# iter. = 280000,  time = 299s,  loss = 7.97e-05  |  mse = 3.62e-06,  rl2 = 2.73e-03
# iter. = 285000,  time = 304s,  loss = 1.49e-05  |  mse = 2.65e-06,  rl2 = 2.32e-03
# iter. = 290000,  time = 309s,  loss = 2.33e-05  |  mse = 2.07e-06,  rl2 = 2.03e-03
# iter. = 295000,  time = 315s,  loss = 9.44e-06  |  mse = 5.45e-07,  rl2 = 1.06e-03
# iter. = 300000,  time = 320s,  loss = 2.35e-05  |  mse = 9.30e-07,  rl2 = 1.34e-03
# iter. = 305000,  time = 325s,  loss = 3.16e-06  |  mse = 6.42e-07,  rl2 = 1.14e-03
# iter. = 310000,  time = 331s,  loss = 6.65e-07  |  mse = 3.38e-07,  rl2 = 8.22e-04
# iter. = 315000,  time = 336s,  loss = 2.00e-05  |  mse = 1.47e-06,  rl2 = 1.71e-03
# iter. = 320000,  time = 341s,  loss = 1.57e-05  |  mse = 1.35e-06,  rl2 = 1.62e-03
# iter. = 325000,  time = 347s,  loss = 2.40e-05  |  mse = 1.41e-06,  rl2 = 1.67e-03
# iter. = 330000,  time = 352s,  loss = 2.46e-06  |  mse = 3.21e-07,  rl2 = 7.99e-04
# iter. = 335000,  time = 357s,  loss = 2.31e-06  |  mse = 1.49e-07,  rl2 = 5.41e-04
# iter. = 340000,  time = 363s,  loss = 1.44e-04  |  mse = 5.46e-07,  rl2 = 1.07e-03
# iter. = 345000,  time = 368s,  loss = 9.77e-07  |  mse = 7.21e-08,  rl2 = 3.88e-04
# iter. = 350000,  time = 373s,  loss = 2.01e-05  |  mse = 8.53e-07,  rl2 = 1.33e-03
# iter. = 355000,  time = 378s,  loss = 4.67e-07  |  mse = 5.91e-08,  rl2 = 3.41e-04
# iter. = 360000,  time = 384s,  loss = 1.20e-06  |  mse = 7.93e-08,  rl2 = 3.95e-04
# iter. = 365000,  time = 389s,  loss = 8.82e-06  |  mse = 2.11e-07,  rl2 = 6.47e-04
# iter. = 370000,  time = 394s,  loss = 1.73e-06  |  mse = 2.97e-07,  rl2 = 7.70e-04
# iter. = 375000,  time = 400s,  loss = 1.73e-06  |  mse = 6.77e-08,  rl2 = 3.67e-04
# iter. = 380000,  time = 405s,  loss = 6.97e-07  |  mse = 4.82e-08,  rl2 = 3.09e-04
# iter. = 385000,  time = 410s,  loss = 2.61e-05  |  mse = 3.94e-07,  rl2 = 8.73e-04
# iter. = 390000,  time = 416s,  loss = 3.70e-06  |  mse = 1.58e-07,  rl2 = 5.61e-04
# iter. = 395000,  time = 421s,  loss = 5.00e-07  |  mse = 9.10e-08,  rl2 = 4.25e-04
# iter. = 400000,  time = 426s,  loss = 1.19e-07  |  mse = 1.51e-08,  rl2 = 1.77e-04
# iter. = 405000,  time = 432s,  loss = 2.10e-06  |  mse = 1.42e-07,  rl2 = 5.28e-04
# iter. = 410000,  time = 437s,  loss = 4.23e-07  |  mse = 2.43e-08,  rl2 = 2.24e-04
# iter. = 415000,  time = 442s,  loss = 4.75e-07  |  mse = 3.38e-08,  rl2 = 2.59e-04
# iter. = 420000,  time = 447s,  loss = 7.01e-08  |  mse = 1.14e-08,  rl2 = 1.55e-04
# iter. = 425000,  time = 453s,  loss = 3.31e-07  |  mse = 2.73e-08,  rl2 = 2.31e-04
# iter. = 430000,  time = 458s,  loss = 2.86e-07  |  mse = 3.06e-08,  rl2 = 2.50e-04
# iter. = 435000,  time = 463s,  loss = 2.72e-07  |  mse = 2.23e-08,  rl2 = 2.09e-04
# iter. = 440000,  time = 469s,  loss = 2.45e-07  |  mse = 5.73e-09,  rl2 = 1.08e-04
# iter. = 445000,  time = 474s,  loss = 1.82e-07  |  mse = 2.25e-08,  rl2 = 2.16e-04
# iter. = 450000,  time = 479s,  loss = 8.54e-08  |  mse = 1.47e-08,  rl2 = 1.75e-04
# iter. = 455000,  time = 485s,  loss = 8.37e-08  |  mse = 8.83e-09,  rl2 = 1.34e-04
# iter. = 460000,  time = 490s,  loss = 4.57e-08  |  mse = 3.55e-09,  rl2 = 8.49e-05
# iter. = 465000,  time = 495s,  loss = 4.59e-08  |  mse = 4.61e-09,  rl2 = 9.73e-05
# iter. = 470000,  time = 501s,  loss = 3.40e-08  |  mse = 5.62e-09,  rl2 = 1.06e-04
# iter. = 475000,  time = 506s,  loss = 3.52e-08  |  mse = 5.35e-09,  rl2 = 1.03e-04
# iter. = 480000,  time = 511s,  loss = 3.22e-08  |  mse = 3.99e-09,  rl2 = 8.90e-05
# iter. = 485000,  time = 516s,  loss = 3.18e-08  |  mse = 2.08e-09,  rl2 = 6.57e-05
# iter. = 490000,  time = 522s,  loss = 3.26e-08  |  mse = 4.74e-09,  rl2 = 9.76e-05
# iter. = 495000,  time = 527s,  loss = 2.81e-08  |  mse = 8.34e-09,  rl2 = 1.29e-04
# iter. = 500000,  time = 532s,  loss = 2.85e-08  |  mse = 2.07e-09,  rl2 = 6.57e-05
# [v2=1.0e-04] :  MSE = 2.37e-09  RL2 = 6.85e-05
# iter. = 00000,  time = 002s,  loss = 1.03e+02  |  mse = 7.60e-01,  rl2 = 1.24e+00
# iter. = 05000,  time = 007s,  loss = 1.38e-02  |  mse = 2.01e-02,  rl2 = 2.01e-01
# iter. = 10000,  time = 013s,  loss = 3.06e-03  |  mse = 4.30e-04,  rl2 = 2.91e-02
# iter. = 15000,  time = 018s,  loss = 7.59e-03  |  mse = 4.12e-04,  rl2 = 2.87e-02
# iter. = 20000,  time = 023s,  loss = 8.86e-04  |  mse = 5.37e-05,  rl2 = 1.07e-02
# iter. = 25000,  time = 028s,  loss = 6.37e-04  |  mse = 4.13e-05,  rl2 = 9.03e-03
# iter. = 30000,  time = 034s,  loss = 8.82e-04  |  mse = 3.17e-05,  rl2 = 8.13e-03
# iter. = 35000,  time = 039s,  loss = 9.51e-04  |  mse = 2.80e-05,  rl2 = 7.37e-03
# iter. = 40000,  time = 044s,  loss = 2.28e-04  |  mse = 2.57e-05,  rl2 = 7.27e-03
# iter. = 45000,  time = 050s,  loss = 1.43e-05  |  mse = 1.48e-05,  rl2 = 5.41e-03
# iter. = 50000,  time = 055s,  loss = 8.68e-03  |  mse = 4.22e-05,  rl2 = 9.32e-03
# iter. = 55000,  time = 060s,  loss = 2.61e-04  |  mse = 2.00e-05,  rl2 = 6.32e-03
# iter. = 60000,  time = 066s,  loss = 1.14e-04  |  mse = 1.07e-05,  rl2 = 4.78e-03
# iter. = 65000,  time = 071s,  loss = 5.20e-04  |  mse = 5.57e-06,  rl2 = 3.36e-03
# iter. = 70000,  time = 076s,  loss = 1.78e-04  |  mse = 1.02e-05,  rl2 = 4.51e-03
# iter. = 75000,  time = 081s,  loss = 7.54e-05  |  mse = 1.65e-05,  rl2 = 5.84e-03
# iter. = 80000,  time = 087s,  loss = 9.21e-04  |  mse = 2.01e-05,  rl2 = 6.29e-03
# iter. = 85000,  time = 092s,  loss = 2.09e-04  |  mse = 9.43e-06,  rl2 = 4.30e-03
# iter. = 90000,  time = 097s,  loss = 2.56e-05  |  mse = 4.19e-06,  rl2 = 2.92e-03
# iter. = 95000,  time = 103s,  loss = 2.87e-03  |  mse = 2.86e-05,  rl2 = 7.50e-03
# iter. = 100000,  time = 108s,  loss = 2.24e-04  |  mse = 6.01e-06,  rl2 = 3.53e-03
# iter. = 105000,  time = 113s,  loss = 1.47e-04  |  mse = 7.21e-06,  rl2 = 3.82e-03
# iter. = 110000,  time = 119s,  loss = 1.04e-04  |  mse = 7.60e-06,  rl2 = 3.96e-03
# iter. = 115000,  time = 124s,  loss = 2.01e-05  |  mse = 2.45e-06,  rl2 = 2.24e-03
# iter. = 120000,  time = 129s,  loss = 2.99e-05  |  mse = 4.73e-06,  rl2 = 3.06e-03
# iter. = 125000,  time = 135s,  loss = 1.93e-04  |  mse = 4.20e-06,  rl2 = 2.89e-03
# iter. = 130000,  time = 140s,  loss = 8.44e-05  |  mse = 5.21e-06,  rl2 = 3.22e-03
# iter. = 135000,  time = 145s,  loss = 2.59e-04  |  mse = 1.06e-05,  rl2 = 4.63e-03
# iter. = 140000,  time = 151s,  loss = 1.36e-04  |  mse = 7.40e-06,  rl2 = 3.78e-03
# iter. = 145000,  time = 156s,  loss = 4.22e-04  |  mse = 5.13e-05,  rl2 = 1.02e-02
# iter. = 150000,  time = 161s,  loss = 5.01e-04  |  mse = 1.49e-05,  rl2 = 5.50e-03
# iter. = 155000,  time = 166s,  loss = 4.51e-05  |  mse = 1.59e-05,  rl2 = 5.55e-03
# iter. = 160000,  time = 172s,  loss = 1.13e-04  |  mse = 2.81e-06,  rl2 = 2.38e-03
# iter. = 165000,  time = 177s,  loss = 9.48e-04  |  mse = 1.75e-05,  rl2 = 5.97e-03
# iter. = 170000,  time = 182s,  loss = 1.35e-04  |  mse = 3.97e-06,  rl2 = 2.83e-03
# iter. = 470000,  time = 501s,  loss = 3.13e-08  |  mse = 6.09e-09,  rl2 = 1.08e-04
# iter. = 475000,  time = 506s,  loss = 3.53e-08  |  mse = 2.81e-09,  rl2 = 7.39e-05
# iter. = 480000,  time = 512s,  loss = 3.95e-08  |  mse = 4.00e-09,  rl2 = 8.87e-05
# iter. = 485000,  time = 517s,  loss = 2.75e-08  |  mse = 2.14e-09,  rl2 = 6.68e-05
# iter. = 490000,  time = 522s,  loss = 3.06e-08  |  mse = 3.43e-09,  rl2 = 8.45e-05
# iter. = 495000,  time = 527s,  loss = 2.69e-08  |  mse = 5.15e-09,  rl2 = 1.01e-04
# iter. = 500000,  time = 533s,  loss = 3.01e-08  |  mse = 1.63e-09,  rl2 = 5.58e-05
# [v2=1.0e-04] :  MSE = 1.94e-09  RL2 = 6.21e-05
# iter. = 00000,  time = 002s,  loss = 2.60e+02  |  mse = 7.32e-01,  rl2 = 1.24e+00
# iter. = 05000,  time = 007s,  loss = 2.18e-02  |  mse = 2.21e-02,  rl2 = 2.12e-01
# iter. = 10000,  time = 013s,  loss = 9.70e-04  |  mse = 5.71e-04,  rl2 = 3.35e-02
# iter. = 15000,  time = 018s,  loss = 8.62e-04  |  mse = 3.39e-04,  rl2 = 2.62e-02
# iter. = 20000,  time = 023s,  loss = 4.94e-04  |  mse = 1.30e-04,  rl2 = 1.63e-02
# iter. = 25000,  time = 028s,  loss = 6.15e-03  |  mse = 2.99e-04,  rl2 = 2.42e-02
# iter. = 30000,  time = 034s,  loss = 7.75e-04  |  mse = 4.62e-05,  rl2 = 9.67e-03
# iter. = 35000,  time = 039s,  loss = 1.62e-03  |  mse = 1.14e-04,  rl2 = 1.53e-02
# iter. = 40000,  time = 044s,  loss = 7.99e-04  |  mse = 4.37e-05,  rl2 = 9.29e-03
# iter. = 45000,  time = 050s,  loss = 3.45e-05  |  mse = 4.14e-05,  rl2 = 9.22e-03
# iter. = 50000,  time = 055s,  loss = 2.34e-04  |  mse = 1.00e-04,  rl2 = 1.43e-02
# iter. = 55000,  time = 060s,  loss = 1.24e-03  |  mse = 4.83e-05,  rl2 = 1.00e-02
# iter. = 60000,  time = 066s,  loss = 2.85e-03  |  mse = 1.81e-04,  rl2 = 1.92e-02
# iter. = 65000,  time = 071s,  loss = 6.52e-05  |  mse = 1.89e-05,  rl2 = 6.15e-03
# iter. = 70000,  time = 076s,  loss = 5.10e-05  |  mse = 9.71e-06,  rl2 = 4.35e-03
# iter. = 75000,  time = 081s,  loss = 1.16e-03  |  mse = 5.29e-05,  rl2 = 1.04e-02
# iter. = 80000,  time = 087s,  loss = 6.93e-05  |  mse = 1.41e-05,  rl2 = 5.30e-03
# iter. = 85000,  time = 092s,  loss = 1.13e-04  |  mse = 2.74e-05,  rl2 = 7.51e-03
# iter. = 90000,  time = 097s,  loss = 1.71e-04  |  mse = 5.38e-05,  rl2 = 1.04e-02
# iter. = 95000,  time = 103s,  loss = 1.19e-04  |  mse = 1.67e-05,  rl2 = 5.73e-03
# iter. = 100000,  time = 108s,  loss = 1.29e-05  |  mse = 1.08e-05,  rl2 = 4.58e-03
# iter. = 105000,  time = 113s,  loss = 4.16e-05  |  mse = 9.90e-06,  rl2 = 4.42e-03
# iter. = 110000,  time = 119s,  loss = 1.32e-03  |  mse = 2.37e-05,  rl2 = 6.87e-03
# iter. = 115000,  time = 124s,  loss = 1.14e-05  |  mse = 1.76e-05,  rl2 = 5.92e-03
# iter. = 120000,  time = 129s,  loss = 1.50e-05  |  mse = 3.99e-06,  rl2 = 2.83e-03
# iter. = 125000,  time = 135s,  loss = 3.43e-05  |  mse = 4.64e-06,  rl2 = 3.01e-03
# iter. = 130000,  time = 140s,  loss = 5.21e-05  |  mse = 4.00e-06,  rl2 = 2.80e-03
# iter. = 135000,  time = 145s,  loss = 1.06e-03  |  mse = 6.05e-05,  rl2 = 1.10e-02
# iter. = 140000,  time = 150s,  loss = 1.85e-05  |  mse = 1.69e-06,  rl2 = 1.83e-03
# iter. = 145000,  time = 156s,  loss = 9.04e-05  |  mse = 7.73e-06,  rl2 = 3.93e-03
# iter. = 150000,  time = 161s,  loss = 1.00e-04  |  mse = 3.59e-05,  rl2 = 8.44e-03
# iter. = 155000,  time = 166s,  loss = 8.95e-06  |  mse = 5.18e-06,  rl2 = 3.21e-03
# iter. = 160000,  time = 172s,  loss = 7.66e-05  |  mse = 4.56e-06,  rl2 = 3.00e-03
# iter. = 165000,  time = 177s,  loss = 7.86e-05  |  mse = 7.88e-06,  rl2 = 3.97e-03
# iter. = 170000,  time = 182s,  loss = 1.92e-05  |  mse = 4.06e-06,  rl2 = 2.86e-03
# iter. = 175000,  time = 188s,  loss = 7.69e-05  |  mse = 3.09e-06,  rl2 = 2.54e-03
# iter. = 180000,  time = 193s,  loss = 1.08e-05  |  mse = 3.51e-06,  rl2 = 2.68e-03
# iter. = 185000,  time = 198s,  loss = 3.25e-06  |  mse = 1.44e-06,  rl2 = 1.69e-03
# iter. = 190000,  time = 204s,  loss = 5.17e-05  |  mse = 5.68e-06,  rl2 = 3.37e-03
# iter. = 195000,  time = 209s,  loss = 2.60e-05  |  mse = 1.30e-06,  rl2 = 1.63e-03
# iter. = 200000,  time = 214s,  loss = 5.23e-04  |  mse = 3.25e-06,  rl2 = 2.54e-03
# iter. = 205000,  time = 219s,  loss = 2.81e-03  |  mse = 2.29e-05,  rl2 = 6.91e-03
# iter. = 210000,  time = 225s,  loss = 2.30e-05  |  mse = 1.96e-06,  rl2 = 2.00e-03
# iter. = 215000,  time = 230s,  loss = 1.06e-04  |  mse = 3.75e-06,  rl2 = 2.85e-03
# iter. = 220000,  time = 235s,  loss = 2.70e-05  |  mse = 1.46e-06,  rl2 = 1.71e-03
# iter. = 225000,  time = 241s,  loss = 1.73e-04  |  mse = 2.92e-05,  rl2 = 7.50e-03
# iter. = 230000,  time = 246s,  loss = 3.04e-05  |  mse = 5.17e-06,  rl2 = 3.20e-03
# iter. = 235000,  time = 251s,  loss = 8.42e-05  |  mse = 2.58e-06,  rl2 = 2.29e-03
# iter. = 240000,  time = 257s,  loss = 4.04e-04  |  mse = 4.29e-06,  rl2 = 2.95e-03
# iter. = 245000,  time = 262s,  loss = 1.01e-05  |  mse = 1.50e-06,  rl2 = 1.75e-03
# iter. = 250000,  time = 267s,  loss = 2.78e-05  |  mse = 2.63e-06,  rl2 = 2.38e-03
# iter. = 255000,  time = 273s,  loss = 1.44e-06  |  mse = 9.01e-07,  rl2 = 1.34e-03
# iter. = 260000,  time = 278s,  loss = 1.63e-05  |  mse = 4.35e-06,  rl2 = 3.00e-03
# iter. = 265000,  time = 283s,  loss = 3.74e-05  |  mse = 1.12e-06,  rl2 = 1.51e-03
# iter. = 270000,  time = 288s,  loss = 1.88e-05  |  mse = 3.70e-06,  rl2 = 2.71e-03
# iter. = 275000,  time = 294s,  loss = 5.52e-05  |  mse = 1.64e-06,  rl2 = 1.80e-03
# iter. = 280000,  time = 299s,  loss = 1.83e-04  |  mse = 2.50e-06,  rl2 = 2.20e-03
# iter. = 285000,  time = 304s,  loss = 3.41e-05  |  mse = 2.25e-06,  rl2 = 2.12e-03
# iter. = 290000,  time = 310s,  loss = 4.28e-06  |  mse = 8.69e-07,  rl2 = 1.29e-03
# iter. = 295000,  time = 315s,  loss = 5.01e-05  |  mse = 1.84e-06,  rl2 = 1.89e-03
# iter. = 300000,  time = 320s,  loss = 1.82e-06  |  mse = 3.79e-07,  rl2 = 8.64e-04
# iter. = 305000,  time = 326s,  loss = 5.64e-06  |  mse = 2.23e-07,  rl2 = 6.48e-04
# iter. = 310000,  time = 331s,  loss = 7.68e-06  |  mse = 7.21e-07,  rl2 = 1.20e-03
# iter. = 315000,  time = 336s,  loss = 3.99e-05  |  mse = 3.04e-06,  rl2 = 2.45e-03
# iter. = 320000,  time = 342s,  loss = 1.90e-06  |  mse = 5.41e-07,  rl2 = 1.06e-03
# iter. = 325000,  time = 347s,  loss = 8.09e-06  |  mse = 3.20e-07,  rl2 = 8.12e-04
# iter. = 330000,  time = 352s,  loss = 1.22e-05  |  mse = 6.83e-07,  rl2 = 1.15e-03
# iter. = 335000,  time = 357s,  loss = 1.13e-05  |  mse = 8.61e-07,  rl2 = 1.31e-03
# iter. = 340000,  time = 363s,  loss = 4.09e-06  |  mse = 1.98e-07,  rl2 = 6.32e-04
# iter. = 345000,  time = 368s,  loss = 6.99e-06  |  mse = 2.54e-07,  rl2 = 7.17e-04
# iter. = 350000,  time = 373s,  loss = 6.50e-06  |  mse = 3.60e-07,  rl2 = 8.44e-04
# iter. = 355000,  time = 379s,  loss = 1.43e-06  |  mse = 8.06e-08,  rl2 = 4.03e-04
# iter. = 360000,  time = 384s,  loss = 9.59e-06  |  mse = 1.97e-07,  rl2 = 6.16e-04
# iter. = 365000,  time = 389s,  loss = 5.05e-06  |  mse = 2.82e-07,  rl2 = 7.59e-04
# iter. = 370000,  time = 395s,  loss = 2.33e-06  |  mse = 1.20e-07,  rl2 = 4.99e-04
# iter. = 375000,  time = 400s,  loss = 4.54e-06  |  mse = 1.55e-07,  rl2 = 5.62e-04
# iter. = 380000,  time = 405s,  loss = 1.41e-06  |  mse = 1.96e-07,  rl2 = 6.40e-04
# iter. = 385000,  time = 411s,  loss = 8.95e-06  |  mse = 2.04e-07,  rl2 = 6.51e-04
# iter. = 390000,  time = 416s,  loss = 5.19e-07  |  mse = 4.63e-08,  rl2 = 3.01e-04
# iter. = 395000,  time = 421s,  loss = 1.21e-06  |  mse = 6.67e-08,  rl2 = 3.64e-04
# iter. = 400000,  time = 426s,  loss = 2.11e-07  |  mse = 4.38e-08,  rl2 = 3.06e-04
# iter. = 405000,  time = 432s,  loss = 2.51e-07  |  mse = 1.75e-08,  rl2 = 1.84e-04
# iter. = 410000,  time = 437s,  loss = 2.51e-07  |  mse = 2.46e-08,  rl2 = 2.26e-04
# iter. = 415000,  time = 442s,  loss = 1.45e-07  |  mse = 2.77e-08,  rl2 = 2.35e-04
# iter. = 420000,  time = 448s,  loss = 7.66e-07  |  mse = 3.85e-08,  rl2 = 2.80e-04
# iter. = 425000,  time = 453s,  loss = 1.34e-07  |  mse = 1.55e-08,  rl2 = 1.78e-04
# iter. = 430000,  time = 458s,  loss = 7.57e-07  |  mse = 3.12e-08,  rl2 = 2.51e-04
# iter. = 435000,  time = 464s,  loss = 5.32e-07  |  mse = 3.16e-08,  rl2 = 2.51e-04
# iter. = 440000,  time = 469s,  loss = 1.10e-07  |  mse = 9.96e-09,  rl2 = 1.44e-04
# iter. = 445000,  time = 474s,  loss = 5.95e-08  |  mse = 2.29e-08,  rl2 = 2.15e-04
# iter. = 450000,  time = 479s,  loss = 1.34e-07  |  mse = 2.24e-08,  rl2 = 2.07e-04
# iter. = 455000,  time = 485s,  loss = 4.98e-08  |  mse = 1.35e-08,  rl2 = 1.64e-04
# iter. = 460000,  time = 490s,  loss = 4.54e-08  |  mse = 1.43e-08,  rl2 = 1.68e-04
# iter. = 465000,  time = 495s,  loss = 4.11e-08  |  mse = 1.13e-08,  rl2 = 1.52e-04
# iter. = 60000,  time = 065s,  loss = 5.97e-04  |  mse = 2.34e-05,  rl2 = 6.84e-03
# iter. = 65000,  time = 071s,  loss = 3.30e-05  |  mse = 1.21e-05,  rl2 = 4.93e-03
# iter. = 70000,  time = 076s,  loss = 3.28e-05  |  mse = 1.79e-05,  rl2 = 5.96e-03
# iter. = 75000,  time = 081s,  loss = 6.27e-05  |  mse = 1.28e-05,  rl2 = 5.08e-03
# iter. = 80000,  time = 087s,  loss = 1.31e-05  |  mse = 8.83e-06,  rl2 = 4.28e-03
# iter. = 85000,  time = 092s,  loss = 1.89e-04  |  mse = 1.80e-05,  rl2 = 5.88e-03
# iter. = 90000,  time = 097s,  loss = 9.52e-04  |  mse = 2.20e-05,  rl2 = 6.56e-03
# iter. = 95000,  time = 103s,  loss = 5.40e-05  |  mse = 6.74e-06,  rl2 = 3.65e-03
# iter. = 100000,  time = 108s,  loss = 1.88e-04  |  mse = 2.14e-05,  rl2 = 6.55e-03
# iter. = 105000,  time = 113s,  loss = 2.84e-05  |  mse = 8.57e-06,  rl2 = 4.16e-03
# iter. = 110000,  time = 119s,  loss = 2.15e-04  |  mse = 1.07e-05,  rl2 = 4.78e-03
# iter. = 115000,  time = 124s,  loss = 2.56e-04  |  mse = 1.82e-05,  rl2 = 6.07e-03
# iter. = 120000,  time = 129s,  loss = 1.87e-04  |  mse = 1.61e-05,  rl2 = 5.58e-03
# iter. = 125000,  time = 134s,  loss = 1.98e-04  |  mse = 3.18e-05,  rl2 = 8.03e-03
# iter. = 130000,  time = 140s,  loss = 2.16e-05  |  mse = 5.49e-06,  rl2 = 3.27e-03
# iter. = 135000,  time = 145s,  loss = 3.34e-04  |  mse = 2.89e-05,  rl2 = 7.65e-03
# iter. = 140000,  time = 150s,  loss = 2.47e-04  |  mse = 3.10e-05,  rl2 = 7.80e-03
# iter. = 145000,  time = 156s,  loss = 1.40e-05  |  mse = 6.67e-06,  rl2 = 3.74e-03
# iter. = 150000,  time = 161s,  loss = 1.11e-04  |  mse = 1.07e-05,  rl2 = 4.67e-03
# iter. = 155000,  time = 166s,  loss = 2.85e-04  |  mse = 1.84e-05,  rl2 = 5.98e-03
# iter. = 160000,  time = 172s,  loss = 2.00e-04  |  mse = 1.43e-05,  rl2 = 5.33e-03
# iter. = 165000,  time = 177s,  loss = 2.99e-04  |  mse = 1.19e-05,  rl2 = 4.89e-03
# iter. = 170000,  time = 182s,  loss = 3.31e-04  |  mse = 9.66e-06,  rl2 = 4.35e-03
# iter. = 175000,  time = 187s,  loss = 2.05e-05  |  mse = 7.74e-06,  rl2 = 3.94e-03
# iter. = 180000,  time = 193s,  loss = 3.65e-04  |  mse = 2.31e-05,  rl2 = 6.81e-03
# iter. = 185000,  time = 198s,  loss = 2.57e-04  |  mse = 2.10e-05,  rl2 = 6.50e-03
# iter. = 190000,  time = 203s,  loss = 5.56e-05  |  mse = 1.24e-05,  rl2 = 5.03e-03
# iter. = 195000,  time = 209s,  loss = 6.74e-05  |  mse = 9.14e-06,  rl2 = 4.36e-03
# iter. = 200000,  time = 214s,  loss = 4.38e-05  |  mse = 6.13e-06,  rl2 = 3.53e-03
# iter. = 205000,  time = 219s,  loss = 1.26e-04  |  mse = 1.98e-05,  rl2 = 6.53e-03
# iter. = 210000,  time = 225s,  loss = 2.96e-04  |  mse = 1.70e-05,  rl2 = 5.85e-03
# iter. = 215000,  time = 230s,  loss = 1.14e-04  |  mse = 1.20e-05,  rl2 = 5.03e-03
# iter. = 220000,  time = 235s,  loss = 1.62e-04  |  mse = 6.00e-06,  rl2 = 3.48e-03
# iter. = 225000,  time = 241s,  loss = 2.85e-05  |  mse = 1.06e-05,  rl2 = 4.67e-03
# iter. = 230000,  time = 246s,  loss = 2.14e-05  |  mse = 8.28e-06,  rl2 = 4.11e-03
# iter. = 235000,  time = 251s,  loss = 1.12e-04  |  mse = 8.29e-06,  rl2 = 4.07e-03
# iter. = 240000,  time = 256s,  loss = 2.90e-05  |  mse = 9.37e-06,  rl2 = 4.46e-03
# iter. = 245000,  time = 262s,  loss = 1.26e-04  |  mse = 3.15e-05,  rl2 = 7.96e-03
# iter. = 250000,  time = 267s,  loss = 7.28e-05  |  mse = 6.45e-06,  rl2 = 3.62e-03
# iter. = 255000,  time = 272s,  loss = 4.38e-05  |  mse = 3.33e-06,  rl2 = 2.62e-03
# iter. = 260000,  time = 278s,  loss = 5.55e-05  |  mse = 1.75e-05,  rl2 = 5.93e-03
# iter. = 265000,  time = 283s,  loss = 1.13e-05  |  mse = 4.96e-06,  rl2 = 3.15e-03
# iter. = 270000,  time = 288s,  loss = 2.17e-05  |  mse = 1.98e-06,  rl2 = 2.03e-03
# iter. = 275000,  time = 294s,  loss = 6.54e-04  |  mse = 9.12e-06,  rl2 = 4.34e-03
# iter. = 280000,  time = 299s,  loss = 2.40e-05  |  mse = 5.05e-06,  rl2 = 3.20e-03
# iter. = 285000,  time = 304s,  loss = 3.21e-05  |  mse = 7.96e-06,  rl2 = 3.98e-03
# iter. = 290000,  time = 310s,  loss = 1.71e-05  |  mse = 6.20e-06,  rl2 = 3.52e-03
# iter. = 295000,  time = 315s,  loss = 1.93e-05  |  mse = 5.43e-06,  rl2 = 3.29e-03
# iter. = 300000,  time = 320s,  loss = 1.88e-05  |  mse = 1.27e-06,  rl2 = 1.62e-03
# iter. = 305000,  time = 325s,  loss = 1.40e-05  |  mse = 1.33e-06,  rl2 = 1.64e-03
# iter. = 310000,  time = 331s,  loss = 1.36e-05  |  mse = 2.77e-06,  rl2 = 2.40e-03
# iter. = 315000,  time = 336s,  loss = 3.25e-05  |  mse = 2.29e-06,  rl2 = 2.20e-03
# iter. = 320000,  time = 341s,  loss = 1.73e-05  |  mse = 2.38e-06,  rl2 = 2.24e-03
# iter. = 325000,  time = 347s,  loss = 8.99e-06  |  mse = 7.36e-07,  rl2 = 1.22e-03
# iter. = 330000,  time = 352s,  loss = 8.37e-06  |  mse = 8.78e-07,  rl2 = 1.35e-03
# iter. = 335000,  time = 357s,  loss = 1.18e-05  |  mse = 7.97e-07,  rl2 = 1.25e-03
# iter. = 340000,  time = 363s,  loss = 5.44e-06  |  mse = 2.08e-06,  rl2 = 2.06e-03
# iter. = 345000,  time = 368s,  loss = 7.59e-06  |  mse = 5.09e-07,  rl2 = 1.00e-03
# iter. = 350000,  time = 373s,  loss = 1.69e-05  |  mse = 8.01e-06,  rl2 = 4.01e-03
# iter. = 355000,  time = 379s,  loss = 7.95e-06  |  mse = 3.66e-07,  rl2 = 8.75e-04
# iter. = 360000,  time = 384s,  loss = 4.43e-06  |  mse = 2.28e-06,  rl2 = 2.16e-03
# iter. = 365000,  time = 389s,  loss = 2.59e-06  |  mse = 4.10e-07,  rl2 = 8.94e-04
# iter. = 370000,  time = 394s,  loss = 2.70e-06  |  mse = 3.80e-07,  rl2 = 8.87e-04
# iter. = 375000,  time = 400s,  loss = 3.93e-06  |  mse = 3.08e-07,  rl2 = 8.04e-04
# iter. = 380000,  time = 405s,  loss = 1.61e-06  |  mse = 3.22e-07,  rl2 = 8.20e-04
# iter. = 385000,  time = 410s,  loss = 4.05e-07  |  mse = 8.27e-08,  rl2 = 4.15e-04
# iter. = 390000,  time = 416s,  loss = 4.66e-07  |  mse = 3.03e-08,  rl2 = 2.38e-04
# iter. = 395000,  time = 421s,  loss = 6.54e-07  |  mse = 4.69e-08,  rl2 = 3.10e-04
# iter. = 400000,  time = 426s,  loss = 2.09e-06  |  mse = 8.71e-08,  rl2 = 4.20e-04
# iter. = 405000,  time = 432s,  loss = 1.55e-06  |  mse = 8.08e-08,  rl2 = 4.02e-04
# iter. = 410000,  time = 437s,  loss = 8.84e-06  |  mse = 5.09e-08,  rl2 = 3.22e-04
# iter. = 415000,  time = 442s,  loss = 1.11e-07  |  mse = 8.99e-09,  rl2 = 1.35e-04
# iter. = 420000,  time = 447s,  loss = 7.52e-07  |  mse = 4.90e-08,  rl2 = 3.16e-04
# iter. = 425000,  time = 453s,  loss = 4.75e-07  |  mse = 2.86e-08,  rl2 = 2.37e-04
# iter. = 430000,  time = 458s,  loss = 9.34e-08  |  mse = 6.69e-09,  rl2 = 1.16e-04
# iter. = 435000,  time = 463s,  loss = 1.67e-07  |  mse = 2.50e-08,  rl2 = 2.27e-04
# iter. = 440000,  time = 469s,  loss = 1.11e-07  |  mse = 7.16e-09,  rl2 = 1.20e-04
# iter. = 445000,  time = 474s,  loss = 9.82e-08  |  mse = 7.55e-09,  rl2 = 1.21e-04
# iter. = 450000,  time = 479s,  loss = 5.87e-08  |  mse = 6.29e-09,  rl2 = 1.12e-04
# iter. = 455000,  time = 485s,  loss = 4.42e-08  |  mse = 4.08e-09,  rl2 = 8.90e-05
# iter. = 460000,  time = 490s,  loss = 3.98e-08  |  mse = 5.30e-09,  rl2 = 1.05e-04
# iter. = 465000,  time = 495s,  loss = 4.01e-08  |  mse = 3.42e-09,  rl2 = 8.12e-05
# iter. = 470000,  time = 501s,  loss = 3.78e-08  |  mse = 6.56e-09,  rl2 = 1.17e-04
# iter. = 475000,  time = 506s,  loss = 3.15e-08  |  mse = 5.10e-09,  rl2 = 1.04e-04
# iter. = 480000,  time = 511s,  loss = 2.80e-08  |  mse = 4.33e-09,  rl2 = 9.37e-05
# iter. = 485000,  time = 516s,  loss = 2.93e-08  |  mse = 1.82e-09,  rl2 = 6.06e-05
# iter. = 490000,  time = 522s,  loss = 2.44e-08  |  mse = 1.64e-09,  rl2 = 5.74e-05
# iter. = 495000,  time = 527s,  loss = 2.52e-08  |  mse = 4.46e-09,  rl2 = 9.45e-05
# iter. = 500000,  time = 532s,  loss = 2.41e-08  |  mse = 3.00e-09,  rl2 = 7.61e-05
# [v2=1.0e-04] :  MSE = 1.99e-09  RL2 = 6.28e-05

# %%
# 5 runs (ref)
ref_params_5, ref_store_nnws_5 = {}, {}
for seed in [10, 20, 30, 40, 50]:
    # run main (ER)
    params, store_nnws = main(ER=0, ER_xx=1.5, weight_ic=100, weight_bc=100,
                              max_lr=2e-3, exponent=1.2, max_iter=500000, seed=seed, gpu=0)
    ref_params_5[seed] = params
    ref_store_nnws_5[seed] = store_nnws
# Out:
# iter. = 00000,  time = 002s,  loss = 7.09e+01  |  mse = 7.51e-01,  rl2 = 1.23e+00
# iter. = 05000,  time = 007s,  loss = 1.50e-02  |  mse = 1.78e-01,  rl2 = 5.94e-01
# iter. = 10000,  time = 012s,  loss = 4.86e-03  |  mse = 3.42e-02,  rl2 = 2.65e-01
# iter. = 15000,  time = 017s,  loss = 1.96e-03  |  mse = 3.07e-03,  rl2 = 7.80e-02
# iter. = 20000,  time = 022s,  loss = 2.91e-04  |  mse = 1.40e-03,  rl2 = 5.29e-02
# iter. = 25000,  time = 027s,  loss = 1.15e-03  |  mse = 5.95e-04,  rl2 = 3.48e-02
# iter. = 30000,  time = 032s,  loss = 9.78e-03  |  mse = 4.73e-04,  rl2 = 3.03e-02
# iter. = 35000,  time = 036s,  loss = 1.17e-03  |  mse = 2.16e-04,  rl2 = 2.11e-02
# iter. = 40000,  time = 041s,  loss = 2.49e-04  |  mse = 1.26e-04,  rl2 = 1.60e-02
# iter. = 45000,  time = 046s,  loss = 4.21e-04  |  mse = 1.22e-04,  rl2 = 1.57e-02
# iter. = 50000,  time = 051s,  loss = 7.09e-04  |  mse = 8.86e-05,  rl2 = 1.32e-02
# iter. = 55000,  time = 056s,  loss = 5.74e-05  |  mse = 1.61e-04,  rl2 = 1.78e-02
# iter. = 60000,  time = 061s,  loss = 1.07e-03  |  mse = 9.31e-05,  rl2 = 1.38e-02
# iter. = 65000,  time = 066s,  loss = 6.44e-04  |  mse = 1.64e-04,  rl2 = 1.80e-02
# iter. = 70000,  time = 071s,  loss = 2.39e-05  |  mse = 4.98e-05,  rl2 = 9.97e-03
# iter. = 75000,  time = 076s,  loss = 1.09e-04  |  mse = 8.77e-05,  rl2 = 1.34e-02
# iter. = 80000,  time = 080s,  loss = 9.48e-05  |  mse = 5.72e-05,  rl2 = 1.06e-02
# iter. = 85000,  time = 085s,  loss = 1.34e-03  |  mse = 6.67e-05,  rl2 = 1.16e-02
# iter. = 90000,  time = 090s,  loss = 1.47e-02  |  mse = 2.62e-04,  rl2 = 2.34e-02
# iter. = 95000,  time = 095s,  loss = 3.91e-05  |  mse = 6.45e-05,  rl2 = 1.13e-02
# iter. = 100000,  time = 100s,  loss = 1.94e-03  |  mse = 3.42e-04,  rl2 = 2.67e-02
# iter. = 105000,  time = 105s,  loss = 8.07e-04  |  mse = 5.80e-05,  rl2 = 1.07e-02
# iter. = 110000,  time = 110s,  loss = 1.07e-04  |  mse = 5.40e-05,  rl2 = 1.06e-02
# iter. = 115000,  time = 115s,  loss = 1.57e-05  |  mse = 6.67e-05,  rl2 = 1.15e-02
# iter. = 120000,  time = 120s,  loss = 2.14e-04  |  mse = 3.03e-05,  rl2 = 7.83e-03
# iter. = 125000,  time = 124s,  loss = 1.15e-03  |  mse = 3.59e-05,  rl2 = 8.31e-03
# iter. = 130000,  time = 129s,  loss = 3.09e-05  |  mse = 2.60e-05,  rl2 = 7.32e-03
# iter. = 135000,  time = 134s,  loss = 2.95e-05  |  mse = 2.53e-05,  rl2 = 7.09e-03
# iter. = 140000,  time = 139s,  loss = 6.79e-06  |  mse = 1.64e-05,  rl2 = 5.66e-03
# iter. = 145000,  time = 144s,  loss = 5.98e-05  |  mse = 2.52e-05,  rl2 = 6.95e-03
# iter. = 150000,  time = 149s,  loss = 1.03e-04  |  mse = 4.06e-05,  rl2 = 8.80e-03
# iter. = 155000,  time = 154s,  loss = 3.67e-05  |  mse = 9.52e-06,  rl2 = 4.35e-03
# iter. = 160000,  time = 159s,  loss = 1.43e-03  |  mse = 5.00e-05,  rl2 = 1.01e-02
# iter. = 165000,  time = 164s,  loss = 1.19e-05  |  mse = 1.16e-05,  rl2 = 4.92e-03
# iter. = 170000,  time = 169s,  loss = 7.66e-06  |  mse = 1.86e-05,  rl2 = 6.14e-03
# iter. = 175000,  time = 173s,  loss = 3.35e-06  |  mse = 1.59e-05,  rl2 = 5.62e-03
# iter. = 180000,  time = 178s,  loss = 3.34e-05  |  mse = 1.89e-05,  rl2 = 6.21e-03
# iter. = 185000,  time = 183s,  loss = 9.18e-06  |  mse = 1.22e-05,  rl2 = 4.92e-03
# iter. = 190000,  time = 188s,  loss = 2.50e-04  |  mse = 4.04e-05,  rl2 = 8.96e-03
# iter. = 195000,  time = 193s,  loss = 3.26e-06  |  mse = 1.88e-05,  rl2 = 6.16e-03
# iter. = 200000,  time = 198s,  loss = 4.05e-06  |  mse = 1.21e-05,  rl2 = 5.03e-03
# iter. = 205000,  time = 203s,  loss = 2.48e-06  |  mse = 1.17e-05,  rl2 = 4.92e-03
# iter. = 210000,  time = 208s,  loss = 3.96e-05  |  mse = 1.21e-05,  rl2 = 5.02e-03
# iter. = 215000,  time = 213s,  loss = 1.00e-04  |  mse = 1.13e-05,  rl2 = 4.78e-03
# iter. = 220000,  time = 217s,  loss = 2.92e-05  |  mse = 1.08e-05,  rl2 = 4.73e-03
# iter. = 225000,  time = 222s,  loss = 4.80e-05  |  mse = 9.93e-06,  rl2 = 4.38e-03
# iter. = 230000,  time = 227s,  loss = 5.63e-05  |  mse = 6.76e-06,  rl2 = 3.69e-03
# iter. = 235000,  time = 232s,  loss = 3.39e-05  |  mse = 1.43e-05,  rl2 = 5.48e-03
# iter. = 240000,  time = 237s,  loss = 1.90e-04  |  mse = 1.11e-05,  rl2 = 4.73e-03
# iter. = 245000,  time = 242s,  loss = 1.20e-05  |  mse = 3.84e-06,  rl2 = 2.71e-03
# iter. = 250000,  time = 247s,  loss = 5.64e-04  |  mse = 2.20e-05,  rl2 = 6.77e-03
# iter. = 255000,  time = 252s,  loss = 1.62e-04  |  mse = 6.80e-06,  rl2 = 3.62e-03
# iter. = 260000,  time = 257s,  loss = 2.47e-06  |  mse = 8.84e-06,  rl2 = 4.20e-03
# iter. = 265000,  time = 261s,  loss = 9.91e-06  |  mse = 1.22e-05,  rl2 = 4.91e-03
# iter. = 270000,  time = 266s,  loss = 3.57e-04  |  mse = 7.94e-06,  rl2 = 3.96e-03
# iter. = 275000,  time = 271s,  loss = 2.51e-05  |  mse = 8.34e-06,  rl2 = 4.18e-03
# iter. = 280000,  time = 276s,  loss = 5.19e-06  |  mse = 2.84e-06,  rl2 = 2.41e-03
# iter. = 285000,  time = 281s,  loss = 1.10e-06  |  mse = 8.52e-06,  rl2 = 4.17e-03
# iter. = 290000,  time = 286s,  loss = 2.39e-06  |  mse = 5.28e-06,  rl2 = 3.29e-03
# iter. = 295000,  time = 291s,  loss = 1.40e-04  |  mse = 1.09e-05,  rl2 = 4.60e-03
# iter. = 300000,  time = 296s,  loss = 4.40e-05  |  mse = 6.58e-06,  rl2 = 3.70e-03
# iter. = 305000,  time = 301s,  loss = 1.23e-06  |  mse = 2.67e-06,  rl2 = 2.28e-03
# iter. = 310000,  time = 305s,  loss = 3.69e-05  |  mse = 3.85e-06,  rl2 = 2.79e-03
# iter. = 315000,  time = 310s,  loss = 4.98e-06  |  mse = 3.29e-06,  rl2 = 2.58e-03
# iter. = 320000,  time = 315s,  loss = 1.06e-05  |  mse = 6.24e-06,  rl2 = 3.51e-03
# iter. = 325000,  time = 320s,  loss = 5.39e-07  |  mse = 4.82e-06,  rl2 = 3.07e-03
# iter. = 330000,  time = 325s,  loss = 1.87e-06  |  mse = 3.49e-06,  rl2 = 2.66e-03
# iter. = 335000,  time = 330s,  loss = 8.93e-07  |  mse = 1.67e-06,  rl2 = 1.81e-03
# iter. = 340000,  time = 335s,  loss = 6.32e-06  |  mse = 1.86e-06,  rl2 = 1.92e-03
# iter. = 345000,  time = 340s,  loss = 5.86e-07  |  mse = 2.86e-06,  rl2 = 2.40e-03
# iter. = 350000,  time = 345s,  loss = 8.99e-05  |  mse = 5.63e-06,  rl2 = 3.30e-03
# iter. = 355000,  time = 349s,  loss = 5.16e-07  |  mse = 1.78e-06,  rl2 = 1.88e-03
# iter. = 360000,  time = 354s,  loss = 1.23e-07  |  mse = 1.37e-06,  rl2 = 1.66e-03
# iter. = 365000,  time = 359s,  loss = 6.03e-06  |  mse = 2.00e-06,  rl2 = 2.01e-03
# iter. = 370000,  time = 364s,  loss = 2.49e-05  |  mse = 8.02e-07,  rl2 = 1.27e-03
# iter. = 375000,  time = 369s,  loss = 5.09e-07  |  mse = 6.01e-07,  rl2 = 1.11e-03
# iter. = 380000,  time = 374s,  loss = 2.34e-06  |  mse = 6.54e-07,  rl2 = 1.15e-03
# iter. = 385000,  time = 379s,  loss = 1.05e-07  |  mse = 5.25e-07,  rl2 = 1.03e-03
# iter. = 390000,  time = 384s,  loss = 2.31e-07  |  mse = 5.88e-07,  rl2 = 1.07e-03
# iter. = 395000,  time = 389s,  loss = 1.84e-06  |  mse = 5.71e-07,  rl2 = 1.11e-03
# iter. = 400000,  time = 393s,  loss = 1.12e-07  |  mse = 3.83e-07,  rl2 = 8.89e-04
# iter. = 405000,  time = 398s,  loss = 2.92e-07  |  mse = 2.22e-07,  rl2 = 6.86e-04
# iter. = 410000,  time = 403s,  loss = 4.71e-07  |  mse = 2.32e-07,  rl2 = 6.83e-04
# iter. = 415000,  time = 408s,  loss = 1.76e-07  |  mse = 1.96e-07,  rl2 = 6.35e-04
# iter. = 420000,  time = 413s,  loss = 2.62e-07  |  mse = 1.39e-07,  rl2 = 5.31e-04
# iter. = 425000,  time = 418s,  loss = 3.43e-07  |  mse = 2.15e-07,  rl2 = 6.54e-04
# iter. = 430000,  time = 423s,  loss = 3.99e-07  |  mse = 1.38e-07,  rl2 = 5.16e-04
# iter. = 435000,  time = 428s,  loss = 6.08e-08  |  mse = 9.43e-08,  rl2 = 4.39e-04
# iter. = 440000,  time = 433s,  loss = 9.86e-08  |  mse = 1.02e-07,  rl2 = 4.46e-04
# iter. = 445000,  time = 437s,  loss = 1.41e-07  |  mse = 1.88e-07,  rl2 = 6.06e-04
# iter. = 450000,  time = 442s,  loss = 7.81e-08  |  mse = 8.18e-08,  rl2 = 4.06e-04
# iter. = 455000,  time = 447s,  loss = 8.68e-08  |  mse = 7.90e-08,  rl2 = 3.94e-04
# iter. = 460000,  time = 452s,  loss = 4.18e-08  |  mse = 5.83e-08,  rl2 = 3.46e-04
# iter. = 465000,  time = 457s,  loss = 4.65e-08  |  mse = 1.23e-07,  rl2 = 4.97e-04
# iter. = 470000,  time = 462s,  loss = 3.70e-08  |  mse = 9.58e-08,  rl2 = 4.46e-04
# iter. = 475000,  time = 467s,  loss = 3.27e-08  |  mse = 3.86e-08,  rl2 = 2.77e-04
# iter. = 480000,  time = 472s,  loss = 2.92e-08  |  mse = 6.30e-08,  rl2 = 3.55e-04
# iter. = 485000,  time = 477s,  loss = 2.97e-08  |  mse = 2.71e-08,  rl2 = 2.39e-04
# iter. = 490000,  time = 481s,  loss = 2.80e-08  |  mse = 5.25e-08,  rl2 = 3.22e-04
# iter. = 495000,  time = 486s,  loss = 2.93e-08  |  mse = 6.07e-08,  rl2 = 3.47e-04
# iter. = 500000,  time = 491s,  loss = 2.98e-08  |  mse = 8.87e-08,  rl2 = 4.18e-04
# [v2=1.0e-04] :  MSE = 6.22e-08  RL2 = 3.51e-04
# iter. = 00000,  time = 002s,  loss = 1.63e+02  |  mse = 9.51e-01,  rl2 = 1.42e+00
# iter. = 05000,  time = 007s,  loss = 9.07e-03  |  mse = 2.02e-01,  rl2 = 6.34e-01
# iter. = 10000,  time = 012s,  loss = 1.13e-02  |  mse = 6.59e-02,  rl2 = 3.64e-01
# iter. = 15000,  time = 017s,  loss = 1.11e-02  |  mse = 1.42e-01,  rl2 = 5.30e-01
# iter. = 20000,  time = 021s,  loss = 4.64e-03  |  mse = 3.64e-03,  rl2 = 8.54e-02
# iter. = 25000,  time = 026s,  loss = 2.11e-03  |  mse = 1.38e-03,  rl2 = 5.26e-02
# iter. = 30000,  time = 031s,  loss = 2.99e-04  |  mse = 1.05e-03,  rl2 = 4.59e-02
# iter. = 35000,  time = 036s,  loss = 1.59e-04  |  mse = 4.73e-04,  rl2 = 3.15e-02
# iter. = 40000,  time = 041s,  loss = 7.71e-04  |  mse = 2.51e-04,  rl2 = 2.24e-02
# iter. = 45000,  time = 046s,  loss = 1.50e-04  |  mse = 2.30e-04,  rl2 = 2.16e-02
# iter. = 50000,  time = 051s,  loss = 1.50e-04  |  mse = 2.78e-04,  rl2 = 2.39e-02
# iter. = 55000,  time = 056s,  loss = 5.89e-03  |  mse = 1.92e-04,  rl2 = 1.99e-02
# iter. = 60000,  time = 061s,  loss = 7.30e-05  |  mse = 1.08e-04,  rl2 = 1.44e-02
# iter. = 65000,  time = 065s,  loss = 4.12e-05  |  mse = 1.44e-04,  rl2 = 1.70e-02
# iter. = 70000,  time = 070s,  loss = 1.15e-03  |  mse = 1.09e-04,  rl2 = 1.52e-02
# iter. = 75000,  time = 075s,  loss = 1.04e-02  |  mse = 6.45e-04,  rl2 = 3.53e-02
# iter. = 80000,  time = 080s,  loss = 1.96e-05  |  mse = 1.10e-04,  rl2 = 1.45e-02
# iter. = 85000,  time = 085s,  loss = 6.26e-04  |  mse = 1.20e-04,  rl2 = 1.57e-02
# iter. = 90000,  time = 090s,  loss = 3.16e-04  |  mse = 8.86e-05,  rl2 = 1.37e-02
# iter. = 95000,  time = 095s,  loss = 6.76e-04  |  mse = 6.99e-05,  rl2 = 1.19e-02
# iter. = 100000,  time = 100s,  loss = 5.36e-05  |  mse = 1.56e-04,  rl2 = 1.79e-02
# iter. = 105000,  time = 105s,  loss = 2.69e-04  |  mse = 8.24e-05,  rl2 = 1.28e-02
# iter. = 110000,  time = 109s,  loss = 2.86e-05  |  mse = 6.12e-05,  rl2 = 1.11e-02
# iter. = 115000,  time = 114s,  loss = 2.07e-04  |  mse = 1.65e-04,  rl2 = 1.82e-02
# iter. = 120000,  time = 119s,  loss = 3.71e-05  |  mse = 7.00e-05,  rl2 = 1.20e-02
# iter. = 125000,  time = 124s,  loss = 9.87e-06  |  mse = 6.76e-05,  rl2 = 1.14e-02
# iter. = 130000,  time = 129s,  loss = 3.36e-03  |  mse = 8.87e-05,  rl2 = 1.34e-02
# iter. = 135000,  time = 134s,  loss = 8.84e-05  |  mse = 5.87e-05,  rl2 = 1.08e-02
# iter. = 140000,  time = 139s,  loss = 1.18e-04  |  mse = 5.51e-05,  rl2 = 1.08e-02
# iter. = 145000,  time = 144s,  loss = 3.58e-04  |  mse = 4.64e-05,  rl2 = 9.42e-03
# iter. = 150000,  time = 149s,  loss = 6.85e-04  |  mse = 5.71e-05,  rl2 = 1.08e-02
# iter. = 155000,  time = 153s,  loss = 8.87e-06  |  mse = 2.79e-05,  rl2 = 7.52e-03
# iter. = 160000,  time = 158s,  loss = 1.90e-05  |  mse = 4.90e-05,  rl2 = 9.68e-03
# iter. = 165000,  time = 163s,  loss = 1.04e-04  |  mse = 3.99e-05,  rl2 = 8.97e-03
# iter. = 170000,  time = 168s,  loss = 1.23e-05  |  mse = 3.52e-05,  rl2 = 8.55e-03
# iter. = 175000,  time = 173s,  loss = 6.26e-06  |  mse = 5.64e-05,  rl2 = 1.05e-02
# iter. = 180000,  time = 178s,  loss = 8.78e-04  |  mse = 5.61e-05,  rl2 = 1.06e-02
# iter. = 185000,  time = 183s,  loss = 4.30e-05  |  mse = 1.91e-05,  rl2 = 6.11e-03
# iter. = 190000,  time = 188s,  loss = 9.51e-05  |  mse = 2.82e-05,  rl2 = 7.53e-03
# iter. = 195000,  time = 193s,  loss = 1.77e-05  |  mse = 4.27e-05,  rl2 = 9.40e-03
# iter. = 200000,  time = 197s,  loss = 4.48e-05  |  mse = 2.35e-05,  rl2 = 6.89e-03
# iter. = 205000,  time = 202s,  loss = 2.43e-04  |  mse = 2.55e-05,  rl2 = 7.17e-03
# iter. = 210000,  time = 207s,  loss = 5.35e-06  |  mse = 1.68e-05,  rl2 = 5.82e-03
# iter. = 215000,  time = 212s,  loss = 2.09e-04  |  mse = 2.58e-05,  rl2 = 7.19e-03
# iter. = 220000,  time = 217s,  loss = 6.73e-05  |  mse = 4.16e-05,  rl2 = 9.04e-03
# iter. = 225000,  time = 222s,  loss = 1.67e-04  |  mse = 4.00e-05,  rl2 = 9.03e-03
# iter. = 230000,  time = 227s,  loss = 3.26e-05  |  mse = 2.60e-05,  rl2 = 7.19e-03
# iter. = 235000,  time = 232s,  loss = 2.28e-05  |  mse = 1.83e-05,  rl2 = 6.01e-03
# iter. = 240000,  time = 237s,  loss = 4.70e-04  |  mse = 2.45e-05,  rl2 = 7.09e-03
# iter. = 245000,  time = 241s,  loss = 3.27e-04  |  mse = 2.58e-05,  rl2 = 7.26e-03
# iter. = 250000,  time = 246s,  loss = 3.26e-06  |  mse = 1.62e-05,  rl2 = 5.80e-03
# iter. = 255000,  time = 251s,  loss = 1.46e-05  |  mse = 9.72e-06,  rl2 = 4.42e-03
# iter. = 260000,  time = 256s,  loss = 6.51e-05  |  mse = 8.30e-06,  rl2 = 4.09e-03
# iter. = 265000,  time = 261s,  loss = 1.27e-04  |  mse = 2.25e-05,  rl2 = 6.75e-03
# iter. = 270000,  time = 266s,  loss = 7.27e-06  |  mse = 5.42e-06,  rl2 = 3.28e-03
# iter. = 275000,  time = 271s,  loss = 3.80e-06  |  mse = 1.16e-05,  rl2 = 4.84e-03
# iter. = 280000,  time = 276s,  loss = 1.61e-04  |  mse = 1.34e-05,  rl2 = 5.25e-03
# iter. = 285000,  time = 281s,  loss = 7.01e-06  |  mse = 1.08e-05,  rl2 = 4.69e-03
# iter. = 290000,  time = 285s,  loss = 3.08e-06  |  mse = 8.60e-06,  rl2 = 4.14e-03
# iter. = 295000,  time = 290s,  loss = 2.57e-06  |  mse = 1.07e-05,  rl2 = 4.71e-03
# iter. = 300000,  time = 295s,  loss = 1.68e-04  |  mse = 2.34e-05,  rl2 = 6.71e-03
# iter. = 305000,  time = 300s,  loss = 7.88e-07  |  mse = 7.29e-06,  rl2 = 3.84e-03
# iter. = 310000,  time = 305s,  loss = 5.58e-06  |  mse = 7.39e-06,  rl2 = 3.85e-03
# iter. = 315000,  time = 310s,  loss = 1.51e-05  |  mse = 9.12e-06,  rl2 = 4.27e-03
# iter. = 320000,  time = 315s,  loss = 4.79e-06  |  mse = 7.72e-06,  rl2 = 3.87e-03
# iter. = 325000,  time = 320s,  loss = 6.34e-07  |  mse = 9.05e-06,  rl2 = 4.23e-03
# iter. = 330000,  time = 325s,  loss = 7.74e-06  |  mse = 4.03e-06,  rl2 = 2.83e-03
# iter. = 335000,  time = 330s,  loss = 2.28e-05  |  mse = 8.27e-06,  rl2 = 4.03e-03
# iter. = 340000,  time = 334s,  loss = 4.03e-06  |  mse = 4.35e-06,  rl2 = 3.01e-03
# iter. = 345000,  time = 339s,  loss = 8.13e-07  |  mse = 3.80e-06,  rl2 = 2.81e-03
# iter. = 350000,  time = 344s,  loss = 6.66e-06  |  mse = 1.72e-06,  rl2 = 1.89e-03
# iter. = 355000,  time = 349s,  loss = 2.80e-06  |  mse = 6.28e-06,  rl2 = 3.52e-03
# iter. = 360000,  time = 354s,  loss = 5.98e-07  |  mse = 2.84e-06,  rl2 = 2.36e-03
# iter. = 365000,  time = 359s,  loss = 3.85e-07  |  mse = 1.88e-06,  rl2 = 1.93e-03
# iter. = 370000,  time = 364s,  loss = 1.24e-06  |  mse = 3.98e-06,  rl2 = 2.82e-03
# iter. = 375000,  time = 369s,  loss = 1.97e-07  |  mse = 2.61e-06,  rl2 = 2.28e-03
# iter. = 380000,  time = 374s,  loss = 1.20e-06  |  mse = 1.94e-06,  rl2 = 1.96e-03
# iter. = 385000,  time = 378s,  loss = 6.63e-07  |  mse = 5.29e-06,  rl2 = 3.20e-03
# iter. = 390000,  time = 383s,  loss = 2.24e-07  |  mse = 1.22e-06,  rl2 = 1.55e-03
# iter. = 395000,  time = 388s,  loss = 1.92e-07  |  mse = 1.17e-06,  rl2 = 1.52e-03
# iter. = 400000,  time = 393s,  loss = 2.11e-07  |  mse = 7.13e-07,  rl2 = 1.21e-03
# iter. = 405000,  time = 398s,  loss = 1.36e-07  |  mse = 1.29e-06,  rl2 = 1.59e-03
# iter. = 410000,  time = 403s,  loss = 2.74e-07  |  mse = 9.72e-07,  rl2 = 1.42e-03
# iter. = 415000,  time = 408s,  loss = 9.41e-08  |  mse = 7.42e-07,  rl2 = 1.22e-03
# iter. = 420000,  time = 413s,  loss = 5.36e-07  |  mse = 5.65e-07,  rl2 = 1.09e-03
# iter. = 425000,  time = 418s,  loss = 4.40e-07  |  mse = 6.93e-07,  rl2 = 1.17e-03
# iter. = 430000,  time = 422s,  loss = 1.02e-07  |  mse = 5.97e-07,  rl2 = 1.11e-03
# iter. = 435000,  time = 427s,  loss = 9.02e-08  |  mse = 7.12e-07,  rl2 = 1.18e-03
# iter. = 440000,  time = 432s,  loss = 1.15e-07  |  mse = 4.15e-07,  rl2 = 9.17e-04
# iter. = 445000,  time = 437s,  loss = 8.17e-08  |  mse = 7.32e-07,  rl2 = 1.23e-03
# iter. = 450000,  time = 442s,  loss = 1.02e-07  |  mse = 3.41e-07,  rl2 = 8.44e-04
# iter. = 455000,  time = 447s,  loss = 7.08e-08  |  mse = 3.46e-07,  rl2 = 8.40e-04
# iter. = 460000,  time = 452s,  loss = 6.07e-08  |  mse = 3.08e-07,  rl2 = 7.90e-04
# iter. = 465000,  time = 457s,  loss = 7.04e-08  |  mse = 3.04e-07,  rl2 = 7.89e-04
# iter. = 470000,  time = 462s,  loss = 5.90e-08  |  mse = 2.92e-07,  rl2 = 7.62e-04
# iter. = 475000,  time = 466s,  loss = 4.70e-08  |  mse = 4.54e-07,  rl2 = 9.52e-04
# iter. = 480000,  time = 471s,  loss = 4.90e-08  |  mse = 4.28e-07,  rl2 = 9.22e-04
# iter. = 485000,  time = 476s,  loss = 4.53e-08  |  mse = 2.58e-07,  rl2 = 7.32e-04
# iter. = 490000,  time = 481s,  loss = 4.51e-08  |  mse = 3.11e-07,  rl2 = 7.90e-04
# iter. = 495000,  time = 486s,  loss = 4.90e-08  |  mse = 2.49e-07,  rl2 = 7.05e-04
# iter. = 500000,  time = 491s,  loss = 4.24e-08  |  mse = 2.02e-07,  rl2 = 6.49e-04
# [v2=1.0e-04] :  MSE = 2.40e-07  RL2 = 6.90e-04
# iter. = 00000,  time = 002s,  loss = 1.03e+02  |  mse = 7.60e-01,  rl2 = 1.24e+00
# iter. = 05000,  time = 007s,  loss = 2.86e-02  |  mse = 1.54e-01,  rl2 = 5.59e-01
# iter. = 10000,  time = 012s,  loss = 1.55e-02  |  mse = 3.66e-02,  rl2 = 2.69e-01
# iter. = 15000,  time = 016s,  loss = 5.44e-04  |  mse = 3.87e-03,  rl2 = 8.80e-02
# iter. = 20000,  time = 021s,  loss = 8.63e-03  |  mse = 4.49e-03,  rl2 = 9.77e-02
# iter. = 25000,  time = 026s,  loss = 2.86e-03  |  mse = 5.92e-04,  rl2 = 3.42e-02
# iter. = 30000,  time = 031s,  loss = 2.21e-04  |  mse = 2.50e-04,  rl2 = 2.28e-02
# iter. = 35000,  time = 036s,  loss = 1.95e-04  |  mse = 2.01e-04,  rl2 = 1.98e-02
# iter. = 40000,  time = 041s,  loss = 6.37e-05  |  mse = 1.44e-04,  rl2 = 1.72e-02
# iter. = 45000,  time = 046s,  loss = 1.85e-04  |  mse = 1.41e-04,  rl2 = 1.67e-02
# iter. = 50000,  time = 051s,  loss = 5.99e-05  |  mse = 6.80e-05,  rl2 = 1.18e-02
# iter. = 55000,  time = 056s,  loss = 5.03e-03  |  mse = 5.38e-04,  rl2 = 3.28e-02
# iter. = 60000,  time = 060s,  loss = 3.14e-04  |  mse = 6.26e-05,  rl2 = 1.16e-02
# iter. = 65000,  time = 065s,  loss = 6.64e-04  |  mse = 6.19e-05,  rl2 = 1.12e-02
# iter. = 70000,  time = 070s,  loss = 3.34e-04  |  mse = 4.86e-05,  rl2 = 9.86e-03
# iter. = 75000,  time = 075s,  loss = 2.26e-05  |  mse = 6.06e-05,  rl2 = 1.12e-02
# iter. = 80000,  time = 080s,  loss = 6.32e-05  |  mse = 5.02e-05,  rl2 = 9.95e-03
# iter. = 85000,  time = 085s,  loss = 3.12e-04  |  mse = 4.39e-05,  rl2 = 9.27e-03
# iter. = 90000,  time = 090s,  loss = 1.69e-04  |  mse = 2.13e-05,  rl2 = 6.58e-03
# iter. = 95000,  time = 095s,  loss = 6.79e-04  |  mse = 3.88e-05,  rl2 = 8.74e-03
# iter. = 100000,  time = 100s,  loss = 1.37e-04  |  mse = 4.53e-05,  rl2 = 9.68e-03
# iter. = 105000,  time = 104s,  loss = 2.25e-03  |  mse = 9.00e-05,  rl2 = 1.35e-02
# iter. = 110000,  time = 109s,  loss = 2.04e-05  |  mse = 3.44e-05,  rl2 = 8.43e-03
# iter. = 115000,  time = 114s,  loss = 1.49e-05  |  mse = 1.66e-05,  rl2 = 5.85e-03
# iter. = 120000,  time = 119s,  loss = 9.36e-06  |  mse = 3.71e-05,  rl2 = 8.57e-03
# iter. = 125000,  time = 124s,  loss = 5.74e-05  |  mse = 2.67e-05,  rl2 = 7.27e-03
# iter. = 130000,  time = 129s,  loss = 3.35e-05  |  mse = 3.63e-05,  rl2 = 8.50e-03
# iter. = 135000,  time = 134s,  loss = 1.64e-04  |  mse = 3.12e-05,  rl2 = 7.94e-03
# iter. = 140000,  time = 139s,  loss = 2.84e-05  |  mse = 2.45e-05,  rl2 = 6.88e-03
# iter. = 145000,  time = 144s,  loss = 1.98e-03  |  mse = 4.08e-05,  rl2 = 9.12e-03
# iter. = 150000,  time = 148s,  loss = 1.62e-05  |  mse = 2.80e-05,  rl2 = 7.54e-03
# iter. = 155000,  time = 153s,  loss = 1.34e-04  |  mse = 4.34e-05,  rl2 = 9.16e-03
# iter. = 160000,  time = 158s,  loss = 1.30e-05  |  mse = 1.79e-05,  rl2 = 6.01e-03
# iter. = 165000,  time = 163s,  loss = 2.41e-04  |  mse = 2.57e-05,  rl2 = 7.25e-03
# iter. = 170000,  time = 168s,  loss = 1.08e-05  |  mse = 1.83e-05,  rl2 = 6.07e-03
# iter. = 175000,  time = 173s,  loss = 2.57e-05  |  mse = 9.96e-06,  rl2 = 4.46e-03
# iter. = 180000,  time = 178s,  loss = 4.42e-05  |  mse = 2.31e-05,  rl2 = 6.68e-03
# iter. = 185000,  time = 183s,  loss = 4.31e-06  |  mse = 1.38e-05,  rl2 = 5.31e-03
# iter. = 190000,  time = 188s,  loss = 9.58e-06  |  mse = 9.12e-06,  rl2 = 4.23e-03
# iter. = 195000,  time = 192s,  loss = 5.90e-06  |  mse = 2.88e-05,  rl2 = 7.56e-03
# iter. = 200000,  time = 197s,  loss = 4.11e-05  |  mse = 1.25e-05,  rl2 = 5.07e-03
# iter. = 205000,  time = 202s,  loss = 3.40e-04  |  mse = 2.34e-05,  rl2 = 6.86e-03
# iter. = 210000,  time = 207s,  loss = 5.96e-05  |  mse = 1.52e-05,  rl2 = 5.38e-03
# iter. = 215000,  time = 212s,  loss = 1.74e-05  |  mse = 8.35e-06,  rl2 = 4.13e-03
# iter. = 220000,  time = 217s,  loss = 7.27e-06  |  mse = 9.23e-06,  rl2 = 4.23e-03
# iter. = 225000,  time = 222s,  loss = 7.58e-06  |  mse = 5.92e-06,  rl2 = 3.46e-03
# iter. = 230000,  time = 227s,  loss = 9.54e-05  |  mse = 1.21e-05,  rl2 = 4.87e-03
# iter. = 235000,  time = 232s,  loss = 3.20e-04  |  mse = 2.23e-05,  rl2 = 6.72e-03
# iter. = 240000,  time = 236s,  loss = 1.69e-05  |  mse = 1.00e-05,  rl2 = 4.54e-03
# iter. = 245000,  time = 241s,  loss = 2.99e-05  |  mse = 7.86e-06,  rl2 = 3.95e-03
# iter. = 250000,  time = 246s,  loss = 4.73e-05  |  mse = 5.65e-06,  rl2 = 3.35e-03
# iter. = 255000,  time = 251s,  loss = 7.06e-06  |  mse = 3.28e-06,  rl2 = 2.55e-03
# iter. = 260000,  time = 256s,  loss = 6.11e-06  |  mse = 5.41e-06,  rl2 = 3.29e-03
# iter. = 265000,  time = 261s,  loss = 4.72e-05  |  mse = 5.65e-06,  rl2 = 3.38e-03
# iter. = 270000,  time = 266s,  loss = 2.81e-06  |  mse = 5.79e-06,  rl2 = 3.40e-03
# iter. = 275000,  time = 271s,  loss = 6.58e-06  |  mse = 3.26e-06,  rl2 = 2.58e-03
# iter. = 280000,  time = 275s,  loss = 8.42e-05  |  mse = 5.43e-06,  rl2 = 3.29e-03
# iter. = 285000,  time = 280s,  loss = 1.16e-05  |  mse = 5.07e-06,  rl2 = 3.21e-03
# iter. = 290000,  time = 285s,  loss = 8.26e-05  |  mse = 4.29e-06,  rl2 = 2.91e-03
# iter. = 295000,  time = 290s,  loss = 2.13e-05  |  mse = 3.59e-06,  rl2 = 2.59e-03
# iter. = 300000,  time = 295s,  loss = 2.02e-06  |  mse = 2.29e-06,  rl2 = 2.14e-03
# iter. = 305000,  time = 300s,  loss = 7.32e-05  |  mse = 6.77e-06,  rl2 = 3.72e-03
# iter. = 310000,  time = 305s,  loss = 1.31e-05  |  mse = 3.97e-06,  rl2 = 2.84e-03
# iter. = 315000,  time = 310s,  loss = 1.49e-05  |  mse = 1.50e-06,  rl2 = 1.70e-03
# iter. = 320000,  time = 315s,  loss = 5.68e-05  |  mse = 3.90e-06,  rl2 = 2.81e-03
# iter. = 325000,  time = 319s,  loss = 7.23e-05  |  mse = 2.42e-06,  rl2 = 2.24e-03
# iter. = 330000,  time = 324s,  loss = 6.32e-06  |  mse = 1.35e-06,  rl2 = 1.65e-03
# iter. = 335000,  time = 329s,  loss = 2.08e-06  |  mse = 9.57e-07,  rl2 = 1.38e-03
# iter. = 340000,  time = 334s,  loss = 1.37e-06  |  mse = 1.18e-06,  rl2 = 1.53e-03
# iter. = 345000,  time = 339s,  loss = 5.04e-05  |  mse = 2.15e-06,  rl2 = 2.10e-03
# iter. = 350000,  time = 344s,  loss = 5.12e-07  |  mse = 3.14e-07,  rl2 = 7.79e-04
# iter. = 355000,  time = 349s,  loss = 5.44e-07  |  mse = 2.47e-07,  rl2 = 6.97e-04
# iter. = 360000,  time = 354s,  loss = 7.76e-07  |  mse = 4.42e-07,  rl2 = 9.35e-04
# iter. = 365000,  time = 359s,  loss = 3.72e-07  |  mse = 5.16e-07,  rl2 = 1.03e-03
# iter. = 370000,  time = 363s,  loss = 6.57e-07  |  mse = 4.26e-07,  rl2 = 9.08e-04
# iter. = 375000,  time = 368s,  loss = 1.07e-06  |  mse = 4.74e-07,  rl2 = 9.65e-04
# iter. = 380000,  time = 373s,  loss = 3.68e-07  |  mse = 2.56e-07,  rl2 = 7.20e-04
# iter. = 385000,  time = 378s,  loss = 2.40e-06  |  mse = 1.99e-07,  rl2 = 6.31e-04
# iter. = 390000,  time = 383s,  loss = 2.79e-07  |  mse = 2.56e-07,  rl2 = 7.17e-04
# iter. = 395000,  time = 388s,  loss = 4.76e-07  |  mse = 2.26e-07,  rl2 = 6.93e-04
# iter. = 400000,  time = 393s,  loss = 2.83e-07  |  mse = 1.07e-07,  rl2 = 4.82e-04
# iter. = 405000,  time = 398s,  loss = 5.61e-06  |  mse = 1.17e-07,  rl2 = 4.84e-04
# iter. = 410000,  time = 403s,  loss = 4.28e-07  |  mse = 8.04e-08,  rl2 = 4.08e-04
# iter. = 415000,  time = 407s,  loss = 1.82e-07  |  mse = 7.15e-08,  rl2 = 3.88e-04
# iter. = 420000,  time = 412s,  loss = 3.16e-07  |  mse = 8.97e-08,  rl2 = 4.26e-04
# iter. = 425000,  time = 417s,  loss = 4.80e-07  |  mse = 6.29e-08,  rl2 = 3.56e-04
# iter. = 430000,  time = 422s,  loss = 2.20e-07  |  mse = 4.43e-08,  rl2 = 2.95e-04
# iter. = 435000,  time = 427s,  loss = 3.69e-07  |  mse = 3.95e-08,  rl2 = 2.77e-04
# iter. = 440000,  time = 432s,  loss = 1.52e-07  |  mse = 4.12e-08,  rl2 = 2.87e-04
# iter. = 445000,  time = 437s,  loss = 7.98e-07  |  mse = 8.42e-08,  rl2 = 4.16e-04
# iter. = 450000,  time = 442s,  loss = 1.26e-07  |  mse = 3.30e-08,  rl2 = 2.58e-04
# iter. = 455000,  time = 447s,  loss = 1.16e-07  |  mse = 3.86e-08,  rl2 = 2.86e-04
# iter. = 460000,  time = 451s,  loss = 1.38e-07  |  mse = 6.91e-08,  rl2 = 3.75e-04
# iter. = 465000,  time = 456s,  loss = 7.76e-08  |  mse = 4.23e-08,  rl2 = 2.88e-04
# iter. = 470000,  time = 461s,  loss = 6.06e-08  |  mse = 3.54e-08,  rl2 = 2.59e-04
# iter. = 475000,  time = 466s,  loss = 4.80e-08  |  mse = 2.55e-08,  rl2 = 2.23e-04
# iter. = 480000,  time = 471s,  loss = 6.60e-08  |  mse = 4.19e-08,  rl2 = 2.87e-04
# iter. = 485000,  time = 476s,  loss = 4.21e-08  |  mse = 2.89e-08,  rl2 = 2.45e-04
# iter. = 490000,  time = 481s,  loss = 4.97e-08  |  mse = 3.81e-08,  rl2 = 2.82e-04
# iter. = 495000,  time = 486s,  loss = 4.37e-08  |  mse = 4.89e-08,  rl2 = 3.13e-04
# iter. = 500000,  time = 490s,  loss = 4.52e-08  |  mse = 1.92e-08,  rl2 = 1.91e-04
# [v2=1.0e-04] :  MSE = 2.69e-08  RL2 = 2.31e-04
# iter. = 00000,  time = 002s,  loss = 2.60e+02  |  mse = 7.32e-01,  rl2 = 1.24e+00
# iter. = 05000,  time = 007s,  loss = 7.58e-03  |  mse = 1.53e-01,  rl2 = 5.57e-01
# iter. = 10000,  time = 012s,  loss = 8.65e-03  |  mse = 4.87e-02,  rl2 = 3.09e-01
# iter. = 15000,  time = 017s,  loss = 8.57e-04  |  mse = 6.10e-03,  rl2 = 1.11e-01
# iter. = 20000,  time = 021s,  loss = 7.60e-04  |  mse = 1.21e-03,  rl2 = 4.96e-02
# iter. = 25000,  time = 026s,  loss = 5.33e-04  |  mse = 5.21e-04,  rl2 = 3.20e-02
# iter. = 30000,  time = 031s,  loss = 6.01e-04  |  mse = 3.71e-04,  rl2 = 2.74e-02
# iter. = 35000,  time = 036s,  loss = 5.90e-05  |  mse = 4.69e-04,  rl2 = 3.09e-02
# iter. = 40000,  time = 041s,  loss = 1.98e-03  |  mse = 1.23e-04,  rl2 = 1.56e-02
# iter. = 45000,  time = 046s,  loss = 3.59e-05  |  mse = 3.49e-04,  rl2 = 2.68e-02
# iter. = 50000,  time = 051s,  loss = 7.64e-04  |  mse = 2.62e-04,  rl2 = 2.32e-02
# iter. = 55000,  time = 056s,  loss = 2.17e-03  |  mse = 1.73e-04,  rl2 = 1.89e-02
# iter. = 60000,  time = 060s,  loss = 2.07e-04  |  mse = 9.01e-05,  rl2 = 1.35e-02
# iter. = 65000,  time = 065s,  loss = 2.13e-04  |  mse = 1.46e-04,  rl2 = 1.71e-02
# iter. = 70000,  time = 070s,  loss = 1.17e-04  |  mse = 7.55e-05,  rl2 = 1.21e-02
# iter. = 75000,  time = 075s,  loss = 2.46e-04  |  mse = 9.78e-05,  rl2 = 1.41e-02
# iter. = 80000,  time = 080s,  loss = 1.23e-04  |  mse = 1.24e-04,  rl2 = 1.57e-02
# iter. = 85000,  time = 085s,  loss = 1.58e-03  |  mse = 8.66e-05,  rl2 = 1.33e-02
# iter. = 90000,  time = 090s,  loss = 1.89e-05  |  mse = 8.92e-05,  rl2 = 1.33e-02
# iter. = 95000,  time = 095s,  loss = 6.47e-05  |  mse = 9.81e-05,  rl2 = 1.39e-02
# iter. = 100000,  time = 099s,  loss = 1.84e-05  |  mse = 5.21e-05,  rl2 = 1.01e-02
# iter. = 105000,  time = 104s,  loss = 1.12e-05  |  mse = 4.92e-05,  rl2 = 9.85e-03
# iter. = 110000,  time = 109s,  loss = 4.97e-05  |  mse = 5.23e-05,  rl2 = 1.02e-02
# iter. = 115000,  time = 114s,  loss = 1.17e-04  |  mse = 4.27e-05,  rl2 = 9.22e-03
# iter. = 120000,  time = 119s,  loss = 9.53e-05  |  mse = 3.36e-05,  rl2 = 8.20e-03
# iter. = 125000,  time = 124s,  loss = 3.00e-05  |  mse = 3.03e-05,  rl2 = 7.67e-03
# iter. = 130000,  time = 129s,  loss = 7.12e-04  |  mse = 3.54e-05,  rl2 = 8.33e-03
# iter. = 135000,  time = 134s,  loss = 8.29e-04  |  mse = 4.65e-05,  rl2 = 9.61e-03
# iter. = 140000,  time = 139s,  loss = 1.15e-04  |  mse = 1.71e-05,  rl2 = 5.82e-03
# iter. = 145000,  time = 143s,  loss = 3.52e-04  |  mse = 3.01e-05,  rl2 = 7.75e-03
# iter. = 150000,  time = 148s,  loss = 1.62e-05  |  mse = 2.49e-05,  rl2 = 7.03e-03
# iter. = 155000,  time = 153s,  loss = 3.25e-05  |  mse = 2.59e-05,  rl2 = 7.16e-03
# iter. = 160000,  time = 158s,  loss = 1.00e-05  |  mse = 1.35e-05,  rl2 = 5.16e-03
# iter. = 165000,  time = 163s,  loss = 6.26e-04  |  mse = 9.72e-05,  rl2 = 1.39e-02
# iter. = 170000,  time = 168s,  loss = 4.22e-05  |  mse = 3.49e-05,  rl2 = 8.40e-03
# iter. = 175000,  time = 173s,  loss = 2.01e-04  |  mse = 2.78e-05,  rl2 = 7.62e-03
# iter. = 180000,  time = 178s,  loss = 5.33e-06  |  mse = 2.43e-05,  rl2 = 7.05e-03
# iter. = 185000,  time = 183s,  loss = 1.50e-05  |  mse = 2.80e-05,  rl2 = 7.48e-03
# iter. = 190000,  time = 187s,  loss = 1.46e-05  |  mse = 9.62e-06,  rl2 = 4.39e-03
# iter. = 195000,  time = 192s,  loss = 7.77e-04  |  mse = 5.88e-05,  rl2 = 1.10e-02
# iter. = 200000,  time = 197s,  loss = 1.26e-05  |  mse = 6.98e-06,  rl2 = 3.72e-03
# iter. = 205000,  time = 202s,  loss = 2.05e-05  |  mse = 1.94e-05,  rl2 = 6.37e-03
# iter. = 210000,  time = 207s,  loss = 2.77e-06  |  mse = 1.13e-05,  rl2 = 4.81e-03
# iter. = 215000,  time = 212s,  loss = 2.66e-05  |  mse = 1.43e-05,  rl2 = 5.58e-03
# iter. = 220000,  time = 217s,  loss = 2.65e-06  |  mse = 1.11e-05,  rl2 = 4.70e-03
# iter. = 225000,  time = 222s,  loss = 1.21e-05  |  mse = 8.22e-06,  rl2 = 3.98e-03
# iter. = 230000,  time = 227s,  loss = 4.75e-04  |  mse = 2.38e-05,  rl2 = 6.87e-03
# iter. = 235000,  time = 231s,  loss = 2.32e-04  |  mse = 1.12e-05,  rl2 = 4.78e-03
# iter. = 240000,  time = 236s,  loss = 8.19e-05  |  mse = 9.25e-06,  rl2 = 4.33e-03
# iter. = 245000,  time = 241s,  loss = 7.12e-05  |  mse = 1.22e-05,  rl2 = 4.97e-03
# iter. = 250000,  time = 246s,  loss = 5.47e-06  |  mse = 1.21e-05,  rl2 = 5.11e-03
# iter. = 255000,  time = 251s,  loss = 3.94e-06  |  mse = 6.63e-06,  rl2 = 3.64e-03
# iter. = 260000,  time = 256s,  loss = 2.08e-04  |  mse = 1.81e-05,  rl2 = 6.12e-03
# iter. = 265000,  time = 261s,  loss = 3.07e-05  |  mse = 1.01e-05,  rl2 = 4.54e-03
# iter. = 270000,  time = 266s,  loss = 1.52e-06  |  mse = 1.21e-05,  rl2 = 4.90e-03
# iter. = 275000,  time = 271s,  loss = 5.76e-06  |  mse = 8.17e-06,  rl2 = 4.02e-03
# iter. = 280000,  time = 275s,  loss = 3.24e-06  |  mse = 2.31e-06,  rl2 = 2.11e-03
# iter. = 285000,  time = 280s,  loss = 7.90e-05  |  mse = 4.23e-06,  rl2 = 2.91e-03
# iter. = 290000,  time = 285s,  loss = 3.97e-06  |  mse = 7.72e-06,  rl2 = 3.85e-03
# iter. = 295000,  time = 290s,  loss = 1.02e-04  |  mse = 6.87e-06,  rl2 = 3.66e-03
# iter. = 300000,  time = 295s,  loss = 3.26e-06  |  mse = 6.45e-06,  rl2 = 3.57e-03
# iter. = 305000,  time = 300s,  loss = 1.32e-06  |  mse = 2.38e-06,  rl2 = 2.12e-03
# iter. = 310000,  time = 305s,  loss = 1.60e-04  |  mse = 8.70e-06,  rl2 = 4.16e-03
# iter. = 315000,  time = 310s,  loss = 6.63e-07  |  mse = 6.36e-06,  rl2 = 3.54e-03
# iter. = 320000,  time = 314s,  loss = 1.95e-06  |  mse = 6.08e-06,  rl2 = 3.56e-03
# iter. = 325000,  time = 319s,  loss = 2.64e-06  |  mse = 4.28e-06,  rl2 = 2.97e-03
# iter. = 330000,  time = 324s,  loss = 8.57e-07  |  mse = 2.06e-06,  rl2 = 2.00e-03
# iter. = 335000,  time = 329s,  loss = 9.70e-07  |  mse = 6.12e-06,  rl2 = 3.50e-03
# iter. = 340000,  time = 334s,  loss = 9.73e-07  |  mse = 1.68e-06,  rl2 = 1.84e-03
# iter. = 345000,  time = 339s,  loss = 6.43e-07  |  mse = 3.01e-06,  rl2 = 2.47e-03
# iter. = 350000,  time = 344s,  loss = 2.49e-05  |  mse = 5.10e-06,  rl2 = 3.18e-03
# iter. = 355000,  time = 349s,  loss = 2.15e-06  |  mse = 1.05e-06,  rl2 = 1.45e-03
# iter. = 360000,  time = 354s,  loss = 1.22e-05  |  mse = 1.65e-06,  rl2 = 1.78e-03
# iter. = 365000,  time = 358s,  loss = 6.15e-07  |  mse = 1.38e-06,  rl2 = 1.68e-03
# iter. = 370000,  time = 363s,  loss = 2.69e-06  |  mse = 2.21e-06,  rl2 = 2.14e-03
# iter. = 375000,  time = 368s,  loss = 1.15e-06  |  mse = 1.12e-06,  rl2 = 1.51e-03
# iter. = 380000,  time = 373s,  loss = 7.26e-07  |  mse = 1.62e-06,  rl2 = 1.84e-03
# iter. = 385000,  time = 378s,  loss = 2.43e-06  |  mse = 7.42e-07,  rl2 = 1.24e-03
# iter. = 390000,  time = 383s,  loss = 1.60e-07  |  mse = 8.58e-07,  rl2 = 1.30e-03
# iter. = 395000,  time = 388s,  loss = 9.76e-07  |  mse = 2.35e-06,  rl2 = 2.16e-03
# iter. = 400000,  time = 393s,  loss = 2.78e-06  |  mse = 1.20e-06,  rl2 = 1.60e-03
# iter. = 405000,  time = 397s,  loss = 2.11e-07  |  mse = 3.98e-07,  rl2 = 8.81e-04
# iter. = 410000,  time = 402s,  loss = 1.42e-07  |  mse = 4.36e-07,  rl2 = 9.50e-04
# iter. = 415000,  time = 407s,  loss = 4.56e-07  |  mse = 5.73e-07,  rl2 = 1.07e-03
# iter. = 420000,  time = 412s,  loss = 7.31e-07  |  mse = 4.58e-07,  rl2 = 9.65e-04
# iter. = 425000,  time = 417s,  loss = 1.98e-07  |  mse = 3.79e-07,  rl2 = 8.79e-04
# iter. = 430000,  time = 422s,  loss = 2.45e-07  |  mse = 5.66e-07,  rl2 = 1.07e-03
# iter. = 435000,  time = 427s,  loss = 1.07e-07  |  mse = 3.90e-07,  rl2 = 8.81e-04
# iter. = 440000,  time = 432s,  loss = 8.43e-08  |  mse = 1.38e-07,  rl2 = 5.35e-04
# iter. = 445000,  time = 437s,  loss = 7.11e-08  |  mse = 4.01e-07,  rl2 = 8.98e-04
# iter. = 450000,  time = 441s,  loss = 1.99e-07  |  mse = 3.83e-07,  rl2 = 8.56e-04
# iter. = 455000,  time = 446s,  loss = 6.82e-08  |  mse = 9.44e-08,  rl2 = 4.32e-04
# iter. = 460000,  time = 451s,  loss = 5.59e-08  |  mse = 1.47e-07,  rl2 = 5.39e-04
# iter. = 465000,  time = 456s,  loss = 3.71e-08  |  mse = 1.84e-07,  rl2 = 6.12e-04
# iter. = 470000,  time = 461s,  loss = 4.92e-08  |  mse = 1.06e-07,  rl2 = 4.56e-04
# iter. = 475000,  time = 466s,  loss = 4.51e-08  |  mse = 1.38e-07,  rl2 = 5.31e-04
# iter. = 480000,  time = 471s,  loss = 3.90e-08  |  mse = 2.02e-07,  rl2 = 6.43e-04
# iter. = 485000,  time = 476s,  loss = 2.80e-08  |  mse = 2.54e-07,  rl2 = 7.09e-04
# iter. = 490000,  time = 481s,  loss = 2.77e-08  |  mse = 2.40e-07,  rl2 = 6.78e-04
# iter. = 495000,  time = 485s,  loss = 3.19e-08  |  mse = 1.42e-07,  rl2 = 5.33e-04
# iter. = 500000,  time = 490s,  loss = 3.37e-08  |  mse = 1.73e-07,  rl2 = 5.87e-04
# [v2=1.0e-04] :  MSE = 1.99e-07  RL2 = 6.29e-04
# iter. = 00000,  time = 002s,  loss = 2.63e+02  |  mse = 6.52e-01,  rl2 = 1.14e+00
# iter. = 05000,  time = 007s,  loss = 1.72e-02  |  mse = 2.07e-01,  rl2 = 6.36e-01
# iter. = 10000,  time = 012s,  loss = 9.00e-03  |  mse = 6.04e-02,  rl2 = 3.59e-01
# iter. = 15000,  time = 016s,  loss = 5.33e-04  |  mse = 4.66e-03,  rl2 = 9.60e-02
# iter. = 20000,  time = 021s,  loss = 6.66e-04  |  mse = 2.79e-03,  rl2 = 7.38e-02
# iter. = 25000,  time = 026s,  loss = 4.34e-04  |  mse = 7.20e-04,  rl2 = 3.74e-02
# iter. = 30000,  time = 031s,  loss = 2.65e-03  |  mse = 7.81e-04,  rl2 = 3.92e-02
# iter. = 35000,  time = 036s,  loss = 1.95e-04  |  mse = 3.48e-04,  rl2 = 2.67e-02
# iter. = 40000,  time = 041s,  loss = 2.09e-04  |  mse = 2.31e-04,  rl2 = 2.15e-02
# iter. = 45000,  time = 046s,  loss = 1.17e-03  |  mse = 1.77e-04,  rl2 = 1.88e-02
# iter. = 50000,  time = 051s,  loss = 6.55e-04  |  mse = 2.61e-04,  rl2 = 2.35e-02
# iter. = 55000,  time = 055s,  loss = 5.52e-05  |  mse = 1.44e-04,  rl2 = 1.73e-02
# iter. = 60000,  time = 060s,  loss = 4.02e-05  |  mse = 6.84e-05,  rl2 = 1.17e-02
# iter. = 65000,  time = 065s,  loss = 6.39e-05  |  mse = 1.52e-04,  rl2 = 1.75e-02
# iter. = 70000,  time = 070s,  loss = 3.50e-05  |  mse = 6.49e-05,  rl2 = 1.13e-02
# iter. = 75000,  time = 075s,  loss = 1.31e-05  |  mse = 4.75e-05,  rl2 = 9.77e-03
# iter. = 80000,  time = 080s,  loss = 1.01e-03  |  mse = 7.13e-05,  rl2 = 1.22e-02
# iter. = 85000,  time = 085s,  loss = 2.81e-04  |  mse = 1.14e-04,  rl2 = 1.48e-02
# iter. = 90000,  time = 090s,  loss = 1.27e-04  |  mse = 3.91e-05,  rl2 = 8.73e-03
# iter. = 95000,  time = 095s,  loss = 5.14e-05  |  mse = 5.66e-05,  rl2 = 1.06e-02
# iter. = 100000,  time = 099s,  loss = 3.17e-04  |  mse = 4.16e-05,  rl2 = 9.14e-03
# iter. = 105000,  time = 104s,  loss = 4.93e-06  |  mse = 4.66e-05,  rl2 = 9.70e-03
# iter. = 110000,  time = 109s,  loss = 1.28e-04  |  mse = 4.35e-05,  rl2 = 9.64e-03
# iter. = 115000,  time = 114s,  loss = 4.97e-04  |  mse = 4.01e-04,  rl2 = 2.85e-02
# iter. = 120000,  time = 119s,  loss = 5.21e-03  |  mse = 1.48e-03,  rl2 = 5.35e-02
# iter. = 125000,  time = 124s,  loss = 2.58e-05  |  mse = 3.87e-05,  rl2 = 8.85e-03
# iter. = 130000,  time = 129s,  loss = 3.00e-04  |  mse = 2.19e-05,  rl2 = 6.54e-03
# iter. = 135000,  time = 134s,  loss = 7.20e-04  |  mse = 3.41e-05,  rl2 = 8.31e-03
# iter. = 140000,  time = 138s,  loss = 1.28e-04  |  mse = 2.32e-05,  rl2 = 6.75e-03
# iter. = 145000,  time = 143s,  loss = 4.19e-05  |  mse = 2.60e-05,  rl2 = 7.38e-03
# iter. = 150000,  time = 148s,  loss = 2.88e-04  |  mse = 2.73e-05,  rl2 = 7.46e-03
# iter. = 155000,  time = 153s,  loss = 1.12e-05  |  mse = 4.02e-05,  rl2 = 8.83e-03
# iter. = 160000,  time = 158s,  loss = 1.96e-04  |  mse = 1.28e-04,  rl2 = 1.60e-02
# iter. = 165000,  time = 163s,  loss = 3.30e-03  |  mse = 1.16e-04,  rl2 = 1.52e-02
# iter. = 170000,  time = 168s,  loss = 9.97e-06  |  mse = 3.20e-05,  rl2 = 7.92e-03
# iter. = 175000,  time = 173s,  loss = 1.61e-05  |  mse = 1.74e-05,  rl2 = 5.90e-03
# iter. = 180000,  time = 178s,  loss = 3.23e-04  |  mse = 6.32e-05,  rl2 = 1.13e-02
# iter. = 185000,  time = 182s,  loss = 1.17e-04  |  mse = 2.56e-05,  rl2 = 7.17e-03
# iter. = 190000,  time = 187s,  loss = 2.98e-04  |  mse = 4.32e-05,  rl2 = 9.38e-03
# iter. = 195000,  time = 192s,  loss = 5.50e-05  |  mse = 3.03e-05,  rl2 = 7.94e-03
# iter. = 200000,  time = 197s,  loss = 5.22e-06  |  mse = 1.07e-05,  rl2 = 4.66e-03
# iter. = 205000,  time = 202s,  loss = 2.28e-05  |  mse = 2.97e-05,  rl2 = 7.99e-03
# iter. = 210000,  time = 207s,  loss = 1.35e-05  |  mse = 1.58e-05,  rl2 = 5.64e-03
# iter. = 215000,  time = 212s,  loss = 3.32e-05  |  mse = 2.20e-05,  rl2 = 6.81e-03
# iter. = 220000,  time = 217s,  loss = 3.95e-06  |  mse = 9.75e-06,  rl2 = 4.43e-03
# iter. = 225000,  time = 222s,  loss = 6.63e-06  |  mse = 1.73e-05,  rl2 = 5.96e-03
# iter. = 230000,  time = 226s,  loss = 2.73e-06  |  mse = 2.05e-05,  rl2 = 6.46e-03
# iter. = 235000,  time = 231s,  loss = 5.68e-05  |  mse = 2.10e-05,  rl2 = 6.48e-03
# iter. = 240000,  time = 236s,  loss = 2.09e-06  |  mse = 1.87e-05,  rl2 = 6.29e-03
# iter. = 245000,  time = 241s,  loss = 7.29e-05  |  mse = 1.86e-05,  rl2 = 6.11e-03
# iter. = 250000,  time = 246s,  loss = 7.06e-05  |  mse = 1.06e-05,  rl2 = 4.63e-03
# iter. = 255000,  time = 251s,  loss = 1.37e-05  |  mse = 1.07e-05,  rl2 = 4.69e-03
# iter. = 260000,  time = 256s,  loss = 1.99e-05  |  mse = 6.54e-06,  rl2 = 3.63e-03
# iter. = 265000,  time = 261s,  loss = 1.25e-04  |  mse = 1.32e-05,  rl2 = 5.14e-03
# iter. = 270000,  time = 266s,  loss = 8.96e-07  |  mse = 8.12e-06,  rl2 = 4.11e-03
# iter. = 275000,  time = 270s,  loss = 1.79e-05  |  mse = 1.32e-05,  rl2 = 5.22e-03
# iter. = 280000,  time = 275s,  loss = 3.96e-06  |  mse = 1.02e-05,  rl2 = 4.54e-03
# iter. = 285000,  time = 280s,  loss = 1.04e-05  |  mse = 8.31e-06,  rl2 = 4.06e-03
# iter. = 290000,  time = 285s,  loss = 5.61e-05  |  mse = 1.50e-05,  rl2 = 5.48e-03
# iter. = 295000,  time = 290s,  loss = 1.48e-06  |  mse = 3.06e-06,  rl2 = 2.47e-03
# iter. = 300000,  time = 295s,  loss = 1.12e-04  |  mse = 5.26e-06,  rl2 = 3.30e-03
# iter. = 305000,  time = 300s,  loss = 2.56e-05  |  mse = 9.32e-06,  rl2 = 4.34e-03
# iter. = 310000,  time = 305s,  loss = 1.77e-06  |  mse = 7.04e-06,  rl2 = 3.83e-03
# iter. = 315000,  time = 310s,  loss = 6.90e-07  |  mse = 6.66e-06,  rl2 = 3.74e-03
# iter. = 320000,  time = 314s,  loss = 3.20e-06  |  mse = 5.65e-06,  rl2 = 3.45e-03
# iter. = 325000,  time = 319s,  loss = 8.24e-07  |  mse = 3.74e-06,  rl2 = 2.75e-03
# iter. = 330000,  time = 324s,  loss = 2.67e-06  |  mse = 3.61e-06,  rl2 = 2.74e-03
# iter. = 335000,  time = 329s,  loss = 1.14e-05  |  mse = 1.84e-06,  rl2 = 1.90e-03
# iter. = 340000,  time = 334s,  loss = 2.68e-06  |  mse = 4.95e-06,  rl2 = 3.19e-03
# iter. = 345000,  time = 339s,  loss = 6.01e-06  |  mse = 2.58e-06,  rl2 = 2.26e-03
# iter. = 350000,  time = 344s,  loss = 4.83e-06  |  mse = 3.50e-06,  rl2 = 2.65e-03
# iter. = 355000,  time = 349s,  loss = 1.46e-06  |  mse = 2.00e-06,  rl2 = 2.05e-03
# iter. = 360000,  time = 354s,  loss = 2.12e-06  |  mse = 2.81e-06,  rl2 = 2.39e-03
# iter. = 365000,  time = 358s,  loss = 7.05e-07  |  mse = 2.61e-06,  rl2 = 2.26e-03
# iter. = 370000,  time = 363s,  loss = 5.76e-07  |  mse = 1.10e-06,  rl2 = 1.51e-03
# iter. = 375000,  time = 368s,  loss = 1.12e-05  |  mse = 2.71e-06,  rl2 = 2.39e-03
# iter. = 380000,  time = 373s,  loss = 1.80e-07  |  mse = 1.78e-06,  rl2 = 1.93e-03
# iter. = 385000,  time = 378s,  loss = 1.95e-06  |  mse = 9.64e-07,  rl2 = 1.42e-03
# iter. = 390000,  time = 383s,  loss = 1.37e-07  |  mse = 7.71e-07,  rl2 = 1.20e-03
# iter. = 395000,  time = 388s,  loss = 3.00e-07  |  mse = 6.13e-07,  rl2 = 1.12e-03
# iter. = 400000,  time = 393s,  loss = 1.41e-06  |  mse = 3.29e-07,  rl2 = 8.17e-04
# iter. = 405000,  time = 398s,  loss = 7.23e-07  |  mse = 2.38e-07,  rl2 = 6.90e-04
# iter. = 410000,  time = 402s,  loss = 3.79e-07  |  mse = 3.50e-07,  rl2 = 8.45e-04
# iter. = 415000,  time = 407s,  loss = 2.28e-07  |  mse = 2.14e-07,  rl2 = 6.58e-04
# iter. = 420000,  time = 412s,  loss = 5.03e-07  |  mse = 2.83e-07,  rl2 = 7.60e-04
# iter. = 425000,  time = 417s,  loss = 1.19e-07  |  mse = 3.17e-07,  rl2 = 7.89e-04
# iter. = 430000,  time = 422s,  loss = 5.14e-07  |  mse = 2.20e-07,  rl2 = 6.63e-04
# iter. = 435000,  time = 427s,  loss = 2.60e-07  |  mse = 3.35e-07,  rl2 = 8.30e-04
# iter. = 440000,  time = 432s,  loss = 1.05e-07  |  mse = 1.67e-07,  rl2 = 5.81e-04
# iter. = 445000,  time = 437s,  loss = 6.83e-08  |  mse = 8.58e-08,  rl2 = 4.07e-04
# iter. = 450000,  time = 442s,  loss = 5.04e-08  |  mse = 2.66e-07,  rl2 = 7.30e-04
# iter. = 455000,  time = 446s,  loss = 4.33e-08  |  mse = 2.39e-07,  rl2 = 6.81e-04
# iter. = 460000,  time = 451s,  loss = 3.54e-08  |  mse = 4.32e-08,  rl2 = 2.99e-04
# iter. = 465000,  time = 456s,  loss = 3.40e-08  |  mse = 1.21e-07,  rl2 = 4.83e-04
# iter. = 470000,  time = 461s,  loss = 3.39e-08  |  mse = 1.28e-07,  rl2 = 5.14e-04
# iter. = 475000,  time = 466s,  loss = 3.03e-08  |  mse = 8.67e-08,  rl2 = 4.29e-04
# iter. = 480000,  time = 471s,  loss = 2.30e-08  |  mse = 1.30e-07,  rl2 = 5.14e-04
# iter. = 485000,  time = 476s,  loss = 2.46e-08  |  mse = 9.86e-08,  rl2 = 4.46e-04
# iter. = 490000,  time = 481s,  loss = 2.53e-08  |  mse = 6.06e-08,  rl2 = 3.49e-04
# iter. = 495000,  time = 486s,  loss = 2.19e-08  |  mse = 5.88e-08,  rl2 = 3.43e-04
# iter. = 500000,  time = 490s,  loss = 2.58e-08  |  mse = 6.37e-08,  rl2 = 3.51e-04
# [v2=1.0e-04] :  MSE = 8.89e-08  RL2 = 4.20e-04

# %%
import pickle
# save all weight
pickle.dump(params_5, open('batch5_final_ac', 'wb'))
pickle.dump(store_nnws_5, open('batch5_hist_ac', 'wb'))
pickle.dump(ref_params_5, open('batch5_final_ac-ref', 'wb'))
pickle.dump(ref_store_nnws_5, open('batch5_hist_ac-ref', 'wb'))

# %%
# read data
mat_data = io.loadmat('allen_cahn.mat')
sim_t = np.repeat(mat_data['t'], 512).reshape(-1,1)
sim_x = np.tile(mat_data['x'], 201).reshape(-1,1)
sim_u = mat_data['usol'].reshape(-1,1)
data_X, data_Y = np.hstack([sim_t, sim_x]), sim_u
t_l, t_u, x_l, x_u = np.min(data_X[:,0]), np.max(data_X[:,0]), np.min(data_X[:,1]), np.max(data_X[:,1])

# convert to jnp
data_X, data_Y = jnp.array(data_X), jnp.array(data_Y)
inputs, labels = data_X, data_Y

# parameter
v2 = 0.0001

# model
model = PINN(128)

# %%
# PINN (final)
params = params_5[10]
pred = model.apply(params, inputs)
u, _, _, _, _, _,_ = jnp.split(pred, 7, axis=1)

# prediction errors
mse = jnp.mean(jnp.square(labels - u))
rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
print ('[v2=%.1e] :  MSE = %.2e  RL2 = %.2e'%(v2, mse, rl2))

# plot
fig = plt.figure(figsize=(15, 3))
plt.subplots_adjust(wspace=0.1)
# low fi
con_lv = 201
ext = [t_l, t_u, x_l, x_u]
# PINN
ax1 = fig.add_subplot(1,3,1)
plt.contourf(labels.reshape(-1, 512).T, con_lv, origin='lower', cmap='jet', extent=ext, vmin=-1, vmax=1);
plt.colorbar(ticks=[-1, 0, 1]); plt.title('Reference'); plt.xlabel('t'); plt.ylabel('x'); plt.yticks([-1, 0, 1]);
ax1 = fig.add_subplot(1,3,2)
plt.contourf(u.reshape(-1, 512).T, con_lv, origin='lower', cmap='jet', extent=ext, vmin=-1, vmax=1);
plt.colorbar(ticks=[-1, 0, 1]); plt.title('Predicted'); plt.yticks([-1, 0, 1]); 
ax1 = fig.add_subplot(1,3,3)
plt.contourf(abs(u - labels).reshape(-1, 512).T, con_lv, origin='lower', cmap='jet', extent=ext, vmin=0, vmax=0.001);
plt.colorbar(ticks=[0, 0.001]); plt.title('Absolute error'); plt.yticks([-1, 0, 1]);
# Out:
# [v2=1.0e-04] :  MSE = 1.41e-09  RL2 = 5.30e-05

# %% [markdown]
#     [v2=1.0e-04] :  MSE = 1.47e-09  RL2 = 5.40e-05

# %%
# average of 5
rl2s = []
for seed in [10, 20, 30, 40, 50]:
    params = params_5[seed]
    pred = model.apply(params, inputs)
    u, _, _, _, _, _, _ = jnp.split(pred, 7, axis=1)
    # prediction errors
    mse = jnp.mean(jnp.square(labels - u))
    rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
    print ('[v2=%.1e] :  MSE = %.2e  RL2 = %.2e'%(v2, mse, rl2))
    rl2s.append(rl2)
rl2s = np.array(rl2s)
print ('[v2=%.1e] :  RL2 best = %.2e  ave = %.2e'%(v2, rl2s.min(), rl2s.mean()))
# Out:
# [v2=1.0e-04] :  MSE = 1.41e-09  RL2 = 5.30e-05
# [v2=1.0e-04] :  MSE = 2.37e-09  RL2 = 6.85e-05
# [v2=1.0e-04] :  MSE = 1.94e-09  RL2 = 6.21e-05
# [v2=1.0e-04] :  MSE = 8.60e-09  RL2 = 1.31e-04
# [v2=1.0e-04] :  MSE = 1.99e-09  RL2 = 6.28e-05
# [v2=1.0e-04] :  RL2 best = 5.30e-05  ave = 7.54e-05

# %%
# convergence
p_time2sol_5 = {}
for seed in [10, 20, 30, 40, 50]:
    store_nnws = store_nnws_5[seed]
    p_time2sol = []
    for i in range(0, len(store_nnws), 6):
        runtime, params = store_nnws[i]
        pred = model.apply(params, inputs)
        u, _, _, _, _, _, _ = jnp.split(pred, 7, axis=1)
        # prediction errors
        mse = jnp.mean(jnp.square(labels - u))
        rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
        #print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
        p_time2sol.append([runtime, rl2])
    runtime, params = store_nnws[-1]
    pred = model.apply(params, inputs)
    u, _, _, _, _, _, _ = jnp.split(pred, 7, axis=1)
    # prediction errors
    mse = jnp.mean(jnp.square(labels - u))
    rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
    #print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
    p_time2sol.append([runtime, rl2])    
    print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
    p_time2sol = np.array(p_time2sol)
    p_time2sol_5[seed] = p_time2sol
# Out:
# [time = 531s] :  RL2 = 5.30e-05
# [time = 532s] :  RL2 = 6.85e-05
# [time = 533s] :  RL2 = 6.21e-05
# [time = 533s] :  RL2 = 1.31e-04
# [time = 532s] :  RL2 = 6.28e-05

# %%
# convergence (ref)
ref_p_time2sol_5 = {}
for seed in [10, 20, 30, 40, 50]:
    store_nnws = ref_store_nnws_5[seed]
    p_time2sol = []
    for i in range(0, len(store_nnws), 6):
        runtime, params = store_nnws[i]
        pred = model.apply(params, inputs)
        u, _, _, _, _, _, _ = jnp.split(pred, 7, axis=1)
        # prediction errors
        mse = jnp.mean(jnp.square(labels - u))
        rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
        #print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
        p_time2sol.append([runtime, rl2])
    runtime, params = store_nnws[-1]
    pred = model.apply(params, inputs)
    u, _, _, _, _, _, _ = jnp.split(pred, 7, axis=1)
    # prediction errors
    mse = jnp.mean(jnp.square(labels - u))
    rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
    #print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
    p_time2sol.append([runtime, rl2])    
    print ('[time = %03ds] :  RL2 = %.2e'%(runtime, rl2))    
    p_time2sol = np.array(p_time2sol)
    ref_p_time2sol_5[seed] = p_time2sol
# Out:
# [time = 491s] :  RL2 = 3.51e-04
# [time = 491s] :  RL2 = 6.90e-04
# [time = 490s] :  RL2 = 2.31e-04
# [time = 490s] :  RL2 = 6.29e-04
# [time = 490s] :  RL2 = 4.20e-04

# %%
fig = plt.figure(figsize=(2, 4))
makers = ['^', '<', '>', 'v', 'o']
for i, seed in enumerate([10, 20, 30, 40, 50]):
    p_time2sol = p_time2sol_5[seed]
    plt.plot(p_time2sol[:,0], p_time2sol[:,1], c='lightgreen', markeredgecolor='green', marker=makers[i], markersize=3, linestyle='-.');
p_time2sol = p_time2sol_5[10]
plt.plot(p_time2sol[:,0], p_time2sol[:,1], c='salmon', markeredgecolor='maroon', marker=makers[0], markersize=3, linestyle='-.', label='Baseline');
plt.plot(p_time2sol[:,0], p_time2sol[:,1], c='lightgreen', markeredgecolor='green', marker=makers[0], markersize=3, linestyle='-.', label='Scale-PINN');
for i, seed in enumerate([10, 20, 30, 40, 50]):
    p_time2sol = ref_p_time2sol_5[seed]
    plt.plot(p_time2sol[:,0], p_time2sol[:,1], c='salmon', markeredgecolor='maroon', marker=makers[i], markersize=3, linestyle='-.');
plt.xlabel('Training time (s)'); plt.ylabel('Relative error'); plt.yscale('log'); plt.ylim(1e-5, 10); plt.xlim(-0.5, 650);
plt.xticks([0, 300, 600]); plt.legend();

# %%
# PINN (final)
params = params_5[10]
pred = model.apply(params, inputs)
u, _, _, _, _, _,_ = jnp.split(pred, 7, axis=1)

# prediction errors
mse = jnp.mean(jnp.square(labels - u))
rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
print ('[v2=%.1e] :  MSE = %.2e  RL2 = %.2e'%(v2, mse, rl2))

# plot
fig = plt.figure(figsize=(2, 1.5))
# low fi
con_lv = 201
ext = [t_l, t_u, x_l, x_u]
# PINN
plt.contourf(u.reshape(-1, 512).T, con_lv, origin='lower', cmap='jet', extent=ext, vmin=-1, vmax=1);
plt.colorbar(ticks=[0, 1]); plt.title('Final (best)'); plt.yticks([-1, 0, 1]); plt.xticks([0.5], ['0.5s']);
# Out:
# [v2=1.0e-04] :  MSE = 1.41e-09  RL2 = 5.30e-05

# %%
# PINN (ref)
params = ref_params_5[10]
pred = model.apply(params, inputs)
u, _, _, _, _, _,_ = jnp.split(pred, 7, axis=1)

# prediction errors
mse = jnp.mean(jnp.square(labels - u))
rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
print ('[v2=%.1e] :  MSE = %.2e  RL2 = %.2e'%(v2, mse, rl2))

# plot
fig = plt.figure(figsize=(2, 1.5))
# low fi
con_lv = 201
ext = [t_l, t_u, x_l, x_u]
# PINN
plt.contourf(u.reshape(-1, 512).T, con_lv, origin='lower', cmap='jet', extent=ext, vmin=-1, vmax=1);
plt.colorbar(ticks=[0, 1]); plt.title('Baseline'); plt.yticks([-1, 0, 1]); plt.xticks([0.5], ['0.5s']);
# Out:
# [v2=1.0e-04] :  MSE = 6.22e-08  RL2 = 3.51e-04

# %%
# PINN (initial)
store_nnws = store_nnws_5[10]
runtime, params = store_nnws[0]
pred = model.apply(params, inputs)
u, _, _, _, _, _,_ = jnp.split(pred, 7, axis=1)

# prediction errors
mse = jnp.mean(jnp.square(labels - u))
rl2 = jnp.linalg.norm(labels - u) / jnp.linalg.norm(labels)
print ('[v2=%.1e] :  MSE = %.2e  RL2 = %.2e'%(v2, mse, rl2))

# plot
fig = plt.figure(figsize=(2, 1.5))
# low fi
con_lv = 201
ext = [t_l, t_u, x_l, x_u]
# PINN
plt.contourf(u.reshape(-1, 512).T, con_lv, origin='lower', cmap='jet', extent=ext, vmin=-1, vmax=1);
plt.colorbar(ticks=[0, 1]); plt.title('Initial'); plt.yticks([-1, 0, 1]); plt.xticks([0.5], ['0.5s']);
# Out:
# [v2=1.0e-04] :  MSE = 7.21e-01  RL2 = 1.20e+00
